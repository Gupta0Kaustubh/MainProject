# %%
pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-24.4.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\kaustubhgupta\anaconda3\lib\site-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kaustubhgupta\anaconda3\lib\site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Downloading Faker-24.4.0-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 59.6 kB/s eta 0:00:29
#     --------------------------------------- 0.0/1.8 MB 59.6 kB/s eta 0:00:29
#    - -------------------------------------- 0.1/1.8 MB 80.0 kB/s eta 0:00:22
#    - -------------------------------------- 0.1/1.8 MB 80.0 kB/s eta 0:00:22
#    - -------------------------------------- 0.1/1.8 MB 83.7 kB/s eta 0:00:21
#    - -------------------------------------- 0.1/1.8 MB 89.9 kB/s eta 0:00:19
#    -- ------------------------------------- 0.1/1.8 MB 102.8 kB/s eta 0:00:17
#    -- ------------------------------------- 0.1/1.8 MB 119.2 kB/s eta 0:00:14
#    -- ------------------------------------- 0.1/1.8 MB 119.2 kB/s eta 0:00:14
#    --- ------------------------------------ 0.1/1.8 MB 135.3 kB/s eta 0:00:12
#    --- ------------------------------------ 0.1/1.8 MB 135.3 kB/s eta 0:00:12
#    --- ------------------------------------ 0.2/1.8 MB 152.0 kB/s eta 0:00:11
#    ---- ----------------------------------- 0.2/1.8 MB 166.2 kB/s eta 0:00:10
#    ---- ----------------------------------- 0.2/1.8 MB 168.3 kB/s eta 0:00:10
#    ----- ---------------------------------- 0.2/1.8 MB 178.8 kB/s eta 0:00:09
#    ----- ---------------------------------- 0.2/1.8 MB 182.6 kB/s eta 0:00:09
#    ------ --------------------------------- 0.3/1.8 MB 205.3 kB/s eta 0:00:08
#    ------ --------------------------------- 0.3/1.8 MB 208.2 kB/s eta 0:00:08
#    ------- -------------------------------- 0.3/1.8 MB 221.0 kB/s eta 0:00:07
#    ------- -------------------------------- 0.3/1.8 MB 230.4 kB/s eta 0:00:07
#    -------- ------------------------------- 0.4/1.8 MB 241.5 kB/s eta 0:00:06
#    --------- ------------------------------ 0.4/1.8 MB 254.2 kB/s eta 0:00:06
#    --------- ------------------------------ 0.4/1.8 MB 272.5 kB/s eta 0:00:05
#    ---------- ----------------------------- 0.5/1.8 MB 283.6 kB/s eta 0:00:05
#    ----------- ---------------------------- 0.5/1.8 MB 296.8 kB/s eta 0:00:05
#    ------------ --------------------------- 0.5/1.8 MB 306.7 kB/s eta 0:00:05
#    ------------ --------------------------- 0.6/1.8 MB 316.0 kB/s eta 0:00:04
#    ------------- -------------------------- 0.6/1.8 MB 333.4 kB/s eta 0:00:04
#    -------------- ------------------------- 0.6/1.8 MB 344.3 kB/s eta 0:00:04
#    --------------- ------------------------ 0.7/1.8 MB 360.0 kB/s eta 0:00:03
#    ---------------- ----------------------- 0.7/1.8 MB 370.1 kB/s eta 0:00:03
#    ----------------- ---------------------- 0.8/1.8 MB 387.1 kB/s eta 0:00:03
#    ------------------ --------------------- 0.8/1.8 MB 393.3 kB/s eta 0:00:03
#    ------------------- -------------------- 0.8/1.8 MB 404.1 kB/s eta 0:00:03
#    ------------------- -------------------- 0.9/1.8 MB 409.6 kB/s eta 0:00:03
#    ------------------- -------------------- 0.9/1.8 MB 409.6 kB/s eta 0:00:03
#    --------------------- ------------------ 0.9/1.8 MB 419.9 kB/s eta 0:00:02
#    --------------------- ------------------ 1.0/1.8 MB 423.3 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.0/1.8 MB 425.2 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 426.8 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 429.9 kB/s eta 0:00:02
#    ------------------------ --------------- 1.1/1.8 MB 434.1 kB/s eta 0:00:02
#    ------------------------ --------------- 1.1/1.8 MB 437.0 kB/s eta 0:00:02
#    ------------------------- -------------- 1.1/1.8 MB 427.7 kB/s eta 0:00:02
#    ------------------------- -------------- 1.1/1.8 MB 436.9 kB/s eta 0:00:02
#    -------------------------- ------------- 1.2/1.8 MB 442.2 kB/s eta 0:00:02
#    -------------------------- ------------- 1.2/1.8 MB 438.3 kB/s eta 0:00:02
#    --------------------------- ------------ 1.2/1.8 MB 440.6 kB/s eta 0:00:02
#    --------------------------- ------------ 1.2/1.8 MB 439.4 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.2/1.8 MB 439.3 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.3/1.8 MB 440.5 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.3/1.8 MB 438.1 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.3/1.8 MB 434.6 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.3/1.8 MB 434.7 kB/s eta 0:00:02
#    ------------------------------ --------- 1.3/1.8 MB 436.9 kB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 433.6 kB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 433.7 kB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 430.5 kB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 432.6 kB/s eta 0:00:01
#    -------------------------------- ------- 1.4/1.8 MB 431.7 kB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 433.8 kB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 435.0 kB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 433.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.8 MB 435.9 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.5/1.8 MB 435.0 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 437.9 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 439.8 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 442.5 kB/s eta 0:00:01
#    ------------------------------------- -- 1.7/1.8 MB 445.2 kB/s eta 0:00:01
#    -------------------------------------- - 1.7/1.8 MB 448.8 kB/s eta 0:00:01
#    ---------------------------------------  1.7/1.8 MB 451.3 kB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 453.8 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 448.5 kB/s eta 0:00:00
# Installing collected packages: Faker
# Successfully installed Faker-24.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
import random

# %%
fake=Faker()

# %%
fake.phone_number()
# Out:
# '001-263-621-1691x9085'

# %%
pip random
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "random"

# %%
from faker import Faker


fake = Faker()

fake_data_list = []
job_roles = [
    "Software Engineer",
    "Frontend Developer",
    "Backend Developer",
    "Full-stack Developer",
    "Mobile App Developer (iOS/Android)",
    "DevOps Engineer",
    "Database Administrator (DBA)",
    "Quality Assurance Engineer (QA Engineer)",
    "Software Tester",
    "Technical Architect",
    "UI/UX Designer",
    "Product Manager",
    "Scrum Master",
    "Agile Coach",
    "Business Analyst",
    "Systems Analyst",
    "Network Engineer",
    "Security Engineer",
    "Data Scientist",
    "Machine Learning Engineer",
    "Artificial Intelligence Specialist",
    "Cloud Solutions Architect",
    "Technical Writer (Documentation Specialist)",
    "IT Support Engineer",
    "IT Administrator",
    "Release Manager",
    "Configuration Manager",
    "Automation Engineer",
    "Performance Engineer",
    "Customer Support Engineer"
]

skills = [
    "Python", "JavaScript", "HTML", "CSS", "React", "Angular", "Vue.js", "Node.js", "Django", "Flask",
    "Java", "Kotlin", "Swift", "Objective-C", "C#", ".NET", "PHP", "Ruby", "SQL", "NoSQL",
    "MongoDB", "MySQL", "PostgreSQL", "Git", "Docker", "Kubernetes", "AWS", "Azure", "Google Cloud Platform",
    "RESTful API", "GraphQL", "CI/CD", "Agile Methodologies", "Scrum", "Test-Driven Development",
    "Behavior-Driven Development", "DevOps", "Continuous Integration", "Continuous Deployment", "Microservices",
    "Containerization", "Machine Learning", "Artificial Intelligence", "Data Science", "Data Analysis",
    "Data Visualization", "Statistical Analysis", "Cybersecurity", "Network Security", "Penetration Testing",
    "Cryptography", "Information Security", "UI/UX Design", "Wireframing", "Prototyping", "User Research",
    "Interaction Design", "Responsive Design", "Accessibility", "Product Management", "Agile Product Management",
    "Requirements Analysis", "User Stories", "Business Analysis", "Technical Writing", "Documentation",
    "Support", "Troubleshooting", "Problem Solving", "Communication", "Collaboration", "Leadership"
]



for i in range(1, 200):
    certificates = random.sample(skills, 4)
    user_data = {
        "userId": "Emp_" + str(i),
        "firstName": fake.first_name(),
        "middleName": fake.first_name(),
        "lastName": fake.last_name(),
        "email": fake.email(),
        "phoneNumber": fake.phone_number(),
        "gender": fake.random_element(elements=("Male", "Female")),
        "doj": fake.date_this_decade(),
        "specializations": certificates,
        "dob": fake.date_of_birth(),
        "city": fake.city(),
        "state": fake.state(),
        "experience": fake.random_int(min=1, max=20),
        "userType": fake.random_element(elements=("Admin", "User")),
        "subscribeNewsletter": fake.boolean(),
        "passwords": fake.password(length=8),  # Ensures password is at least 8 characters long
    }
    fake_data_list.append(user_data)

# Print the generated fake data
for user_data in fake_data_list:
    print(user_data)
# Out:
# {'userId': 'Emp_1', 'firstName': 'Matthew', 'middleName': 'Paul', 'lastName': 'Glover', 'email': 'bartonjennifer@example.org', 'phoneNumber': '881.761.4460x35974', 'gender': 'Male', 'doj': datetime.date(2023, 4, 12), 'specializations': ['Swift', 'CSS', 'Microservices', 'Agile Methodologies'], 'dob': datetime.date(1963, 8, 22), 'city': 'Lake Michaelmouth', 'state': 'Alabama', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '%3nTkCkc'}
# {'userId': 'Emp_2', 'firstName': 'Deanna', 'middleName': 'Kristina', 'lastName': 'Compton', 'email': 'eric98@example.com', 'phoneNumber': '(474)817-0347x0015', 'gender': 'Male', 'doj': datetime.date(2020, 4, 25), 'specializations': ['Flask', 'CSS', 'Product Management', 'MySQL'], 'dob': datetime.date(1918, 12, 19), 'city': 'West Kathleenmouth', 'state': 'California', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '+3_hWojY'}
# {'userId': 'Emp_3', 'firstName': 'Meghan', 'middleName': 'John', 'lastName': 'Brown', 'email': 'desireesullivan@example.net', 'phoneNumber': '2717406194', 'gender': 'Female', 'doj': datetime.date(2024, 1, 28), 'specializations': ['Business Analysis', 'Communication', 'Agile Methodologies', 'Behavior-Driven Development'], 'dob': datetime.date(2016, 2, 22), 'city': 'Clarktown', 'state': 'Ohio', 'experience': 11, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '(^sQ0Imf'}
# {'userId': 'Emp_4', 'firstName': 'Douglas', 'middleName': 'Daniel', 'lastName': 'Decker', 'email': 'bradymarcus@example.com', 'phoneNumber': '001-726-224-7462x1079', 'gender': 'Male', 'doj': datetime.date(2023, 8, 9), 'specializations': ['MongoDB', '.NET', 'PHP', 'User Research'], 'dob': datetime.date(2003, 12, 5), 'city': 'Lake Tinamouth', 'state': 'New York', 'experience': 4, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '%N1hBQYf'}
# {'userId': 'Emp_5', 'firstName': 'Lindsay', 'middleName': 'Dustin', 'lastName': 'Simpson', 'email': 'dlucas@example.com', 'phoneNumber': '(305)763-1995', 'gender': 'Female', 'doj': datetime.date(2023, 7, 20), 'specializations': ['Network Security', 'Microservices', 'Accessibility', 'Collaboration'], 'dob': datetime.date(1916, 1, 11), 'city': 'Martinezmouth', 'state': 'Nevada', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '#7VXCc+v'}
# {'userId': 'Emp_6', 'firstName': 'Diane', 'middleName': 'Scott', 'lastName': 'Taylor', 'email': 'fkhan@example.com', 'phoneNumber': '652-640-1133x3333', 'gender': 'Female', 'doj': datetime.date(2021, 1, 24), 'specializations': ['Statistical Analysis', 'Network Security', 'User Stories', 'Google Cloud Platform'], 'dob': datetime.date(2016, 8, 25), 'city': 'North Erikachester', 'state': 'New Hampshire', 'experience': 15, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '*TO4jNua'}
# {'userId': 'Emp_7', 'firstName': 'Mary', 'middleName': 'Robert', 'lastName': 'Miller', 'email': 'christopher71@example.com', 'phoneNumber': '338-908-8729', 'gender': 'Male', 'doj': datetime.date(2024, 2, 16), 'specializations': ['Git', 'Java', 'Communication', 'Microservices'], 'dob': datetime.date(2009, 4, 27), 'city': 'Port Davidside', 'state': 'Massachusetts', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '*3ZyjSpg'}
# {'userId': 'Emp_8', 'firstName': 'Samantha', 'middleName': 'Candice', 'lastName': 'Griffin', 'email': 'salazarconnie@example.net', 'phoneNumber': '+1-895-727-1160', 'gender': 'Male', 'doj': datetime.date(2020, 6, 28), 'specializations': ['Support', 'GraphQL', 'User Research', 'Behavior-Driven Development'], 'dob': datetime.date(1917, 12, 1), 'city': 'Emilyland', 'state': 'New Hampshire', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '6_(08^Qy'}
# {'userId': 'Emp_9', 'firstName': 'Tiffany', 'middleName': 'Mary', 'lastName': 'Patterson', 'email': 'chandlersuzanne@example.net', 'phoneNumber': '639.462.8882', 'gender': 'Female', 'doj': datetime.date(2022, 3, 10), 'specializations': ['JavaScript', 'Scrum', 'UI/UX Design', 'Ruby'], 'dob': datetime.date(1914, 1, 14), 'city': 'New John', 'state': 'New Mexico', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '!8pT+b8R'}
# {'userId': 'Emp_10', 'firstName': 'Steven', 'middleName': 'Timothy', 'lastName': 'Cohen', 'email': 'curtisdennis@example.org', 'phoneNumber': '258-831-3706x78110', 'gender': 'Male', 'doj': datetime.date(2022, 5, 21), 'specializations': ['Penetration Testing', 'PHP', 'Product Management', 'Azure'], 'dob': datetime.date(1924, 7, 1), 'city': 'South Barbaramouth', 'state': 'Iowa', 'experience': 8, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'qi!9H!Rw'}
# {'userId': 'Emp_11', 'firstName': 'David', 'middleName': 'Alexander', 'lastName': 'Sanders', 'email': 'suttonmary@example.com', 'phoneNumber': '(781)381-9083', 'gender': 'Female', 'doj': datetime.date(2022, 11, 24), 'specializations': ['Kotlin', 'C#', 'Python', 'Kubernetes'], 'dob': datetime.date(1931, 6, 28), 'city': 'Barnesland', 'state': 'North Dakota', 'experience': 13, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'gY^P4GcD'}
# {'userId': 'Emp_12', 'firstName': 'David', 'middleName': 'Andrew', 'lastName': 'Hawkins', 'email': 'joseph19@example.net', 'phoneNumber': '+1-604-591-8931x0565', 'gender': 'Female', 'doj': datetime.date(2023, 8, 22), 'specializations': ['Objective-C', 'Azure', 'Docker', 'Containerization'], 'dob': datetime.date(1988, 4, 5), 'city': 'Gilesborough', 'state': 'Pennsylvania', 'experience': 16, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'E)85IjDw'}
# {'userId': 'Emp_13', 'firstName': 'Christopher', 'middleName': 'Diane', 'lastName': 'Brown', 'email': 'millerbrandon@example.org', 'phoneNumber': '(667)367-5676x7260', 'gender': 'Male', 'doj': datetime.date(2023, 10, 26), 'specializations': ['Angular', 'Agile Methodologies', 'Kotlin', 'Machine Learning'], 'dob': datetime.date(2021, 8, 11), 'city': 'New Alanland', 'state': 'New Jersey', 'experience': 12, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '%n3$Pb3^'}
# {'userId': 'Emp_14', 'firstName': 'Rhonda', 'middleName': 'Michele', 'lastName': 'Carpenter', 'email': 'evansjulie@example.net', 'phoneNumber': '915.877.5452x104', 'gender': 'Male', 'doj': datetime.date(2020, 7, 22), 'specializations': ['React', 'MySQL', 'Git', 'Scrum'], 'dob': datetime.date(1984, 12, 31), 'city': 'West Monica', 'state': 'Maine', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '*93dZig+'}
# {'userId': 'Emp_15', 'firstName': 'David', 'middleName': 'Margaret', 'lastName': 'Petersen', 'email': 'logancheryl@example.com', 'phoneNumber': '556-215-3418', 'gender': 'Male', 'doj': datetime.date(2024, 1, 15), 'specializations': ['React', 'Java', 'Google Cloud Platform', 'Docker'], 'dob': datetime.date(1952, 4, 30), 'city': 'Stephanietown', 'state': 'South Carolina', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'n(329ZTd'}
# {'userId': 'Emp_16', 'firstName': 'Lindsay', 'middleName': 'Erik', 'lastName': 'Meyer', 'email': 'rebekah88@example.com', 'phoneNumber': '870.631.1530x5322', 'gender': 'Female', 'doj': datetime.date(2021, 8, 8), 'specializations': ['Microservices', 'Behavior-Driven Development', 'Continuous Deployment', 'CSS'], 'dob': datetime.date(1980, 3, 7), 'city': 'South Linda', 'state': 'West Virginia', 'experience': 1, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '_O83VHu+'}
# {'userId': 'Emp_17', 'firstName': 'Megan', 'middleName': 'Jonathan', 'lastName': 'Fowler', 'email': 'aaron34@example.com', 'phoneNumber': '927.365.0582x474', 'gender': 'Male', 'doj': datetime.date(2020, 10, 14), 'specializations': ['Python', 'JavaScript', 'Containerization', 'Azure'], 'dob': datetime.date(1955, 11, 22), 'city': 'Port Michelle', 'state': 'Arkansas', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'l+xaT0Oh'}
# {'userId': 'Emp_18', 'firstName': 'Angela', 'middleName': 'Teresa', 'lastName': 'Jones', 'email': 'paul15@example.org', 'phoneNumber': '391.541.6105x928', 'gender': 'Male', 'doj': datetime.date(2022, 4, 11), 'specializations': ['Wireframing', 'Containerization', 'Data Visualization', 'Kotlin'], 'dob': datetime.date(1915, 2, 22), 'city': 'New Anthony', 'state': 'Oregon', 'experience': 20, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': ')Q+_1R+h'}
# {'userId': 'Emp_19', 'firstName': 'Joshua', 'middleName': 'David', 'lastName': 'Velazquez', 'email': 'elizabeth31@example.net', 'phoneNumber': '305-951-2183x73046', 'gender': 'Female', 'doj': datetime.date(2021, 12, 22), 'specializations': ['Node.js', 'NoSQL', 'C#', 'Network Security'], 'dob': datetime.date(1958, 12, 2), 'city': 'East David', 'state': 'Kansas', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'p+y3Wnl1'}
# {'userId': 'Emp_20', 'firstName': 'Francisco', 'middleName': 'Eileen', 'lastName': 'Camacho', 'email': 'shermandavid@example.com', 'phoneNumber': '867-577-2746x419', 'gender': 'Female', 'doj': datetime.date(2022, 7, 21), 'specializations': ['Accessibility', 'Google Cloud Platform', 'Penetration Testing', 'Swift'], 'dob': datetime.date(1964, 9, 26), 'city': 'East Joshua', 'state': 'Alaska', 'experience': 18, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '@28XAG0g'}
# {'userId': 'Emp_21', 'firstName': 'Tyler', 'middleName': 'Matthew', 'lastName': 'Mejia', 'email': 'bailey62@example.org', 'phoneNumber': '719.420.4815x16460', 'gender': 'Female', 'doj': datetime.date(2021, 7, 21), 'specializations': ['GraphQL', 'NoSQL', 'Data Science', 'CI/CD'], 'dob': datetime.date(1980, 1, 28), 'city': 'Santiagobury', 'state': 'New Jersey', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '#11N8Voo'}
# {'userId': 'Emp_22', 'firstName': 'Kenneth', 'middleName': 'Kurt', 'lastName': 'Reynolds', 'email': 'davisamy@example.net', 'phoneNumber': '968.943.2391', 'gender': 'Male', 'doj': datetime.date(2022, 3, 4), 'specializations': ['HTML', 'Microservices', 'Python', 'Wireframing'], 'dob': datetime.date(1981, 7, 7), 'city': 'Loganside', 'state': 'Maine', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#js6A0Tm'}
# {'userId': 'Emp_23', 'firstName': 'Tammy', 'middleName': 'John', 'lastName': 'Morris', 'email': 'ayerspeggy@example.org', 'phoneNumber': '+1-393-596-4195x40534', 'gender': 'Female', 'doj': datetime.date(2024, 1, 10), 'specializations': ['GraphQL', 'Business Analysis', 'Cryptography', 'MongoDB'], 'dob': datetime.date(1985, 10, 12), 'city': 'West Michelleburgh', 'state': 'Idaho', 'experience': 6, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '&D5kZ3Hf'}
# {'userId': 'Emp_24', 'firstName': 'Taylor', 'middleName': 'Matthew', 'lastName': 'Barrett', 'email': 'lharris@example.net', 'phoneNumber': '6374675692', 'gender': 'Female', 'doj': datetime.date(2023, 8, 22), 'specializations': ['Leadership', 'Statistical Analysis', 'Agile Methodologies', 'User Stories'], 'dob': datetime.date(1950, 11, 27), 'city': 'Lake Rebeccabury', 'state': 'Oregon', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '7X)1VJJb'}
# {'userId': 'Emp_25', 'firstName': 'Brandon', 'middleName': 'Jeremy', 'lastName': 'Maxwell', 'email': 'gordoneric@example.net', 'phoneNumber': '(628)943-3088', 'gender': 'Female', 'doj': datetime.date(2021, 2, 25), 'specializations': ['Wireframing', 'Microservices', 'AWS', 'Behavior-Driven Development'], 'dob': datetime.date(1930, 2, 17), 'city': 'Port Heatherhaven', 'state': 'Nebraska', 'experience': 11, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'N3!25Yzm'}
# {'userId': 'Emp_26', 'firstName': 'Linda', 'middleName': 'Marcus', 'lastName': 'Cruz', 'email': 'omcneil@example.net', 'phoneNumber': '870.435.0904x103', 'gender': 'Male', 'doj': datetime.date(2023, 8, 13), 'specializations': ['Continuous Integration', 'Prototyping', '.NET', 'Vue.js'], 'dob': datetime.date(1920, 7, 21), 'city': 'North Jeremyton', 'state': 'Wisconsin', 'experience': 13, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '!_5iXjkh'}
# {'userId': 'Emp_27', 'firstName': 'Tim', 'middleName': 'Carrie', 'lastName': 'Stark', 'email': 'davidwoods@example.com', 'phoneNumber': '708-412-7537', 'gender': 'Male', 'doj': datetime.date(2023, 10, 18), 'specializations': ['Git', 'Kubernetes', 'Node.js', 'Agile Methodologies'], 'dob': datetime.date(1908, 5, 14), 'city': 'Port Petermouth', 'state': 'South Carolina', 'experience': 8, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '&0CHmlzU'}
# {'userId': 'Emp_28', 'firstName': 'Maria', 'middleName': 'Abigail', 'lastName': 'Colon', 'email': 'nancy21@example.net', 'phoneNumber': '001-549-513-1298x90724', 'gender': 'Female', 'doj': datetime.date(2021, 7, 9), 'specializations': ['Accessibility', 'JavaScript', 'Microservices', 'Data Science'], 'dob': datetime.date(1995, 8, 18), 'city': 'Kellyfurt', 'state': 'New Jersey', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'x*p9b9Gz'}
# {'userId': 'Emp_29', 'firstName': 'Sara', 'middleName': 'Jennifer', 'lastName': 'Medina', 'email': 'pcollier@example.com', 'phoneNumber': '390-334-1731', 'gender': 'Male', 'doj': datetime.date(2020, 9, 7), 'specializations': ['JavaScript', 'Microservices', 'Behavior-Driven Development', 'Technical Writing'], 'dob': datetime.date(1963, 4, 11), 'city': 'Salazarmouth', 'state': 'Washington', 'experience': 4, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '2(i5Wydf'}
# {'userId': 'Emp_30', 'firstName': 'Craig', 'middleName': 'Brittany', 'lastName': 'Ramirez', 'email': 'william02@example.com', 'phoneNumber': '437.358.5203', 'gender': 'Male', 'doj': datetime.date(2020, 5, 13), 'specializations': ['RESTful API', 'GraphQL', 'NoSQL', 'Angular'], 'dob': datetime.date(1984, 1, 24), 'city': 'North Ambertown', 'state': 'Indiana', 'experience': 2, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '$yl41SCk'}
# {'userId': 'Emp_31', 'firstName': 'Susan', 'middleName': 'Robert', 'lastName': 'Williams', 'email': 'beverlyhunt@example.org', 'phoneNumber': '+1-746-979-2623', 'gender': 'Female', 'doj': datetime.date(2020, 11, 5), 'specializations': ['Penetration Testing', 'Collaboration', 'Requirements Analysis', 'Azure'], 'dob': datetime.date(1935, 3, 16), 'city': 'Austinberg', 'state': 'New Jersey', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'xyfL)3Lx'}
# {'userId': 'Emp_32', 'firstName': 'Bruce', 'middleName': 'Crystal', 'lastName': 'Burton', 'email': 'martinchristian@example.net', 'phoneNumber': '988.610.7149x238', 'gender': 'Female', 'doj': datetime.date(2022, 12, 6), 'specializations': ['Microservices', 'SQL', 'Objective-C', 'Continuous Deployment'], 'dob': datetime.date(1913, 1, 21), 'city': 'Rodriguezborough', 'state': 'Georgia', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'K$_6NIwh'}
# {'userId': 'Emp_33', 'firstName': 'Benjamin', 'middleName': 'Aaron', 'lastName': 'Martinez', 'email': 'michaelelliott@example.com', 'phoneNumber': '274-325-6926x849', 'gender': 'Female', 'doj': datetime.date(2022, 6, 9), 'specializations': ['Containerization', 'Penetration Testing', 'Ruby', 'PostgreSQL'], 'dob': datetime.date(1952, 6, 1), 'city': 'Lake Michellebury', 'state': 'California', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '!u8Mw^aC'}
# {'userId': 'Emp_34', 'firstName': 'Heidi', 'middleName': 'Joshua', 'lastName': 'Gonzalez', 'email': 'qrhodes@example.org', 'phoneNumber': '001-925-749-5248x43544', 'gender': 'Female', 'doj': datetime.date(2020, 1, 21), 'specializations': ['AWS', 'Google Cloud Platform', 'PHP', 'Network Security'], 'dob': datetime.date(1998, 7, 17), 'city': 'Oconnorfort', 'state': 'Hawaii', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '*q2RKHnp'}
# {'userId': 'Emp_35', 'firstName': 'Joshua', 'middleName': 'Justin', 'lastName': 'Garcia', 'email': 'wilkinssylvia@example.org', 'phoneNumber': '+1-607-480-8388x242', 'gender': 'Female', 'doj': datetime.date(2021, 7, 7), 'specializations': ['Continuous Integration', 'User Stories', 'DevOps', 'Data Visualization'], 'dob': datetime.date(1927, 11, 26), 'city': 'South Laurie', 'state': 'Hawaii', 'experience': 11, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '#Q(6g@Rz'}
# {'userId': 'Emp_36', 'firstName': 'Christian', 'middleName': 'Jacqueline', 'lastName': 'Newton', 'email': 'samantha68@example.com', 'phoneNumber': '6588774381', 'gender': 'Male', 'doj': datetime.date(2020, 5, 26), 'specializations': ['Machine Learning', 'CSS', 'SQL', 'Angular'], 'dob': datetime.date(1923, 3, 22), 'city': 'New Joetown', 'state': 'Arizona', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'k@1mRQ(a'}
# {'userId': 'Emp_37', 'firstName': 'Gary', 'middleName': 'Anna', 'lastName': 'Morales', 'email': 'rogerrosario@example.com', 'phoneNumber': '346-920-0341x0576', 'gender': 'Male', 'doj': datetime.date(2022, 7, 30), 'specializations': ['UI/UX Design', 'Agile Methodologies', 'PHP', 'Statistical Analysis'], 'dob': datetime.date(1911, 8, 1), 'city': 'Scottville', 'state': 'Missouri', 'experience': 14, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '$6Uh3q1N'}
# {'userId': 'Emp_38', 'firstName': 'Mark', 'middleName': 'Jack', 'lastName': 'Schneider', 'email': 'scottchase@example.com', 'phoneNumber': '7716195300', 'gender': 'Female', 'doj': datetime.date(2022, 2, 18), 'specializations': ['Containerization', 'C#', 'Test-Driven Development', 'MongoDB'], 'dob': datetime.date(1947, 8, 22), 'city': 'South Steven', 'state': 'Delaware', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '+28)G9Qk'}
# {'userId': 'Emp_39', 'firstName': 'Edward', 'middleName': 'Melissa', 'lastName': 'Mitchell', 'email': 'tylerjones@example.org', 'phoneNumber': '+1-411-438-0189x99350', 'gender': 'Male', 'doj': datetime.date(2023, 4, 6), 'specializations': ['Angular', 'Collaboration', 'C#', 'Statistical Analysis'], 'dob': datetime.date(2019, 6, 5), 'city': 'Matthewburgh', 'state': 'Oregon', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^8Xx33Vx'}
# {'userId': 'Emp_40', 'firstName': 'April', 'middleName': 'Gregory', 'lastName': 'Watson', 'email': 'hclark@example.com', 'phoneNumber': '(297)944-3402', 'gender': 'Male', 'doj': datetime.date(2023, 1, 12), 'specializations': ['C#', 'Java', 'Responsive Design', 'Swift'], 'dob': datetime.date(1938, 3, 5), 'city': 'Wendyfort', 'state': 'Rhode Island', 'experience': 16, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'Ts!z7L&y'}
# {'userId': 'Emp_41', 'firstName': 'Maria', 'middleName': 'Kristine', 'lastName': 'Campbell', 'email': 'fletchermarissa@example.org', 'phoneNumber': '4512364915', 'gender': 'Male', 'doj': datetime.date(2022, 5, 21), 'specializations': ['Git', 'Swift', 'Docker', 'MySQL'], 'dob': datetime.date(1917, 3, 28), 'city': 'North Lindaland', 'state': 'Ohio', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%8f4%I^c'}
# {'userId': 'Emp_42', 'firstName': 'Aaron', 'middleName': 'Madison', 'lastName': 'Stephens', 'email': 'johnsonmatthew@example.net', 'phoneNumber': '248.534.6957x190', 'gender': 'Male', 'doj': datetime.date(2021, 3, 4), 'specializations': ['Accessibility', 'CI/CD', 'Statistical Analysis', 'Network Security'], 'dob': datetime.date(1963, 11, 13), 'city': 'Lake Danielton', 'state': 'Oklahoma', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '(2cNeC#R'}
# {'userId': 'Emp_43', 'firstName': 'Connie', 'middleName': 'Daniel', 'lastName': 'Washington', 'email': 'johnmurray@example.org', 'phoneNumber': '447-884-1989x6531', 'gender': 'Female', 'doj': datetime.date(2021, 3, 24), 'specializations': ['Artificial Intelligence', 'Vue.js', 'Containerization', 'Agile Product Management'], 'dob': datetime.date(1915, 6, 22), 'city': 'South Anthony', 'state': 'Colorado', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '@&P99BJi'}
# {'userId': 'Emp_44', 'firstName': 'Shelly', 'middleName': 'Phillip', 'lastName': 'Ellis', 'email': 'margaretmoore@example.com', 'phoneNumber': '306-802-0061x378', 'gender': 'Female', 'doj': datetime.date(2021, 10, 13), 'specializations': ['DevOps', 'SQL', 'Continuous Integration', 'Product Management'], 'dob': datetime.date(1994, 9, 20), 'city': 'West Moniquehaven', 'state': 'Wyoming', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '%28qC3Vd'}
# {'userId': 'Emp_45', 'firstName': 'Andrea', 'middleName': 'David', 'lastName': 'Mitchell', 'email': 'christopher43@example.org', 'phoneNumber': '+1-559-997-0823x6663', 'gender': 'Female', 'doj': datetime.date(2020, 9, 25), 'specializations': ['Communication', 'Behavior-Driven Development', 'Docker', 'Objective-C'], 'dob': datetime.date(1994, 5, 27), 'city': 'North Susan', 'state': 'Utah', 'experience': 16, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '^a$8)dHy'}
# {'userId': 'Emp_46', 'firstName': 'Rhonda', 'middleName': 'Shelby', 'lastName': 'Robinson', 'email': 'josephdelgado@example.org', 'phoneNumber': '001-328-842-7278x9024', 'gender': 'Female', 'doj': datetime.date(2021, 5, 28), 'specializations': ['Support', 'Network Security', 'Azure', 'Node.js'], 'dob': datetime.date(1940, 11, 24), 'city': 'Powersview', 'state': 'Utah', 'experience': 13, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '#5M!Xl()'}
# {'userId': 'Emp_47', 'firstName': 'Kevin', 'middleName': 'Cheryl', 'lastName': 'Bender', 'email': 'cameron71@example.com', 'phoneNumber': '857.861.2236', 'gender': 'Female', 'doj': datetime.date(2021, 7, 24), 'specializations': ['Technical Writing', 'Product Management', 'Prototyping', 'Test-Driven Development'], 'dob': datetime.date(1924, 8, 28), 'city': 'West Brittanyton', 'state': 'Wyoming', 'experience': 13, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'He@H1Txy'}
# {'userId': 'Emp_48', 'firstName': 'Brian', 'middleName': 'Kevin', 'lastName': 'Wise', 'email': 'npotter@example.com', 'phoneNumber': '(310)883-4517', 'gender': 'Female', 'doj': datetime.date(2022, 6, 10), 'specializations': ['AWS', 'Requirements Analysis', 'UI/UX Design', 'Vue.js'], 'dob': datetime.date(1985, 4, 27), 'city': 'Walkerborough', 'state': 'North Carolina', 'experience': 14, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'U)3Plvbj'}
# {'userId': 'Emp_49', 'firstName': 'Tyler', 'middleName': 'Susan', 'lastName': 'Hawkins', 'email': 'emilyfrazier@example.org', 'phoneNumber': '+1-650-836-0763', 'gender': 'Male', 'doj': datetime.date(2022, 10, 15), 'specializations': ['Google Cloud Platform', 'Responsive Design', 'Wireframing', 'Penetration Testing'], 'dob': datetime.date(2002, 6, 6), 'city': 'East Carrie', 'state': 'Indiana', 'experience': 19, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'I$B3RmnH'}
# {'userId': 'Emp_50', 'firstName': 'Anthony', 'middleName': 'Robert', 'lastName': 'Francis', 'email': 'dillonkristy@example.com', 'phoneNumber': '+1-301-988-5190x0888', 'gender': 'Male', 'doj': datetime.date(2021, 8, 8), 'specializations': ['Wireframing', 'Support', 'RESTful API', 'Objective-C'], 'dob': datetime.date(1974, 1, 18), 'city': 'New Danielview', 'state': 'Missouri', 'experience': 12, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 's+(0^K0n'}
# {'userId': 'Emp_51', 'firstName': 'Amy', 'middleName': 'Samuel', 'lastName': 'Williams', 'email': 'aaguilar@example.org', 'phoneNumber': '873.265.8379x5331', 'gender': 'Female', 'doj': datetime.date(2023, 2, 18), 'specializations': ['Containerization', 'AWS', 'Penetration Testing', 'Statistical Analysis'], 'dob': datetime.date(1958, 7, 28), 'city': 'Wheelerfort', 'state': 'Oklahoma', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'Rp$G1DgM'}
# {'userId': 'Emp_52', 'firstName': 'Theresa', 'middleName': 'Edwin', 'lastName': 'Burns', 'email': 'weisssamantha@example.org', 'phoneNumber': '720.302.2052', 'gender': 'Male', 'doj': datetime.date(2022, 7, 13), 'specializations': ['Azure', 'Vue.js', 'Troubleshooting', 'Data Science'], 'dob': datetime.date(1974, 2, 9), 'city': 'North Maria', 'state': 'Washington', 'experience': 20, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '(8#a08Ln'}
# {'userId': 'Emp_53', 'firstName': 'Steve', 'middleName': 'Andrew', 'lastName': 'Baker', 'email': 'elizabethgonzalez@example.net', 'phoneNumber': '(523)911-0589x9389', 'gender': 'Female', 'doj': datetime.date(2023, 3, 25), 'specializations': ['Kubernetes', 'Wireframing', 'Collaboration', 'Scrum'], 'dob': datetime.date(1973, 8, 15), 'city': 'Port Patrick', 'state': 'Wisconsin', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'c^P2BOLk'}
# {'userId': 'Emp_54', 'firstName': 'Yolanda', 'middleName': 'David', 'lastName': 'Ford', 'email': 'bethany90@example.com', 'phoneNumber': '491-213-8016', 'gender': 'Male', 'doj': datetime.date(2022, 11, 29), 'specializations': ['Angular', 'Swift', 'Wireframing', 'Kubernetes'], 'dob': datetime.date(1920, 8, 26), 'city': 'Davidborough', 'state': 'New Hampshire', 'experience': 12, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '^$6eUbQr'}
# {'userId': 'Emp_55', 'firstName': 'David', 'middleName': 'Patrick', 'lastName': 'Armstrong', 'email': 'brianbrown@example.net', 'phoneNumber': '741.241.4113x533', 'gender': 'Female', 'doj': datetime.date(2021, 4, 14), 'specializations': ['UI/UX Design', 'Microservices', 'React', 'CI/CD'], 'dob': datetime.date(2018, 9, 8), 'city': 'Anitaburgh', 'state': 'Maryland', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^qZy3Ekd'}
# {'userId': 'Emp_56', 'firstName': 'Kimberly', 'middleName': 'Vincent', 'lastName': 'Vega', 'email': 'brian50@example.com', 'phoneNumber': '933.780.6339', 'gender': 'Female', 'doj': datetime.date(2022, 3, 12), 'specializations': ['Vue.js', 'Interaction Design', 'Azure', 'Communication'], 'dob': datetime.date(2014, 11, 7), 'city': 'Alecview', 'state': 'Ohio', 'experience': 12, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '+#4BXZBf'}
# {'userId': 'Emp_57', 'firstName': 'Ray', 'middleName': 'Steven', 'lastName': 'Mitchell', 'email': 'marygarcia@example.com', 'phoneNumber': '001-902-741-8637x5495', 'gender': 'Male', 'doj': datetime.date(2020, 5, 16), 'specializations': ['Network Security', 'Swift', 'CI/CD', 'Kotlin'], 'dob': datetime.date(1975, 4, 23), 'city': 'Phillipsstad', 'state': 'Texas', 'experience': 14, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '!*(I2CXy'}
# {'userId': 'Emp_58', 'firstName': 'Clinton', 'middleName': 'Brenda', 'lastName': 'Brown', 'email': 'floressusan@example.com', 'phoneNumber': '(774)868-9831x58636', 'gender': 'Female', 'doj': datetime.date(2020, 1, 15), 'specializations': ['HTML', 'CSS', 'Penetration Testing', 'Business Analysis'], 'dob': datetime.date(1994, 11, 29), 'city': 'Port Daniel', 'state': 'Wisconsin', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^NI$0Iyz'}
# {'userId': 'Emp_59', 'firstName': 'Bryan', 'middleName': 'Kenneth', 'lastName': 'Vasquez', 'email': 'tracylester@example.com', 'phoneNumber': '(254)318-0279', 'gender': 'Male', 'doj': datetime.date(2023, 11, 30), 'specializations': ['Requirements Analysis', 'Collaboration', 'DevOps', 'Kubernetes'], 'dob': datetime.date(1948, 5, 20), 'city': 'North Stephanieberg', 'state': 'Wyoming', 'experience': 7, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '$1Tc7uBz'}
# {'userId': 'Emp_60', 'firstName': 'Anthony', 'middleName': 'Corey', 'lastName': 'Brown', 'email': 'thomas00@example.com', 'phoneNumber': '001-975-778-4169x851', 'gender': 'Male', 'doj': datetime.date(2020, 8, 2), 'specializations': ['User Stories', 'HTML', 'PHP', 'Ruby'], 'dob': datetime.date(2024, 2, 16), 'city': 'Justinport', 'state': 'Kentucky', 'experience': 1, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'M&7DcK^c'}
# {'userId': 'Emp_61', 'firstName': 'Richard', 'middleName': 'Daniel', 'lastName': 'Huffman', 'email': 'frank63@example.org', 'phoneNumber': '(245)469-4997', 'gender': 'Female', 'doj': datetime.date(2021, 9, 5), 'specializations': ['Communication', 'Product Management', 'Python', 'CI/CD'], 'dob': datetime.date(2014, 8, 6), 'city': 'Katiebury', 'state': 'North Dakota', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '@IW7Uiqd'}
# {'userId': 'Emp_62', 'firstName': 'Leonard', 'middleName': 'Randall', 'lastName': 'Cook', 'email': 'ruizjamie@example.com', 'phoneNumber': '305-327-8151x41775', 'gender': 'Male', 'doj': datetime.date(2021, 6, 13), 'specializations': ['Problem Solving', 'Information Security', 'Docker', 'PostgreSQL'], 'dob': datetime.date(2006, 5, 8), 'city': 'Cindyfurt', 'state': 'Nebraska', 'experience': 15, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '!*0Xb+n)'}
# {'userId': 'Emp_63', 'firstName': 'Amy', 'middleName': 'Paige', 'lastName': 'Burton', 'email': 'monroepaula@example.net', 'phoneNumber': '001-896-936-4456x9693', 'gender': 'Female', 'doj': datetime.date(2023, 2, 1), 'specializations': ['HTML', 'Continuous Deployment', 'Continuous Integration', 'Leadership'], 'dob': datetime.date(1999, 5, 24), 'city': 'Kaylahaven', 'state': 'Oregon', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'fr^5TJFa'}
# {'userId': 'Emp_64', 'firstName': 'Tracy', 'middleName': 'Carmen', 'lastName': 'Garcia', 'email': 'calderonlori@example.net', 'phoneNumber': '+1-382-418-4421x215', 'gender': 'Male', 'doj': datetime.date(2020, 5, 1), 'specializations': ['.NET', 'SQL', 'MySQL', 'Requirements Analysis'], 'dob': datetime.date(1950, 10, 23), 'city': 'Carloshaven', 'state': 'Utah', 'experience': 6, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '#0FvAExW'}
# {'userId': 'Emp_65', 'firstName': 'Daniel', 'middleName': 'Elizabeth', 'lastName': 'Fernandez', 'email': 'kristen01@example.net', 'phoneNumber': '001-749-470-3051x5130', 'gender': 'Male', 'doj': datetime.date(2022, 12, 28), 'specializations': ['JavaScript', 'Product Management', 'PHP', 'Data Visualization'], 'dob': datetime.date(1994, 9, 8), 'city': 'Lake Nicholasland', 'state': 'New Jersey', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '4N^Zu6Va'}
# {'userId': 'Emp_66', 'firstName': 'Nathan', 'middleName': 'Leslie', 'lastName': 'Ford', 'email': 'fosterjeffrey@example.org', 'phoneNumber': '896.802.1152', 'gender': 'Female', 'doj': datetime.date(2023, 9, 4), 'specializations': ['Data Analysis', 'CSS', 'Responsive Design', 'Support'], 'dob': datetime.date(2020, 7, 18), 'city': 'Floresport', 'state': 'Mississippi', 'experience': 4, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'O(m6RVw7'}
# {'userId': 'Emp_67', 'firstName': 'Alyssa', 'middleName': 'John', 'lastName': 'Lang', 'email': 'jhernandez@example.net', 'phoneNumber': '773-249-9108x41265', 'gender': 'Female', 'doj': datetime.date(2022, 2, 15), 'specializations': ['Troubleshooting', 'RESTful API', 'UI/UX Design', 'Behavior-Driven Development'], 'dob': datetime.date(2000, 4, 25), 'city': 'New Michellechester', 'state': 'Iowa', 'experience': 10, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '17%_H3Lm'}
# {'userId': 'Emp_68', 'firstName': 'Ethan', 'middleName': 'Richard', 'lastName': 'Thomas', 'email': 'josephlewis@example.net', 'phoneNumber': '683.242.8436', 'gender': 'Female', 'doj': datetime.date(2023, 5, 28), 'specializations': ['Prototyping', 'AWS', 'Continuous Deployment', 'NoSQL'], 'dob': datetime.date(1912, 7, 27), 'city': 'Colleenstad', 'state': 'Kentucky', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '!3kHm7mU'}
# {'userId': 'Emp_69', 'firstName': 'Kimberly', 'middleName': 'Nicholas', 'lastName': 'Allen', 'email': 'raymond20@example.org', 'phoneNumber': '3767231477', 'gender': 'Female', 'doj': datetime.date(2022, 3, 19), 'specializations': ['Communication', 'CI/CD', 'Network Security', 'Data Analysis'], 'dob': datetime.date(1950, 10, 25), 'city': 'East Nicholas', 'state': 'Arizona', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '9&0tWOVi'}
# {'userId': 'Emp_70', 'firstName': 'Heather', 'middleName': 'Brad', 'lastName': 'Anderson', 'email': 'acampbell@example.net', 'phoneNumber': '(829)492-2737x330', 'gender': 'Male', 'doj': datetime.date(2022, 5, 23), 'specializations': ['MySQL', 'Data Analysis', 'AWS', 'C#'], 'dob': datetime.date(1982, 10, 20), 'city': 'Davidborough', 'state': 'Wisconsin', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '!L1Jh*ai'}
# {'userId': 'Emp_71', 'firstName': 'Ashley', 'middleName': 'Joseph', 'lastName': 'Harper', 'email': 'greenjason@example.net', 'phoneNumber': '+1-324-931-0285x95637', 'gender': 'Male', 'doj': datetime.date(2021, 2, 27), 'specializations': ['MongoDB', 'Node.js', 'Continuous Integration', 'Scrum'], 'dob': datetime.date(1988, 2, 25), 'city': 'Gloverstad', 'state': 'Texas', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'q!9Q7Zmr'}
# {'userId': 'Emp_72', 'firstName': 'Briana', 'middleName': 'Michael', 'lastName': 'Daniel', 'email': 'richardgomez@example.com', 'phoneNumber': '(847)827-7253x6328', 'gender': 'Female', 'doj': datetime.date(2020, 10, 5), 'specializations': ['Kubernetes', 'JavaScript', 'Data Science', 'Kotlin'], 'dob': datetime.date(1980, 7, 23), 'city': 'East Jamesville', 'state': 'West Virginia', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '&7CMW#Bm'}
# {'userId': 'Emp_73', 'firstName': 'Richard', 'middleName': 'Maria', 'lastName': 'Horn', 'email': 'sschmidt@example.com', 'phoneNumber': '892-954-5619', 'gender': 'Female', 'doj': datetime.date(2021, 3, 4), 'specializations': ['MySQL', 'Support', 'Google Cloud Platform', 'Machine Learning'], 'dob': datetime.date(1983, 3, 13), 'city': 'North Kevin', 'state': 'Louisiana', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'T_72WiGB'}
# {'userId': 'Emp_74', 'firstName': 'April', 'middleName': 'James', 'lastName': 'Wilson', 'email': 'pamelahernandez@example.com', 'phoneNumber': '2725763074', 'gender': 'Female', 'doj': datetime.date(2023, 11, 30), 'specializations': ['Artificial Intelligence', 'Python', 'Data Visualization', 'Cryptography'], 'dob': datetime.date(1964, 3, 13), 'city': 'Thompsonberg', 'state': 'West Virginia', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '+^0P%ZXb'}
# {'userId': 'Emp_75', 'firstName': 'Tonya', 'middleName': 'Vincent', 'lastName': 'Ortiz', 'email': 'samuelmercer@example.org', 'phoneNumber': '764-543-0119', 'gender': 'Female', 'doj': datetime.date(2024, 3, 27), 'specializations': ['Interaction Design', 'Requirements Analysis', 'HTML', 'Network Security'], 'dob': datetime.date(1971, 8, 8), 'city': 'Pamelabury', 'state': 'Arkansas', 'experience': 8, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '@2OZu4kf'}
# {'userId': 'Emp_76', 'firstName': 'Paul', 'middleName': 'Curtis', 'lastName': 'Hunter', 'email': 'qmoon@example.net', 'phoneNumber': '993-286-4141', 'gender': 'Female', 'doj': datetime.date(2023, 9, 22), 'specializations': ['Communication', 'GraphQL', 'AWS', 'MongoDB'], 'dob': datetime.date(1940, 7, 12), 'city': 'South Anthonytown', 'state': 'Maine', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'Ml!^7SWt'}
# {'userId': 'Emp_77', 'firstName': 'Stacy', 'middleName': 'William', 'lastName': 'Garner', 'email': 'collinsharry@example.com', 'phoneNumber': '944-259-8289x8083', 'gender': 'Female', 'doj': datetime.date(2021, 5, 2), 'specializations': ['Communication', 'Artificial Intelligence', 'Node.js', 'Data Visualization'], 'dob': datetime.date(1991, 3, 25), 'city': 'Freemanmouth', 'state': 'Arizona', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^8%Rc#f#'}
# {'userId': 'Emp_78', 'firstName': 'Mary', 'middleName': 'Barbara', 'lastName': 'Roth', 'email': 'middletongregory@example.com', 'phoneNumber': '001-388-260-6817x47158', 'gender': 'Male', 'doj': datetime.date(2023, 1, 14), 'specializations': ['Network Security', 'Cryptography', 'Prototyping', 'Google Cloud Platform'], 'dob': datetime.date(1973, 1, 10), 'city': 'Bradfordfort', 'state': 'Utah', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '*U77tSCu'}
# {'userId': 'Emp_79', 'firstName': 'Jennifer', 'middleName': 'Tiffany', 'lastName': 'Jimenez', 'email': 'tracywilliams@example.org', 'phoneNumber': '929.262.7471x45527', 'gender': 'Male', 'doj': datetime.date(2020, 1, 16), 'specializations': ['Communication', 'NoSQL', 'Scrum', 'Cybersecurity'], 'dob': datetime.date(1982, 10, 23), 'city': 'East Jennifer', 'state': 'Utah', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'V*H+2Gwe'}
# {'userId': 'Emp_80', 'firstName': 'Adam', 'middleName': 'Jorge', 'lastName': 'Miller', 'email': 'jamesgonzalez@example.org', 'phoneNumber': '+1-321-382-6608x9229', 'gender': 'Female', 'doj': datetime.date(2021, 7, 21), 'specializations': ['Vue.js', 'C#', 'Swift', 'CSS'], 'dob': datetime.date(2020, 6, 3), 'city': 'Coffeyfurt', 'state': 'Florida', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'G&G7Omvw'}
# {'userId': 'Emp_81', 'firstName': 'John', 'middleName': 'Shelly', 'lastName': 'Brown', 'email': 'thomaskevin@example.org', 'phoneNumber': '723-232-1071x8411', 'gender': 'Male', 'doj': datetime.date(2022, 5, 10), 'specializations': ['RESTful API', 'Wireframing', 'Responsive Design', 'Continuous Integration'], 'dob': datetime.date(2000, 10, 16), 'city': 'Mccarthyview', 'state': 'Kentucky', 'experience': 13, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'L*z4LaHK'}
# {'userId': 'Emp_82', 'firstName': 'Brian', 'middleName': 'Monica', 'lastName': 'Butler', 'email': 'andersonstephanie@example.com', 'phoneNumber': '645.866.2584x75542', 'gender': 'Female', 'doj': datetime.date(2022, 6, 2), 'specializations': ['User Stories', 'PostgreSQL', 'PHP', 'Java'], 'dob': datetime.date(1952, 12, 1), 'city': 'New Kimberly', 'state': 'New Hampshire', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '#1tBggR2'}
# {'userId': 'Emp_83', 'firstName': 'Christine', 'middleName': 'Mary', 'lastName': 'Ochoa', 'email': 'jennajackson@example.net', 'phoneNumber': '(884)684-1470x01991', 'gender': 'Female', 'doj': datetime.date(2022, 4, 14), 'specializations': ['Continuous Deployment', 'Data Science', 'Cryptography', 'Responsive Design'], 'dob': datetime.date(2013, 8, 7), 'city': 'Mckinneyview', 'state': 'Arkansas', 'experience': 9, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '#C*16Fai'}
# {'userId': 'Emp_84', 'firstName': 'David', 'middleName': 'Jeremy', 'lastName': 'Harrison', 'email': 'rdyer@example.com', 'phoneNumber': '930-441-6535', 'gender': 'Male', 'doj': datetime.date(2024, 3, 14), 'specializations': ['Data Analysis', 'Angular', 'Kotlin', 'Behavior-Driven Development'], 'dob': datetime.date(1923, 6, 29), 'city': 'Martinezshire', 'state': 'Texas', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')S7FaNgU'}
# {'userId': 'Emp_85', 'firstName': 'Elizabeth', 'middleName': 'John', 'lastName': 'Hernandez', 'email': 'clinton92@example.com', 'phoneNumber': '393-430-9878', 'gender': 'Male', 'doj': datetime.date(2024, 1, 23), 'specializations': ['Agile Methodologies', 'CSS', 'Swift', 'User Stories'], 'dob': datetime.date(1952, 4, 16), 'city': 'Mikeside', 'state': 'Montana', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '@9BKq1bj'}
# {'userId': 'Emp_86', 'firstName': 'Elizabeth', 'middleName': 'Tyler', 'lastName': 'George', 'email': 'david17@example.net', 'phoneNumber': '(627)466-6671', 'gender': 'Female', 'doj': datetime.date(2024, 1, 12), 'specializations': ['Agile Methodologies', 'Test-Driven Development', 'Data Science', 'Ruby'], 'dob': datetime.date(1946, 7, 31), 'city': 'Morganborough', 'state': 'Oklahoma', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'zA^h_7Aj'}
# {'userId': 'Emp_87', 'firstName': 'Linda', 'middleName': 'David', 'lastName': 'Adams', 'email': 'scott50@example.net', 'phoneNumber': '(240)855-4172', 'gender': 'Female', 'doj': datetime.date(2023, 10, 2), 'specializations': ['DevOps', 'Interaction Design', 'Flask', 'Leadership'], 'dob': datetime.date(1997, 11, 6), 'city': 'Lake Yvette', 'state': 'Alabama', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')h4yWn+m'}
# {'userId': 'Emp_88', 'firstName': 'Tamara', 'middleName': 'Jimmy', 'lastName': 'Phillips', 'email': 'nbeck@example.net', 'phoneNumber': '527-571-5802', 'gender': 'Male', 'doj': datetime.date(2020, 8, 8), 'specializations': ['JavaScript', 'Node.js', 'Flask', 'Vue.js'], 'dob': datetime.date(2022, 12, 22), 'city': 'Owensfort', 'state': 'Nebraska', 'experience': 2, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '+n0!NAco'}
# {'userId': 'Emp_89', 'firstName': 'Heather', 'middleName': 'Justin', 'lastName': 'Saunders', 'email': 'katherine98@example.com', 'phoneNumber': '(759)829-3329x4563', 'gender': 'Female', 'doj': datetime.date(2021, 12, 5), 'specializations': ['Information Security', 'Documentation', 'Data Science', 'PHP'], 'dob': datetime.date(1946, 6, 7), 'city': 'Cochranhaven', 'state': 'Oregon', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '+Z0O5rqU'}
# {'userId': 'Emp_90', 'firstName': 'Diane', 'middleName': 'Natalie', 'lastName': 'Spencer', 'email': 'victor42@example.org', 'phoneNumber': '877.540.9053x878', 'gender': 'Male', 'doj': datetime.date(2021, 12, 20), 'specializations': ['SQL', 'Containerization', 'Azure', 'Swift'], 'dob': datetime.date(1927, 9, 3), 'city': 'Spencerland', 'state': 'Delaware', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%3q74ENj'}
# {'userId': 'Emp_91', 'firstName': 'Karl', 'middleName': 'Ricky', 'lastName': 'Harmon', 'email': 'kingcurtis@example.org', 'phoneNumber': '7434711515', 'gender': 'Female', 'doj': datetime.date(2021, 5, 31), 'specializations': ['PHP', 'RESTful API', 'Problem Solving', 'Interaction Design'], 'dob': datetime.date(1968, 3, 14), 'city': 'Hollymouth', 'state': 'Mississippi', 'experience': 6, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '!0XhJINm'}
# {'userId': 'Emp_92', 'firstName': 'William', 'middleName': 'Christopher', 'lastName': 'Li', 'email': 'ashley38@example.com', 'phoneNumber': '4787192390', 'gender': 'Male', 'doj': datetime.date(2020, 7, 19), 'specializations': ['Requirements Analysis', 'Business Analysis', 'Accessibility', 'Kotlin'], 'dob': datetime.date(1918, 3, 9), 'city': 'Jeremyland', 'state': 'Pennsylvania', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'b*0VeEfe'}
# {'userId': 'Emp_93', 'firstName': 'Emily', 'middleName': 'Eric', 'lastName': 'Gentry', 'email': 'xgould@example.net', 'phoneNumber': '001-849-897-7307x3461', 'gender': 'Male', 'doj': datetime.date(2023, 4, 2), 'specializations': ['PHP', 'DevOps', 'MySQL', 'GraphQL'], 'dob': datetime.date(2000, 2, 4), 'city': 'Carmenmouth', 'state': 'Nevada', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '!8J@&gU1'}
# {'userId': 'Emp_94', 'firstName': 'Brittany', 'middleName': 'Sarah', 'lastName': 'Keith', 'email': 'zgates@example.org', 'phoneNumber': '466-947-4977x449', 'gender': 'Female', 'doj': datetime.date(2020, 10, 13), 'specializations': ['Collaboration', 'Ruby', 'Vue.js', 'Scrum'], 'dob': datetime.date(1928, 11, 23), 'city': 'Port Jeremyland', 'state': 'Hawaii', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '&2G)sTcn'}
# {'userId': 'Emp_95', 'firstName': 'Heather', 'middleName': 'Samuel', 'lastName': 'Adams', 'email': 'uchandler@example.org', 'phoneNumber': '+1-545-667-3774x38505', 'gender': 'Male', 'doj': datetime.date(2020, 12, 23), 'specializations': ['Java', 'Vue.js', 'PHP', 'Interaction Design'], 'dob': datetime.date(1965, 1, 19), 'city': 'Dawnburgh', 'state': 'Hawaii', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^r6!XmU#'}
# {'userId': 'Emp_96', 'firstName': 'Ian', 'middleName': 'Ryan', 'lastName': 'Dawson', 'email': 'janet89@example.net', 'phoneNumber': '675-711-7325x1500', 'gender': 'Male', 'doj': datetime.date(2020, 8, 8), 'specializations': ['DevOps', 'Documentation', 'CSS', 'Cybersecurity'], 'dob': datetime.date(1971, 10, 14), 'city': 'Ryanville', 'state': 'Alaska', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^z7fa6Um'}
# {'userId': 'Emp_97', 'firstName': 'Michael', 'middleName': 'Sarah', 'lastName': 'Krause', 'email': 'kelly93@example.org', 'phoneNumber': '(369)460-8504x60449', 'gender': 'Male', 'doj': datetime.date(2023, 4, 4), 'specializations': ['HTML', 'RESTful API', 'Leadership', 'UI/UX Design'], 'dob': datetime.date(2005, 12, 17), 'city': 'South Natalieville', 'state': 'Virginia', 'experience': 6, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'g%7Wbvut'}
# {'userId': 'Emp_98', 'firstName': 'Michelle', 'middleName': 'Carl', 'lastName': 'Hensley', 'email': 'udavid@example.com', 'phoneNumber': '(277)356-9225x6020', 'gender': 'Male', 'doj': datetime.date(2021, 7, 30), 'specializations': ['Microservices', 'Swift', 'Data Visualization', 'Artificial Intelligence'], 'dob': datetime.date(2023, 2, 21), 'city': 'Markfurt', 'state': 'South Dakota', 'experience': 9, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '(@9B&Ywp'}
# {'userId': 'Emp_99', 'firstName': 'Robin', 'middleName': 'Brandon', 'lastName': 'Alexander', 'email': 'uespinoza@example.org', 'phoneNumber': '+1-410-701-4568x3899', 'gender': 'Female', 'doj': datetime.date(2024, 1, 5), 'specializations': ['AWS', 'Problem Solving', 'Objective-C', 'Technical Writing'], 'dob': datetime.date(1990, 8, 7), 'city': 'Tranville', 'state': 'Texas', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'u#0Db6ug'}
# {'userId': 'Emp_100', 'firstName': 'Joel', 'middleName': 'Angelica', 'lastName': 'Jones', 'email': 'nsmith@example.org', 'phoneNumber': '7986905573', 'gender': 'Female', 'doj': datetime.date(2020, 9, 23), 'specializations': ['Agile Product Management', 'Technical Writing', 'Continuous Integration', 'Network Security'], 'dob': datetime.date(1986, 4, 9), 'city': 'Stevenhaven', 'state': 'Rhode Island', 'experience': 16, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'b#9b)Kfr'}
# {'userId': 'Emp_101', 'firstName': 'Leslie', 'middleName': 'Mark', 'lastName': 'Rodriguez', 'email': 'carlosdaniel@example.net', 'phoneNumber': '(265)972-0106', 'gender': 'Female', 'doj': datetime.date(2021, 6, 28), 'specializations': ['GraphQL', 'Vue.js', 'HTML', 'Azure'], 'dob': datetime.date(1951, 10, 13), 'city': 'South Rebeccahaven', 'state': 'Washington', 'experience': 7, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '1^0)Hx7l'}
# {'userId': 'Emp_102', 'firstName': 'Dylan', 'middleName': 'Rebecca', 'lastName': 'Clark', 'email': 'frostdanielle@example.net', 'phoneNumber': '900.893.4673', 'gender': 'Male', 'doj': datetime.date(2021, 6, 20), 'specializations': ['Flask', 'DevOps', 'Node.js', 'Artificial Intelligence'], 'dob': datetime.date(1963, 12, 18), 'city': 'New Victoria', 'state': 'Maine', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'Z*!(4Zh9'}
# ...
# {'userId': 'Emp_166', 'firstName': 'Tony', 'middleName': 'Patricia', 'lastName': 'Hodges', 'email': 'sanchezbryce@example.org', 'phoneNumber': '001-928-499-2491x2288', 'gender': 'Female', 'doj': datetime.date(2021, 8, 29), 'specializations': ['SQL', 'Artificial Intelligence', 'Agile Product Management', 'RESTful API'], 'dob': datetime.date(2019, 8, 20), 'city': 'New Phillipton', 'state': 'Massachusetts', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^s20AAo5'}
# {'userId': 'Emp_167', 'firstName': 'Kelly', 'middleName': 'Daniel', 'lastName': 'Watson', 'email': 'jennifer87@example.com', 'phoneNumber': '001-647-408-5554x5016', 'gender': 'Female', 'doj': datetime.date(2022, 2, 2), 'specializations': ['Test-Driven Development', 'Network Security', 'AWS', 'JavaScript'], 'dob': datetime.date(1970, 12, 28), 'city': 'Richardsonland', 'state': 'West Virginia', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'X)u8B)x1'}
# {'userId': 'Emp_168', 'firstName': 'Nicholas', 'middleName': 'Christian', 'lastName': 'Malone', 'email': 'donna68@example.net', 'phoneNumber': '418-325-0286x03746', 'gender': 'Male', 'doj': datetime.date(2023, 4, 22), 'specializations': ['NoSQL', 'Accessibility', 'PostgreSQL', 'Flask'], 'dob': datetime.date(1990, 4, 30), 'city': 'Michellebury', 'state': 'Wisconsin', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^7uOrsZh'}
# {'userId': 'Emp_169', 'firstName': 'Ashley', 'middleName': 'Sherri', 'lastName': 'Christensen', 'email': 'curtiscarol@example.net', 'phoneNumber': '482.575.2098x017', 'gender': 'Male', 'doj': datetime.date(2023, 6, 25), 'specializations': ['Vue.js', 'AWS', 'Microservices', 'Product Management'], 'dob': datetime.date(1930, 3, 21), 'city': 'North Laceyfort', 'state': 'Illinois', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^H6QVUUa'}
# {'userId': 'Emp_170', 'firstName': 'Shannon', 'middleName': 'Tracy', 'lastName': 'Lopez', 'email': 'wjohnson@example.com', 'phoneNumber': '9969047265', 'gender': 'Male', 'doj': datetime.date(2020, 1, 6), 'specializations': ['Django', 'Product Management', 'Collaboration', 'Ruby'], 'dob': datetime.date(1998, 1, 21), 'city': 'West Ryanberg', 'state': 'Montana', 'experience': 5, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '&H4JUdt%'}
# {'userId': 'Emp_171', 'firstName': 'Ronnie', 'middleName': 'Anthony', 'lastName': 'Woodard', 'email': 'okramer@example.org', 'phoneNumber': '(680)889-0277x51895', 'gender': 'Male', 'doj': datetime.date(2020, 6, 24), 'specializations': ['Git', 'Communication', 'Accessibility', 'Scrum'], 'dob': datetime.date(1978, 4, 7), 'city': 'North Jaredton', 'state': 'Tennessee', 'experience': 17, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'Jb)7BN&w'}
# {'userId': 'Emp_172', 'firstName': 'Denise', 'middleName': 'Amy', 'lastName': 'Lewis', 'email': 'dwilliams@example.org', 'phoneNumber': '593-556-2326x25932', 'gender': 'Male', 'doj': datetime.date(2023, 10, 21), 'specializations': ['Java', 'Statistical Analysis', 'Machine Learning', 'Python'], 'dob': datetime.date(1944, 10, 8), 'city': 'Port Jenniferbury', 'state': 'Indiana', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': ')&5Af)_o'}
# {'userId': 'Emp_173', 'firstName': 'Jasmine', 'middleName': 'Richard', 'lastName': 'Vang', 'email': 'william43@example.com', 'phoneNumber': '6743730880', 'gender': 'Male', 'doj': datetime.date(2021, 11, 15), 'specializations': ['JavaScript', 'SQL', 'Business Analysis', 'Technical Writing'], 'dob': datetime.date(1968, 6, 28), 'city': 'Medinachester', 'state': 'Georgia', 'experience': 11, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'r)o3apUn'}
# {'userId': 'Emp_174', 'firstName': 'Melissa', 'middleName': 'Courtney', 'lastName': 'Montoya', 'email': 'destinybrown@example.net', 'phoneNumber': '228.233.1992x34696', 'gender': 'Male', 'doj': datetime.date(2020, 11, 30), 'specializations': ['CI/CD', 'Product Management', 'PostgreSQL', 'Azure'], 'dob': datetime.date(2004, 4, 8), 'city': 'Port Thomasside', 'state': 'Colorado', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '*yt4PY$g'}
# {'userId': 'Emp_175', 'firstName': 'Pamela', 'middleName': 'Debra', 'lastName': 'Stewart', 'email': 'shellyfrancis@example.com', 'phoneNumber': '315-278-9221', 'gender': 'Female', 'doj': datetime.date(2021, 7, 23), 'specializations': ['Git', 'SQL', 'Collaboration', 'PHP'], 'dob': datetime.date(1919, 6, 14), 'city': 'Port Lindseyfurt', 'state': 'Indiana', 'experience': 19, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '$#4DBJkn'}
# {'userId': 'Emp_176', 'firstName': 'Jacqueline', 'middleName': 'Adam', 'lastName': 'Oconnor', 'email': 'paulwagner@example.com', 'phoneNumber': '(343)884-4527x326', 'gender': 'Male', 'doj': datetime.date(2020, 4, 12), 'specializations': ['Data Visualization', 'Interaction Design', 'NoSQL', 'DevOps'], 'dob': datetime.date(1970, 4, 28), 'city': 'South Rachel', 'state': 'Vermont', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '&2^U2Eta'}
# {'userId': 'Emp_177', 'firstName': 'Benjamin', 'middleName': 'Katherine', 'lastName': 'Buchanan', 'email': 'millervanessa@example.org', 'phoneNumber': '+1-859-871-9268', 'gender': 'Male', 'doj': datetime.date(2020, 1, 31), 'specializations': ['Agile Product Management', 'Google Cloud Platform', 'Java', 'React'], 'dob': datetime.date(1955, 4, 10), 'city': 'Jamesfort', 'state': 'Idaho', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^1T!xy8h'}
# {'userId': 'Emp_178', 'firstName': 'Natalie', 'middleName': 'Stephanie', 'lastName': 'Mejia', 'email': 'warrenmargaret@example.net', 'phoneNumber': '610-633-7815x3578', 'gender': 'Female', 'doj': datetime.date(2022, 3, 25), 'specializations': ['SQL', 'UI/UX Design', 'AWS', 'CSS'], 'dob': datetime.date(1966, 3, 19), 'city': 'Kellyport', 'state': 'Idaho', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^2Fqglon'}
# {'userId': 'Emp_179', 'firstName': 'Darren', 'middleName': 'Jason', 'lastName': 'Boyd', 'email': 'agardner@example.net', 'phoneNumber': '+1-981-890-8466x435', 'gender': 'Male', 'doj': datetime.date(2020, 8, 13), 'specializations': ['Information Security', 'Prototyping', 'Microservices', 'Leadership'], 'dob': datetime.date(1992, 12, 24), 'city': 'North Johnbury', 'state': 'South Carolina', 'experience': 13, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'R(s^1UBw'}
# {'userId': 'Emp_180', 'firstName': 'Daniel', 'middleName': 'Jennifer', 'lastName': 'Smith', 'email': 'chenry@example.org', 'phoneNumber': '966.323.3788', 'gender': 'Male', 'doj': datetime.date(2022, 11, 20), 'specializations': ['Responsive Design', 'Python', 'MySQL', 'Containerization'], 'dob': datetime.date(1915, 1, 27), 'city': 'North Kristina', 'state': 'Oregon', 'experience': 1, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '_K^p7Rsg'}
# {'userId': 'Emp_181', 'firstName': 'Andrea', 'middleName': 'Kyle', 'lastName': 'Anderson', 'email': 'smithkevin@example.org', 'phoneNumber': '940.894.4425', 'gender': 'Male', 'doj': datetime.date(2020, 1, 31), 'specializations': ['Collaboration', 'SQL', 'Microservices', 'JavaScript'], 'dob': datetime.date(1955, 2, 21), 'city': 'Kellyview', 'state': 'New Hampshire', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#5#r3OSy'}
# {'userId': 'Emp_182', 'firstName': 'Hunter', 'middleName': 'Joel', 'lastName': 'Joseph', 'email': 'lloyddavid@example.com', 'phoneNumber': '(229)224-5375x915', 'gender': 'Female', 'doj': datetime.date(2023, 8, 6), 'specializations': ['Node.js', 'HTML', 'Agile Product Management', 'Azure'], 'dob': datetime.date(1912, 6, 24), 'city': 'North Justintown', 'state': 'Delaware', 'experience': 8, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '&7@0L*7q'}
# {'userId': 'Emp_183', 'firstName': 'Brandi', 'middleName': 'David', 'lastName': 'Wilson', 'email': 'rebecca03@example.net', 'phoneNumber': '001-241-919-9421', 'gender': 'Male', 'doj': datetime.date(2024, 2, 12), 'specializations': ['PostgreSQL', 'Java', 'Responsive Design', 'AWS'], 'dob': datetime.date(1946, 9, 20), 'city': 'East John', 'state': 'Illinois', 'experience': 6, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'V@3Hfvfy'}
# {'userId': 'Emp_184', 'firstName': 'Travis', 'middleName': 'Jason', 'lastName': 'Thomas', 'email': 'bjackson@example.org', 'phoneNumber': '(573)880-3870', 'gender': 'Female', 'doj': datetime.date(2024, 3, 31), 'specializations': ['Kotlin', 'PostgreSQL', 'Documentation', 'Troubleshooting'], 'dob': datetime.date(1991, 11, 10), 'city': 'Flemingmouth', 'state': 'Virginia', 'experience': 10, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '$l7)WFee'}
# {'userId': 'Emp_185', 'firstName': 'Heather', 'middleName': 'Ronald', 'lastName': 'Moore', 'email': 'amanda00@example.org', 'phoneNumber': '001-320-797-2295x39684', 'gender': 'Male', 'doj': datetime.date(2020, 5, 4), 'specializations': ['Artificial Intelligence', 'PHP', 'Django', 'PostgreSQL'], 'dob': datetime.date(1980, 6, 2), 'city': 'West Nicolemouth', 'state': 'South Dakota', 'experience': 14, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^4cL37Xa'}
# {'userId': 'Emp_186', 'firstName': 'Erik', 'middleName': 'Jonathan', 'lastName': 'Watson', 'email': 'bonnie15@example.net', 'phoneNumber': '+1-466-222-9574', 'gender': 'Female', 'doj': datetime.date(2022, 11, 9), 'specializations': ['Penetration Testing', 'GraphQL', 'Docker', 'MongoDB'], 'dob': datetime.date(1972, 11, 4), 'city': 'Katherinefort', 'state': 'Texas', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#8CW8owV'}
# {'userId': 'Emp_187', 'firstName': 'Kathleen', 'middleName': 'Nancy', 'lastName': 'Phillips', 'email': 'raymond94@example.com', 'phoneNumber': '6027098519', 'gender': 'Female', 'doj': datetime.date(2020, 7, 9), 'specializations': ['SQL', 'Behavior-Driven Development', 'Accessibility', 'User Stories'], 'dob': datetime.date(1911, 5, 5), 'city': 'Victorialand', 'state': 'North Dakota', 'experience': 10, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '_ky)8xZv'}
# {'userId': 'Emp_188', 'firstName': 'Michael', 'middleName': 'Kathleen', 'lastName': 'Green', 'email': 'william98@example.com', 'phoneNumber': '523.926.3668x8523', 'gender': 'Female', 'doj': datetime.date(2023, 2, 21), 'specializations': ['Java', 'Microservices', 'C#', 'Objective-C'], 'dob': datetime.date(1979, 9, 16), 'city': 'South Daniel', 'state': 'Nevada', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '_6YNVBsU'}
# {'userId': 'Emp_189', 'firstName': 'Maria', 'middleName': 'Vincent', 'lastName': 'Irwin', 'email': 'hrice@example.com', 'phoneNumber': '793.646.1340', 'gender': 'Male', 'doj': datetime.date(2020, 12, 5), 'specializations': ['Problem Solving', 'Collaboration', 'Objective-C', 'Continuous Integration'], 'dob': datetime.date(1951, 6, 24), 'city': 'Wisemouth', 'state': 'Utah', 'experience': 8, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'Y)89lNZk'}
# {'userId': 'Emp_190', 'firstName': 'Aaron', 'middleName': 'Emily', 'lastName': 'Waller', 'email': 'huntdebbie@example.com', 'phoneNumber': '5128570160', 'gender': 'Female', 'doj': datetime.date(2020, 4, 19), 'specializations': ['Kotlin', 'Cybersecurity', 'Machine Learning', 'PostgreSQL'], 'dob': datetime.date(1924, 11, 4), 'city': 'Johnathanview', 'state': 'New Hampshire', 'experience': 2, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '&3Vsg1Xg'}
# {'userId': 'Emp_191', 'firstName': 'Caleb', 'middleName': 'Joseph', 'lastName': 'Sexton', 'email': 'tpeters@example.com', 'phoneNumber': '(858)419-4612x25251', 'gender': 'Female', 'doj': datetime.date(2021, 7, 22), 'specializations': ['PHP', 'Scrum', 'Data Analysis', 'Support'], 'dob': datetime.date(1994, 8, 24), 'city': 'Draketown', 'state': 'New Jersey', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%68OxMu8'}
# {'userId': 'Emp_192', 'firstName': 'Thomas', 'middleName': 'Christopher', 'lastName': 'Williams', 'email': 'timothyfisher@example.org', 'phoneNumber': '001-216-871-0471x468', 'gender': 'Male', 'doj': datetime.date(2020, 9, 15), 'specializations': ['Statistical Analysis', 'Network Security', 'Git', 'Support'], 'dob': datetime.date(1988, 2, 21), 'city': 'North Kathleen', 'state': 'Utah', 'experience': 4, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^5%mhRit'}
# {'userId': 'Emp_193', 'firstName': 'Dustin', 'middleName': 'John', 'lastName': 'Wolfe', 'email': 'nelsonnicole@example.com', 'phoneNumber': '667.954.9109x1012', 'gender': 'Male', 'doj': datetime.date(2021, 2, 6), 'specializations': ['Cybersecurity', 'Angular', 'Swift', 'Network Security'], 'dob': datetime.date(1969, 6, 5), 'city': 'West Mary', 'state': 'Oklahoma', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '$1574Cpw'}
# {'userId': 'Emp_194', 'firstName': 'Sara', 'middleName': 'Patrick', 'lastName': 'Campbell', 'email': 'msoto@example.com', 'phoneNumber': '001-911-621-8413x32005', 'gender': 'Male', 'doj': datetime.date(2023, 5, 30), 'specializations': ['Documentation', 'Agile Methodologies', 'Artificial Intelligence', 'Node.js'], 'dob': datetime.date(1976, 12, 26), 'city': 'West Erinbury', 'state': 'New Hampshire', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'w_7U5Noe'}
# {'userId': 'Emp_195', 'firstName': 'Becky', 'middleName': 'Bradley', 'lastName': 'Beck', 'email': 'cynthia60@example.net', 'phoneNumber': '(755)888-7262x391', 'gender': 'Female', 'doj': datetime.date(2023, 9, 11), 'specializations': ['Problem Solving', 'RESTful API', 'Microservices', 'Azure'], 'dob': datetime.date(1931, 10, 22), 'city': 'Belindafort', 'state': 'Alabama', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'y7%a4BWd'}
# {'userId': 'Emp_196', 'firstName': 'Heather', 'middleName': 'Robert', 'lastName': 'Black', 'email': 'hsantiago@example.com', 'phoneNumber': '+1-305-542-9484', 'gender': 'Female', 'doj': datetime.date(2023, 7, 6), 'specializations': ['Leadership', 'GraphQL', 'Troubleshooting', 'Behavior-Driven Development'], 'dob': datetime.date(2017, 4, 30), 'city': 'West Sarahbury', 'state': 'Minnesota', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '*7I+C%mw'}
# {'userId': 'Emp_197', 'firstName': 'Jimmy', 'middleName': 'Deborah', 'lastName': 'Lewis', 'email': 'martha29@example.org', 'phoneNumber': '870-276-0654x77611', 'gender': 'Female', 'doj': datetime.date(2023, 1, 6), 'specializations': ['DevOps', 'Continuous Deployment', 'HTML', 'User Research'], 'dob': datetime.date(1941, 12, 25), 'city': 'New Jonathanmouth', 'state': 'Oregon', 'experience': 5, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'Y!)_6HnY'}
# {'userId': 'Emp_198', 'firstName': 'Ricky', 'middleName': 'Dominique', 'lastName': 'Graves', 'email': 'elizabethpatel@example.net', 'phoneNumber': '001-266-739-8634x0186', 'gender': 'Female', 'doj': datetime.date(2020, 3, 30), 'specializations': ['Vue.js', 'Wireframing', 'Django', 'Objective-C'], 'dob': datetime.date(1994, 7, 15), 'city': 'Steelemouth', 'state': 'Washington', 'experience': 4, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '@^2URyyC'}
# {'userId': 'Emp_199', 'firstName': 'Justin', 'middleName': 'Maxwell', 'lastName': 'Turner', 'email': 'reedcarla@example.com', 'phoneNumber': '(804)474-1995', 'gender': 'Male', 'doj': datetime.date(2022, 10, 8), 'specializations': ['Kotlin', 'CI/CD', 'GraphQL', 'Penetration Testing'], 'dob': datetime.date(2008, 1, 16), 'city': 'Lake Jonathan', 'state': 'New Hampshire', 'experience': 14, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'Nr!1UVmV'}

# %%
# Write data to CSV file
csv_file_path = "user_data1.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for user_data in fake_data_list:
        writer.writerow(user_data)

print(f"User data has been saved to {csv_file_path}")
# Out:
# User data has been saved to user_data1.csv

# %%
import csv

# %%
fake_data_list = []
for i in range(1, 100):
    certificates = random.sample(skills, 4)
    user_data = {
        "userId": "Emp_" + str(i),
        "trainerName": fake.first_name(),
        "trainerDesignation": fake.random_element(elements=job_roles),
        "trainerRating": fake.random_int(min=1, max=5),
        "trainerSpecialization": certificates,
    }
    fake_data_list.append(user_data)

# Print the generated fake data
for user_data in fake_data_list:
    print(user_data)
# Out:
# {'userId': 'Emp_1', 'trainerName': 'Timothy', 'trainerDesignation': 'Scrum Master', 'trainerRating': 4, 'trainerSpecialization': ['Information Security', 'MySQL', 'Agile Methodologies', 'Data Science']}
# {'userId': 'Emp_2', 'trainerName': 'Derek', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 2, 'trainerSpecialization': ['Azure', 'Technical Writing', 'Penetration Testing', 'Docker']}
# {'userId': 'Emp_3', 'trainerName': 'Christina', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Prototyping', 'Interaction Design', 'Agile Methodologies', 'Wireframing']}
# {'userId': 'Emp_4', 'trainerName': 'Cindy', 'trainerDesignation': 'Security Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Ruby', 'UI/UX Design', 'Data Science', 'Python']}
# {'userId': 'Emp_5', 'trainerName': 'Jonathan', 'trainerDesignation': 'Technical Architect', 'trainerRating': 2, 'trainerSpecialization': ['Git', 'Statistical Analysis', 'Cybersecurity', 'Containerization']}
# {'userId': 'Emp_6', 'trainerName': 'Natalie', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 3, 'trainerSpecialization': ['Requirements Analysis', 'Problem Solving', 'Agile Methodologies', 'Flask']}
# {'userId': 'Emp_7', 'trainerName': 'Amber', 'trainerDesignation': 'Backend Developer', 'trainerRating': 4, 'trainerSpecialization': ['Wireframing', 'Kotlin', 'Documentation', 'PostgreSQL']}
# {'userId': 'Emp_8', 'trainerName': 'Edward', 'trainerDesignation': 'IT Administrator', 'trainerRating': 1, 'trainerSpecialization': ['Azure', 'Containerization', 'Collaboration', 'Documentation']}
# {'userId': 'Emp_9', 'trainerName': 'Todd', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Cryptography', 'Responsive Design', 'Collaboration', 'Test-Driven Development']}
# {'userId': 'Emp_10', 'trainerName': 'Vincent', 'trainerDesignation': 'Technical Architect', 'trainerRating': 3, 'trainerSpecialization': ['Angular', 'Agile Methodologies', 'CSS', 'Technical Writing']}
# {'userId': 'Emp_11', 'trainerName': 'Donald', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Ruby', 'Django', 'Troubleshooting', 'CSS']}
# {'userId': 'Emp_12', 'trainerName': 'Amy', 'trainerDesignation': 'Product Manager', 'trainerRating': 4, 'trainerSpecialization': ['Communication', 'NoSQL', 'Documentation', 'AWS']}
# {'userId': 'Emp_13', 'trainerName': 'Lisa', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Continuous Deployment', 'Kubernetes', 'Interaction Design', 'Microservices']}
# {'userId': 'Emp_14', 'trainerName': 'Victoria', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Troubleshooting', 'Responsive Design', 'Support', 'Scrum']}
# {'userId': 'Emp_15', 'trainerName': 'Sarah', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Information Security', 'Test-Driven Development', 'Django', 'MongoDB']}
# {'userId': 'Emp_16', 'trainerName': 'Kathy', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Vue.js', '.NET', 'Microservices', 'Data Science']}
# {'userId': 'Emp_17', 'trainerName': 'Shane', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 5, 'trainerSpecialization': ['NoSQL', 'C#', '.NET', 'Problem Solving']}
# {'userId': 'Emp_18', 'trainerName': 'Deanna', 'trainerDesignation': 'Software Tester', 'trainerRating': 2, 'trainerSpecialization': ['Statistical Analysis', 'Documentation', '.NET', 'Collaboration']}
# {'userId': 'Emp_19', 'trainerName': 'Christopher', 'trainerDesignation': 'Security Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Problem Solving', 'SQL', 'Technical Writing', 'Behavior-Driven Development']}
# {'userId': 'Emp_20', 'trainerName': 'Matthew', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 3, 'trainerSpecialization': ['Kubernetes', 'Flask', 'C#', 'SQL']}
# {'userId': 'Emp_21', 'trainerName': 'Paul', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 3, 'trainerSpecialization': ['Microservices', 'Data Science', 'Google Cloud Platform', 'Machine Learning']}
# {'userId': 'Emp_22', 'trainerName': 'Tyler', 'trainerDesignation': 'Security Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Requirements Analysis', 'Penetration Testing', 'AWS', 'Troubleshooting']}
# {'userId': 'Emp_23', 'trainerName': 'Vincent', 'trainerDesignation': 'Frontend Developer', 'trainerRating': 2, 'trainerSpecialization': ['Objective-C', 'Vue.js', 'Technical Writing', 'Swift']}
# {'userId': 'Emp_24', 'trainerName': 'Alexandra', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 2, 'trainerSpecialization': ['Kubernetes', 'Troubleshooting', 'Statistical Analysis', 'C#']}
# {'userId': 'Emp_25', 'trainerName': 'Brianna', 'trainerDesignation': 'Business Analyst', 'trainerRating': 3, 'trainerSpecialization': ['Angular', 'Google Cloud Platform', 'Django', 'React']}
# {'userId': 'Emp_26', 'trainerName': 'Elizabeth', 'trainerDesignation': 'Scrum Master', 'trainerRating': 2, 'trainerSpecialization': ['Cybersecurity', 'GraphQL', 'Penetration Testing', 'UI/UX Design']}
# {'userId': 'Emp_27', 'trainerName': 'Gloria', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 1, 'trainerSpecialization': ['Ruby', 'Behavior-Driven Development', 'Google Cloud Platform', 'Microservices']}
# {'userId': 'Emp_28', 'trainerName': 'Christina', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 1, 'trainerSpecialization': ['Leadership', 'Accessibility', 'Troubleshooting', 'Product Management']}
# {'userId': 'Emp_29', 'trainerName': 'Penny', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 2, 'trainerSpecialization': ['Node.js', 'Collaboration', 'Penetration Testing', 'Technical Writing']}
# {'userId': 'Emp_30', 'trainerName': 'Daniel', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Interaction Design', 'Agile Methodologies', 'Communication', 'MySQL']}
# {'userId': 'Emp_31', 'trainerName': 'Julie', 'trainerDesignation': 'Network Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Microservices', 'User Research', 'Accessibility', 'Continuous Integration']}
# {'userId': 'Emp_32', 'trainerName': 'Brendan', 'trainerDesignation': 'IT Administrator', 'trainerRating': 5, 'trainerSpecialization': ['Vue.js', 'Communication', 'AWS', 'Data Visualization']}
# {'userId': 'Emp_33', 'trainerName': 'Matthew', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 1, 'trainerSpecialization': ['Information Security', 'Flask', 'SQL', 'Network Security']}
# {'userId': 'Emp_34', 'trainerName': 'Joshua', 'trainerDesignation': 'Configuration Manager', 'trainerRating': 4, 'trainerSpecialization': ['CI/CD', 'Information Security', 'Data Science', 'Accessibility']}
# {'userId': 'Emp_35', 'trainerName': 'Joel', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 2, 'trainerSpecialization': ['NoSQL', 'DevOps', 'Node.js', 'Interaction Design']}
# {'userId': 'Emp_36', 'trainerName': 'Elizabeth', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 4, 'trainerSpecialization': ['Machine Learning', 'Leadership', 'Objective-C', 'Kotlin']}
# {'userId': 'Emp_37', 'trainerName': 'Carly', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 5, 'trainerSpecialization': ['Kotlin', 'Containerization', 'Penetration Testing', 'Google Cloud Platform']}
# {'userId': 'Emp_38', 'trainerName': 'Phillip', 'trainerDesignation': 'Business Analyst', 'trainerRating': 5, 'trainerSpecialization': ['RESTful API', 'Vue.js', 'Containerization', 'Technical Writing']}
# {'userId': 'Emp_39', 'trainerName': 'Terri', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 3, 'trainerSpecialization': ['Collaboration', 'Angular', 'DevOps', 'Problem Solving']}
# {'userId': 'Emp_40', 'trainerName': 'Matthew', 'trainerDesignation': 'Release Manager', 'trainerRating': 1, 'trainerSpecialization': ['C#', 'Node.js', 'Accessibility', 'SQL']}
# {'userId': 'Emp_41', 'trainerName': 'Mary', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Problem Solving', 'Vue.js', 'Interaction Design', 'GraphQL']}
# {'userId': 'Emp_42', 'trainerName': 'Cindy', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Troubleshooting', 'Ruby', 'Prototyping', 'Behavior-Driven Development']}
# {'userId': 'Emp_43', 'trainerName': 'Pamela', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 3, 'trainerSpecialization': ['Kotlin', 'Wireframing', 'Azure', 'HTML']}
# {'userId': 'Emp_44', 'trainerName': 'Alexander', 'trainerDesignation': 'Release Manager', 'trainerRating': 2, 'trainerSpecialization': ['Network Security', 'Python', 'Vue.js', 'Responsive Design']}
# {'userId': 'Emp_45', 'trainerName': 'Darryl', 'trainerDesignation': 'Full-stack Developer', 'trainerRating': 3, 'trainerSpecialization': ['React', 'User Stories', 'Support', 'Penetration Testing']}
# {'userId': 'Emp_46', 'trainerName': 'William', 'trainerDesignation': 'Release Manager', 'trainerRating': 4, 'trainerSpecialization': ['Agile Methodologies', 'Troubleshooting', 'Git', 'Problem Solving']}
# {'userId': 'Emp_47', 'trainerName': 'Travis', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 2, 'trainerSpecialization': ['UI/UX Design', 'JavaScript', 'Continuous Integration', 'Prototyping']}
# {'userId': 'Emp_48', 'trainerName': 'Michael', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 3, 'trainerSpecialization': ['Git', 'Angular', 'Kubernetes', 'Data Science']}
# {'userId': 'Emp_49', 'trainerName': 'Robert', 'trainerDesignation': 'Network Engineer', 'trainerRating': 3, 'trainerSpecialization': ['DevOps', 'Data Analysis', 'Interaction Design', 'Python']}
# {'userId': 'Emp_50', 'trainerName': 'Heather', 'trainerDesignation': 'Configuration Manager', 'trainerRating': 1, 'trainerSpecialization': ['Data Analysis', 'Accessibility', 'Requirements Analysis', 'Kotlin']}
# {'userId': 'Emp_51', 'trainerName': 'Nicole', 'trainerDesignation': 'Agile Coach', 'trainerRating': 4, 'trainerSpecialization': ['Prototyping', 'User Stories', 'Java', 'Support']}
# {'userId': 'Emp_52', 'trainerName': 'Joel', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 2, 'trainerSpecialization': ['React', 'User Stories', 'Product Management', 'AWS']}
# {'userId': 'Emp_53', 'trainerName': 'Edward', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 5, 'trainerSpecialization': ['C#', 'PHP', 'Requirements Analysis', 'Data Science']}
# {'userId': 'Emp_54', 'trainerName': 'Bradley', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 1, 'trainerSpecialization': ['.NET', 'Containerization', 'Agile Product Management', 'User Stories']}
# {'userId': 'Emp_55', 'trainerName': 'Victoria', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 4, 'trainerSpecialization': ['NoSQL', 'User Research', 'MySQL', 'Java']}
# {'userId': 'Emp_56', 'trainerName': 'Ann', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 3, 'trainerSpecialization': ['Responsive Design', 'Statistical Analysis', 'Data Science', 'Django']}
# {'userId': 'Emp_57', 'trainerName': 'Joseph', 'trainerDesignation': 'Technical Architect', 'trainerRating': 4, 'trainerSpecialization': ['Kubernetes', 'Problem Solving', 'Data Science', 'Prototyping']}
# {'userId': 'Emp_58', 'trainerName': 'Lisa', 'trainerDesignation': 'Frontend Developer', 'trainerRating': 5, 'trainerSpecialization': ['Wireframing', 'Data Analysis', 'Support', 'PostgreSQL']}
# {'userId': 'Emp_59', 'trainerName': 'Jose', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 5, 'trainerSpecialization': ['User Research', 'Data Science', 'Accessibility', 'NoSQL']}
# {'userId': 'Emp_60', 'trainerName': 'Julie', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Python', 'Business Analysis', 'Scrum', '.NET']}
# {'userId': 'Emp_61', 'trainerName': 'Willie', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 1, 'trainerSpecialization': ['Vue.js', 'Data Analysis', 'Machine Learning', 'Information Security']}
# {'userId': 'Emp_62', 'trainerName': 'Kyle', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 1, 'trainerSpecialization': ['Containerization', 'Agile Product Management', 'AWS', 'Angular']}
# {'userId': 'Emp_63', 'trainerName': 'Kathleen', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Data Analysis', 'Kotlin', 'Django', 'Objective-C']}
# {'userId': 'Emp_64', 'trainerName': 'Christina', 'trainerDesignation': 'Agile Coach', 'trainerRating': 5, 'trainerSpecialization': ['C#', 'User Research', 'Machine Learning', 'Containerization']}
# {'userId': 'Emp_65', 'trainerName': 'Allison', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 3, 'trainerSpecialization': ['Information Security', 'Java', 'DevOps', 'Scrum']}
# {'userId': 'Emp_66', 'trainerName': 'Angela', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Business Analysis', 'Leadership', 'Machine Learning', 'Continuous Deployment']}
# {'userId': 'Emp_67', 'trainerName': 'Benjamin', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 3, 'trainerSpecialization': ['Artificial Intelligence', 'Java', 'Wireframing', 'Azure']}
# {'userId': 'Emp_68', 'trainerName': 'Krista', 'trainerDesignation': 'Network Engineer', 'trainerRating': 2, 'trainerSpecialization': ['User Research', 'Node.js', 'SQL', 'JavaScript']}
# {'userId': 'Emp_69', 'trainerName': 'Sylvia', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Java', 'Django', 'Ruby', 'Cybersecurity']}
# {'userId': 'Emp_70', 'trainerName': 'Dale', 'trainerDesignation': 'Agile Coach', 'trainerRating': 5, 'trainerSpecialization': ['Angular', 'Support', 'Node.js', 'Azure']}
# {'userId': 'Emp_71', 'trainerName': 'Katelyn', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 5, 'trainerSpecialization': ['Containerization', 'Azure', 'RESTful API', 'Docker']}
# {'userId': 'Emp_72', 'trainerName': 'Marcus', 'trainerDesignation': 'Scrum Master', 'trainerRating': 5, 'trainerSpecialization': ['Accessibility', 'RESTful API', 'User Research', 'Data Science']}
# {'userId': 'Emp_73', 'trainerName': 'Robert', 'trainerDesignation': 'IT Administrator', 'trainerRating': 3, 'trainerSpecialization': ['PHP', 'DevOps', 'Product Management', 'AWS']}
# {'userId': 'Emp_74', 'trainerName': 'Julia', 'trainerDesignation': 'Software Engineer', 'trainerRating': 5, 'trainerSpecialization': ['NoSQL', 'CI/CD', 'Data Visualization', 'PostgreSQL']}
# {'userId': 'Emp_75', 'trainerName': 'Deborah', 'trainerDesignation': 'Backend Developer', 'trainerRating': 3, 'trainerSpecialization': ['Penetration Testing', 'Python', 'Google Cloud Platform', 'Information Security']}
# {'userId': 'Emp_76', 'trainerName': 'Nicole', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 3, 'trainerSpecialization': ['Continuous Integration', '.NET', 'CI/CD', 'Accessibility']}
# {'userId': 'Emp_77', 'trainerName': 'Marie', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Business Analysis', 'SQL', 'Documentation', 'Accessibility']}
# {'userId': 'Emp_78', 'trainerName': 'Charles', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Django', 'MySQL', 'AWS', 'C#']}
# {'userId': 'Emp_79', 'trainerName': 'Emily', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 1, 'trainerSpecialization': ['Git', 'MongoDB', 'Behavior-Driven Development', 'UI/UX Design']}
# {'userId': 'Emp_80', 'trainerName': 'Steven', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 4, 'trainerSpecialization': ['C#', 'Prototyping', 'Collaboration', 'PostgreSQL']}
# {'userId': 'Emp_81', 'trainerName': 'Joel', 'trainerDesignation': 'Software Engineer', 'trainerRating': 1, 'trainerSpecialization': ['SQL', 'Ruby', 'Agile Methodologies', 'Flask']}
# {'userId': 'Emp_82', 'trainerName': 'April', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Azure', 'Problem Solving', 'Business Analysis', 'Docker']}
# {'userId': 'Emp_83', 'trainerName': 'Ethan', 'trainerDesignation': 'Network Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Angular', 'JavaScript', 'Accessibility', 'GraphQL']}
# {'userId': 'Emp_84', 'trainerName': 'Helen', 'trainerDesignation': 'Technical Architect', 'trainerRating': 2, 'trainerSpecialization': ['Artificial Intelligence', 'Google Cloud Platform', 'JavaScript', 'React']}
# {'userId': 'Emp_85', 'trainerName': 'Pamela', 'trainerDesignation': 'Network Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Responsive Design', 'Docker', 'Data Visualization', 'Data Analysis']}
# {'userId': 'Emp_86', 'trainerName': 'Wendy', 'trainerDesignation': 'Technical Architect', 'trainerRating': 4, 'trainerSpecialization': ['User Research', 'Kotlin', 'Node.js', 'HTML']}
# {'userId': 'Emp_87', 'trainerName': 'John', 'trainerDesignation': 'Backend Developer', 'trainerRating': 3, 'trainerSpecialization': ['Collaboration', 'Business Analysis', 'Google Cloud Platform', 'Technical Writing']}
# {'userId': 'Emp_88', 'trainerName': 'Jacob', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 3, 'trainerSpecialization': ['Requirements Analysis', 'React', 'Technical Writing', 'PostgreSQL']}
# {'userId': 'Emp_89', 'trainerName': 'Jason', 'trainerDesignation': 'Software Engineer', 'trainerRating': 5, 'trainerSpecialization': ['C#', '.NET', 'Responsive Design', 'React']}
# {'userId': 'Emp_90', 'trainerName': 'Jonathan', 'trainerDesignation': 'Product Manager', 'trainerRating': 2, 'trainerSpecialization': ['Prototyping', 'AWS', 'Continuous Integration', 'MySQL']}
# {'userId': 'Emp_91', 'trainerName': 'Nicholas', 'trainerDesignation': 'Security Engineer', 'trainerRating': 4, 'trainerSpecialization': ['MySQL', 'Agile Methodologies', 'Product Management', 'Troubleshooting']}
# {'userId': 'Emp_92', 'trainerName': 'Christopher', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 1, 'trainerSpecialization': ['.NET', 'Microservices', 'PHP', 'Agile Methodologies']}
# {'userId': 'Emp_93', 'trainerName': 'Jake', 'trainerDesignation': 'Scrum Master', 'trainerRating': 3, 'trainerSpecialization': ['Support', 'Requirements Analysis', 'Swift', 'Flask']}
# {'userId': 'Emp_94', 'trainerName': 'Cody', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Azure', 'Product Management', 'AWS', 'JavaScript']}
# {'userId': 'Emp_95', 'trainerName': 'Anna', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 1, 'trainerSpecialization': ['NoSQL', 'Kubernetes', 'Leadership', 'Agile Product Management']}
# {'userId': 'Emp_96', 'trainerName': 'Nicole', 'trainerDesignation': 'Software Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Network Security', 'Agile Product Management', 'Django', 'Ruby']}
# {'userId': 'Emp_97', 'trainerName': 'Levi', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 3, 'trainerSpecialization': ['DevOps', 'Data Visualization', 'SQL', 'C#']}
# {'userId': 'Emp_98', 'trainerName': 'Matthew', 'trainerDesignation': 'Software Tester', 'trainerRating': 4, 'trainerSpecialization': ['Artificial Intelligence', 'Responsive Design', 'Flask', 'Java']}
# {'userId': 'Emp_99', 'trainerName': 'Ashlee', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Machine Learning', 'Microservices', 'Continuous Integration', 'Data Analysis']}
# {'userId': 'Emp_100', 'trainerName': 'Sarah', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 1, 'trainerSpecialization': ['CSS', 'Swift', 'Technical Writing', 'PostgreSQL']}
# {'userId': 'Emp_101', 'trainerName': 'Danielle', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 5, 'trainerSpecialization': ['Continuous Deployment', 'Network Security', 'Microservices', 'Information Security']}
# {'userId': 'Emp_102', 'trainerName': 'Kevin', 'trainerDesignation': 'Scrum Master', 'trainerRating': 1, 'trainerSpecialization': ['Kotlin', 'Containerization', 'JavaScript', 'PHP']}
# {'userId': 'Emp_103', 'trainerName': 'Cynthia', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Communication', 'User Stories', 'Statistical Analysis', 'Kubernetes']}
# {'userId': 'Emp_104', 'trainerName': 'Gina', 'trainerDesignation': 'Backend Developer', 'trainerRating': 1, 'trainerSpecialization': ['Business Analysis', 'Troubleshooting', 'AWS', 'Leadership']}
# {'userId': 'Emp_105', 'trainerName': 'Kaitlyn', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 3, 'trainerSpecialization': ['GraphQL', 'Leadership', 'Java', 'DevOps']}
# {'userId': 'Emp_106', 'trainerName': 'Dorothy', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 2, 'trainerSpecialization': ['Troubleshooting', 'DevOps', 'React', 'Ruby']}
# {'userId': 'Emp_107', 'trainerName': 'Joshua', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Behavior-Driven Development', 'Node.js', 'NoSQL', 'Microservices']}
# {'userId': 'Emp_108', 'trainerName': 'Martin', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 3, 'trainerSpecialization': ['Business Analysis', 'Git', 'Vue.js', 'Agile Methodologies']}
# {'userId': 'Emp_109', 'trainerName': 'Sierra', 'trainerDesignation': 'Software Tester', 'trainerRating': 2, 'trainerSpecialization': ['Statistical Analysis', 'AWS', 'Data Analysis', 'Data Science']}
# {'userId': 'Emp_110', 'trainerName': 'David', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 3, 'trainerSpecialization': ['Collaboration', 'Statistical Analysis', 'JavaScript', 'Requirements Analysis']}
# {'userId': 'Emp_111', 'trainerName': 'Charles', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Vue.js', 'Objective-C', 'PHP', 'Agile Methodologies']}
# {'userId': 'Emp_112', 'trainerName': 'Kayla', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 5, 'trainerSpecialization': ['React', 'HTML', 'Python', 'Problem Solving']}
# {'userId': 'Emp_113', 'trainerName': 'Teresa', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Django', 'Data Visualization', 'Network Security', 'Support']}
# {'userId': 'Emp_114', 'trainerName': 'Steven', 'trainerDesignation': 'IT Administrator', 'trainerRating': 3, 'trainerSpecialization': ['Documentation', 'Vue.js', 'JavaScript', 'Swift']}
# {'userId': 'Emp_115', 'trainerName': 'Morgan', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 5, 'trainerSpecialization': ['Agile Product Management', 'User Research', 'Data Analysis', 'Penetration Testing']}
# {'userId': 'Emp_116', 'trainerName': 'Elaine', 'trainerDesignation': 'IT Administrator', 'trainerRating': 4, 'trainerSpecialization': ['Support', 'Django', 'Data Visualization', 'Interaction Design']}
# {'userId': 'Emp_117', 'trainerName': 'Joshua', 'trainerDesignation': 'Frontend Developer', 'trainerRating': 2, 'trainerSpecialization': ['Data Science', 'Cybersecurity', 'MongoDB', 'Data Visualization']}
# {'userId': 'Emp_118', 'trainerName': 'Mary', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 4, 'trainerSpecialization': ['CSS', 'Communication', 'Accessibility', 'Objective-C']}
# {'userId': 'Emp_119', 'trainerName': 'Andrew', 'trainerDesignation': 'Frontend Developer', 'trainerRating': 3, 'trainerSpecialization': ['Kubernetes', 'DevOps', 'GraphQL', 'Troubleshooting']}
# {'userId': 'Emp_120', 'trainerName': 'Jacob', 'trainerDesignation': 'Software Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Technical Writing', 'Collaboration', 'Objective-C', 'Wireframing']}
# {'userId': 'Emp_121', 'trainerName': 'Jessica', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Agile Product Management', 'Network Security', 'CI/CD', 'Vue.js']}
# {'userId': 'Emp_122', 'trainerName': 'Madison', 'trainerDesignation': 'IT Administrator', 'trainerRating': 4, 'trainerSpecialization': ['Requirements Analysis', 'Azure', 'RESTful API', 'DevOps']}
# {'userId': 'Emp_123', 'trainerName': 'Cheyenne', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 3, 'trainerSpecialization': ['Leadership', 'HTML', 'Business Analysis', 'CI/CD']}
# {'userId': 'Emp_124', 'trainerName': 'Lisa', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 2, 'trainerSpecialization': ['Statistical Analysis', 'DevOps', 'Git', 'Technical Writing']}
# {'userId': 'Emp_125', 'trainerName': 'Tiffany', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Cybersecurity', 'Leadership', 'Behavior-Driven Development', 'GraphQL']}
# {'userId': 'Emp_126', 'trainerName': 'Evan', 'trainerDesignation': 'IT Administrator', 'trainerRating': 3, 'trainerSpecialization': ['React', 'Data Visualization', 'User Stories', 'AWS']}
# {'userId': 'Emp_127', 'trainerName': 'Kim', 'trainerDesignation': 'Product Manager', 'trainerRating': 3, 'trainerSpecialization': ['Prototyping', 'Kubernetes', 'Data Analysis', 'Wireframing']}
# {'userId': 'Emp_128', 'trainerName': 'Crystal', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Django', 'Data Analysis', 'User Stories', 'Kubernetes']}
# {'userId': 'Emp_129', 'trainerName': 'Trevor', 'trainerDesignation': 'Agile Coach', 'trainerRating': 2, 'trainerSpecialization': ['Wireframing', 'Google Cloud Platform', 'GraphQL', 'Vue.js']}
# {'userId': 'Emp_130', 'trainerName': 'Sheri', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Git', 'Accessibility', 'UI/UX Design', 'Vue.js']}
# {'userId': 'Emp_131', 'trainerName': 'Omar', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Support', 'CSS', '.NET', 'NoSQL']}
# {'userId': 'Emp_132', 'trainerName': 'Christian', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Product Management', 'Data Science', 'Information Security', 'Wireframing']}
# {'userId': 'Emp_133', 'trainerName': 'Kristie', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 5, 'trainerSpecialization': ['MongoDB', 'Leadership', 'Penetration Testing', 'Prototyping']}
# {'userId': 'Emp_134', 'trainerName': 'Grant', 'trainerDesignation': 'Product Manager', 'trainerRating': 4, 'trainerSpecialization': ['Vue.js', 'CI/CD', 'Angular', 'Documentation']}
# {'userId': 'Emp_135', 'trainerName': 'Curtis', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 5, 'trainerSpecialization': ['Docker', 'Penetration Testing', 'React', 'Angular']}
# {'userId': 'Emp_136', 'trainerName': 'Ryan', 'trainerDesignation': 'Software Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Leadership', 'Containerization', 'Cryptography', 'Kotlin']}
# {'userId': 'Emp_137', 'trainerName': 'Lisa', 'trainerDesignation': 'Network Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Responsive Design', 'RESTful API', 'Angular', 'Accessibility']}
# {'userId': 'Emp_138', 'trainerName': 'Ricardo', 'trainerDesignation': 'Frontend Developer', 'trainerRating': 5, 'trainerSpecialization': ['GraphQL', 'Problem Solving', 'C#', 'Cybersecurity']}
# {'userId': 'Emp_139', 'trainerName': 'Ebony', 'trainerDesignation': 'Software Engineer', 'trainerRating': 2, 'trainerSpecialization': ['React', 'Django', 'Artificial Intelligence', 'Statistical Analysis']}
# {'userId': 'Emp_140', 'trainerName': 'Jason', 'trainerDesignation': 'Software Tester', 'trainerRating': 3, 'trainerSpecialization': ['Penetration Testing', 'Agile Product Management', 'Ruby', 'Test-Driven Development']}
# {'userId': 'Emp_141', 'trainerName': 'Anthony', 'trainerDesignation': 'Release Manager', 'trainerRating': 2, 'trainerSpecialization': ['Angular', 'Data Analysis', 'Statistical Analysis', '.NET']}
# {'userId': 'Emp_142', 'trainerName': 'Corey', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 5, 'trainerSpecialization': ['Ruby', 'Docker', 'CI/CD', 'Product Management']}
# {'userId': 'Emp_143', 'trainerName': 'Jacqueline', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 2, 'trainerSpecialization': ['PHP', 'Kotlin', 'Documentation', 'HTML']}
# {'userId': 'Emp_144', 'trainerName': 'Russell', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Ruby', 'User Stories', 'Test-Driven Development', 'PHP']}
# {'userId': 'Emp_145', 'trainerName': 'Debbie', 'trainerDesignation': 'Frontend Developer', 'trainerRating': 1, 'trainerSpecialization': ['Cryptography', 'CI/CD', 'Requirements Analysis', 'Wireframing']}
# {'userId': 'Emp_146', 'trainerName': 'Michael', 'trainerDesignation': 'Data Scientist', 'trainerRating': 1, 'trainerSpecialization': ['Information Security', 'Cybersecurity', 'Node.js', 'Communication']}
# {'userId': 'Emp_147', 'trainerName': 'Michael', 'trainerDesignation': 'IT Administrator', 'trainerRating': 2, 'trainerSpecialization': ['Problem Solving', 'Technical Writing', 'Agile Methodologies', 'Data Visualization']}
# {'userId': 'Emp_148', 'trainerName': 'Katrina', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Objective-C', 'Communication', 'SQL', 'Artificial Intelligence']}
# {'userId': 'Emp_149', 'trainerName': 'Dustin', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Angular', 'Continuous Deployment', 'Information Security', 'React']}
# {'userId': 'Emp_150', 'trainerName': 'Amy', 'trainerDesignation': 'Product Manager', 'trainerRating': 3, 'trainerSpecialization': ['Responsive Design', 'Git', 'Machine Learning', 'Collaboration']}
# {'userId': 'Emp_151', 'trainerName': 'Mark', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 4, 'trainerSpecialization': ['Agile Product Management', 'Troubleshooting', 'Swift', 'Git']}
# {'userId': 'Emp_152', 'trainerName': 'Lindsay', 'trainerDesignation': 'Scrum Master', 'trainerRating': 2, 'trainerSpecialization': ['Wireframing', 'Kubernetes', 'Data Visualization', 'Leadership']}
# {'userId': 'Emp_153', 'trainerName': 'Danielle', 'trainerDesignation': 'Software Tester', 'trainerRating': 2, 'trainerSpecialization': ['Requirements Analysis', 'Support', 'Continuous Integration', 'Vue.js']}
# {'userId': 'Emp_154', 'trainerName': 'Jonathan', 'trainerDesignation': 'Business Analyst', 'trainerRating': 2, 'trainerSpecialization': ['.NET', 'Continuous Deployment', 'Google Cloud Platform', 'Accessibility']}
# {'userId': 'Emp_155', 'trainerName': 'Clifford', 'trainerDesignation': 'Product Manager', 'trainerRating': 5, 'trainerSpecialization': ['Cybersecurity', 'PostgreSQL', 'Requirements Analysis', 'Ruby']}
# {'userId': 'Emp_156', 'trainerName': 'Amy', 'trainerDesignation': 'Scrum Master', 'trainerRating': 2, 'trainerSpecialization': ['Containerization', 'Agile Product Management', 'Troubleshooting', 'Business Analysis']}
# {'userId': 'Emp_157', 'trainerName': 'Robert', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 3, 'trainerSpecialization': ['Kotlin', 'Wireframing', 'Objective-C', 'Swift']}
# {'userId': 'Emp_158', 'trainerName': 'Joseph', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 5, 'trainerSpecialization': ['.NET', 'Data Science', 'Interaction Design', 'Agile Product Management']}
# {'userId': 'Emp_159', 'trainerName': 'Ashley', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 1, 'trainerSpecialization': ['Python', 'Wireframing', 'Angular', 'Network Security']}
# {'userId': 'Emp_160', 'trainerName': 'Tara', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 2, 'trainerSpecialization': ['Communication', 'NoSQL', 'Interaction Design', 'Continuous Deployment']}
# {'userId': 'Emp_161', 'trainerName': 'Michael', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 5, 'trainerSpecialization': ['Test-Driven Development', 'Leadership', 'Django', 'Swift']}
# {'userId': 'Emp_162', 'trainerName': 'Mackenzie', 'trainerDesignation': 'Product Manager', 'trainerRating': 4, 'trainerSpecialization': ['Business Analysis', 'Behavior-Driven Development', 'Technical Writing', 'PHP']}
# {'userId': 'Emp_163', 'trainerName': 'Janet', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 2, 'trainerSpecialization': ['Vue.js', 'Kotlin', 'Penetration Testing', 'Prototyping']}
# {'userId': 'Emp_164', 'trainerName': 'Shawn', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Kotlin', 'Leadership', 'Vue.js', 'Python']}
# {'userId': 'Emp_165', 'trainerName': 'Brittany', 'trainerDesignation': 'Network Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Ruby', 'Kotlin', 'CI/CD', 'Data Science']}
# {'userId': 'Emp_166', 'trainerName': 'Robin', 'trainerDesignation': 'Agile Coach', 'trainerRating': 1, 'trainerSpecialization': ['PHP', 'User Stories', 'Business Analysis', 'Vue.js']}
# {'userId': 'Emp_167', 'trainerName': 'Eric', 'trainerDesignation': 'Backend Developer', 'trainerRating': 1, 'trainerSpecialization': ['Penetration Testing', 'React', 'SQL', 'Data Science']}
# {'userId': 'Emp_168', 'trainerName': 'Craig', 'trainerDesignation': 'Technical Architect', 'trainerRating': 2, 'trainerSpecialization': ['User Research', 'Penetration Testing', 'UI/UX Design', 'Docker']}
# {'userId': 'Emp_169', 'trainerName': 'Vernon', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 3, 'trainerSpecialization': ['Scrum', 'User Research', 'Requirements Analysis', 'Data Analysis']}
# {'userId': 'Emp_170', 'trainerName': 'Daniel', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 3, 'trainerSpecialization': ['Continuous Deployment', 'Data Visualization', 'Penetration Testing', 'Java']}
# {'userId': 'Emp_171', 'trainerName': 'Courtney', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 3, 'trainerSpecialization': ['Business Analysis', 'Support', 'User Stories', 'Accessibility']}
# {'userId': 'Emp_172', 'trainerName': 'Edwin', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 3, 'trainerSpecialization': ['Containerization', 'C#', 'DevOps', 'PostgreSQL']}
# {'userId': 'Emp_173', 'trainerName': 'Johnny', 'trainerDesignation': 'Frontend Developer', 'trainerRating': 5, 'trainerSpecialization': ['User Research', 'Prototyping', 'Agile Product Management', 'PostgreSQL']}
# {'userId': 'Emp_174', 'trainerName': 'Jose', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 5, 'trainerSpecialization': ['Azure', 'Git', 'User Stories', 'Interaction Design']}
# {'userId': 'Emp_175', 'trainerName': 'Brooke', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 4, 'trainerSpecialization': ['Ruby', 'Communication', 'GraphQL', 'Flask']}
# {'userId': 'Emp_176', 'trainerName': 'Jennifer', 'trainerDesignation': 'Data Scientist', 'trainerRating': 2, 'trainerSpecialization': ['Google Cloud Platform', 'Responsive Design', 'Network Security', 'Behavior-Driven Development']}
# {'userId': 'Emp_177', 'trainerName': 'Elizabeth', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 1, 'trainerSpecialization': ['Continuous Integration', 'React', 'Node.js', 'Collaboration']}
# {'userId': 'Emp_178', 'trainerName': 'Marissa', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Django', 'Troubleshooting', 'Python', 'Java']}
# {'userId': 'Emp_179', 'trainerName': 'Carolyn', 'trainerDesignation': 'Full-stack Developer', 'trainerRating': 3, 'trainerSpecialization': ['SQL', 'Data Analysis', 'Kubernetes', 'Docker']}
# {'userId': 'Emp_180', 'trainerName': 'Brian', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Scrum', 'C#', 'Data Visualization', 'AWS']}
# {'userId': 'Emp_181', 'trainerName': 'Hannah', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 2, 'trainerSpecialization': ['React', 'Angular', 'JavaScript', 'Azure']}
# {'userId': 'Emp_182', 'trainerName': 'Aaron', 'trainerDesignation': 'Technical Architect', 'trainerRating': 4, 'trainerSpecialization': ['Test-Driven Development', 'Scrum', 'Network Security', 'Technical Writing']}
# {'userId': 'Emp_183', 'trainerName': 'Kelly', 'trainerDesignation': 'Technical Architect', 'trainerRating': 5, 'trainerSpecialization': ['Network Security', 'Information Security', 'PostgreSQL', 'Continuous Deployment']}
# {'userId': 'Emp_184', 'trainerName': 'Stephanie', 'trainerDesignation': 'Data Scientist', 'trainerRating': 3, 'trainerSpecialization': ['Vue.js', 'AWS', 'MongoDB', 'Kotlin']}
# {'userId': 'Emp_185', 'trainerName': 'Mark', 'trainerDesignation': 'Technical Architect', 'trainerRating': 1, 'trainerSpecialization': ['Python', 'PostgreSQL', 'Communication', 'Flask']}
# {'userId': 'Emp_186', 'trainerName': 'Mary', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 2, 'trainerSpecialization': ['Data Analysis', 'Objective-C', 'Flask', 'Ruby']}
# {'userId': 'Emp_187', 'trainerName': 'John', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 4, 'trainerSpecialization': ['Azure', 'Data Analysis', 'Statistical Analysis', 'Behavior-Driven Development']}
# {'userId': 'Emp_188', 'trainerName': 'Debra', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 3, 'trainerSpecialization': ['Information Security', 'Artificial Intelligence', 'Responsive Design', 'Data Visualization']}
# {'userId': 'Emp_189', 'trainerName': 'Christopher', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Test-Driven Development', 'Troubleshooting', 'Scrum', 'Product Management']}
# {'userId': 'Emp_190', 'trainerName': 'Johnny', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Microservices', 'Support', 'Scrum', 'Prototyping']}
# {'userId': 'Emp_191', 'trainerName': 'Christine', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Kubernetes', 'SQL', 'Test-Driven Development', 'GraphQL']}
# {'userId': 'Emp_192', 'trainerName': 'Rachel', 'trainerDesignation': 'Scrum Master', 'trainerRating': 3, 'trainerSpecialization': ['PostgreSQL', 'NoSQL', 'Cybersecurity', 'CI/CD']}
# {'userId': 'Emp_193', 'trainerName': 'Jacob', 'trainerDesignation': 'IT Administrator', 'trainerRating': 3, 'trainerSpecialization': ['Data Visualization', 'Python', 'Penetration Testing', 'MongoDB']}
# {'userId': 'Emp_194', 'trainerName': 'Michael', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 2, 'trainerSpecialization': ['Wireframing', 'Problem Solving', 'C#', 'UI/UX Design']}
# {'userId': 'Emp_195', 'trainerName': 'Allison', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 4, 'trainerSpecialization': ['Cybersecurity', 'DevOps', 'Cryptography', 'Requirements Analysis']}
# {'userId': 'Emp_196', 'trainerName': 'Todd', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Support', 'Containerization', '.NET', 'Angular']}
# {'userId': 'Emp_197', 'trainerName': 'Frank', 'trainerDesignation': 'Business Analyst', 'trainerRating': 3, 'trainerSpecialization': ['DevOps', 'RESTful API', 'Swift', 'MySQL']}
# {'userId': 'Emp_198', 'trainerName': 'Tina', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 3, 'trainerSpecialization': ['Kotlin', 'Penetration Testing', 'Google Cloud Platform', 'Information Security']}
# {'userId': 'Emp_199', 'trainerName': 'Olivia', 'trainerDesignation': 'Scrum Master', 'trainerRating': 1, 'trainerSpecialization': ['Leadership', 'UI/UX Design', 'Accessibility', 'GraphQL']}

# %%
# Write data to CSV file
csv_file_path = "trainer_data.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for user_data in fake_data_list:
        writer.writerow(user_data)

print(f"User data has been saved to {csv_file_path}")
# Out:
# User data has been saved to trainer_data.csv

# %%
from datetime import timedelta
fake_data_list = []

# Define the list of possible training names
training_names = [
    "Introduction to Python Programming",
    "Web Development Fundamentals",
    "Data Science Essentials",
    "Machine Learning Basics",
    "Introduction to JavaScript",
    "Frontend Development with React",
    "Backend Development with Node.js",
    "Database Management with MongoDB",
    "Cloud Computing Fundamentals",
    "Cybersecurity Essentials",
]

# Generate fake data
for i in range(1, 100):
    certificates = random.sample(training_names, 4)
    start_date = fake.date_this_decade()
    end_date = start_date + timedelta(days=random.randint(5, 10))  # Random end date 5 to 10 days ahead
    training_data = {
        "trainingId": "Training_" + str(i),
        "trainingName": fake.random_element(elements=certificates),
        "trainingDescription": fake.sentence(),
        "trainerId": "Emp_" + str(i),
        "trainerName": fake.name(),
        "startDate": start_date,
        "endDate": end_date,
        "optimizedDuration": fake.random_int(min=1, max=40),
        "createdAt": fake.date_time_this_year(),
    }
    fake_data_list.append(training_data)

# Write data to CSV file
csv_file_path = "training_data.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for training_data in fake_data_list:
        writer.writerow(training_data)

print(f"Training data has been saved to {csv_file_path}")
# Out:
# Training data has been saved to training_data.csv

# %%
import csv
import random
from faker import Faker

fake = Faker()

fake_data_list = []

# Define the list of possible quiz names
quiz_names = [
    "Introduction to Python Quiz",
    "Web Development Fundamentals Quiz",
    "Data Science Essentials Quiz",
    "Machine Learning Basics Quiz",
    "Introduction to JavaScript Quiz",
    "Frontend Development with React Quiz",
    "Backend Development with Node.js Quiz",
    "Database Management with MongoDB Quiz",
    "Cloud Computing Fundamentals Quiz",
    "Cybersecurity Essentials Quiz"
]

# Define the list of possible file names for questions
question_files = [
    "questions1.csv",
    "questions2.csv",
    "questions3.csv",
    "questions4.csv",
    "questions5.csv"
]

# Generate fake data
for i in range(1, 100):
    quiz_data = {
        "quizName": fake.random_element(elements=quiz_names),
        "trainingId": "Training_" + str(i),
        "trainingName": fake.sentence(),
        "maxScores": fake.random_int(min=100, max=100),
        "minScores": fake.random_int(min=50, max=50),
        "difficultyLevel": fake.random_element(elements=("easy", "moderate", "hard")),
        "questionFile": fake.random_element(elements=question_files),
    }
    fake_data_list.append(quiz_data)

# Write data to CSV file
csv_file_path = "quiz_data.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for quiz_data in fake_data_list:
        writer.writerow(quiz_data)

print(f"Quiz data has been saved to {csv_file_path}")
# Out:
# Quiz data has been saved to quiz_data.csv

# %%
import csv
import random
from faker import Faker

fake = Faker()

fake_data_list = []

# Define the list of possible training statuses
training_statuses = ['pending', 'in_progress', 'completed']

# Generate fake data
for i in range(1, 1000):
    training_status = fake.random_element(elements=training_statuses)
    if training_status == 'pending':
        assessment_percentage_done = 0
        assessment_completion_time_in_hours= None
    elif training_status == 'completed':
        assessment_percentage_done = 100
        assessment_completion_time_in_hours = fake.random_int(min=1, max=60)
    else:
        assessment_percentage_done = fake.random_int(min=0, max=100)
        assessment_completion_time_in_hours = fake.random_int(min=0, max=60)
        
    if training_status in ['pending', 'in_progress']:
        score_achieved_in_quiz = None
        quiz_passed_or_failed = None
    else:
        score_achieved_in_quiz = fake.random_int(min=0, max=100)
        if score_achieved_in_quiz < 50:
            quiz_passed_or_failed = 'failed'
        else:
            quiz_passed_or_failed = 'passed'
        
    training_id = fake.random_int(min=1, max=100)
    trainer_id = fake.random_int(min=1, max=100)
    user_id = fake.random_int(min=1, max=200)
    
    tracker_data = {
        "userId": "Emp_" + str(user_id),
        "trainingId": "Training_" + str(training_id),
        "trainerId": "Emp_" + str(trainer_id),
        "trainingStatus": training_status,
        "assessment_percentage_done": assessment_percentage_done,
        "assessment_completion_time_in_hours": assessment_completion_time_in_hours,
        "scoreAchievedInQuiz": score_achieved_in_quiz,
        "quizPassedOrFailed": quiz_passed_or_failed,
        "ratingGivenByTrainer": fake.random_int(min=1, max=5),
    }
    fake_data_list.append(tracker_data)

# Write data to CSV file
csv_file_path = "tracker_data1.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = ["userId", "trainingId", "trainerId", "trainingStatus", "assessment_percentage_done", 
                  "assessment_completion_time_in_hours", "scoreAchievedInQuiz", "quizPassedOrFailed", 
                  "ratingGivenByTrainer"]
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for tracker_data in fake_data_list:
        writer.writerow(tracker_data)

print(f"Tracker data has been saved to {csv_file_path}")
# Out:
# Tracker data has been saved to tracker_data1.csv

# %%
import csv
import pandas as pd

# %%
df = pd.DataFrame(user_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.DataFrame(user_data[0])
#
# KeyError: 0

# %%
import pandas as pd

num_records=pd.read_csv('Project.userdetails.csv')

# %%
df=pd.DataFrame(num_records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 2
#       1 df=pd.DataFrame(num_records)
# ----> 2 iloc.df[1]
#
# NameError: name 'iloc' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7748\1395128912.py in ?()
#       1 fake_data_list=df['Empid']
# ----> 2 fake_data_list.removenull()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'removenull'

# %%
num_records
import rand

# %%
skills = [
    "Python", "JavaScript", "HTML", "CSS", "React", "Angular", "Vue.js", "Node.js", "Django", "Flask",
    "Java", "Kotlin", "Swift", "Objective-C", "C#", ".NET", "PHP", "Ruby", "SQL", "NoSQL",
    "MongoDB", "MySQL", "PostgreSQL", "Git", "Docker", "Kubernetes", "AWS", "Azure", "Google Cloud Platform",
    "RESTful API", "GraphQL", "CI/CD", "Agile Methodologies", "Scrum", "Test-Driven Development",
    "Behavior-Driven Development", "DevOps", "Continuous Integration", "Continuous Deployment", "Microservices",
    "Containerization", "Machine Learning", "Artificial Intelligence", "Data Science", "Data Analysis",
    "Data Visualization", "Statistical Analysis", "Cybersecurity", "Network Security", "Penetration Testing",
    "Cryptography", "Information Security", "UI/UX Design", "Wireframing", "Prototyping", "User Research",
    "Interaction Design", "Responsive Design", "Accessibility", "Product Management", "Agile Product Management",
    "Requirements Analysis", "User Stories", "Business Analysis", "Technical Writing", "Documentation",
    "Support", "Troubleshooting", "Problem Solving", "Communication", "Collaboration", "Leadership"
]

# %%
 data = []
for i in fake_data_list:
    empid = i
    certificates = random.sample(skills, 4)  # Pick 4 unique certificates randomly
    for certificate in certificates:
        record = {
            "Empid": empid,
            "certificateName": certificate,
            "issuingOrganization": fake.company(),
            "issueDate": fake.date(),
            "ExpireDate": fake.future_date(),
            "credentialID": fake.uuid4(),
            "Status": random.choice(["Approved", "Rejected"])
        }
        data.append(record)

# %%
df=pd.DataFrame(data)

# %%
df.to_csv('certificateData.csv')

# %%
projects = [
    "PixelPlex Crypto Trader",
    "BlueFinity Evoke",
    "CyberCode Online Store",
    "TechTrek Data Analyzer",
    "ByteBlitz Document Manager",
    "NexGen Mobile Scheduler",
    "Streamline Solutions CRM",
    "DataLink Inventory Tracker",
    "SilverLinx POS System",
    "EchoTech Task Manager",
    "CodeCraft Web Builder",
    "FusionSoft Email Client",
    "LogicLane Project Tracker",
    "VortexVision Virtual Assistant",
    "InnovateSoft Budget Planner",
    "DataForge Dashboard Creator",
    "SwiftShift Time Tracker",
    "MetaMind Chatbot Builder",
    "TechNova Backup Solution",
    "QuickTech Remote Support",
    "CatalystCommerce",
    "DataSync",
    "AgileFlow",
    "InnovatePro",
    "ByteBoost",
    "PixelWare",
    "DataPulse",
    "CyberLink",
    "SwiftWave",
    "TechSprint",
    "InnovaTech",
    "DataBridge",
    "PixelWorks",
    "CyberTech",
    "CodeCraft",
    "AgileWare",
    "ByteForge",
    "PixelPulse",
    "DataCraft",
    "TechSpark",
    "SwiftCode",
    "AgileTech",
    "DataWave"
]

# %%
project_types = [
    "Web Application",
    "Mobile App",
    "Desktop Software",
    "CRM System",
    "Inventory Management System",
    "E-commerce Platform",
    "Content Management System",
    "Task Management Tool",
    "Email Client",
    "Document Management System",
    "Chatbot",
    "Virtual Assistant",
    "Budget Planner",
    "Dashboard Creator",
    "Time Tracking Tool",
    "POS System",
    "Backup Solution",
    "Remote Support Tool",
    "Crypto Trader",
    "Data Analyzer",
    "Social Networking Platform",
    "Online Marketplace",
    "Customer Service Software",
    "Payment Gateway",
    "Booking System",
    "Learning Management System",
    "Customer Relationship Management",
    "Project Management Software",
    "Human Resource Management System",
    "Inventory Control System",
    "Event Management Software",
    "Appointment Scheduling Software",
    "Survey Software",
    "Healthcare Management System",
    "Sales Forecasting Software",
    "Accounting Software",
    "Asset Management System",
    "Content Delivery Network",
    "Data Visualization Tool",
    "Educational Software",
    "Fleet Management System",
    "Help Desk Software",
    "Retail Management System",
    "Supply Chain Management Software",
    "Ticketing System",
    "Warehouse Management System",
    "Workflow Management Software"
]

# %%
project_roles = [
    "Developer",
    "Designer",
    "Project Manager",
    "Quality Assurance Engineer",
    "Business Analyst",
    "DevOps Engineer",
    "Database Administrator",
    "Technical Architect",
    "UI/UX Designer",
    "Product Manager",
    "Network Engineer",
    "Cybersecurity Specialist",
    "Data Scientist",
    "Machine Learning Engineer",
    "Artificial Intelligence Engineer",
    "Cloud Solutions Architect",
    "Technical Writer",
    "IT Support Specialist",
    "Release Manager",
    "Configuration Manager",
    "Automation Tester",
    "Performance Engineer"
]

# %%
project1 = random.sample(projects, 4)
project1
# Out:
# ['DataCraft', 'CodeCraft', 'NexGen Mobile Scheduler', 'InnovaTech']

# %%
data = []
for i in fake_data_list:
    empid = i
    project = random.sample(projects, 4)  # Pick 4 unique certificates randomly
    for pro in project:
        record = {
            "Empid": empid,
            "projectName": pro,
            "projectType": random.choice(project_types),
            "description": fake.text(),
            "startDate": fake.date(),
            "endDate": fake.future_date(),
            "role": random.choice(project_roles),
            "Status": random.choice(["Approved", "Rejected"])
        }
        data.append(record)

# %%
  data
# Out:
# [{'Empid': 'Emp_0',
#   'projectName': 'PixelPulse',
#   'projectType': 'Document Management System',
#   'description': 'Window agent season consumer ahead. Benefit bring imagine.',
#   'startDate': '1992-01-12',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'IT Support Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_0',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Human Resource Management System',
#   'description': 'Edge how customer. This trade treatment science read than check gas. Ahead act might everything. Appear rise generation kitchen letter degree station.\nMost sit west population send book whole.',
#   'startDate': '1976-05-11',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_0',
#   'projectName': 'AgileTech',
#   'projectType': 'Web Application',
#   'description': 'Push government think. Nothing parent age.\nYet study rich thus door tell tree. Happen wife age hear movie election.\nMust somebody expert compare necessary vote campaign. Sometimes read environmental.',
#   'startDate': '1972-04-07',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_0',
#   'projectName': 'DataPulse',
#   'projectType': 'Accounting Software',
#   'description': 'Month close truth hard. Morning form control. Amount pay smile after seek nothing behavior result.\nThree act field true cover.',
#   'startDate': '2000-01-08',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'InnovaTech',
#   'projectType': 'Retail Management System',
#   'description': 'If doctor open several people per. Bar later air positive their. One thousand someone unit air.',
#   'startDate': '1972-01-15',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'DataBridge',
#   'projectType': 'Document Management System',
#   'description': 'Ever exactly rock street. Least life too notice network. Official its yet notice task as.',
#   'startDate': '2012-01-01',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'InnovatePro',
#   'projectType': 'Budget Planner',
#   'description': 'Capital human edge ever likely stock stock any. Ahead quality executive choice what. Discuss research product describe father factor.',
#   'startDate': '2016-11-08',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Release Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'AgileWare',
#   'projectType': 'Content Management System',
#   'description': 'Court present machine candidate get pick. Floor know might live.',
#   'startDate': '2016-08-27',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_2',
#   'projectName': 'ByteBoost',
#   'projectType': 'Event Management Software',
#   'description': 'Throw international hand. Education coach talk. Side second act including effect lose probably wind.\nReflect property beat similar. Hand number green American religious various necessary draw.',
#   'startDate': '1978-11-27',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_2',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Booking System',
#   'description': 'Spend buy accept yourself many president another. This executive there hear realize think. Most pattern stay term pressure sea.\nBy seek popular see wrong.',
#   'startDate': '1985-04-30',
#   'endDate': datetime.date(2024, 4, 10),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_2',
#   'projectName': 'InnovatePro',
#   'projectType': 'Virtual Assistant',
#   'description': 'Unit plan on course ahead brother. Far too west director very guy. Again least behavior organization form family boy. Scene color physical skin authority everybody attack.',
#   'startDate': '1981-08-11',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Developer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_2',
#   'projectName': 'CodeCraft',
#   'projectType': 'Inventory Control System',
#   'description': 'Cold price research end difficult.\nBeyond majority notice bill role. Discover while at three various think.',
#   'startDate': '1986-09-28',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_3',
#   'projectName': 'SwiftWave',
#   'projectType': 'Crypto Trader',
#   'description': 'Growth speech find specific happy conference. Top issue figure world situation drug worry. Leg force someone quite matter.',
#   'startDate': '1990-09-08',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_3',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Customer Service Software',
#   'description': 'Maybe international still notice develop operation.\nTelevision speech future dinner wind. Person decision again politics range Mr group. House for huge mother opportunity investment.',
#   'startDate': '1973-07-12',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'UI/UX Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_3',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Human Resource Management System',
#   'description': 'New class hit without when amount suggest. Happen official scene may power early woman. Space charge charge whose.',
#   'startDate': '1977-08-18',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_3',
#   'projectName': 'TechSpark',
#   'projectType': 'Chatbot',
#   'description': 'Something next PM send finally two.\nGeneration color human yeah truth conference the. Yet more lot expect determine traditional know. Boy play give put form letter response.',
#   'startDate': '2023-03-11',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_4',
#   'projectName': 'BlueFinity Evoke',
#   'projectType': 'Customer Service Software',
#   'description': 'Dark rule together garden travel them. Remember president citizen seem officer doctor amount for.',
#   'startDate': '2000-03-30',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_4',
#   'projectName': 'TechSprint',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Congress happen nice level short Democrat. Person suffer visit power just near group.',
#   'startDate': '2019-03-12',
#   'endDate': datetime.date(2024, 5, 1),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_4',
#   'projectName': 'QuickTech Remote Support',
#   'projectType': 'POS System',
#   'description': 'Or question middle ever behavior matter experience skill. Beat evidence house. Down shoulder dream fight.\nMan entire account yourself focus decision employee. She property picture cell woman stand.',
#   'startDate': '1984-01-10',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Artificial Intelligence Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_4',
#   'projectName': 'DataForge Dashboard Creator',
#   'projectType': 'Booking System',
#   'description': 'Policy collection above movement. Young also rate type big candidate political culture.\nA among value feel newspaper. System show although stock like. Stop amount kid board.',
#   'startDate': '1989-03-22',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_5',
#   'projectName': 'AgileFlow',
#   'projectType': 'Payment Gateway',
#   'description': 'Personal land page garden. Some player so push year. Step test industry.\nFloor million happen relate doctor like. Window plant send new ever situation. Understand stand place senior sport.',
#   'startDate': '1988-08-18',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Release Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_5',
#   'projectName': 'PixelPlex Crypto Trader',
#   'projectType': 'Payment Gateway',
#   'description': 'Finally we agent put church dream themselves whom. Side same teach pressure.\nEnjoy administration feel. These fill finish bed big good. Wish return democratic way also.',
#   'startDate': '1975-09-19',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_5',
#   'projectName': 'AgileWare',
#   'projectType': 'Learning Management System',
#   'description': 'Stop often race. Take attack result have. Become of officer whether simply. Idea sort enough.\nIncluding stand should cup budget. Perhaps total suffer smile dog. Each value effect method purpose join.',
#   'startDate': '2016-09-07',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_5',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Project Management Software',
#   'description': 'Send science safe lawyer store. Alone maintain season doctor.\nArea thousand feeling care their economy officer. Indicate authority happy morning article two senior.',
#   'startDate': '1977-01-12',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_6',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'Task Management Tool',
#   'description': 'Work service part firm. Economic toward join evening indeed environment western. Hair any off federal focus them everything.',
#   'startDate': '1985-06-05',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_6',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Dashboard Creator',
#   'description': 'Congress entire benefit. Television defense why surface catch. Firm quality center manager one.\nTotal summer wide. Space realize always meet approach country mouth.',
#   'startDate': '1995-10-03',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Data Scientist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_6',
#   'projectName': 'TechSpark',
#   'projectType': 'Event Management Software',
#   'description': 'Health condition front worry million order. Prove wall impact. Glass under address series sign American majority.\nInstead pressure mother great action real star. Stand everybody staff authority thus.',
#   'startDate': '1973-01-26',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'IT Support Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_6',
#   'projectName': 'PixelWorks',
#   'projectType': 'Budget Planner',
#   'description': 'Evening stand agree adult. Nor might business.\nProperty ask reason cover thank natural change. Necessary a son early join country store.',
#   'startDate': '1984-04-16',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_7',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Event Management Software',
#   'description': 'Although brother cost mind law. List matter whatever rock quality industry season. Drop section maintain begin.',
#   'startDate': '1992-01-25',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_7',
#   'projectName': 'MetaMind Chatbot Builder',
#   'projectType': 'Healthcare Management System',
#   'description': 'Wonder some apply ask loss increase imagine experience. Customer discover eye generation growth his.\nPicture ball light. Every fear reach investment staff really.',
#   'startDate': '1999-08-31',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_7',
#   'projectName': 'QuickTech Remote Support',
#   'projectType': 'E-commerce Platform',
#   'description': 'Attack be major sure financial long bar. Rock page once on rather you produce. See none indeed character room glass.\nFood manager feel store find science. War front person want man.',
#   'startDate': '1982-02-23',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'UI/UX Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_7',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Asset Management System',
#   'description': 'Imagine book lose. Fish network attention fact store along body. Often wide strategy not challenge.\nBlood up American seek. Assume back instead adult.',
#   'startDate': '2015-07-26',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'UI/UX Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_8',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Booking System',
#   'description': 'Particular road before two image she. Trial various decision drive. Range other should sea society remember. Institution professional parent easy exactly hundred own coach.',
#   'startDate': '1983-08-26',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_8',
#   'projectName': 'DataCraft',
#   'projectType': 'Data Analyzer',
#   'description': 'Air girl new talk treatment skill activity. Protect article attention would.',
#   'startDate': '2022-01-10',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_8',
#   'projectName': 'AgileTech',
#   'projectType': 'Customer Service Software',
#   'description': 'Sign town mean traditional significant.\nEven nearly cover result. Next nature before TV.\nBorn than pick realize yeah. Actually direction responsibility program left which.',
#   'startDate': '1972-10-12',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_8',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Human Resource Management System',
#   'description': 'Accept rate finish note travel wear throw. This hand sport interview everybody. Water enjoy music make.\nMean read require age.',
#   'startDate': '1977-12-26',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Project Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'CyberCode Online Store',
#   'projectType': 'Human Resource Management System',
#   'description': 'Blood last half firm. Expert miss wear card use find investment. American radio line green environment here bill.',
#   'startDate': '2018-03-18',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'DataWave',
#   'projectType': 'Accounting Software',
#   'description': 'Site play local somebody drive forget Mrs. Main phone hot beat forward difficult.\nOnce teacher film pay. Across child economy each.',
#   'startDate': '1990-07-08',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Release Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Fleet Management System',
#   'description': 'Together car pressure some where must action. Listen test friend last exactly. Face article short cover as write region.',
#   'startDate': '1992-07-10',
#   'endDate': datetime.date(2024, 4, 10),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'InnovaTech',
#   'projectType': 'Document Management System',
#   'description': 'Data suffer message laugh media well behind.\nAgo and serious marriage. Near almost bank arm station car. Apply peace option during without recognize enter.',
#   'startDate': '1998-07-25',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_10',
#   'projectName': 'PixelWorks',
#   'projectType': 'Sales Forecasting Software',
#   'description': 'Full entire view detail option member. Process power majority check amount officer pattern crime. Fill here especially enjoy party.',
#   'startDate': '1998-07-21',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'UI/UX Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_10',
#   'projectName': 'TechTrek Data Analyzer',
#   'projectType': 'Survey Software',
#   'description': 'Stuff small light teacher everybody up nearly.\nReach them admit number avoid enough. Performance of PM perform cup fight. Most represent approach.',
#   'startDate': '2004-08-23',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'Technical Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_10',
#   'projectName': 'AgileFlow',
#   'projectType': 'Web Application',
#   'description': 'People from determine time democratic dog. Alone wait although name leader.\nHis Mr cost wall. Rock physical impact film daughter best amount.',
#   'startDate': '2010-01-28',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_10',
#   'projectName': 'VortexVision Virtual Assistant',
#   'projectType': 'Content Delivery Network',
#   'description': 'Decade stop including wish put down poor. Minute institution reach nation build last. Fire anything financial sure method far size.',
#   'startDate': '2004-11-06',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_11',
#   'projectName': 'DataWave',
#   'projectType': 'Fleet Management System',
#   'description': 'Key beyond between.\nBase side father. General bank five five cover.\nHuge rate probably reach possible. Son drop account begin recent lay recognize. Election medical card play maintain rich more part.',
#   'startDate': '1976-10-02',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_11',
#   'projectName': 'PixelWare',
#   'projectType': 'Mobile App',
#   'description': 'Low million view whom increase much guess door. Bad particular sure television development firm.',
#   'startDate': '1991-11-08',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_11',
#   'projectName': 'AgileFlow',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Seek reach official hold. Leg animal different cold business look tonight with.\nAccept truth over number network each great. Letter nice help behavior man realize.',
#   'startDate': '2003-01-28',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_11',
#   'projectName': 'SilverLinx POS System',
#   'projectType': 'Inventory Control System',
#   'description': 'Performance above open.\nThese card positive cost medical agency like. Father official here.',
#   'startDate': '1986-05-20',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_12',
#   'projectName': 'ByteBoost',
#   'projectType': 'Healthcare Management System',
#   'description': 'Ahead health us prevent science strategy middle. Language surface budget political woman help fall eat.\nBut with clearly significant group summer same.',
#   'startDate': '1992-02-14',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_12',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Chatbot',
#   'description': 'Apply a every hit board pass. Per because budget. Mrs exactly character list again husband. Write outside present offer general natural.',
#   'startDate': '1977-10-04',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Technical Writer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_12',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Warehouse Management System',
#   'description': 'Participant song left order some worker.\nParent moment skill agent modern explain he. These its win.',
#   'startDate': '1971-11-06',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_12',
#   'projectName': 'PixelPulse',
#   'projectType': 'Educational Software',
#   'description': 'Respond away evening certain agree movie.\nLeast agree dog way memory right. Mission better drug design book. Some what game job budget.',
#   'startDate': '2022-06-16',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'FusionSoft Email Client',
#   'projectType': 'E-commerce Platform',
#   'description': 'Southern half far. Open actually future interview officer late instead commercial. As meeting federal maybe drug day miss.',
#   'startDate': '1997-11-06',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'SilverLinx POS System',
#   'projectType': 'Asset Management System',
#   'description': 'His choice character image high turn sort speak.\nLine customer form debate act. Public worker lose detail between instead. Any service behavior environmental south.',
#   'startDate': '1971-04-03',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Accounting Software',
#   'description': 'Buy report health positive term. Plant dinner lawyer. Product full keep guy buy.\nEven scene best coach. Game green involve blue get control. Culture until effect hope try TV.',
#   'startDate': '1970-11-06',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Event Management Software',
#   'description': 'Themselves lawyer trouble pull authority television now. Writer purpose impact begin within box itself.\nAmerican do this conference your possible. Participant first start contain clearly.',
#   'startDate': '2017-03-08',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_14',
#   'projectName': 'InnovaTech',
#   'projectType': 'Educational Software',
#   'description': 'And common more including mind field during. Professor yourself read message protect finally lawyer.\nWatch clear audience include. Opportunity sense specific provide.',
#   'startDate': '1977-03-09',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_14',
#   'projectName': 'TechTrek Data Analyzer',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Seat protect surface yard particularly window attorney. Movie until wife yard.\nPresent manager thus couple any.',
#   'startDate': '1977-12-11',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_14',
#   'projectName': 'CyberCode Online Store',
#   'projectType': 'Inventory Management System',
#   'description': 'Still chance forward blood. Word dog pattern interesting.\nShe floor power sell. Drug argue wrong floor race. Already born fact real son course evidence.\nFive head each mention.',
#   'startDate': '2017-02-20',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_14',
#   'projectName': 'CyberLink',
#   'projectType': 'Asset Management System',
#   'description': 'Class of chance entire worker strategy.\nHealth memory their class today plant. Sell will contain boy century national meet.',
#   'startDate': '1996-08-06',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Release Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_15',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'POS System',
#   'description': 'Guy than conference would sound. Clearly when yet create within let cultural. Contain heart onto save large reason.\nSuccessful personal old issue. Mind interesting really part.',
#   'startDate': '1993-10-22',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Configuration Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_15',
#   'projectName': 'AgileFlow',
#   'projectType': 'Crypto Trader',
#   'description': 'Company whose chance commercial person name. Power home couple ability know.',
#   'startDate': '2014-09-12',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_15',
#   'projectName': 'AgileTech',
#   'projectType': 'Online Marketplace',
#   'description': 'Husband summer activity vote decade financial will. Movie how line local north similar. Start there Congress group follow. Stand ok thus peace another manage billion open.',
#   'startDate': '1975-04-23',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Data Scientist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_15',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Ticketing System',
#   'description': 'Improve adult throw lay might. Only star she improve owner three. Feeling front scene wrong actually total.',
#   'startDate': '1997-11-13',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_16',
#   'projectName': 'AgileFlow',
#   'projectType': 'Chatbot',
#   'description': 'Indicate red type ready task. Field author report opportunity international rich during. Rule interview tonight guess direction standard.\nOver fill add such. Nation include majority day feel behind.',
#   'startDate': '2001-10-07',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Product Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_16',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'Educational Software',
#   'description': 'Institution language weight show visit. Matter pass yourself smile recognize school.\nMessage security person no his clear campaign election.\nJob close apply.',
#   'startDate': '1988-08-19',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Technical Writer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_16',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Content Delivery Network',
#   'description': 'Imagine letter team language. Else say improve probably. Drop or beyond dog oil base.',
#   'startDate': '1993-04-19',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_16',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Time Tracking Tool',
#   'description': 'Under office not be. But positive interesting law western idea ahead.\nWhile data decade common machine. Part church material director long dinner. Easy film second choice join everyone.',
#   'startDate': '1990-07-05',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Artificial Intelligence Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_17',
#   'projectName': 'ByteForge',
#   'projectType': 'Data Analyzer',
#   'description': 'According behind anyone standard. Writer our level because fall feeling.\nFew measure media. Power avoid practice good population sea. Tv husband find company.',
#   'startDate': '2021-04-30',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_17',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'Online Marketplace',
#   'description': 'Take office service hour head especially. Agreement president work building rich say. Magazine Democrat image nothing. Price nature new create.',
#   'startDate': '2011-09-23',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_17',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Warehouse Management System',
#   'description': 'Million skill beyond behind condition perhaps. Operation enter artist. Heavy grow describe whom suggest power itself.',
#   'startDate': '2005-01-28',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_17',
#   'projectName': 'PixelWorks',
#   'projectType': 'Virtual Assistant',
#   'description': 'Explain reduce outside entire. Much audience system prove court dinner. Maintain soon arm behind.\nAuthor blood leader new skin ahead. Indeed might industry which paper alone.',
#   'startDate': '1970-01-07',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Artificial Intelligence Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_18',
#   'projectName': 'PixelPlex Crypto Trader',
#   'projectType': 'Educational Software',
#   'description': 'Enjoy bad spend. Positive street with officer administration part.\nImportant father follow machine then occur all. Site so commercial cost because. Scene perform tell compare to simple maybe study.',
#   'startDate': '1993-08-12',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Business Analyst',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_18',
#   'projectName': 'PixelWorks',
#   'projectType': 'Customer Service Software',
#   'description': 'Various much production all safe whatever per body. Customer everybody specific skill agency. Sense information produce do field cell.',
#   'startDate': '2007-05-29',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_18',
#   'projectName': 'DataWave',
#   'projectType': 'Content Delivery Network',
#   'description': 'Marriage still level tonight force size.\nFace wife majority machine eat my. Seek wait bad section service poor. Evening idea Mrs current nor election note. Like remain federal fire.',
#   'startDate': '2017-06-04',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_18',
#   'projectName': 'CatalystCommerce',
#   'projectType': 'Content Delivery Network',
#   'description': 'Suggest perhaps medical attorney capital. Central husband physical represent during factor. Father step fact animal civil remember force.\nBox water movement study arrive debate director.',
#   'startDate': '1997-09-18',
#   'endDate': datetime.date(2024, 5, 1),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_19',
#   'projectName': 'AgileFlow',
#   'projectType': 'Chatbot',
#   'description': 'Number similar skin yourself. Suggest big you usually side song kind marriage. Paper again off economic walk season.\nTrue look run toward allow all. Anyone operation decide less.',
#   'startDate': '2021-01-24',
#   'endDate': datetime.date(2024, 5, 1),
#   'role': 'DevOps Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_19',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Ticketing System',
#   'description': 'Stand miss special population recent treat account. Serve college lot situation blood chance already. Fight level believe though pressure.',
#   'startDate': '2016-01-28',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_19',
#   'projectName': 'VortexVision Virtual Assistant',
#   'projectType': 'Workflow Management Software',
#   'description': 'Property hold first important financial worry art year. Degree born whom against recently pull area serve.',
#   'startDate': '2009-11-07',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'DevOps Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_19',
#   'projectName': 'TechSprint',
#   'projectType': 'Task Management Tool',
#   'description': 'Capital now the successful middle follow note well.\nTraining enjoy tough close subject season hot. Person certain fly while enter by our. Speak dog save finish her method.\nOfficer standard dark ever.',
#   'startDate': '2009-02-23',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_20',
#   'projectName': 'DataPulse',
#   'projectType': 'Dashboard Creator',
#   'description': 'Stock matter total medical effect stop natural. Mission memory miss store everybody similar. Tv represent yard position.\nEvery money bad social cell. Need catch air send this than.',
#   'startDate': '1985-03-01',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_20',
#   'projectName': 'PixelPulse',
#   'projectType': 'Healthcare Management System',
#   'description': 'Billion traditional letter room company. Eat quite eye real. High let rule house. Two cost since woman far break.',
#   'startDate': '2020-04-02',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_20',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Remote Support Tool',
#   'description': 'Grow according happy consumer mind Mr director. Offer employee decision local race.',
#   'startDate': '2012-03-03',
#   'endDate': datetime.date(2024, 4, 10),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_20',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'E-commerce Platform',
#   'description': 'Respond daughter perhaps marriage range. Wife rock long human.\nThis make yet we. Card media find cost piece trouble. Head individual mind.',
#   'startDate': '1987-11-22',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_21',
#   'projectName': 'SwiftWave',
#   'projectType': 'Warehouse Management System',
#   'description': 'We message animal team town involve seven table. Place rather improve black scientist next enough role. Color where traditional owner fish film close. Receive easy owner performance coach.',
#   'startDate': '2007-08-13',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_21',
#   'projectName': 'CatalystCommerce',
#   'projectType': 'CRM System',
#   'description': 'Stand outside staff night actually almost lose. Involve city against process little meeting could. Church shake world time.\nMeeting medical culture. Campaign tax detail approach.',
#   'startDate': '2017-05-26',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_21',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Appointment Scheduling Software',
#   'description': 'Up job should green sign interview everyone. Star across show summer.\nHappy their get.\nThink get ground father suddenly. Second fire message.\nBag environmental moment look. High run right political.',
#   'startDate': '1976-01-14',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_21',
#   'projectName': 'TechSpark',
#   'projectType': 'Learning Management System',
#   'description': 'Practice hot easy collection buy. Network strong despite front. Professor travel decide include.\nDetermine wind strategy former how. Left bit scientist.',
#   'startDate': '2003-05-09',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_22',
#   'projectName': 'PixelWare',
#   'projectType': 'Asset Management System',
#   'description': 'Through per seek answer have street. Front building argue cut seven data. Leave history behind head.\nReady two yes write who.',
#   'startDate': '1991-01-04',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_22',
#   'projectName': 'PixelPulse',
#   'projectType': 'Workflow Management Software',
#   'description': 'Moment authority land place. Treat real movie send his in war budget.\nFederal another letter thus plant green available. Explain option among your. Sound close water station blood.',
#   'startDate': '2016-05-17',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Project Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_22',
#   'projectName': 'CyberCode Online Store',
#   'projectType': 'Customer Relationship Management',
#   'description': 'While whether gas minute should own. Sell unit road put agree grow. Give trouble rest.\nInside card box prevent gas standard apply would. Production range less bad go knowledge.',
#   'startDate': '1991-07-13',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_22',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Human Resource Management System',
#   'description': 'Its research language skin. Traditional left recently. Again phone want act.\nRoom return resource effect focus piece. Example admit fear career responsibility interesting.',
#   'startDate': '2023-10-30',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Technical Writer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_23',
#   'projectName': 'PixelWorks',
#   'projectType': 'CRM System',
#   'description': 'Decide little through. Trade candidate military movement. Summer particular party home.\nShould modern six fine. Second bit ball interest both cause.',
#   'startDate': '1982-07-05',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_23',
#   'projectName': 'CodeCraft',
#   'projectType': 'Retail Management System',
#   'description': 'Edge apply few road. Some realize service piece program.\nAdministration boy health green social conference. Forward public item suggest course stop send student.',
#   'startDate': '1977-07-30',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Performance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_23',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'CRM System',
#   'description': 'Clearly what open example which apply. Much only skin institution group country on.\nFact yeah both room yes animal. Mrs require represent early owner exactly include lawyer.',
#   'startDate': '2002-07-08',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_23',
#   'projectName': 'CatalystCommerce',
#   'projectType': 'Fleet Management System',
#   'description': 'Especially north season mission. Part set heart free rate. Past body store compare.\nAddress upon reflect government eat financial energy. Lot according improve safe receive quickly.',
#   'startDate': '2007-02-03',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_24',
#   'projectName': 'AgileFlow',
#   'projectType': 'Healthcare Management System',
#   'description': 'Matter stop woman thank yeah. Perhaps idea able lawyer quickly claim talk economic.\nSocial sometimes central attack. Protect interesting be traditional build. Certain stage population century give.',
#   'startDate': '1995-06-11',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_24',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Payment Gateway',
#   'description': 'Instead course example finish. No much notice president. Attack trial home woman news third.\nAccording training firm forward movie would. Capital maybe what TV cut. Think road beyond.',
#   'startDate': '2013-09-14',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_24',
#   'projectName': 'DataPulse',
#   'projectType': 'Inventory Management System',
#   'description': 'Baby course surface late bill. Social lead help common house management model. Democrat project despite card author role thousand.',
#   'startDate': '1994-05-05',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Business Analyst',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_24',
#   'projectName': 'SwiftCode',
#   'projectType': 'Supply Chain Management Software',
#   'description': 'About its approach realize respond sell leave. Service lay return learn billion recent relationship.\nExactly the professional after. Must bar major clear. Seat organization media never.',
#   'startDate': '1977-09-05',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Performance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_25',
#   'projectName': 'CyberLink',
#   'projectType': 'CRM System',
#   'description': 'Before new lay teach everything western. Study either hundred property to now. Tell knowledge part fish serve.\nSell produce garden leave. Individual where mission. According debate actually now six.',
#   'startDate': '2010-09-07',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_25',
#   'projectName': 'DataSync',
#   'projectType': 'Help Desk Software',
#   'description': 'According them federal there discuss people. Seem seek good computer.',
#   'startDate': '2002-09-06',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_25',
#   'projectName': 'FusionSoft Email Client',
#   'projectType': 'Crypto Trader',
#   'description': 'Citizen alone religious prevent. Early current check whom instead central.',
#   'startDate': '2024-02-11',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_25',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Virtual Assistant',
#   'description': 'Suggest international back green decide by. Mr Congress pull time message charge. Avoid more moment range can.\nSo Democrat structure middle reason top candidate. Air to these receive car.',
#   'startDate': '2004-12-26',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_26',
#   'projectName': 'ByteForge',
#   'projectType': 'Booking System',
#   'description': 'Event expect wish. Lot with stage early bed government human. Run too among employee discuss expect teach.\nWall road order travel bad. Red soon particular network bag by.',
#   'startDate': '2021-09-06',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_26',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'Booking System',
#   'description': 'Computer better turn start inside black. Down authority across think. Evidence low worry begin age manage move.\nHold protect again especially century out. Teach push decision reduce start red travel.',
#   'startDate': '2013-11-01',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_26',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'POS System',
#   'description': 'Image half building consumer car. Blood theory home purpose look professional. Spring tree crime officer they citizen could.',
#   'startDate': '1980-12-17',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_26',
#   'projectName': 'CyberLink',
#   'projectType': 'Accounting Software',
#   'description': 'Expect lay wind late. Inside figure government a blood.\nAt new score writer. Guess store husband along. Whether with doctor image find term one.',
#   'startDate': '1973-07-16',
#   'endDate': datetime.date(2024, 4, 29),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_27',
#   'projectName': 'CodeCraft',
#   'projectType': 'Crypto Trader',
#   'description': 'As Mrs simple man. Tv add include agency strategy they collection ground.\nSay north third life. Everything result crime pass. Have involve son world consumer Republican.',
#   'startDate': '1999-08-16',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_27',
#   'projectName': 'DataSync',
#   'projectType': 'Sales Forecasting Software',
#   'description': 'Ground article no. Avoid want floor true.\nExplain still beyond. Seven its cut agency standard pressure act. Still professional first cup.',
#   'startDate': '2012-01-07',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_27',
#   'projectName': 'BlueFinity Evoke',
#   'projectType': 'Fleet Management System',
#   'description': 'Back action four child. Reach shake mind seven rule show worker.\nCheck pass writer discuss. Bag beat yet hair left key seek. Number much free local.',
#   'startDate': '1997-03-22',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_27',
#   'projectName': 'PixelWare',
#   'projectType': 'Supply Chain Management Software',
#   'description': 'Program employee kitchen discover him. Gun at answer training line drive.\nDefense claim land of enjoy offer. Only source could religious resource service finish.',
#   'startDate': '2009-07-20',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_28',
#   'projectName': 'SwiftCode',
#   'projectType': 'Task Management Tool',
#   'description': 'Into believe north morning remain. That tree no general modern wear traditional.\nCut avoid hope anyone agency follow structure plant. Manage operation past bring executive job record.',
#   'startDate': '2004-09-19',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_28',
#   'projectName': 'DataBridge',
#   'projectType': 'POS System',
#   'description': 'Explain moment week TV stock show. Voice break treatment leg value fill.\nMuch turn represent seem increase purpose easy.\nSave stop her memory. Level probably force continue ok decision play.',
#   'startDate': '1977-02-24',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_28',
#   'projectName': 'TechTrek Data Analyzer',
#   'projectType': 'Social Networking Platform',
#   'description': 'Month eat ahead table own result quickly.\nBoy out four. Rate trial way. Operation see discuss condition field sense.\nManagement least west trial watch friend by. Challenge hope letter his.',
#   'startDate': '2016-08-30',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_28',
#   'projectName': 'DataCraft',
#   'projectType': 'Workflow Management Software',
#   'description': 'Short become part figure party mother question truth. Society certain as. Either go eight Republican west computer.',
#   'startDate': '1985-02-28',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Configuration Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_29',
#   'projectName': 'InnovaTech',
#   'projectType': 'Booking System',
#   'description': 'Each develop audience compare actually represent project. Read seem answer hair area return. Collection collection them current cause office interview. Out culture responsibility drop will on.',
#   'startDate': '1974-12-26',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_29',
#   'projectName': 'InnovatePro',
#   'projectType': 'Content Management System',
#   'description': 'Magazine service want common hair onto church analysis. Floor material run white reason.\nBoth section song yourself learn. According friend hard mean such student.',
#   'startDate': '2023-06-01',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Release Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_29',
#   'projectName': 'ByteForge',
#   'projectType': 'Customer Relationship Management',
#   'description': 'Part concern give none nation test same. Art run raise remain nice radio.\nKid trip himself. Expect expect leader some. Threat meet agent response. Author federal carry never.',
#   'startDate': '1990-02-25',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Performance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_29',
#   'projectName': 'AgileWare',
#   'projectType': 'Customer Service Software',
#   'description': 'Off other owner. Well difference chair food government.\nCall reflect list heart ever cup truth traditional. Project spend total shoulder film everybody near boy.',
#   'startDate': '1973-02-05',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_30',
#   'projectName': 'PixelWorks',
#   'projectType': 'Backup Solution',
# ...
#   'startDate': '2022-08-29',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_240',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Accounting Software',
#   'description': 'Especially situation bring we. Various article space detail best newspaper.\nHappen serve attention if drop five. Lead participant employee loss.',
#   'startDate': '2013-12-17',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Developer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_240',
#   'projectName': 'DataCraft',
#   'projectType': 'Warehouse Management System',
#   'description': 'Serious kind science environment table behind. This various tax thought arm pay.\nMember nature relate live improve. Class business important certain truth. Popular tonight view note.',
#   'startDate': '1996-03-29',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_240',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Document Management System',
#   'description': 'Which measure member technology pressure.\nEspecially agency offer dog. Also year cost land difference performance today.',
#   'startDate': '2018-05-26',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_241',
#   'projectName': 'DataBridge',
#   'projectType': 'Retail Management System',
#   'description': 'Name show strategy participant same main candidate. Art reality understand money give pretty save.\nNext you nation. Challenge house start TV.',
#   'startDate': '2021-10-21',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_241',
#   'projectName': 'DataPulse',
#   'projectType': 'Accounting Software',
#   'description': 'Dinner wait memory. War Mrs somebody could environmental daughter. Series camera management want moment such.',
#   'startDate': '1999-03-15',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_241',
#   'projectName': 'DataCraft',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Apply simply but use marriage road nature. Policy machine avoid recently rich away. Player perhaps out.\nParent wonder tax herself edge civil. Practice heart or. Art less give news.',
#   'startDate': '2001-08-12',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_241',
#   'projectName': 'ByteForge',
#   'projectType': 'Human Resource Management System',
#   'description': 'Behind blue method people. Painting as remain.\nPay television whole represent enter budget part. At when race relate none magazine design that.\nBag change huge. All career two too.',
#   'startDate': '2014-01-05',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Data Scientist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_242',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Ticketing System',
#   'description': 'Ability into join wife change human. Role strong week four. Bad great civil seem strategy between improve.\nMay box size white. Or four book.',
#   'startDate': '2017-06-08',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_242',
#   'projectName': 'AgileFlow',
#   'projectType': 'E-commerce Platform',
#   'description': 'Threat gas behind true away toward walk. Hard night personal where figure station after dog. Boy better nor represent.',
#   'startDate': '2019-12-24',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_242',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Warehouse Management System',
#   'description': 'Write claim physical treatment think. Herself example entire compare east eye friend. By then security month model center sound growth.',
#   'startDate': '2009-12-26',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Configuration Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_242',
#   'projectName': 'DataWave',
#   'projectType': 'Dashboard Creator',
#   'description': 'Adult mother security should speech detail eat. Member order couple opportunity see knowledge.',
#   'startDate': '2006-10-31',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_243',
#   'projectName': 'TechSprint',
#   'projectType': 'Content Delivery Network',
#   'description': 'Tonight police study. Detail southern together suggest.\nRecent commercial go finish between direction expert. Very boy wide break. Fly exist set style continue study.',
#   'startDate': '1988-07-05',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Technical Writer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_243',
#   'projectName': 'PixelWare',
#   'projectType': 'POS System',
#   'description': 'Build ability garden fall open. Project page popular Democrat clearly professor.\nStar add over coach section attack itself.\nDog process production eight discover. Environmental likely along like.',
#   'startDate': '2019-06-06',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_243',
#   'projectName': 'MetaMind Chatbot Builder',
#   'projectType': 'Time Tracking Tool',
#   'description': 'Watch how again along record increase. Later soon computer race ask about ago.',
#   'startDate': '2015-08-17',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Configuration Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_243',
#   'projectName': 'DataCraft',
#   'projectType': 'Project Management Software',
#   'description': 'Off watch report church word source. Wall movement question. Candidate agency security sister ground ground. Else everyone his grow determine quite.',
#   'startDate': '1997-11-03',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'PixelPlex Crypto Trader',
#   'projectType': 'Remote Support Tool',
#   'description': 'Week test defense agree white group have. Range rise source I reach hot month. Raise cold nothing listen significant.',
#   'startDate': '2018-04-09',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Workflow Management Software',
#   'description': 'Within current field husband camera down. Wonder pressure month.\nVarious return raise nation economy their day. At leg much onto speak.',
#   'startDate': '1993-12-06',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'SwiftCode',
#   'projectType': 'Fleet Management System',
#   'description': 'Thank international human boy set six young. Set image table officer myself interview old.\nDrive impact stand various fire east. Cover front reach job training allow month.',
#   'startDate': '1984-07-09',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'VortexVision Virtual Assistant',
#   'projectType': 'Healthcare Management System',
#   'description': 'Focus cup wrong evening finish by many without. Serve administration reality major special contain.',
#   'startDate': '1975-07-22',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'Online Marketplace',
#   'description': 'Attention fly I day current color research now. Share across language.\nCarry also your general specific always keep. Seat view although around industry just know statement. Your society wall way.',
#   'startDate': '2010-10-10',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Warehouse Management System',
#   'description': 'Item shoulder clearly ever. Their discussion everyone seek. Law fire choice memory.\nTeam Congress they worry. Cell try raise force. Like service teacher whose. Produce against debate score property.',
#   'startDate': '2010-01-05',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'DataCraft',
#   'projectType': 'Retail Management System',
#   'description': 'Small floor be theory quite tonight.',
#   'startDate': '1983-10-04',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Backup Solution',
#   'description': 'Court indeed understand hear discussion protect.\nFactor myself his through assume choose listen. Human able our run age.\nResponse cover some provide. Investment value clearly politics section say.',
#   'startDate': '1974-02-06',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_246',
#   'projectName': 'ByteForge',
#   'projectType': 'Online Marketplace',
#   'description': 'Alone bring PM agency me. Or member rest benefit.\nItem meet per score reality country. Staff condition process against. Away example pull dinner down investment cover.',
#   'startDate': '1977-05-22',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Business Analyst',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_246',
#   'projectName': 'SilverLinx POS System',
#   'projectType': 'Dashboard Creator',
#   'description': 'East home accept try per. Lay collection discuss.\nProfessor moment special whole. Entire instead where despite husband share local practice. Car analysis travel join choose report.',
#   'startDate': '1990-07-09',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Technical Writer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_246',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'POS System',
#   'description': 'School organization manager rate relationship. Pm along attack force.\nSome particularly growth concern. Heavy today including mind politics already parent.\nMedia each about decide.',
#   'startDate': '1985-08-29',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_246',
#   'projectName': 'DataPulse',
#   'projectType': 'Help Desk Software',
#   'description': 'Plant number expect she thing country simple. South create season reflect including population individual national.\nDraw system they ground. Top remember power rule. Quite piece a agent.',
#   'startDate': '1979-06-07',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_247',
#   'projectName': 'SwiftWave',
#   'projectType': 'Ticketing System',
#   'description': 'Official six ahead late resource few democratic. Current order behind source mention. Term main employee time man lose wide.\nLeast after could another. Contain guy growth current.',
#   'startDate': '1985-07-17',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_247',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Project Management Software',
#   'description': 'Money media their put would follow by. Rather although born call part movement.\nThose current feel force bit. Begin value couple lose southern lot. Watch later most stop.',
#   'startDate': '2021-03-04',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_247',
#   'projectName': 'InnovatePro',
#   'projectType': 'Healthcare Management System',
#   'description': 'Get movie personal nation.\nHeavy deal great drive. Card after either behind town fear market.\nLater bar arm. Player page learn degree must. Foot campaign experience occur their image your.',
#   'startDate': '1999-06-05',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_247',
#   'projectName': 'PixelPulse',
#   'projectType': 'Web Application',
#   'description': 'Food civil grow. Skin perhaps price some. Local heavy fund relate.\nReason people treat through answer performance executive project. Board star show task those house.',
#   'startDate': '2010-04-08',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_248',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Survey Software',
#   'description': 'Reason chance take whom. Third available player trip report little. Report for all authority.\nCongress drug ground practice chair. Air want despite. Rather new left.',
#   'startDate': '1998-12-11',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_248',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Retail Management System',
#   'description': 'Physical thought election day occur. Factor somebody foot evening policy form.\nLate even writer yet performance note. Raise deep defense common situation. Watch less weight world.',
#   'startDate': '2011-05-06',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Business Analyst',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_248',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Event Management Software',
#   'description': 'Around face fine reduce American you religious. Situation on shake physical own drop.\nBetween ok home water let loss. Quality song if view office Congress according morning.',
#   'startDate': '1997-12-13',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_248',
#   'projectName': 'AgileWare',
#   'projectType': 'Payment Gateway',
#   'description': 'These its it lay bed baby win. Bit size thought.\nGrowth wish number theory especially hit growth. Little large body suggest use official.',
#   'startDate': '1999-04-27',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_249',
#   'projectName': 'FusionSoft Email Client',
#   'projectType': 'Educational Software',
#   'description': 'Response various seat order show program last. Away yeah still our personal ask generation. Skin art her space newspaper its.\nModel travel national project. Hospital anything nor old.',
#   'startDate': '1999-09-24',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_249',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Backup Solution',
#   'description': 'Kind reality item impact raise possible use. Point member mother trial oil including. Down later the pass trial body.',
#   'startDate': '2001-07-16',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_249',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Virtual Assistant',
#   'description': 'Industry near action people. Phone else side star air certain. International spring player child same themselves wait. Until significant lose.',
#   'startDate': '1971-08-09',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_249',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Booking System',
#   'description': 'Lose tonight sign situation. They today environment produce.\nThough family court thousand. Again production result task billion rate themselves. Born Congress show rather dark matter.',
#   'startDate': '2018-01-24',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  ...]

# %%
df=pd.DataFrame(data)

# %%
skills = [
    "Python",
    "JavaScript",
    "HTML",
    "CSS",
    "React",
    "Angular",
    "Vue.js",
    "Node.js",
    "Django",
    "Flask",
    "Java",
    "Kotlin",
    "Swift",
    "Objective-C",
    "C#",
    ".NET",
    "PHP",
    "Ruby",
    "SQL",
    "NoSQL",
    "MongoDB",
    "MySQL",
    "PostgreSQL",
    "Git",
    "Docker",
    "Kubernetes",
    "AWS",
    "Azure",
    "Google Cloud Platform",
    "RESTful API",
    "GraphQL",
    "CI/CD",
    "Agile Methodologies",
    "Scrum",
    "Test-Driven Development",
    "Behavior-Driven Development",
    "DevOps",
    "Continuous Integration",
    "Continuous Deployment",
    "Microservices",
    "Containerization",
    "Machine Learning",
    "Artificial Intelligence",
    "Data Science",
    "Data Analysis",
    "Data Visualization",
    "Statistical Analysis",
    "Cybersecurity",
    "Network Security",
    "Penetration Testing",
    "Cryptography",
    "Information Security",
    "UI/UX Design",
    "Wireframing",
    "Prototyping",
    "User Research",
    "Interaction Design",
    "Responsive Design",
    "Accessibility",
    "Product Management",
    "Agile Product Management",
    "Requirements Analysis",
    "User Stories",
    "Business Analysis",
    "Technical Writing",
    "Documentation",
    "Support",
    "Troubleshooting",
    "Problem Solving",
    "Communication",
    "Collaboration",
    "Leadership"
]

# %%
data = []
for i in fake_data_list:
    empid = i
    Skill = random.sample(skills, 4)  # Pick 4 unique certificates randomly
    for s in Skill:
        record = {
            "Empid": empid,
            "skillName": s,
            "Proficiency": random.choice(["Intermidiate", "Expert","Beginner","Advance"])
        }
        data.append(record)

# %%
df=pd.DataFrame(data)
df
# Out:
#       Empid              skillName   Proficiency
# 0     Emp_0        Troubleshooting       Advance
# 1     Emp_0                GraphQL        Expert
# 2     Emp_0                 Vue.js       Advance
# 3     Emp_0        Problem Solving      Beginner
# 4     Emp_1                Support        Expert
# ...     ...                    ...           ...
# 4011    NaN  Continuous Deployment      Beginner
# 4012    NaN                   .NET  Intermidiate
# 4013    NaN     Product Management  Intermidiate
# 4014    NaN       Machine Learning  Intermidiate
# 4015    NaN          Microservices      Beginner
#
# [4016 rows x 3 columns]

# %%
df.to_csv('skills.csv')
