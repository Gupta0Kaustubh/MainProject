# %%
pip install Faker
# Out:
# Collecting Faker
#   Obtaining dependency information for Faker from https://files.pythonhosted.org/packages/72/04/b5290fc71cad85eadd86d24ad21dd70e76a98a073db6c1c7a925df7ba037/Faker-24.7.1-py3-none-any.whl.metadata
#   Downloading Faker-24.7.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\kaust\appdata\local\programs\python\python311\lib\site-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kaust\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Downloading Faker-24.7.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.4/1.8 MB 8.1 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.8 MB 6.3 MB/s eta 0:00:01
#    --------------------- ------------------ 0.9/1.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 5.1 MB/s eta 0:00:00
# Installing collected packages: Faker
# Successfully installed Faker-24.7.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from faker import Faker
import random

# %%
fake=Faker()

# %%
fake.phone_number()
# Out:
# '001-263-621-1691x9085'

# %%
pip random
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "random"

# %%
from faker import Faker


fake = Faker()

fake_data_list = []
job_roles = [
    "Software Engineer",
    "Frontend Developer",
    "Backend Developer",
    "Full-stack Developer",
    "Mobile App Developer (iOS/Android)",
    "DevOps Engineer",
    "Database Administrator (DBA)",
    "Quality Assurance Engineer (QA Engineer)",
    "Software Tester",
    "Technical Architect",
    "UI/UX Designer",
    "Product Manager",
    "Scrum Master",
    "Agile Coach",
    "Business Analyst",
    "Systems Analyst",
    "Network Engineer",
    "Security Engineer",
    "Data Scientist",
    "Machine Learning Engineer",
    "Artificial Intelligence Specialist",
    "Cloud Solutions Architect",
    "Technical Writer (Documentation Specialist)",
    "IT Support Engineer",
    "IT Administrator",
    "Release Manager",
    "Configuration Manager",
    "Automation Engineer",
    "Performance Engineer",
    "Customer Support Engineer"
]

skills = [
    "Python", "JavaScript", "HTML", "CSS", "React", "Angular", "Vue.js", "Node.js", "Django", "Flask",
    "Java", "Kotlin", "Swift", "Objective-C", "C#", ".NET", "PHP", "Ruby", "SQL", "NoSQL",
    "MongoDB", "MySQL", "PostgreSQL", "Git", "Docker", "Kubernetes", "AWS", "Azure", "Google Cloud Platform",
    "RESTful API", "GraphQL", "CI/CD", "Agile Methodologies", "Scrum", "Test-Driven Development",
    "Behavior-Driven Development", "DevOps", "Continuous Integration", "Continuous Deployment", "Microservices",
    "Containerization", "Machine Learning", "Artificial Intelligence", "Data Science", "Data Analysis",
    "Data Visualization", "Statistical Analysis", "Cybersecurity", "Network Security", "Penetration Testing",
    "Cryptography", "Information Security"
]



for i in range(1, 200):
    certificates = random.sample(skills, 4)
    user_data = {
        "userId": "Emp_" + str(i),
        "firstName": fake.first_name(),
        "middleName": fake.first_name(),
        "lastName": fake.last_name(),
        "email": fake.email(),
        "phoneNumber": fake.phone_number(),
        "gender": fake.random_element(elements=("Male", "Female")),
        "doj": fake.date_this_decade(),
        "specializations": certificates,
        "dob": fake.date_of_birth(),
        "city": fake.city(),
        "state": fake.state(),
        "experience": fake.random_int(min=1, max=20),
        "userType": fake.random_element(elements=("User",)),
        "subscribeNewsletter": fake.boolean(),
        "passwords": fake.password(length=8),  # Ensures password is at least 8 characters long
    }
    fake_data_list.append(user_data)

# Print the generated fake data
for user_data in fake_data_list:
    print(user_data)
# Out:
# {'userId': 'Emp_1', 'firstName': 'Cathy', 'middleName': 'Robert', 'lastName': 'Mata', 'email': 'johnbaker@example.com', 'phoneNumber': '(375)527-9939', 'gender': 'Male', 'doj': datetime.date(2023, 3, 9), 'specializations': ['Kubernetes', 'MySQL', 'C#', 'NoSQL'], 'dob': datetime.date(2015, 4, 7), 'city': 'Bryanstad', 'state': 'Arizona', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'NQ@y9_Ov'}
# {'userId': 'Emp_2', 'firstName': 'David', 'middleName': 'Robert', 'lastName': 'Sanford', 'email': 'corymiller@example.com', 'phoneNumber': '248.611.9083', 'gender': 'Male', 'doj': datetime.date(2022, 6, 16), 'specializations': ['C#', 'DevOps', 'MongoDB', 'Objective-C'], 'dob': datetime.date(1993, 8, 16), 'city': 'East Alexamouth', 'state': 'South Dakota', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'G)15(NdX'}
# {'userId': 'Emp_3', 'firstName': 'Kendra', 'middleName': 'Lauren', 'lastName': 'Sanchez', 'email': 'boothpatrick@example.com', 'phoneNumber': '001-853-345-0172x1681', 'gender': 'Female', 'doj': datetime.date(2022, 10, 2), 'specializations': ['HTML', 'Test-Driven Development', 'Google Cloud Platform', 'GraphQL'], 'dob': datetime.date(1970, 7, 30), 'city': 'Christyburgh', 'state': 'Virginia', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '$rP2BHvI'}
# {'userId': 'Emp_4', 'firstName': 'Lauren', 'middleName': 'Tracy', 'lastName': 'Vargas', 'email': 'emorales@example.net', 'phoneNumber': '+1-932-448-8082x0694', 'gender': 'Male', 'doj': datetime.date(2024, 2, 19), 'specializations': ['NoSQL', 'Objective-C', 'Continuous Deployment', 'Continuous Integration'], 'dob': datetime.date(1954, 7, 7), 'city': 'Robertstad', 'state': 'Colorado', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'h)4kTZYp'}
# {'userId': 'Emp_5', 'firstName': 'Kathryn', 'middleName': 'Bryan', 'lastName': 'Davis', 'email': 'autumnramirez@example.com', 'phoneNumber': '+1-599-373-5337', 'gender': 'Male', 'doj': datetime.date(2020, 9, 5), 'specializations': ['Flask', 'Angular', 'JavaScript', 'PostgreSQL'], 'dob': datetime.date(1953, 5, 21), 'city': 'West Timothy', 'state': 'Montana', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '(Q)0Ws2y'}
# {'userId': 'Emp_6', 'firstName': 'Tina', 'middleName': 'Dennis', 'lastName': 'Rose', 'email': 'bwood@example.net', 'phoneNumber': '+1-234-849-2848x903', 'gender': 'Male', 'doj': datetime.date(2020, 8, 19), 'specializations': ['Statistical Analysis', 'C#', 'Agile Methodologies', 'Docker'], 'dob': datetime.date(1941, 9, 19), 'city': 'Wallacemouth', 'state': 'Nevada', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '%4IXkLt%'}
# {'userId': 'Emp_7', 'firstName': 'Benjamin', 'middleName': 'Travis', 'lastName': 'Thomas', 'email': 'allenandrea@example.com', 'phoneNumber': '+1-731-328-3211x347', 'gender': 'Male', 'doj': datetime.date(2024, 2, 20), 'specializations': ['GraphQL', 'React', 'Penetration Testing', 'Kotlin'], 'dob': datetime.date(1956, 11, 8), 'city': 'Natalieview', 'state': 'Connecticut', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '*78A1Hqu'}
# {'userId': 'Emp_8', 'firstName': 'Brandon', 'middleName': 'Nathan', 'lastName': 'Wagner', 'email': 'weavernancy@example.org', 'phoneNumber': '943-336-6843', 'gender': 'Male', 'doj': datetime.date(2020, 1, 28), 'specializations': ['Microservices', 'Test-Driven Development', '.NET', 'Data Visualization'], 'dob': datetime.date(2012, 2, 17), 'city': 'Matthewfort', 'state': 'New Mexico', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '0_5k#Dbg'}
# {'userId': 'Emp_9', 'firstName': 'Patrick', 'middleName': 'Jason', 'lastName': 'Arnold', 'email': 'zferguson@example.com', 'phoneNumber': '(898)209-1253', 'gender': 'Male', 'doj': datetime.date(2020, 8, 10), 'specializations': ['MySQL', 'Kubernetes', 'Continuous Integration', 'Ruby'], 'dob': datetime.date(1995, 3, 15), 'city': 'Bassstad', 'state': 'Oregon', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#7OUp&cy'}
# {'userId': 'Emp_10', 'firstName': 'Erin', 'middleName': 'Jessica', 'lastName': 'Hall', 'email': 'rcooley@example.net', 'phoneNumber': '+1-256-843-3864x5107', 'gender': 'Female', 'doj': datetime.date(2022, 9, 11), 'specializations': ['AWS', 'NoSQL', 'Angular', 'Objective-C'], 'dob': datetime.date(1951, 5, 29), 'city': 'Lake Davidbury', 'state': 'Utah', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')2C*qp2e'}
# {'userId': 'Emp_11', 'firstName': 'Peggy', 'middleName': 'Christina', 'lastName': 'Herman', 'email': 'ojohnson@example.net', 'phoneNumber': '622-217-7571x521', 'gender': 'Female', 'doj': datetime.date(2021, 4, 30), 'specializations': ['GraphQL', 'Python', 'Statistical Analysis', 'Django'], 'dob': datetime.date(1945, 11, 1), 'city': 'East Amandatown', 'state': 'Oklahoma', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'P(l4Cnh('}
# {'userId': 'Emp_12', 'firstName': 'Erica', 'middleName': 'Kristin', 'lastName': 'Williams', 'email': 'donna36@example.com', 'phoneNumber': '+1-402-565-1081x757', 'gender': 'Male', 'doj': datetime.date(2024, 1, 26), 'specializations': ['C#', 'Statistical Analysis', 'Node.js', 'Data Visualization'], 'dob': datetime.date(2004, 10, 29), 'city': 'New David', 'state': 'Nebraska', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '+3@9CNlu'}
# {'userId': 'Emp_13', 'firstName': 'Christy', 'middleName': 'Sarah', 'lastName': 'Kline', 'email': 'patricia66@example.com', 'phoneNumber': '309-398-4550', 'gender': 'Female', 'doj': datetime.date(2023, 2, 4), 'specializations': ['Kubernetes', 'CSS', 'Django', 'Kotlin'], 'dob': datetime.date(1985, 9, 30), 'city': 'Conniemouth', 'state': 'Wyoming', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '+5nES5Dg'}
# {'userId': 'Emp_14', 'firstName': 'William', 'middleName': 'Johnathan', 'lastName': 'Zamora', 'email': 'ppetersen@example.net', 'phoneNumber': '001-624-595-5950', 'gender': 'Female', 'doj': datetime.date(2021, 11, 9), 'specializations': ['Cryptography', 'JavaScript', 'Flask', 'Machine Learning'], 'dob': datetime.date(1999, 5, 3), 'city': 'Shawnside', 'state': 'Maine', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'Yum%0fVb'}
# {'userId': 'Emp_15', 'firstName': 'Danny', 'middleName': 'Julie', 'lastName': 'Oconnell', 'email': 'victor58@example.net', 'phoneNumber': '(733)345-9710x1705', 'gender': 'Male', 'doj': datetime.date(2021, 4, 6), 'specializations': ['MongoDB', 'Java', 'Agile Methodologies', 'PHP'], 'dob': datetime.date(1948, 2, 11), 'city': 'East Nicholas', 'state': 'Oregon', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'wHg)5R8e'}
# {'userId': 'Emp_16', 'firstName': 'Alex', 'middleName': 'Desiree', 'lastName': 'Duke', 'email': 'todd46@example.net', 'phoneNumber': '001-528-304-8884x280', 'gender': 'Male', 'doj': datetime.date(2022, 8, 16), 'specializations': ['Machine Learning', 'Kubernetes', 'Continuous Deployment', 'Django'], 'dob': datetime.date(1918, 10, 4), 'city': 'Melaniehaven', 'state': 'Louisiana', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'KKG)1cTm'}
# {'userId': 'Emp_17', 'firstName': 'Derrick', 'middleName': 'Brittany', 'lastName': 'Kelly', 'email': 'rrobinson@example.net', 'phoneNumber': '001-397-602-7900', 'gender': 'Female', 'doj': datetime.date(2023, 5, 3), 'specializations': ['Docker', 'RESTful API', 'Penetration Testing', 'Scrum'], 'dob': datetime.date(1988, 12, 27), 'city': 'Watsonberg', 'state': 'Iowa', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '__223WWn'}
# {'userId': 'Emp_18', 'firstName': 'Nathan', 'middleName': 'Robert', 'lastName': 'Smith', 'email': 'braychristopher@example.net', 'phoneNumber': '(560)841-5138x930', 'gender': 'Female', 'doj': datetime.date(2020, 5, 30), 'specializations': ['NoSQL', 'DevOps', 'Microservices', 'JavaScript'], 'dob': datetime.date(1940, 2, 29), 'city': 'West Suzanne', 'state': 'Louisiana', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '&0In)5Bc'}
# {'userId': 'Emp_19', 'firstName': 'Julie', 'middleName': 'Jeffrey', 'lastName': 'Peters', 'email': 'sjohnson@example.org', 'phoneNumber': '+1-256-322-4681x83949', 'gender': 'Female', 'doj': datetime.date(2020, 9, 28), 'specializations': ['Objective-C', 'Flask', 'Data Visualization', 'Continuous Integration'], 'dob': datetime.date(2001, 4, 3), 'city': 'North Allisonside', 'state': 'Virginia', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'R%8AYfq2'}
# {'userId': 'Emp_20', 'firstName': 'Michael', 'middleName': 'Steve', 'lastName': 'Obrien', 'email': 'richardhood@example.com', 'phoneNumber': '001-242-721-4678x801', 'gender': 'Male', 'doj': datetime.date(2020, 2, 18), 'specializations': ['Python', 'Statistical Analysis', 'AWS', 'Artificial Intelligence'], 'dob': datetime.date(1989, 4, 16), 'city': 'Ericmouth', 'state': 'Illinois', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%64Nz@m!'}
# {'userId': 'Emp_21', 'firstName': 'Sarah', 'middleName': 'James', 'lastName': 'Crawford', 'email': 'williamwilliams@example.org', 'phoneNumber': '+1-611-901-9789x3062', 'gender': 'Female', 'doj': datetime.date(2022, 4, 14), 'specializations': ['Git', 'Cybersecurity', 'Flask', 'SQL'], 'dob': datetime.date(1967, 5, 24), 'city': 'Stephanieton', 'state': 'New Jersey', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '*0K!LUTo'}
# {'userId': 'Emp_22', 'firstName': 'John', 'middleName': 'Kenneth', 'lastName': 'Nelson', 'email': 'justinevans@example.org', 'phoneNumber': '9136471600', 'gender': 'Female', 'doj': datetime.date(2022, 5, 16), 'specializations': ['Java', 'Kubernetes', 'Angular', 'Azure'], 'dob': datetime.date(1920, 5, 27), 'city': 'West Timothytown', 'state': 'New Hampshire', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'I&m5D1Ky'}
# {'userId': 'Emp_23', 'firstName': 'Ronald', 'middleName': 'Daniel', 'lastName': 'Gonzalez', 'email': 'amberrobinson@example.org', 'phoneNumber': '(677)277-1182', 'gender': 'Female', 'doj': datetime.date(2021, 10, 17), 'specializations': ['Cryptography', 'Google Cloud Platform', 'Data Science', 'MySQL'], 'dob': datetime.date(1963, 4, 15), 'city': 'Katelynside', 'state': 'Minnesota', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '6!$(3Nqb'}
# {'userId': 'Emp_24', 'firstName': 'Anthony', 'middleName': 'Autumn', 'lastName': 'Goodman', 'email': 'charles22@example.com', 'phoneNumber': '399.371.6320x670', 'gender': 'Male', 'doj': datetime.date(2021, 6, 11), 'specializations': ['Flask', 'Google Cloud Platform', 'Node.js', 'Test-Driven Development'], 'dob': datetime.date(1979, 4, 7), 'city': 'New Vincentfurt', 'state': 'New York', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': ')7oj5Hgd'}
# {'userId': 'Emp_25', 'firstName': 'Jodi', 'middleName': 'Jose', 'lastName': 'Gordon', 'email': 'mray@example.org', 'phoneNumber': '(712)971-1327x273', 'gender': 'Male', 'doj': datetime.date(2021, 4, 9), 'specializations': ['Data Visualization', 'Microservices', 'NoSQL', 'Kotlin'], 'dob': datetime.date(1913, 12, 16), 'city': 'South Michele', 'state': 'Michigan', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')8v2ADc0'}
# {'userId': 'Emp_26', 'firstName': 'Michael', 'middleName': 'Scott', 'lastName': 'Thomas', 'email': 'matthewsjeffrey@example.net', 'phoneNumber': '(545)704-8326', 'gender': 'Male', 'doj': datetime.date(2021, 4, 9), 'specializations': ['Machine Learning', 'Ruby', 'Git', 'Angular'], 'dob': datetime.date(2018, 11, 3), 'city': 'Rogersfurt', 'state': 'Massachusetts', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '@44JSWfm'}
# {'userId': 'Emp_27', 'firstName': 'Kathleen', 'middleName': 'Michael', 'lastName': 'Le', 'email': 'christian10@example.com', 'phoneNumber': '725.295.3876', 'gender': 'Male', 'doj': datetime.date(2021, 12, 12), 'specializations': ['Test-Driven Development', 'Kotlin', 'Penetration Testing', '.NET'], 'dob': datetime.date(2012, 1, 7), 'city': 'Lake Robertside', 'state': 'Montana', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'Z!#5LlmV'}
# {'userId': 'Emp_28', 'firstName': 'James', 'middleName': 'Matthew', 'lastName': 'Jones', 'email': 'cohenheather@example.net', 'phoneNumber': '850-487-5305', 'gender': 'Female', 'doj': datetime.date(2020, 7, 11), 'specializations': ['Azure', 'Python', '.NET', 'Kotlin'], 'dob': datetime.date(2008, 2, 11), 'city': 'Dixonview', 'state': 'Illinois', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'f$k0BCcz'}
# {'userId': 'Emp_29', 'firstName': 'Mary', 'middleName': 'Samuel', 'lastName': 'Glenn', 'email': 'brenda12@example.net', 'phoneNumber': '366-343-9280x27111', 'gender': 'Female', 'doj': datetime.date(2021, 5, 10), 'specializations': ['Vue.js', 'Test-Driven Development', 'GraphQL', 'AWS'], 'dob': datetime.date(1929, 12, 26), 'city': 'North Teresatown', 'state': 'Michigan', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '&wvn0vUk'}
# {'userId': 'Emp_30', 'firstName': 'Brian', 'middleName': 'Michelle', 'lastName': 'Williams', 'email': 'katherine18@example.org', 'phoneNumber': '343.988.0246x011', 'gender': 'Male', 'doj': datetime.date(2023, 4, 14), 'specializations': ['Kubernetes', 'Behavior-Driven Development', 'Network Security', '.NET'], 'dob': datetime.date(1922, 10, 14), 'city': 'Kathystad', 'state': 'Alabama', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'n^9W@_wy'}
# {'userId': 'Emp_31', 'firstName': 'Tara', 'middleName': 'Richard', 'lastName': 'White', 'email': 'nortonsusan@example.net', 'phoneNumber': '001-921-468-1662x1240', 'gender': 'Female', 'doj': datetime.date(2021, 2, 11), 'specializations': ['.NET', 'AWS', 'Agile Methodologies', 'HTML'], 'dob': datetime.date(1971, 9, 25), 'city': 'South Christopherland', 'state': 'Louisiana', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '4_*)3Mtg'}
# {'userId': 'Emp_32', 'firstName': 'Matthew', 'middleName': 'Regina', 'lastName': 'Valdez', 'email': 'barberjohnny@example.net', 'phoneNumber': '(595)954-2680', 'gender': 'Female', 'doj': datetime.date(2021, 12, 13), 'specializations': ['Agile Methodologies', 'Test-Driven Development', 'Microservices', 'Artificial Intelligence'], 'dob': datetime.date(1941, 8, 12), 'city': 'North Stephanie', 'state': 'Iowa', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '(B7Y)Ef1'}
# {'userId': 'Emp_33', 'firstName': 'Mark', 'middleName': 'Marissa', 'lastName': 'Jimenez', 'email': 'debbie93@example.net', 'phoneNumber': '798.974.6348', 'gender': 'Female', 'doj': datetime.date(2022, 12, 5), 'specializations': ['Flask', 'Django', 'Google Cloud Platform', 'Data Science'], 'dob': datetime.date(2004, 1, 31), 'city': 'New Belindafort', 'state': 'South Dakota', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '#!8Hx!39'}
# {'userId': 'Emp_34', 'firstName': 'Valerie', 'middleName': 'Aaron', 'lastName': 'White', 'email': 'cbruce@example.org', 'phoneNumber': '6522860248', 'gender': 'Female', 'doj': datetime.date(2022, 10, 10), 'specializations': ['Python', 'Git', 'Cryptography', 'Java'], 'dob': datetime.date(1993, 12, 10), 'city': 'Cainchester', 'state': 'Nebraska', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^Ev5FeL_'}
# {'userId': 'Emp_35', 'firstName': 'Megan', 'middleName': 'Michael', 'lastName': 'Cohen', 'email': 'ashleymontgomery@example.com', 'phoneNumber': '001-378-725-0881x75709', 'gender': 'Female', 'doj': datetime.date(2021, 1, 9), 'specializations': ['Continuous Integration', 'Angular', 'Network Security', 'Data Science'], 'dob': datetime.date(2007, 3, 11), 'city': 'Turnermouth', 'state': 'Montana', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#)x3@Qsg'}
# {'userId': 'Emp_36', 'firstName': 'Clayton', 'middleName': 'Micheal', 'lastName': 'Cruz', 'email': 'wisejames@example.org', 'phoneNumber': '(313)247-7837', 'gender': 'Female', 'doj': datetime.date(2023, 12, 26), 'specializations': ['Information Security', 'Kubernetes', 'NoSQL', 'Continuous Deployment'], 'dob': datetime.date(2000, 10, 18), 'city': 'East Grantberg', 'state': 'Wisconsin', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '$b9pBjoj'}
# {'userId': 'Emp_37', 'firstName': 'Brenda', 'middleName': 'Jessica', 'lastName': 'Bennett', 'email': 'jlee@example.org', 'phoneNumber': '001-845-570-0363x87742', 'gender': 'Female', 'doj': datetime.date(2020, 8, 31), 'specializations': ['Scrum', 'PHP', 'Network Security', 'MongoDB'], 'dob': datetime.date(1991, 7, 3), 'city': 'Tinaburgh', 'state': 'Mississippi', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '+gvwC8Nh'}
# {'userId': 'Emp_38', 'firstName': 'Sherry', 'middleName': 'Roger', 'lastName': 'Hardy', 'email': 'andersonjack@example.net', 'phoneNumber': '9359869269', 'gender': 'Female', 'doj': datetime.date(2021, 7, 14), 'specializations': ['Behavior-Driven Development', 'Information Security', 'Microservices', 'PHP'], 'dob': datetime.date(2024, 3, 18), 'city': 'Hallville', 'state': 'Mississippi', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'a_44EyGc'}
# {'userId': 'Emp_39', 'firstName': 'Theresa', 'middleName': 'Mary', 'lastName': 'Steele', 'email': 'mariahjohnson@example.net', 'phoneNumber': '+1-239-396-6021x023', 'gender': 'Female', 'doj': datetime.date(2021, 6, 5), 'specializations': ['AWS', 'Microservices', 'Cryptography', 'Java'], 'dob': datetime.date(1944, 10, 12), 'city': 'South Melissa', 'state': 'West Virginia', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': ')5EoXK8j'}
# {'userId': 'Emp_40', 'firstName': 'Christopher', 'middleName': 'Shannon', 'lastName': 'Montgomery', 'email': 'vanessajones@example.org', 'phoneNumber': '693.655.0880', 'gender': 'Male', 'doj': datetime.date(2020, 12, 16), 'specializations': ['GraphQL', 'Continuous Deployment', 'NoSQL', 'Ruby'], 'dob': datetime.date(1936, 5, 23), 'city': 'New Colin', 'state': 'Arkansas', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '@Y2+KKwb'}
# {'userId': 'Emp_41', 'firstName': 'Jennifer', 'middleName': 'Patrick', 'lastName': 'Wu', 'email': 'kathleen87@example.com', 'phoneNumber': '(552)985-0489x505', 'gender': 'Male', 'doj': datetime.date(2023, 12, 24), 'specializations': ['Statistical Analysis', 'Microservices', 'Containerization', 'Python'], 'dob': datetime.date(1923, 8, 10), 'city': 'North Rachel', 'state': 'Vermont', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '!6%K9Ajg'}
# {'userId': 'Emp_42', 'firstName': 'Carolyn', 'middleName': 'Desiree', 'lastName': 'Greene', 'email': 'kathleen94@example.org', 'phoneNumber': '(928)559-5243x9191', 'gender': 'Female', 'doj': datetime.date(2020, 8, 3), 'specializations': ['MySQL', 'Cryptography', 'Information Security', 'Django'], 'dob': datetime.date(1960, 3, 3), 'city': 'Teresafort', 'state': 'Alaska', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'Z)s4RXUm'}
# {'userId': 'Emp_43', 'firstName': 'Brandi', 'middleName': 'Daniel', 'lastName': 'Garcia', 'email': 'mcgeederek@example.org', 'phoneNumber': '974-719-9516', 'gender': 'Female', 'doj': datetime.date(2022, 2, 17), 'specializations': ['Docker', 'PostgreSQL', 'C#', 'MySQL'], 'dob': datetime.date(1982, 1, 16), 'city': 'Kimberlyborough', 'state': 'Rhode Island', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'R)6UUzhg'}
# {'userId': 'Emp_44', 'firstName': 'Nicole', 'middleName': 'Elaine', 'lastName': 'Parker', 'email': 'alice74@example.org', 'phoneNumber': '(842)444-3794x8472', 'gender': 'Female', 'doj': datetime.date(2023, 9, 24), 'specializations': ['Docker', 'Penetration Testing', 'Artificial Intelligence', 'Azure'], 'dob': datetime.date(2022, 6, 16), 'city': 'Johnchester', 'state': 'New Jersey', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%98BI3sR'}
# {'userId': 'Emp_45', 'firstName': 'Bradley', 'middleName': 'Christopher', 'lastName': 'Williams', 'email': 'martinheather@example.com', 'phoneNumber': '3865541391', 'gender': 'Male', 'doj': datetime.date(2023, 12, 14), 'specializations': ['.NET', 'CI/CD', 'Containerization', 'AWS'], 'dob': datetime.date(1937, 3, 25), 'city': 'Warrenside', 'state': 'Missouri', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '&0**79Uh'}
# {'userId': 'Emp_46', 'firstName': 'Gary', 'middleName': 'Monica', 'lastName': 'Solis', 'email': 'susan86@example.com', 'phoneNumber': '828.985.5644x3848', 'gender': 'Male', 'doj': datetime.date(2020, 11, 14), 'specializations': ['CI/CD', 'NoSQL', 'PHP', 'Information Security'], 'dob': datetime.date(1940, 8, 20), 'city': 'Davidsonton', 'state': 'Nebraska', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'J&3_Ngvy'}
# {'userId': 'Emp_47', 'firstName': 'Robert', 'middleName': 'James', 'lastName': 'Marshall', 'email': 'vweiss@example.com', 'phoneNumber': '751.608.3207', 'gender': 'Male', 'doj': datetime.date(2022, 5, 1), 'specializations': ['Continuous Integration', 'Behavior-Driven Development', 'NoSQL', 'Docker'], 'dob': datetime.date(1940, 2, 25), 'city': 'Ashleybury', 'state': 'North Dakota', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#6M*3&r$'}
# {'userId': 'Emp_48', 'firstName': 'Victoria', 'middleName': 'Michael', 'lastName': 'Johnson', 'email': 'taylordominic@example.net', 'phoneNumber': '(900)927-3509', 'gender': 'Male', 'doj': datetime.date(2022, 6, 23), 'specializations': ['Node.js', 'Test-Driven Development', 'PostgreSQL', 'Kubernetes'], 'dob': datetime.date(1998, 10, 25), 'city': 'Stuartton', 'state': 'New Mexico', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '3(48UTw$'}
# {'userId': 'Emp_49', 'firstName': 'Timothy', 'middleName': 'Philip', 'lastName': 'Obrien', 'email': 'gblackwell@example.org', 'phoneNumber': '+1-560-618-7889x88205', 'gender': 'Male', 'doj': datetime.date(2022, 7, 13), 'specializations': ['CI/CD', 'Django', 'Kubernetes', 'Java'], 'dob': datetime.date(1910, 9, 7), 'city': 'Port Linda', 'state': 'Iowa', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '@P87DFPx'}
# {'userId': 'Emp_50', 'firstName': 'Connie', 'middleName': 'Paula', 'lastName': 'Murphy', 'email': 'rcox@example.org', 'phoneNumber': '(343)519-8180x721', 'gender': 'Female', 'doj': datetime.date(2021, 11, 1), 'specializations': ['React', 'Microservices', 'Test-Driven Development', 'CI/CD'], 'dob': datetime.date(1928, 5, 23), 'city': 'North Robin', 'state': 'New York', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '+Y8CVmlD'}
# {'userId': 'Emp_51', 'firstName': 'Richard', 'middleName': 'Shelby', 'lastName': 'Jenkins', 'email': 'gabrielle67@example.net', 'phoneNumber': '001-445-525-5258x71943', 'gender': 'Female', 'doj': datetime.date(2022, 10, 10), 'specializations': ['CI/CD', 'PostgreSQL', 'Vue.js', 'Information Security'], 'dob': datetime.date(1931, 4, 27), 'city': 'Carterton', 'state': 'Pennsylvania', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '+_7AC^qo'}
# {'userId': 'Emp_52', 'firstName': 'Richard', 'middleName': 'Shane', 'lastName': 'Ferguson', 'email': 'sboone@example.org', 'phoneNumber': '001-992-987-5145x168', 'gender': 'Male', 'doj': datetime.date(2021, 1, 7), 'specializations': ['JavaScript', 'Containerization', 'React', 'Data Science'], 'dob': datetime.date(1946, 10, 21), 'city': 'Davisport', 'state': 'Wisconsin', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'y^F7X+zL'}
# {'userId': 'Emp_53', 'firstName': 'Sharon', 'middleName': 'Raymond', 'lastName': 'Graham', 'email': 'lucasbrewer@example.com', 'phoneNumber': '541-253-5524x074', 'gender': 'Female', 'doj': datetime.date(2022, 11, 20), 'specializations': ['Objective-C', 'Penetration Testing', 'Flask', 'MongoDB'], 'dob': datetime.date(1922, 8, 15), 'city': 'Jamesside', 'state': 'South Carolina', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^3GPPz4)'}
# {'userId': 'Emp_54', 'firstName': 'Rebecca', 'middleName': 'Brooke', 'lastName': 'Black', 'email': 'richard77@example.org', 'phoneNumber': '001-890-679-7928x27401', 'gender': 'Male', 'doj': datetime.date(2021, 9, 5), 'specializations': ['AWS', 'Swift', 'Network Security', 'MySQL'], 'dob': datetime.date(1930, 2, 24), 'city': 'Stacyburgh', 'state': 'North Carolina', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '98%8Bqii'}
# {'userId': 'Emp_55', 'firstName': 'Thomas', 'middleName': 'Kimberly', 'lastName': 'Phillips', 'email': 'kiararuiz@example.net', 'phoneNumber': '001-896-548-5431x7499', 'gender': 'Female', 'doj': datetime.date(2023, 9, 28), 'specializations': ['Azure', 'Kubernetes', 'Scrum', 'Ruby'], 'dob': datetime.date(2005, 11, 23), 'city': 'Markmouth', 'state': 'Hawaii', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '_3&eYA4k'}
# {'userId': 'Emp_56', 'firstName': 'Joseph', 'middleName': 'Kimberly', 'lastName': 'Frank', 'email': 'toddclark@example.net', 'phoneNumber': '989-930-1811x071', 'gender': 'Female', 'doj': datetime.date(2021, 11, 20), 'specializations': ['Scrum', 'Java', 'Cryptography', 'Kotlin'], 'dob': datetime.date(1997, 11, 13), 'city': 'South Amanda', 'state': 'California', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'x^1jaTze'}
# {'userId': 'Emp_57', 'firstName': 'Sara', 'middleName': 'Brandon', 'lastName': 'Brown', 'email': 'jaystark@example.com', 'phoneNumber': '8059395381', 'gender': 'Male', 'doj': datetime.date(2023, 7, 27), 'specializations': ['PostgreSQL', 'Swift', 'MySQL', 'Data Analysis'], 'dob': datetime.date(1950, 7, 9), 'city': 'Jordanview', 'state': 'West Virginia', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'L#oO3VYr'}
# {'userId': 'Emp_58', 'firstName': 'Daniel', 'middleName': 'Christopher', 'lastName': 'Mckinney', 'email': 'lowekathy@example.com', 'phoneNumber': '001-445-376-2507', 'gender': 'Female', 'doj': datetime.date(2023, 4, 22), 'specializations': ['Test-Driven Development', 'Behavior-Driven Development', 'Data Analysis', 'AWS'], 'dob': datetime.date(1908, 10, 20), 'city': 'Pamelaview', 'state': 'Hawaii', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '%S1JWeXB'}
# {'userId': 'Emp_59', 'firstName': 'Jennifer', 'middleName': 'Teresa', 'lastName': 'Bailey', 'email': 'coxbrian@example.org', 'phoneNumber': '(963)676-4368', 'gender': 'Male', 'doj': datetime.date(2022, 8, 9), 'specializations': ['Swift', 'Data Science', 'CSS', 'Node.js'], 'dob': datetime.date(1956, 10, 31), 'city': 'Martinport', 'state': 'Kentucky', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '5#53Cx0r'}
# {'userId': 'Emp_60', 'firstName': 'Christina', 'middleName': 'Austin', 'lastName': 'Harrison', 'email': 'christina81@example.com', 'phoneNumber': '+1-232-334-7265x083', 'gender': 'Female', 'doj': datetime.date(2021, 9, 24), 'specializations': ['Continuous Integration', 'GraphQL', 'MongoDB', 'Flask'], 'dob': datetime.date(1997, 5, 31), 'city': 'North Katieview', 'state': 'Kentucky', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '&a9!6SUv'}
# {'userId': 'Emp_61', 'firstName': 'Heather', 'middleName': 'Jeremiah', 'lastName': 'Hawkins', 'email': 'zmiller@example.org', 'phoneNumber': '5819636511', 'gender': 'Female', 'doj': datetime.date(2021, 3, 20), 'specializations': ['PostgreSQL', 'Continuous Deployment', 'Cryptography', 'DevOps'], 'dob': datetime.date(1992, 10, 26), 'city': 'East Tony', 'state': 'Nebraska', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#v9C66By'}
# {'userId': 'Emp_62', 'firstName': 'Gregory', 'middleName': 'Jennifer', 'lastName': 'Oconnor', 'email': 'ellisricky@example.net', 'phoneNumber': '001-453-258-5751x63218', 'gender': 'Male', 'doj': datetime.date(2020, 12, 19), 'specializations': ['Objective-C', 'Data Science', 'MongoDB', 'Microservices'], 'dob': datetime.date(1952, 1, 28), 'city': 'Jonathanport', 'state': 'Nevada', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '7&3E^Epl'}
# {'userId': 'Emp_63', 'firstName': 'Alexandra', 'middleName': 'Jennifer', 'lastName': 'King', 'email': 'coffeyryan@example.org', 'phoneNumber': '001-605-511-4290x5248', 'gender': 'Male', 'doj': datetime.date(2022, 11, 16), 'specializations': ['HTML', 'JavaScript', 'Microservices', 'Artificial Intelligence'], 'dob': datetime.date(1915, 2, 23), 'city': 'Mendozafurt', 'state': 'Florida', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'J!5Miu*X'}
# {'userId': 'Emp_64', 'firstName': 'Bethany', 'middleName': 'Patricia', 'lastName': 'Lewis', 'email': 'hayden32@example.org', 'phoneNumber': '896-651-3409x736', 'gender': 'Female', 'doj': datetime.date(2021, 11, 6), 'specializations': ['Data Visualization', '.NET', 'Network Security', 'Statistical Analysis'], 'dob': datetime.date(1960, 2, 8), 'city': 'East David', 'state': 'Mississippi', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '!8UCbiZ&'}
# {'userId': 'Emp_65', 'firstName': 'Kristin', 'middleName': 'Janice', 'lastName': 'Cruz', 'email': 'robin05@example.org', 'phoneNumber': '552-679-6494x181', 'gender': 'Female', 'doj': datetime.date(2023, 1, 19), 'specializations': ['JavaScript', 'Ruby', 'Statistical Analysis', 'Information Security'], 'dob': datetime.date(2022, 9, 1), 'city': 'Samuelport', 'state': 'Texas', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'Jds@8oOt'}
# {'userId': 'Emp_66', 'firstName': 'Debra', 'middleName': 'Bethany', 'lastName': 'Mcintyre', 'email': 'jonathon83@example.com', 'phoneNumber': '(245)791-9730', 'gender': 'Female', 'doj': datetime.date(2020, 2, 18), 'specializations': ['Information Security', 'Django', 'PHP', 'Data Visualization'], 'dob': datetime.date(1982, 4, 26), 'city': 'New Michelle', 'state': 'New Jersey', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')27TZ#yv'}
# {'userId': 'Emp_67', 'firstName': 'Lance', 'middleName': 'Julia', 'lastName': 'Lopez', 'email': 'pberry@example.com', 'phoneNumber': '338-643-9524', 'gender': 'Female', 'doj': datetime.date(2020, 4, 9), 'specializations': ['.NET', 'Microservices', 'Ruby', 'Test-Driven Development'], 'dob': datetime.date(1963, 6, 10), 'city': 'Bishopmouth', 'state': 'South Carolina', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '$0EZtOR%'}
# {'userId': 'Emp_68', 'firstName': 'Virginia', 'middleName': 'Edward', 'lastName': 'Rodriguez', 'email': 'kristinahernandez@example.com', 'phoneNumber': '613-304-7263x24467', 'gender': 'Female', 'doj': datetime.date(2023, 2, 8), 'specializations': ['RESTful API', 'Flask', 'MySQL', 'Continuous Deployment'], 'dob': datetime.date(1970, 1, 24), 'city': 'New Joseph', 'state': 'Oklahoma', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '*j9DVzX5'}
# {'userId': 'Emp_69', 'firstName': 'Amy', 'middleName': 'Patrick', 'lastName': 'Soto', 'email': 'millsjason@example.org', 'phoneNumber': '369-288-6294', 'gender': 'Female', 'doj': datetime.date(2024, 2, 5), 'specializations': ['PostgreSQL', 'Java', 'Flask', 'Azure'], 'dob': datetime.date(2013, 4, 21), 'city': 'East Dianeberg', 'state': 'Louisiana', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '2pk_6#Nt'}
# {'userId': 'Emp_70', 'firstName': 'Derrick', 'middleName': 'Deborah', 'lastName': 'Taylor', 'email': 'hughesrichard@example.com', 'phoneNumber': '787-673-6832x04109', 'gender': 'Male', 'doj': datetime.date(2021, 5, 12), 'specializations': ['Python', 'Information Security', 'Statistical Analysis', 'Flask'], 'dob': datetime.date(2010, 3, 16), 'city': 'Jacksontown', 'state': 'New Hampshire', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '4J%0nJ@b'}
# {'userId': 'Emp_71', 'firstName': 'Robert', 'middleName': 'Jon', 'lastName': 'Warner', 'email': 'xchen@example.org', 'phoneNumber': '747-785-3169', 'gender': 'Female', 'doj': datetime.date(2022, 7, 1), 'specializations': ['Machine Learning', 'SQL', 'Behavior-Driven Development', 'Docker'], 'dob': datetime.date(1953, 10, 31), 'city': 'Tylerhaven', 'state': 'Maine', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'T^n9Epyi'}
# {'userId': 'Emp_72', 'firstName': 'Christine', 'middleName': 'Mary', 'lastName': 'Sellers', 'email': 'mfrazier@example.com', 'phoneNumber': '(747)641-2300', 'gender': 'Female', 'doj': datetime.date(2020, 12, 14), 'specializations': ['Kubernetes', 'MySQL', 'Test-Driven Development', 'Continuous Deployment'], 'dob': datetime.date(1942, 2, 7), 'city': 'Juliefort', 'state': 'Mississippi', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^q&3Fx@r'}
# {'userId': 'Emp_73', 'firstName': 'Paul', 'middleName': 'Bryce', 'lastName': 'Palmer', 'email': 'felicia63@example.net', 'phoneNumber': '8545265790', 'gender': 'Female', 'doj': datetime.date(2022, 2, 16), 'specializations': ['Continuous Integration', 'Git', 'RESTful API', 'Data Analysis'], 'dob': datetime.date(1982, 3, 30), 'city': 'Lauraland', 'state': 'Washington', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'n^H1lRMg'}
# {'userId': 'Emp_74', 'firstName': 'Brittany', 'middleName': 'Daniel', 'lastName': 'Davila', 'email': 'elizabeth89@example.com', 'phoneNumber': '(681)523-1691x233', 'gender': 'Female', 'doj': datetime.date(2024, 2, 24), 'specializations': ['PHP', 'Flask', 'Java', 'Cybersecurity'], 'dob': datetime.date(1955, 5, 26), 'city': 'Robertsport', 'state': 'Vermont', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '$!6HBDRc'}
# {'userId': 'Emp_75', 'firstName': 'James', 'middleName': 'Leonard', 'lastName': 'Fleming', 'email': 'amyblake@example.org', 'phoneNumber': '+1-240-863-9322x711', 'gender': 'Female', 'doj': datetime.date(2021, 2, 9), 'specializations': ['Agile Methodologies', 'CSS', 'Data Science', 'Statistical Analysis'], 'dob': datetime.date(2006, 5, 6), 'city': 'Lake Joel', 'state': 'Arizona', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')x4DvyaW'}
# {'userId': 'Emp_76', 'firstName': 'Lori', 'middleName': 'Christopher', 'lastName': 'Martinez', 'email': 'jennifermyers@example.com', 'phoneNumber': '548.887.5596x937', 'gender': 'Male', 'doj': datetime.date(2022, 5, 3), 'specializations': ['HTML', 'AWS', 'Artificial Intelligence', 'Behavior-Driven Development'], 'dob': datetime.date(2001, 3, 31), 'city': 'New Robert', 'state': 'Florida', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '+cb7ZmW%'}
# {'userId': 'Emp_77', 'firstName': 'Christopher', 'middleName': 'Susan', 'lastName': 'Saunders', 'email': 'katelynbell@example.org', 'phoneNumber': '+1-651-808-0222x5408', 'gender': 'Male', 'doj': datetime.date(2021, 1, 14), 'specializations': ['Django', 'Machine Learning', 'Data Visualization', 'Python'], 'dob': datetime.date(2006, 7, 4), 'city': 'Elizabethbury', 'state': 'California', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '%q)2SKxz'}
# {'userId': 'Emp_78', 'firstName': 'Sarah', 'middleName': 'Samuel', 'lastName': 'White', 'email': 'rdixon@example.com', 'phoneNumber': '681.655.7556', 'gender': 'Female', 'doj': datetime.date(2022, 2, 23), 'specializations': ['Objective-C', 'Swift', 'Artificial Intelligence', 'Git'], 'dob': datetime.date(1925, 6, 25), 'city': 'Watkinsside', 'state': 'New Jersey', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^89TXyIo'}
# {'userId': 'Emp_79', 'firstName': 'Michelle', 'middleName': 'Robert', 'lastName': 'Mooney', 'email': 'xharris@example.com', 'phoneNumber': '001-270-900-2415x38291', 'gender': 'Male', 'doj': datetime.date(2020, 11, 1), 'specializations': ['Machine Learning', 'Node.js', 'Containerization', 'Penetration Testing'], 'dob': datetime.date(1918, 2, 13), 'city': 'Jasmineton', 'state': 'Illinois', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '1d*6WHmP'}
# {'userId': 'Emp_80', 'firstName': 'Margaret', 'middleName': 'Jasmine', 'lastName': 'Brewer', 'email': 'shane21@example.com', 'phoneNumber': '+1-997-563-8817x837', 'gender': 'Male', 'doj': datetime.date(2020, 2, 14), 'specializations': ['HTML', 'Agile Methodologies', 'Information Security', 'Data Science'], 'dob': datetime.date(2015, 12, 2), 'city': 'New Patriciaville', 'state': 'Michigan', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^PJv1Gqp'}
# {'userId': 'Emp_81', 'firstName': 'Jennifer', 'middleName': 'Rick', 'lastName': 'Howard', 'email': 'ramirezcindy@example.net', 'phoneNumber': '245-868-6468', 'gender': 'Male', 'doj': datetime.date(2020, 5, 20), 'specializations': ['Git', 'Django', 'Cryptography', 'Statistical Analysis'], 'dob': datetime.date(1982, 6, 10), 'city': 'Michaelfort', 'state': 'Alaska', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%419EtAh'}
# {'userId': 'Emp_82', 'firstName': 'Brandon', 'middleName': 'Elizabeth', 'lastName': 'Adams', 'email': 'changbrian@example.com', 'phoneNumber': '430.627.5399', 'gender': 'Female', 'doj': datetime.date(2022, 12, 28), 'specializations': ['Objective-C', 'Node.js', 'Flask', 'RESTful API'], 'dob': datetime.date(2002, 11, 26), 'city': 'Boothshire', 'state': 'New Mexico', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '*X0qEK(r'}
# {'userId': 'Emp_83', 'firstName': 'Tracy', 'middleName': 'Mark', 'lastName': 'Moore', 'email': 'kennethrhodes@example.org', 'phoneNumber': '665-622-0128', 'gender': 'Female', 'doj': datetime.date(2023, 3, 30), 'specializations': ['Node.js', 'Objective-C', 'Java', 'Kotlin'], 'dob': datetime.date(1951, 1, 8), 'city': 'Sherryshire', 'state': 'Iowa', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'fx!91XIj'}
# {'userId': 'Emp_84', 'firstName': 'Ian', 'middleName': 'Jonathan', 'lastName': 'Robinson', 'email': 'ecopeland@example.net', 'phoneNumber': '+1-894-513-6536', 'gender': 'Male', 'doj': datetime.date(2021, 2, 18), 'specializations': ['Machine Learning', 'Agile Methodologies', 'Django', 'C#'], 'dob': datetime.date(1998, 12, 16), 'city': 'Jamesside', 'state': 'Georgia', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '(07eoW9x'}
# {'userId': 'Emp_85', 'firstName': 'Mark', 'middleName': 'John', 'lastName': 'Henry', 'email': 'rpierce@example.net', 'phoneNumber': '(622)279-2040x857', 'gender': 'Male', 'doj': datetime.date(2020, 12, 9), 'specializations': ['DevOps', 'Flask', 'Node.js', 'PHP'], 'dob': datetime.date(1956, 9, 15), 'city': 'New Jennifer', 'state': 'Iowa', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')^3I9dsK'}
# {'userId': 'Emp_86', 'firstName': 'Joseph', 'middleName': 'Kevin', 'lastName': 'Byrd', 'email': 'ucarter@example.net', 'phoneNumber': '653-643-6697x7761', 'gender': 'Male', 'doj': datetime.date(2020, 2, 5), 'specializations': ['Data Visualization', 'PHP', 'DevOps', 'Flask'], 'dob': datetime.date(2000, 12, 27), 'city': 'Lopezview', 'state': 'Louisiana', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'F&9CMgzn'}
# {'userId': 'Emp_87', 'firstName': 'Justin', 'middleName': 'Brenda', 'lastName': 'Owens', 'email': 'hilllindsay@example.com', 'phoneNumber': '001-751-543-7299', 'gender': 'Female', 'doj': datetime.date(2020, 9, 16), 'specializations': ['Angular', 'RESTful API', 'HTML', 'CI/CD'], 'dob': datetime.date(1932, 11, 9), 'city': 'Ricardoshire', 'state': 'Idaho', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'e+6(rMcf'}
# {'userId': 'Emp_88', 'firstName': 'Christopher', 'middleName': 'Ryan', 'lastName': 'Trevino', 'email': 'jessicawilliams@example.net', 'phoneNumber': '490.337.9475x244', 'gender': 'Female', 'doj': datetime.date(2021, 5, 24), 'specializations': ['PHP', 'Flask', 'React', 'Artificial Intelligence'], 'dob': datetime.date(1913, 5, 10), 'city': 'North Paul', 'state': 'Nebraska', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '0_!8Ht_z'}
# {'userId': 'Emp_89', 'firstName': 'Alexander', 'middleName': 'Michael', 'lastName': 'Harris', 'email': 'dicksonhelen@example.org', 'phoneNumber': '001-257-346-7140x27252', 'gender': 'Female', 'doj': datetime.date(2022, 6, 29), 'specializations': ['Google Cloud Platform', 'Objective-C', 'Cybersecurity', 'Behavior-Driven Development'], 'dob': datetime.date(1908, 4, 9), 'city': 'New Ericamouth', 'state': 'Oregon', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '8N#r7B3e'}
# {'userId': 'Emp_90', 'firstName': 'John', 'middleName': 'Valerie', 'lastName': 'Blair', 'email': 'louismichael@example.com', 'phoneNumber': '880-766-1743x056', 'gender': 'Female', 'doj': datetime.date(2022, 1, 13), 'specializations': ['Continuous Deployment', 'Google Cloud Platform', 'Cybersecurity', 'Vue.js'], 'dob': datetime.date(1922, 12, 25), 'city': 'Brendatown', 'state': 'Indiana', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '*4(fXcip'}
# {'userId': 'Emp_91', 'firstName': 'Peter', 'middleName': 'Teresa', 'lastName': 'Soto', 'email': 'eguerrero@example.net', 'phoneNumber': '+1-346-203-5194x87589', 'gender': 'Male', 'doj': datetime.date(2021, 11, 2), 'specializations': ['RESTful API', 'AWS', 'Containerization', 'Django'], 'dob': datetime.date(2024, 2, 23), 'city': 'Port Sarahside', 'state': 'Wyoming', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': ')e69GGpa'}
# {'userId': 'Emp_92', 'firstName': 'Robert', 'middleName': 'Alejandro', 'lastName': 'Cervantes', 'email': 'nicolas94@example.com', 'phoneNumber': '282-730-5171', 'gender': 'Female', 'doj': datetime.date(2020, 1, 9), 'specializations': ['Containerization', 'Data Visualization', '.NET', 'Node.js'], 'dob': datetime.date(1998, 5, 18), 'city': 'Ritahaven', 'state': 'Rhode Island', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '6f#$09Mp'}
# {'userId': 'Emp_93', 'firstName': 'Melissa', 'middleName': 'Brian', 'lastName': 'Mclean', 'email': 'christophermontoya@example.net', 'phoneNumber': '216-344-3642', 'gender': 'Female', 'doj': datetime.date(2020, 10, 20), 'specializations': ['GraphQL', 'Artificial Intelligence', 'AWS', 'Git'], 'dob': datetime.date(1949, 8, 30), 'city': 'Huffton', 'state': 'Oklahoma', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '!8iR7Mb+'}
# {'userId': 'Emp_94', 'firstName': 'Tony', 'middleName': 'Catherine', 'lastName': 'Nicholson', 'email': 'brandyday@example.com', 'phoneNumber': '001-783-326-5266x468', 'gender': 'Male', 'doj': datetime.date(2022, 10, 15), 'specializations': ['Docker', 'Swift', 'Artificial Intelligence', 'Continuous Integration'], 'dob': datetime.date(1989, 7, 21), 'city': 'Peterschester', 'state': 'Washington', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'f7%q5XvB'}
# {'userId': 'Emp_95', 'firstName': 'Brandon', 'middleName': 'Robert', 'lastName': 'Diaz', 'email': 'justin99@example.org', 'phoneNumber': '529.905.8958', 'gender': 'Female', 'doj': datetime.date(2020, 5, 31), 'specializations': ['Cybersecurity', 'MySQL', 'Information Security', 'PostgreSQL'], 'dob': datetime.date(1982, 7, 9), 'city': 'Bryantchester', 'state': 'Arizona', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '9@+2H&xb'}
# {'userId': 'Emp_96', 'firstName': 'Billy', 'middleName': 'Joseph', 'lastName': 'Scott', 'email': 'hickmanhaley@example.com', 'phoneNumber': '(328)888-1049x080', 'gender': 'Male', 'doj': datetime.date(2023, 11, 8), 'specializations': ['Microservices', 'Google Cloud Platform', 'Scrum', 'Java'], 'dob': datetime.date(1974, 1, 14), 'city': 'Holmestown', 'state': 'Tennessee', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '*T4sSy$j'}
# {'userId': 'Emp_97', 'firstName': 'Michael', 'middleName': 'Scott', 'lastName': 'Myers', 'email': 'martinezmary@example.com', 'phoneNumber': '+1-622-323-8243x15036', 'gender': 'Male', 'doj': datetime.date(2024, 1, 3), 'specializations': ['MongoDB', 'Behavior-Driven Development', 'Swift', 'GraphQL'], 'dob': datetime.date(1981, 2, 13), 'city': 'Jessicahaven', 'state': 'South Dakota', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '@s#c59Lr'}
# {'userId': 'Emp_98', 'firstName': 'Michael', 'middleName': 'David', 'lastName': 'Rivera', 'email': 'sdavis@example.com', 'phoneNumber': '001-771-319-1978x956', 'gender': 'Female', 'doj': datetime.date(2023, 9, 5), 'specializations': ['Azure', 'Scrum', 'Data Science', 'Data Visualization'], 'dob': datetime.date(2023, 7, 14), 'city': 'Howellfurt', 'state': 'Georgia', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^_5xC^mJ'}
# {'userId': 'Emp_99', 'firstName': 'Steven', 'middleName': 'Paul', 'lastName': 'Wright', 'email': 'daniel65@example.net', 'phoneNumber': '804-392-7017x9361', 'gender': 'Male', 'doj': datetime.date(2021, 3, 16), 'specializations': ['Kotlin', 'Artificial Intelligence', 'Docker', 'Java'], 'dob': datetime.date(1923, 1, 28), 'city': 'Peterburgh', 'state': 'New Jersey', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'DD0&6XWe'}
# {'userId': 'Emp_100', 'firstName': 'Richard', 'middleName': 'Robert', 'lastName': 'Jackson', 'email': 'uhunt@example.com', 'phoneNumber': '(624)985-2926x583', 'gender': 'Female', 'doj': datetime.date(2022, 3, 10), 'specializations': ['Penetration Testing', 'Angular', 'Python', 'HTML'], 'dob': datetime.date(1981, 2, 11), 'city': 'Lake Thomas', 'state': 'Nebraska', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'a&8J3zLl'}
# {'userId': 'Emp_101', 'firstName': 'Lisa', 'middleName': 'Heather', 'lastName': 'Scott', 'email': 'kimberlyball@example.com', 'phoneNumber': '+1-499-789-9816x83096', 'gender': 'Male', 'doj': datetime.date(2022, 5, 17), 'specializations': ['Git', 'Azure', 'DevOps', 'Angular'], 'dob': datetime.date(1985, 2, 25), 'city': 'Simpsonshire', 'state': 'Washington', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'hCE+8)Na'}
# {'userId': 'Emp_102', 'firstName': 'Matthew', 'middleName': 'Dawn', 'lastName': 'Wilson', 'email': 'daniel51@example.org', 'phoneNumber': '+1-610-850-8750', 'gender': 'Male', 'doj': datetime.date(2021, 3, 6), 'specializations': ['Java', 'Ruby', 'Google Cloud Platform', 'Scrum'], 'dob': datetime.date(1942, 5, 31), 'city': 'Floresshire', 'state': 'Oregon', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '&lAe5Aek'}
# {'userId': 'Emp_103', 'firstName': 'Travis', 'middleName': 'Patrick', 'lastName': 'Graham', 'email': 'tmendoza@example.net', 'phoneNumber': '001-732-814-4550x19312', 'gender': 'Male', 'doj': datetime.date(2022, 11, 26), 'specializations': ['Azure', 'Network Security', 'Information Security', 'Microservices'], 'dob': datetime.date(2002, 6, 13), 'city': 'South Denise', 'state': 'Ohio', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '@nWm6Zfr'}
# ...
# {'userId': 'Emp_166', 'firstName': 'Jeremy', 'middleName': 'Adam', 'lastName': 'Henderson', 'email': 'john11@example.org', 'phoneNumber': '+1-542-305-4925x47233', 'gender': 'Male', 'doj': datetime.date(2023, 11, 5), 'specializations': ['Ruby', 'HTML', 'React', 'Penetration Testing'], 'dob': datetime.date(1913, 12, 18), 'city': 'East Markmouth', 'state': 'Oregon', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')@O8OfAa'}
# {'userId': 'Emp_167', 'firstName': 'Keith', 'middleName': 'Kyle', 'lastName': 'Holt', 'email': 'tara22@example.net', 'phoneNumber': '387-557-0389x51437', 'gender': 'Male', 'doj': datetime.date(2020, 5, 24), 'specializations': ['Penetration Testing', 'C#', 'Data Analysis', 'Ruby'], 'dob': datetime.date(2010, 9, 21), 'city': 'North Michelle', 'state': 'Tennessee', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '$7Swxh5Y'}
# {'userId': 'Emp_168', 'firstName': 'Angela', 'middleName': 'Kevin', 'lastName': 'Henderson', 'email': 'rduncan@example.org', 'phoneNumber': '682.694.3361x77072', 'gender': 'Male', 'doj': datetime.date(2023, 6, 29), 'specializations': ['.NET', 'CI/CD', 'PHP', 'C#'], 'dob': datetime.date(1956, 5, 13), 'city': 'North James', 'state': 'Mississippi', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '+c4DQVMc'}
# {'userId': 'Emp_169', 'firstName': 'April', 'middleName': 'Christina', 'lastName': 'Gordon', 'email': 'debbie82@example.net', 'phoneNumber': '(457)286-7285', 'gender': 'Male', 'doj': datetime.date(2020, 1, 6), 'specializations': ['Swift', 'JavaScript', 'Artificial Intelligence', 'DevOps'], 'dob': datetime.date(1932, 2, 19), 'city': 'Huynhhaven', 'state': 'Wisconsin', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '4%D1PIn!'}
# {'userId': 'Emp_170', 'firstName': 'Kendra', 'middleName': 'Carl', 'lastName': 'Rice', 'email': 'mark78@example.org', 'phoneNumber': '001-778-230-5861x8268', 'gender': 'Male', 'doj': datetime.date(2020, 7, 23), 'specializations': ['Cybersecurity', 'Git', 'Java', 'Kubernetes'], 'dob': datetime.date(1989, 12, 14), 'city': 'East Justinfurt', 'state': 'Hawaii', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': ')_0Ruh*('}
# {'userId': 'Emp_171', 'firstName': 'Louis', 'middleName': 'John', 'lastName': 'Robinson', 'email': 'margaretrobinson@example.net', 'phoneNumber': '+1-423-357-0299', 'gender': 'Female', 'doj': datetime.date(2022, 10, 3), 'specializations': ['Continuous Deployment', 'Scrum', 'Data Analysis', 'Java'], 'dob': datetime.date(2006, 9, 10), 'city': 'Lake Martinhaven', 'state': 'Nevada', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^@Z4!KWs'}
# {'userId': 'Emp_172', 'firstName': 'Jonathan', 'middleName': 'Samantha', 'lastName': 'Patel', 'email': 'gonzalesbrian@example.org', 'phoneNumber': '001-515-605-2768x915', 'gender': 'Male', 'doj': datetime.date(2021, 1, 13), 'specializations': ['MongoDB', 'HTML', 'Continuous Integration', 'SQL'], 'dob': datetime.date(1939, 7, 14), 'city': 'West Paulland', 'state': 'Vermont', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '&aY7YEcR'}
# {'userId': 'Emp_173', 'firstName': 'Donna', 'middleName': 'Hannah', 'lastName': 'Weber', 'email': 'derekwallace@example.net', 'phoneNumber': '+1-676-971-1053x02399', 'gender': 'Male', 'doj': datetime.date(2021, 2, 2), 'specializations': ['Continuous Deployment', 'Python', 'JavaScript', 'PHP'], 'dob': datetime.date(2011, 8, 4), 'city': 'Katrinaview', 'state': 'Mississippi', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '&32Iqdr&'}
# {'userId': 'Emp_174', 'firstName': 'Brianna', 'middleName': 'Alisha', 'lastName': 'Medina', 'email': 'zacosta@example.org', 'phoneNumber': '001-770-710-1044x865', 'gender': 'Male', 'doj': datetime.date(2024, 3, 29), 'specializations': ['MongoDB', 'Python', 'Agile Methodologies', 'AWS'], 'dob': datetime.date(1956, 9, 12), 'city': 'New Thomas', 'state': 'Florida', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%dy7NL1u'}
# {'userId': 'Emp_175', 'firstName': 'Lori', 'middleName': 'Katherine', 'lastName': 'Lawrence', 'email': 'mosskathryn@example.org', 'phoneNumber': '429-848-8934', 'gender': 'Female', 'doj': datetime.date(2022, 3, 2), 'specializations': ['Containerization', 'HTML', 'Scrum', 'Microservices'], 'dob': datetime.date(2005, 3, 2), 'city': 'New Williambury', 'state': 'West Virginia', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '&8awUdIq'}
# {'userId': 'Emp_176', 'firstName': 'Rachel', 'middleName': 'Sue', 'lastName': 'Green', 'email': 'michael38@example.org', 'phoneNumber': '908.762.4417x6725', 'gender': 'Female', 'doj': datetime.date(2022, 9, 17), 'specializations': ['MySQL', 'Django', 'Objective-C', 'Statistical Analysis'], 'dob': datetime.date(1959, 8, 3), 'city': 'Lake Tanya', 'state': 'Oregon', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '!p8XJrJ+'}
# {'userId': 'Emp_177', 'firstName': 'Justin', 'middleName': 'Dawn', 'lastName': 'Cunningham', 'email': 'david48@example.com', 'phoneNumber': '001-236-789-5310x08707', 'gender': 'Male', 'doj': datetime.date(2021, 5, 14), 'specializations': ['Statistical Analysis', 'Angular', 'NoSQL', 'Continuous Integration'], 'dob': datetime.date(1963, 2, 20), 'city': 'North Angela', 'state': 'Nevada', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'H(8Jk!wX'}
# {'userId': 'Emp_178', 'firstName': 'Monica', 'middleName': 'Monique', 'lastName': 'Jones', 'email': 'vsmith@example.net', 'phoneNumber': '396-906-8629x378', 'gender': 'Male', 'doj': datetime.date(2020, 1, 28), 'specializations': ['CSS', 'Cybersecurity', 'Containerization', 'Behavior-Driven Development'], 'dob': datetime.date(1975, 7, 18), 'city': 'South Nicholetown', 'state': 'Georgia', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': ')5J9NfD+'}
# {'userId': 'Emp_179', 'firstName': 'Monica', 'middleName': 'Tammy', 'lastName': 'Ward', 'email': 'hodana@example.org', 'phoneNumber': '(627)894-5199', 'gender': 'Male', 'doj': datetime.date(2020, 10, 14), 'specializations': ['Django', 'Scrum', 'Java', 'Node.js'], 'dob': datetime.date(1955, 3, 11), 'city': 'New Sharimouth', 'state': 'West Virginia', 'experience': 19, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#7W7Cn$d'}
# {'userId': 'Emp_180', 'firstName': 'Robin', 'middleName': 'Emily', 'lastName': 'Martinez', 'email': 'tylerhaley@example.com', 'phoneNumber': '799-811-4805', 'gender': 'Female', 'doj': datetime.date(2021, 5, 19), 'specializations': ['HTML', 'Docker', 'Machine Learning', 'CI/CD'], 'dob': datetime.date(1987, 9, 3), 'city': 'Lake Carol', 'state': 'North Dakota', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'h%q9v3Hn'}
# {'userId': 'Emp_181', 'firstName': 'Andrew', 'middleName': 'Anthony', 'lastName': 'Cole', 'email': 'davisgregory@example.org', 'phoneNumber': '+1-996-597-7433', 'gender': 'Female', 'doj': datetime.date(2020, 9, 23), 'specializations': ['Continuous Deployment', 'GraphQL', 'PostgreSQL', 'Node.js'], 'dob': datetime.date(1996, 9, 9), 'city': 'South Taylorberg', 'state': 'North Carolina', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'y^K9Ac2E'}
# {'userId': 'Emp_182', 'firstName': 'Steven', 'middleName': 'Chloe', 'lastName': 'Heath', 'email': 'amber95@example.com', 'phoneNumber': '873-316-6209', 'gender': 'Male', 'doj': datetime.date(2021, 6, 18), 'specializations': ['DevOps', 'Git', 'CI/CD', 'Containerization'], 'dob': datetime.date(1961, 11, 8), 'city': 'Stephanieview', 'state': 'Washington', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '%7IIM(iP'}
# {'userId': 'Emp_183', 'firstName': 'Lisa', 'middleName': 'Jesse', 'lastName': 'Hudson', 'email': 'craiglaura@example.com', 'phoneNumber': '249.790.2331', 'gender': 'Male', 'doj': datetime.date(2024, 2, 12), 'specializations': ['Java', 'JavaScript', 'Information Security', 'Django'], 'dob': datetime.date(1987, 6, 27), 'city': 'Thomaschester', 'state': 'Indiana', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'm)x@9Lzu'}
# {'userId': 'Emp_184', 'firstName': 'Eric', 'middleName': 'Janice', 'lastName': 'Snyder', 'email': 'kristyclark@example.net', 'phoneNumber': '+1-444-635-2803x9118', 'gender': 'Female', 'doj': datetime.date(2021, 4, 15), 'specializations': ['MySQL', 'RESTful API', 'Angular', 'Objective-C'], 'dob': datetime.date(1979, 6, 1), 'city': 'New Natasha', 'state': 'Tennessee', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '*F4X6ZEc'}
# {'userId': 'Emp_185', 'firstName': 'Joshua', 'middleName': 'Pamela', 'lastName': 'Martinez', 'email': 'ramosaaron@example.net', 'phoneNumber': '455.600.0875x0738', 'gender': 'Male', 'doj': datetime.date(2022, 3, 9), 'specializations': ['CSS', 'Python', 'Node.js', 'Azure'], 'dob': datetime.date(1963, 12, 16), 'city': 'Gardnerstad', 'state': 'Virginia', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')35^DwAk'}
# {'userId': 'Emp_186', 'firstName': 'Carrie', 'middleName': 'Gina', 'lastName': 'Zimmerman', 'email': 'daniel11@example.net', 'phoneNumber': '738.281.5913x3531', 'gender': 'Female', 'doj': datetime.date(2021, 8, 22), 'specializations': ['Objective-C', 'Cybersecurity', 'Kotlin', 'Node.js'], 'dob': datetime.date(2009, 5, 4), 'city': 'Gentrytown', 'state': 'Wyoming', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^+3tXnmq'}
# {'userId': 'Emp_187', 'firstName': 'Carolyn', 'middleName': 'Allison', 'lastName': 'Woods', 'email': 'amanda10@example.com', 'phoneNumber': '(206)404-9468', 'gender': 'Male', 'doj': datetime.date(2023, 2, 21), 'specializations': ['Test-Driven Development', 'Network Security', 'Java', 'Microservices'], 'dob': datetime.date(2007, 12, 15), 'city': 'South Lindafurt', 'state': 'Missouri', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '_P8tSdBx'}
# {'userId': 'Emp_188', 'firstName': 'Sandra', 'middleName': 'Janet', 'lastName': 'Dixon', 'email': 'jarvisrobert@example.com', 'phoneNumber': '318.429.0841', 'gender': 'Male', 'doj': datetime.date(2020, 11, 16), 'specializations': ['Google Cloud Platform', 'Docker', 'GraphQL', 'NoSQL'], 'dob': datetime.date(2001, 7, 13), 'city': 'East Amyton', 'state': 'West Virginia', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '7*3wIMht'}
# {'userId': 'Emp_189', 'firstName': 'Kelly', 'middleName': 'Savannah', 'lastName': 'Turner', 'email': 'hayesdeanna@example.com', 'phoneNumber': '+1-994-755-5823x6594', 'gender': 'Male', 'doj': datetime.date(2024, 4, 2), 'specializations': ['Microservices', 'Artificial Intelligence', 'Kotlin', 'Data Science'], 'dob': datetime.date(1916, 10, 16), 'city': 'Hannaland', 'state': 'Maryland', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'H+8BCwvC'}
# {'userId': 'Emp_190', 'firstName': 'Dean', 'middleName': 'Deborah', 'lastName': 'Lopez', 'email': 'maria66@example.org', 'phoneNumber': '+1-352-735-6003x138', 'gender': 'Male', 'doj': datetime.date(2022, 11, 16), 'specializations': ['Machine Learning', 'Docker', 'C#', 'Data Science'], 'dob': datetime.date(1922, 12, 9), 'city': 'New Christina', 'state': 'Alabama', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#%cY1VaN'}
# {'userId': 'Emp_191', 'firstName': 'Larry', 'middleName': 'Alan', 'lastName': 'Jackson', 'email': 'orrashley@example.net', 'phoneNumber': '(757)669-3888', 'gender': 'Male', 'doj': datetime.date(2022, 6, 3), 'specializations': ['Python', 'Objective-C', 'Ruby', 'PHP'], 'dob': datetime.date(1984, 5, 14), 'city': 'Port Amanda', 'state': 'Louisiana', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'V&0E5QXv'}
# {'userId': 'Emp_192', 'firstName': 'Tyrone', 'middleName': 'Christopher', 'lastName': 'Hernandez', 'email': 'ravenflores@example.com', 'phoneNumber': '001-812-681-4451x586', 'gender': 'Male', 'doj': datetime.date(2021, 6, 2), 'specializations': ['Scrum', 'Angular', 'Network Security', 'Data Analysis'], 'dob': datetime.date(1911, 8, 16), 'city': 'Port Markside', 'state': 'Florida', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'p)*4BUvk'}
# {'userId': 'Emp_193', 'firstName': 'Beth', 'middleName': 'Jessica', 'lastName': 'Mccall', 'email': 'jeremy07@example.org', 'phoneNumber': '(628)467-7576x5441', 'gender': 'Female', 'doj': datetime.date(2024, 3, 18), 'specializations': ['CSS', 'Scrum', 'Node.js', 'Docker'], 'dob': datetime.date(1984, 10, 7), 'city': 'Armstrongview', 'state': 'Florida', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'j%5K6Bls'}
# {'userId': 'Emp_194', 'firstName': 'Tanya', 'middleName': 'Nicholas', 'lastName': 'Williams', 'email': 'lanejennifer@example.org', 'phoneNumber': '(784)752-2980x411', 'gender': 'Male', 'doj': datetime.date(2020, 11, 24), 'specializations': ['NoSQL', 'React', 'DevOps', 'Data Science'], 'dob': datetime.date(1913, 12, 5), 'city': 'Smithburgh', 'state': 'Kansas', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '(g4N*Axj'}
# {'userId': 'Emp_195', 'firstName': 'William', 'middleName': 'Kimberly', 'lastName': 'Johnson', 'email': 'daniellebowman@example.com', 'phoneNumber': '+1-563-427-4742x72095', 'gender': 'Male', 'doj': datetime.date(2023, 6, 14), 'specializations': ['PHP', 'React', 'Angular', 'RESTful API'], 'dob': datetime.date(1952, 7, 23), 'city': 'Lake Garybury', 'state': 'South Carolina', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'O+1jKOsR'}
# {'userId': 'Emp_196', 'firstName': 'John', 'middleName': 'Dorothy', 'lastName': 'Vaughn', 'email': 'gregory36@example.com', 'phoneNumber': '216-817-5154', 'gender': 'Male', 'doj': datetime.date(2020, 6, 27), 'specializations': ['GraphQL', '.NET', 'Cybersecurity', 'Information Security'], 'dob': datetime.date(2013, 4, 21), 'city': 'East Gabriellashire', 'state': 'Massachusetts', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'e#2pHXhn'}
# {'userId': 'Emp_197', 'firstName': 'Alexandria', 'middleName': 'James', 'lastName': 'Martinez', 'email': 'sarah02@example.org', 'phoneNumber': '780.747.4095x109', 'gender': 'Female', 'doj': datetime.date(2020, 9, 11), 'specializations': ['Behavior-Driven Development', 'SQL', 'Information Security', 'Cryptography'], 'dob': datetime.date(1934, 7, 27), 'city': 'New Douglas', 'state': 'Idaho', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '_5QyswoC'}
# {'userId': 'Emp_198', 'firstName': 'Mark', 'middleName': 'Beth', 'lastName': 'Arnold', 'email': 'franciscobishop@example.net', 'phoneNumber': '521.994.1324', 'gender': 'Male', 'doj': datetime.date(2022, 12, 20), 'specializations': ['.NET', 'HTML', 'Continuous Deployment', 'React'], 'dob': datetime.date(2014, 11, 25), 'city': 'Wendyview', 'state': 'New Mexico', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '$54ULQoy'}
# {'userId': 'Emp_199', 'firstName': 'William', 'middleName': 'Cynthia', 'lastName': 'Golden', 'email': 'esantiago@example.org', 'phoneNumber': '911-554-7956', 'gender': 'Female', 'doj': datetime.date(2022, 8, 2), 'specializations': ['Machine Learning', 'Swift', 'Data Visualization', 'Docker'], 'dob': datetime.date(1931, 12, 13), 'city': 'Stanleyborough', 'state': 'North Dakota', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '6*B*7VGm'}

# %%
# Write data to CSV file
csv_file_path = "user_data1.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for user_data in fake_data_list:
        writer.writerow(user_data)

print(f"User data has been saved to {csv_file_path}")
# Out:
# User data has been saved to user_data1.csv

# %%
import csv
from datetime import datetime, timedelta

# %%
fake_data_list = []
for i in range(1, 50):
    certificates = random.sample(skills, 4)
    user_id = fake.random_int(min=1, max=200)
    user_data = {
        "userId": "Emp_" + str(user_id),
        "trainerName": fake.first_name(),
        "trainerDesignation": fake.random_element(elements=job_roles),
        "trainerRating": fake.random_int(min=1, max=5),
        "trainerSpecialization": certificates,
    }
    fake_data_list.append(user_data)

# Print the generated fake data
for user_data in fake_data_list:
    print(user_data)
# Out:
# {'userId': 'Emp_189', 'trainerName': 'Derrick', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 2, 'trainerSpecialization': ['Scrum', '.NET', 'Git', 'PHP']}
# {'userId': 'Emp_143', 'trainerName': 'Jared', 'trainerDesignation': 'Scrum Master', 'trainerRating': 1, 'trainerSpecialization': ['Machine Learning', 'Django', 'JavaScript', 'Azure']}
# {'userId': 'Emp_193', 'trainerName': 'Melinda', 'trainerDesignation': 'Business Analyst', 'trainerRating': 2, 'trainerSpecialization': ['Artificial Intelligence', 'Java', 'HTML', 'Vue.js']}
# {'userId': 'Emp_195', 'trainerName': 'Michael', 'trainerDesignation': 'Technical Architect', 'trainerRating': 5, 'trainerSpecialization': ['GraphQL', 'React', 'Flask', 'Artificial Intelligence']}
# {'userId': 'Emp_107', 'trainerName': 'Jamie', 'trainerDesignation': 'Data Scientist', 'trainerRating': 2, 'trainerSpecialization': ['Cybersecurity', 'Artificial Intelligence', 'DevOps', 'Network Security']}
# {'userId': 'Emp_79', 'trainerName': 'Jennifer', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Ruby', 'Statistical Analysis', 'Kubernetes', 'SQL']}
# {'userId': 'Emp_166', 'trainerName': 'Brandon', 'trainerDesignation': 'Backend Developer', 'trainerRating': 3, 'trainerSpecialization': ['.NET', 'DevOps', 'Google Cloud Platform', 'Continuous Deployment']}
# {'userId': 'Emp_56', 'trainerName': 'Donald', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 5, 'trainerSpecialization': ['Continuous Deployment', '.NET', 'RESTful API', 'C#']}
# {'userId': 'Emp_124', 'trainerName': 'Christopher', 'trainerDesignation': 'Network Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Vue.js', 'PostgreSQL', 'HTML', 'Git']}
# {'userId': 'Emp_181', 'trainerName': 'Adam', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 4, 'trainerSpecialization': ['NoSQL', 'Google Cloud Platform', 'PHP', 'Agile Methodologies']}
# {'userId': 'Emp_30', 'trainerName': 'Jacob', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 5, 'trainerSpecialization': ['Agile Methodologies', 'Behavior-Driven Development', 'Python', 'Containerization']}
# {'userId': 'Emp_24', 'trainerName': 'Jeffrey', 'trainerDesignation': 'Configuration Manager', 'trainerRating': 5, 'trainerSpecialization': ['Java', 'Network Security', 'Machine Learning', 'CSS']}
# {'userId': 'Emp_76', 'trainerName': 'Emily', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 4, 'trainerSpecialization': ['Continuous Deployment', 'Statistical Analysis', 'Artificial Intelligence', 'AWS']}
# {'userId': 'Emp_104', 'trainerName': 'James', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 1, 'trainerSpecialization': ['Kubernetes', 'NoSQL', 'Containerization', 'React']}
# {'userId': 'Emp_63', 'trainerName': 'Derrick', 'trainerDesignation': 'Product Manager', 'trainerRating': 1, 'trainerSpecialization': ['Data Visualization', 'Network Security', 'Python', 'Kotlin']}
# {'userId': 'Emp_93', 'trainerName': 'Ronald', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 2, 'trainerSpecialization': ['Statistical Analysis', 'DevOps', '.NET', 'Python']}
# {'userId': 'Emp_124', 'trainerName': 'Michael', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Data Analysis', 'Data Visualization', 'GraphQL', 'Behavior-Driven Development']}
# {'userId': 'Emp_56', 'trainerName': 'Susan', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 3, 'trainerSpecialization': ['PHP', '.NET', 'CI/CD', 'C#']}
# {'userId': 'Emp_3', 'trainerName': 'Rebecca', 'trainerDesignation': 'Agile Coach', 'trainerRating': 2, 'trainerSpecialization': ['NoSQL', 'Network Security', 'Scrum', 'Artificial Intelligence']}
# {'userId': 'Emp_15', 'trainerName': 'Rebecca', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 1, 'trainerSpecialization': ['Google Cloud Platform', 'PHP', 'Penetration Testing', 'Azure']}
# {'userId': 'Emp_111', 'trainerName': 'Courtney', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 4, 'trainerSpecialization': ['SQL', 'Scrum', 'Containerization', 'C#']}
# {'userId': 'Emp_131', 'trainerName': 'Nathaniel', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 2, 'trainerSpecialization': ['Django', 'Microservices', 'Information Security', 'Python']}
# {'userId': 'Emp_123', 'trainerName': 'Andrew', 'trainerDesignation': 'Software Tester', 'trainerRating': 5, 'trainerSpecialization': ['Objective-C', 'Java', 'Penetration Testing', 'Microservices']}
# {'userId': 'Emp_119', 'trainerName': 'Nicholas', 'trainerDesignation': 'Scrum Master', 'trainerRating': 1, 'trainerSpecialization': ['Git', 'Node.js', 'Data Visualization', 'Artificial Intelligence']}
# {'userId': 'Emp_188', 'trainerName': 'Robert', 'trainerDesignation': 'Software Engineer', 'trainerRating': 5, 'trainerSpecialization': ['CI/CD', 'Information Security', 'Vue.js', 'Continuous Deployment']}
# {'userId': 'Emp_200', 'trainerName': 'Christine', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Azure', 'Objective-C', 'Git', 'Continuous Integration']}
# {'userId': 'Emp_182', 'trainerName': 'Jeffrey', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 5, 'trainerSpecialization': ['Flask', 'Data Visualization', 'Scrum', 'C#']}
# {'userId': 'Emp_17', 'trainerName': 'Felicia', 'trainerDesignation': 'Agile Coach', 'trainerRating': 4, 'trainerSpecialization': ['Node.js', 'CI/CD', 'Java', 'Flask']}
# {'userId': 'Emp_104', 'trainerName': 'Tammy', 'trainerDesignation': 'Business Analyst', 'trainerRating': 3, 'trainerSpecialization': ['Kubernetes', 'Test-Driven Development', 'NoSQL', 'GraphQL']}
# {'userId': 'Emp_146', 'trainerName': 'Cassidy', 'trainerDesignation': 'Software Engineer', 'trainerRating': 3, 'trainerSpecialization': ['SQL', 'Docker', 'CI/CD', 'Network Security']}
# {'userId': 'Emp_41', 'trainerName': 'Angela', 'trainerDesignation': 'Software Engineer', 'trainerRating': 3, 'trainerSpecialization': ['SQL', 'Kubernetes', 'Test-Driven Development', 'Machine Learning']}
# {'userId': 'Emp_171', 'trainerName': 'Lisa', 'trainerDesignation': 'IT Administrator', 'trainerRating': 4, 'trainerSpecialization': ['PHP', 'Data Science', 'Information Security', 'Machine Learning']}
# {'userId': 'Emp_40', 'trainerName': 'Tracy', 'trainerDesignation': 'Network Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Behavior-Driven Development', 'Git', 'C#', 'Statistical Analysis']}
# {'userId': 'Emp_138', 'trainerName': 'Shannon', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Swift', 'PHP', 'Flask', 'Data Science']}
# {'userId': 'Emp_140', 'trainerName': 'Christopher', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 3, 'trainerSpecialization': ['Data Visualization', 'SQL', 'Django', 'Behavior-Driven Development']}
# {'userId': 'Emp_90', 'trainerName': 'Jeffrey', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Java', 'RESTful API', 'Data Analysis', 'Cryptography']}
# {'userId': 'Emp_92', 'trainerName': 'Ernest', 'trainerDesignation': 'Agile Coach', 'trainerRating': 3, 'trainerSpecialization': ['Node.js', 'Cybersecurity', 'Ruby', 'GraphQL']}
# {'userId': 'Emp_108', 'trainerName': 'George', 'trainerDesignation': 'Technical Architect', 'trainerRating': 4, 'trainerSpecialization': ['CSS', 'Google Cloud Platform', 'Kubernetes', 'Agile Methodologies']}
# {'userId': 'Emp_167', 'trainerName': 'Shannon', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 5, 'trainerSpecialization': ['Continuous Deployment', 'Cryptography', 'GraphQL', 'Ruby']}
# {'userId': 'Emp_68', 'trainerName': 'Lori', 'trainerDesignation': 'Full-stack Developer', 'trainerRating': 3, 'trainerSpecialization': ['MongoDB', 'Penetration Testing', 'CI/CD', 'Scrum']}
# {'userId': 'Emp_63', 'trainerName': 'Troy', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 3, 'trainerSpecialization': ['MySQL', 'Kubernetes', 'Agile Methodologies', 'Continuous Deployment']}
# {'userId': 'Emp_90', 'trainerName': 'Miguel', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 1, 'trainerSpecialization': ['Python', 'Git', 'NoSQL', 'AWS']}
# {'userId': 'Emp_15', 'trainerName': 'Judy', 'trainerDesignation': 'Frontend Developer', 'trainerRating': 5, 'trainerSpecialization': ['Machine Learning', 'JavaScript', 'Artificial Intelligence', 'DevOps']}
# {'userId': 'Emp_180', 'trainerName': 'Joshua', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Agile Methodologies', 'Data Visualization', 'AWS', 'Penetration Testing']}
# {'userId': 'Emp_175', 'trainerName': 'Lucas', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 5, 'trainerSpecialization': ['Objective-C', 'Statistical Analysis', 'Machine Learning', 'Git']}
# {'userId': 'Emp_132', 'trainerName': 'Andrew', 'trainerDesignation': 'Security Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Cryptography', 'HTML', 'AWS', 'Node.js']}
# {'userId': 'Emp_13', 'trainerName': 'Connie', 'trainerDesignation': 'Backend Developer', 'trainerRating': 5, 'trainerSpecialization': ['SQL', 'Angular', 'MySQL', 'HTML']}
# {'userId': 'Emp_124', 'trainerName': 'William', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Ruby', 'Data Analysis', 'GraphQL', 'Azure']}
# {'userId': 'Emp_106', 'trainerName': 'Brian', 'trainerDesignation': 'Full-stack Developer', 'trainerRating': 5, 'trainerSpecialization': ['MySQL', 'Node.js', 'RESTful API', 'PHP']}

# %%
# Write data to CSV file
csv_file_path = "trainer_data1.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for user_data in fake_data_list:
        writer.writerow(user_data)

print(f"User data has been saved to {csv_file_path}")
# Out:
# User data has been saved to trainer_data1.csv

# %%
import random
from faker import Faker
from datetime import timedelta
import csv

# Initialize Faker
fake = Faker()

fake_data_list = []

# Define the list of possible training names
training_names = [
    "Introduction to Python Programming",
    "Web Development Fundamentals",
    "Data Science Essentials",
    "Machine Learning Basics",
    "Introduction to JavaScript",
    "Frontend Development with React",
    "Backend Development with Node.js",
    "Database Management with MongoDB",
    "Cloud Computing Fundamentals",
    "Cybersecurity Essentials"
]

# Generate fake data
for i in range(1, 100):
    certificates = random.sample(training_names, 4)
    start_date = fake.date_between(start_date=datetime(2024, 1, 1), end_date=datetime(2024, 12, 31))
    end_date = start_date + timedelta(days=random.randint(5, 10))  # Random end date 5 to 10 days ahead
    user_id = fake.random_int(min=1, max=200)
    training_data = {
        "trainingId": "Training_" + str(i),
        "trainingName": fake.random_element(elements=certificates),
        "trainingDescription": fake.sentence(),
        "trainerId": "Emp_" + str(user_id),
        "startDate": start_date,
        "endDate": end_date,
        "optimizedDuration": fake.random_int(min=1, max=40),
        "timingOfTraining": f"{start_date.strftime('%Y-%m-%d %H:%M:%S')} - {end_date.strftime('%Y-%m-%d %H:%M:%S')}",  # New column for timing
        "createdAt": fake.date_time_this_year(),
    }
    fake_data_list.append(training_data)

# Write data to CSV file
csv_file_path = "training_data1.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for training_data in fake_data_list:
        writer.writerow(training_data)

print(f"Training data has been saved to {csv_file_path}")
# Out:
# Training data has been saved to training_data1.csv

# %%
import csv
import random
from faker import Faker

fake = Faker()

fake_data_list = []

# Define the list of possible quiz names
quiz_names = [
    "Introduction to Python Quiz",
    "Web Development Fundamentals Quiz",
    "Data Science Essentials Quiz",
    "Machine Learning Basics Quiz",
    "Introduction to JavaScript Quiz",
    "Frontend Development with React Quiz",
    "Backend Development with Node.js Quiz",
    "Database Management with MongoDB Quiz",
    "Cloud Computing Fundamentals Quiz",
    "Cybersecurity Essentials Quiz"
]

# Define the list of possible file names for questions
question_files = [
    "questions1.csv",
    "questions2.csv",
    "questions3.csv",
    "questions4.csv",
    "questions5.csv"
]

# Generate fake data
for i in range(1, 100):
    quiz_data = {
        "quizName": fake.random_element(elements=quiz_names),
        "trainingId": "Training_" + str(i),
        "trainingName": fake.sentence(),
        "maxScores": fake.random_int(min=100, max=100),
        "minScores": fake.random_int(min=50, max=50),
        "difficultyLevel": fake.random_element(elements=("easy", "moderate", "hard")),
        "questionFile": fake.random_element(elements=question_files),
    }
    fake_data_list.append(quiz_data)

# Write data to CSV file
csv_file_path = "quiz_data1.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for quiz_data in fake_data_list:
        writer.writerow(quiz_data)

print(f"Quiz data has been saved to {csv_file_path}")
# Out:
# Quiz data has been saved to quiz_data1.csv

# %%
import csv
import random
from faker import Faker

fake = Faker()

fake_data_list = []

# Define the list of possible training statuses
training_statuses = ['pending', 'in_progress', 'completed']

# Generate fake data
for i in range(1, 1000):
    training_status = fake.random_element(elements=training_statuses)
    if training_status == 'pending':
        assessment_percentage_done = 0
        assessment_completion_time_in_hours= None
    elif training_status == 'completed':
        assessment_percentage_done = 100
        assessment_completion_time_in_hours = fake.random_int(min=1, max=60)
    else:
        assessment_percentage_done = fake.random_int(min=0, max=100)
        assessment_completion_time_in_hours = None
        
    if training_status in ['pending', 'in_progress']:
        score_achieved_in_quiz = None
        quiz_passed_or_failed = None
    else:
        score_achieved_in_quiz = fake.random_int(min=0, max=100)
        if score_achieved_in_quiz < 50:
            quiz_passed_or_failed = 'failed'
        else:
            quiz_passed_or_failed = 'passed'
        
    training_id = fake.random_int(min=1, max=100)
    trainer_id = fake.random_int(min=1, max=100)
    user_id = fake.random_int(min=1, max=200)
    
    tracker_data = {
        "userId": "Emp_" + str(user_id),
        "trainingId": "Training_" + str(training_id),
        "trainingStatus": training_status,
        "assessment_percentage_done": assessment_percentage_done,
        "assessment_completion_time_in_hours": assessment_completion_time_in_hours,
        "scoreAchievedInQuiz": score_achieved_in_quiz,
        "quizPassedOrFailed": quiz_passed_or_failed,
        "ratingGivenByTrainer": fake.random_int(min=1, max=5),
    }
    fake_data_list.append(tracker_data)

# Write data to CSV file
csv_file_path = "tracker_data1.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = ["userId", "trainingId", "trainerId", "trainingStatus", "assessment_percentage_done", 
                  "assessment_completion_time_in_hours", "scoreAchievedInQuiz", "quizPassedOrFailed", 
                  "ratingGivenByTrainer"]
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for tracker_data in fake_data_list:
        writer.writerow(tracker_data)

print(f"Tracker data has been saved to {csv_file_path}")
# Out:
# Tracker data has been saved to tracker_data1.csv

# %%
import csv
import pandas as pd

# %%
df = pd.DataFrame(user_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.DataFrame(user_data[0])
#
# KeyError: 0

# %%
import pandas as pd

num_records=pd.read_csv('Project.userdetails.csv')

# %%
df=pd.DataFrame(num_records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 2
#       1 df=pd.DataFrame(num_records)
# ----> 2 iloc.df[1]
#
# NameError: name 'iloc' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7748\1395128912.py in ?()
#       1 fake_data_list=df['Empid']
# ----> 2 fake_data_list.removenull()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'removenull'

# %%
num_records
import rand

# %%
skills = [
    "Python", "JavaScript", "HTML", "CSS", "React", "Angular", "Vue.js", "Node.js", "Django", "Flask",
    "Java", "Kotlin", "Swift", "Objective-C", "C#", ".NET", "PHP", "Ruby", "SQL", "NoSQL",
    "MongoDB", "MySQL", "PostgreSQL", "Git", "Docker", "Kubernetes", "AWS", "Azure", "Google Cloud Platform",
    "RESTful API", "GraphQL", "CI/CD", "Agile Methodologies", "Scrum", "Test-Driven Development",
    "Behavior-Driven Development", "DevOps", "Continuous Integration", "Continuous Deployment", "Microservices",
    "Containerization", "Machine Learning", "Artificial Intelligence", "Data Science", "Data Analysis",
    "Data Visualization", "Statistical Analysis", "Cybersecurity", "Network Security", "Penetration Testing",
    "Cryptography", "Information Security", "UI/UX Design", "Wireframing", "Prototyping", "User Research",
    "Interaction Design", "Responsive Design", "Accessibility", "Product Management", "Agile Product Management",
    "Requirements Analysis", "User Stories", "Business Analysis", "Technical Writing", "Documentation",
    "Support", "Troubleshooting", "Problem Solving", "Communication", "Collaboration", "Leadership"
]

# %%
 data = []
for i in fake_data_list:
    empid = i
    certificates = random.sample(skills, 4)  # Pick 4 unique certificates randomly
    for certificate in certificates:
        record = {
            "Empid": empid,
            "certificateName": certificate,
            "issuingOrganization": fake.company(),
            "issueDate": fake.date(),
            "ExpireDate": fake.future_date(),
            "credentialID": fake.uuid4(),
            "Status": random.choice(["Approved", "Rejected"])
        }
        data.append(record)

# %%
df=pd.DataFrame(data)

# %%
df.to_csv('certificateData.csv')

# %%
projects = [
    "PixelPlex Crypto Trader",
    "BlueFinity Evoke",
    "CyberCode Online Store",
    "TechTrek Data Analyzer",
    "ByteBlitz Document Manager",
    "NexGen Mobile Scheduler",
    "Streamline Solutions CRM",
    "DataLink Inventory Tracker",
    "SilverLinx POS System",
    "EchoTech Task Manager",
    "CodeCraft Web Builder",
    "FusionSoft Email Client",
    "LogicLane Project Tracker",
    "VortexVision Virtual Assistant",
    "InnovateSoft Budget Planner",
    "DataForge Dashboard Creator",
    "SwiftShift Time Tracker",
    "MetaMind Chatbot Builder",
    "TechNova Backup Solution",
    "QuickTech Remote Support",
    "CatalystCommerce",
    "DataSync",
    "AgileFlow",
    "InnovatePro",
    "ByteBoost",
    "PixelWare",
    "DataPulse",
    "CyberLink",
    "SwiftWave",
    "TechSprint",
    "InnovaTech",
    "DataBridge",
    "PixelWorks",
    "CyberTech",
    "CodeCraft",
    "AgileWare",
    "ByteForge",
    "PixelPulse",
    "DataCraft",
    "TechSpark",
    "SwiftCode",
    "AgileTech",
    "DataWave"
]

# %%
project_types = [
    "Web Application",
    "Mobile App",
    "Desktop Software",
    "CRM System",
    "Inventory Management System",
    "E-commerce Platform",
    "Content Management System",
    "Task Management Tool",
    "Email Client",
    "Document Management System",
    "Chatbot",
    "Virtual Assistant",
    "Budget Planner",
    "Dashboard Creator",
    "Time Tracking Tool",
    "POS System",
    "Backup Solution",
    "Remote Support Tool",
    "Crypto Trader",
    "Data Analyzer",
    "Social Networking Platform",
    "Online Marketplace",
    "Customer Service Software",
    "Payment Gateway",
    "Booking System",
    "Learning Management System",
    "Customer Relationship Management",
    "Project Management Software",
    "Human Resource Management System",
    "Inventory Control System",
    "Event Management Software",
    "Appointment Scheduling Software",
    "Survey Software",
    "Healthcare Management System",
    "Sales Forecasting Software",
    "Accounting Software",
    "Asset Management System",
    "Content Delivery Network",
    "Data Visualization Tool",
    "Educational Software",
    "Fleet Management System",
    "Help Desk Software",
    "Retail Management System",
    "Supply Chain Management Software",
    "Ticketing System",
    "Warehouse Management System",
    "Workflow Management Software"
]

# %%
project_roles = [
    "Developer",
    "Designer",
    "Project Manager",
    "Quality Assurance Engineer",
    "Business Analyst",
    "DevOps Engineer",
    "Database Administrator",
    "Technical Architect",
    "UI/UX Designer",
    "Product Manager",
    "Network Engineer",
    "Cybersecurity Specialist",
    "Data Scientist",
    "Machine Learning Engineer",
    "Artificial Intelligence Engineer",
    "Cloud Solutions Architect",
    "Technical Writer",
    "IT Support Specialist",
    "Release Manager",
    "Configuration Manager",
    "Automation Tester",
    "Performance Engineer"
]

# %%
project1 = random.sample(projects, 4)
project1
# Out:
# ['DataCraft', 'CodeCraft', 'NexGen Mobile Scheduler', 'InnovaTech']

# %%
data = []
for i in fake_data_list:
    empid = i
    project = random.sample(projects, 4)  # Pick 4 unique certificates randomly
    for pro in project:
        record = {
            "Empid": empid,
            "projectName": pro,
            "projectType": random.choice(project_types),
            "description": fake.text(),
            "startDate": fake.date(),
            "endDate": fake.future_date(),
            "role": random.choice(project_roles),
            "Status": random.choice(["Approved", "Rejected"])
        }
        data.append(record)

# %%
  data
# Out:
# [{'Empid': 'Emp_0',
#   'projectName': 'PixelPulse',
#   'projectType': 'Document Management System',
#   'description': 'Window agent season consumer ahead. Benefit bring imagine.',
#   'startDate': '1992-01-12',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'IT Support Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_0',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Human Resource Management System',
#   'description': 'Edge how customer. This trade treatment science read than check gas. Ahead act might everything. Appear rise generation kitchen letter degree station.\nMost sit west population send book whole.',
#   'startDate': '1976-05-11',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_0',
#   'projectName': 'AgileTech',
#   'projectType': 'Web Application',
#   'description': 'Push government think. Nothing parent age.\nYet study rich thus door tell tree. Happen wife age hear movie election.\nMust somebody expert compare necessary vote campaign. Sometimes read environmental.',
#   'startDate': '1972-04-07',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_0',
#   'projectName': 'DataPulse',
#   'projectType': 'Accounting Software',
#   'description': 'Month close truth hard. Morning form control. Amount pay smile after seek nothing behavior result.\nThree act field true cover.',
#   'startDate': '2000-01-08',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'InnovaTech',
#   'projectType': 'Retail Management System',
#   'description': 'If doctor open several people per. Bar later air positive their. One thousand someone unit air.',
#   'startDate': '1972-01-15',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'DataBridge',
#   'projectType': 'Document Management System',
#   'description': 'Ever exactly rock street. Least life too notice network. Official its yet notice task as.',
#   'startDate': '2012-01-01',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'InnovatePro',
#   'projectType': 'Budget Planner',
#   'description': 'Capital human edge ever likely stock stock any. Ahead quality executive choice what. Discuss research product describe father factor.',
#   'startDate': '2016-11-08',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Release Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'AgileWare',
#   'projectType': 'Content Management System',
#   'description': 'Court present machine candidate get pick. Floor know might live.',
#   'startDate': '2016-08-27',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_2',
#   'projectName': 'ByteBoost',
#   'projectType': 'Event Management Software',
#   'description': 'Throw international hand. Education coach talk. Side second act including effect lose probably wind.\nReflect property beat similar. Hand number green American religious various necessary draw.',
#   'startDate': '1978-11-27',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_2',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Booking System',
#   'description': 'Spend buy accept yourself many president another. This executive there hear realize think. Most pattern stay term pressure sea.\nBy seek popular see wrong.',
#   'startDate': '1985-04-30',
#   'endDate': datetime.date(2024, 4, 10),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_2',
#   'projectName': 'InnovatePro',
#   'projectType': 'Virtual Assistant',
#   'description': 'Unit plan on course ahead brother. Far too west director very guy. Again least behavior organization form family boy. Scene color physical skin authority everybody attack.',
#   'startDate': '1981-08-11',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Developer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_2',
#   'projectName': 'CodeCraft',
#   'projectType': 'Inventory Control System',
#   'description': 'Cold price research end difficult.\nBeyond majority notice bill role. Discover while at three various think.',
#   'startDate': '1986-09-28',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_3',
#   'projectName': 'SwiftWave',
#   'projectType': 'Crypto Trader',
#   'description': 'Growth speech find specific happy conference. Top issue figure world situation drug worry. Leg force someone quite matter.',
#   'startDate': '1990-09-08',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_3',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Customer Service Software',
#   'description': 'Maybe international still notice develop operation.\nTelevision speech future dinner wind. Person decision again politics range Mr group. House for huge mother opportunity investment.',
#   'startDate': '1973-07-12',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'UI/UX Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_3',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Human Resource Management System',
#   'description': 'New class hit without when amount suggest. Happen official scene may power early woman. Space charge charge whose.',
#   'startDate': '1977-08-18',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_3',
#   'projectName': 'TechSpark',
#   'projectType': 'Chatbot',
#   'description': 'Something next PM send finally two.\nGeneration color human yeah truth conference the. Yet more lot expect determine traditional know. Boy play give put form letter response.',
#   'startDate': '2023-03-11',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_4',
#   'projectName': 'BlueFinity Evoke',
#   'projectType': 'Customer Service Software',
#   'description': 'Dark rule together garden travel them. Remember president citizen seem officer doctor amount for.',
#   'startDate': '2000-03-30',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_4',
#   'projectName': 'TechSprint',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Congress happen nice level short Democrat. Person suffer visit power just near group.',
#   'startDate': '2019-03-12',
#   'endDate': datetime.date(2024, 5, 1),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_4',
#   'projectName': 'QuickTech Remote Support',
#   'projectType': 'POS System',
#   'description': 'Or question middle ever behavior matter experience skill. Beat evidence house. Down shoulder dream fight.\nMan entire account yourself focus decision employee. She property picture cell woman stand.',
#   'startDate': '1984-01-10',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Artificial Intelligence Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_4',
#   'projectName': 'DataForge Dashboard Creator',
#   'projectType': 'Booking System',
#   'description': 'Policy collection above movement. Young also rate type big candidate political culture.\nA among value feel newspaper. System show although stock like. Stop amount kid board.',
#   'startDate': '1989-03-22',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_5',
#   'projectName': 'AgileFlow',
#   'projectType': 'Payment Gateway',
#   'description': 'Personal land page garden. Some player so push year. Step test industry.\nFloor million happen relate doctor like. Window plant send new ever situation. Understand stand place senior sport.',
#   'startDate': '1988-08-18',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Release Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_5',
#   'projectName': 'PixelPlex Crypto Trader',
#   'projectType': 'Payment Gateway',
#   'description': 'Finally we agent put church dream themselves whom. Side same teach pressure.\nEnjoy administration feel. These fill finish bed big good. Wish return democratic way also.',
#   'startDate': '1975-09-19',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_5',
#   'projectName': 'AgileWare',
#   'projectType': 'Learning Management System',
#   'description': 'Stop often race. Take attack result have. Become of officer whether simply. Idea sort enough.\nIncluding stand should cup budget. Perhaps total suffer smile dog. Each value effect method purpose join.',
#   'startDate': '2016-09-07',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_5',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Project Management Software',
#   'description': 'Send science safe lawyer store. Alone maintain season doctor.\nArea thousand feeling care their economy officer. Indicate authority happy morning article two senior.',
#   'startDate': '1977-01-12',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_6',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'Task Management Tool',
#   'description': 'Work service part firm. Economic toward join evening indeed environment western. Hair any off federal focus them everything.',
#   'startDate': '1985-06-05',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_6',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Dashboard Creator',
#   'description': 'Congress entire benefit. Television defense why surface catch. Firm quality center manager one.\nTotal summer wide. Space realize always meet approach country mouth.',
#   'startDate': '1995-10-03',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Data Scientist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_6',
#   'projectName': 'TechSpark',
#   'projectType': 'Event Management Software',
#   'description': 'Health condition front worry million order. Prove wall impact. Glass under address series sign American majority.\nInstead pressure mother great action real star. Stand everybody staff authority thus.',
#   'startDate': '1973-01-26',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'IT Support Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_6',
#   'projectName': 'PixelWorks',
#   'projectType': 'Budget Planner',
#   'description': 'Evening stand agree adult. Nor might business.\nProperty ask reason cover thank natural change. Necessary a son early join country store.',
#   'startDate': '1984-04-16',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_7',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Event Management Software',
#   'description': 'Although brother cost mind law. List matter whatever rock quality industry season. Drop section maintain begin.',
#   'startDate': '1992-01-25',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_7',
#   'projectName': 'MetaMind Chatbot Builder',
#   'projectType': 'Healthcare Management System',
#   'description': 'Wonder some apply ask loss increase imagine experience. Customer discover eye generation growth his.\nPicture ball light. Every fear reach investment staff really.',
#   'startDate': '1999-08-31',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_7',
#   'projectName': 'QuickTech Remote Support',
#   'projectType': 'E-commerce Platform',
#   'description': 'Attack be major sure financial long bar. Rock page once on rather you produce. See none indeed character room glass.\nFood manager feel store find science. War front person want man.',
#   'startDate': '1982-02-23',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'UI/UX Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_7',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Asset Management System',
#   'description': 'Imagine book lose. Fish network attention fact store along body. Often wide strategy not challenge.\nBlood up American seek. Assume back instead adult.',
#   'startDate': '2015-07-26',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'UI/UX Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_8',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Booking System',
#   'description': 'Particular road before two image she. Trial various decision drive. Range other should sea society remember. Institution professional parent easy exactly hundred own coach.',
#   'startDate': '1983-08-26',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_8',
#   'projectName': 'DataCraft',
#   'projectType': 'Data Analyzer',
#   'description': 'Air girl new talk treatment skill activity. Protect article attention would.',
#   'startDate': '2022-01-10',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_8',
#   'projectName': 'AgileTech',
#   'projectType': 'Customer Service Software',
#   'description': 'Sign town mean traditional significant.\nEven nearly cover result. Next nature before TV.\nBorn than pick realize yeah. Actually direction responsibility program left which.',
#   'startDate': '1972-10-12',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_8',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Human Resource Management System',
#   'description': 'Accept rate finish note travel wear throw. This hand sport interview everybody. Water enjoy music make.\nMean read require age.',
#   'startDate': '1977-12-26',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Project Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'CyberCode Online Store',
#   'projectType': 'Human Resource Management System',
#   'description': 'Blood last half firm. Expert miss wear card use find investment. American radio line green environment here bill.',
#   'startDate': '2018-03-18',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'DataWave',
#   'projectType': 'Accounting Software',
#   'description': 'Site play local somebody drive forget Mrs. Main phone hot beat forward difficult.\nOnce teacher film pay. Across child economy each.',
#   'startDate': '1990-07-08',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Release Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Fleet Management System',
#   'description': 'Together car pressure some where must action. Listen test friend last exactly. Face article short cover as write region.',
#   'startDate': '1992-07-10',
#   'endDate': datetime.date(2024, 4, 10),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'InnovaTech',
#   'projectType': 'Document Management System',
#   'description': 'Data suffer message laugh media well behind.\nAgo and serious marriage. Near almost bank arm station car. Apply peace option during without recognize enter.',
#   'startDate': '1998-07-25',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_10',
#   'projectName': 'PixelWorks',
#   'projectType': 'Sales Forecasting Software',
#   'description': 'Full entire view detail option member. Process power majority check amount officer pattern crime. Fill here especially enjoy party.',
#   'startDate': '1998-07-21',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'UI/UX Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_10',
#   'projectName': 'TechTrek Data Analyzer',
#   'projectType': 'Survey Software',
#   'description': 'Stuff small light teacher everybody up nearly.\nReach them admit number avoid enough. Performance of PM perform cup fight. Most represent approach.',
#   'startDate': '2004-08-23',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'Technical Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_10',
#   'projectName': 'AgileFlow',
#   'projectType': 'Web Application',
#   'description': 'People from determine time democratic dog. Alone wait although name leader.\nHis Mr cost wall. Rock physical impact film daughter best amount.',
#   'startDate': '2010-01-28',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_10',
#   'projectName': 'VortexVision Virtual Assistant',
#   'projectType': 'Content Delivery Network',
#   'description': 'Decade stop including wish put down poor. Minute institution reach nation build last. Fire anything financial sure method far size.',
#   'startDate': '2004-11-06',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_11',
#   'projectName': 'DataWave',
#   'projectType': 'Fleet Management System',
#   'description': 'Key beyond between.\nBase side father. General bank five five cover.\nHuge rate probably reach possible. Son drop account begin recent lay recognize. Election medical card play maintain rich more part.',
#   'startDate': '1976-10-02',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_11',
#   'projectName': 'PixelWare',
#   'projectType': 'Mobile App',
#   'description': 'Low million view whom increase much guess door. Bad particular sure television development firm.',
#   'startDate': '1991-11-08',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_11',
#   'projectName': 'AgileFlow',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Seek reach official hold. Leg animal different cold business look tonight with.\nAccept truth over number network each great. Letter nice help behavior man realize.',
#   'startDate': '2003-01-28',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_11',
#   'projectName': 'SilverLinx POS System',
#   'projectType': 'Inventory Control System',
#   'description': 'Performance above open.\nThese card positive cost medical agency like. Father official here.',
#   'startDate': '1986-05-20',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_12',
#   'projectName': 'ByteBoost',
#   'projectType': 'Healthcare Management System',
#   'description': 'Ahead health us prevent science strategy middle. Language surface budget political woman help fall eat.\nBut with clearly significant group summer same.',
#   'startDate': '1992-02-14',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_12',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Chatbot',
#   'description': 'Apply a every hit board pass. Per because budget. Mrs exactly character list again husband. Write outside present offer general natural.',
#   'startDate': '1977-10-04',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Technical Writer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_12',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Warehouse Management System',
#   'description': 'Participant song left order some worker.\nParent moment skill agent modern explain he. These its win.',
#   'startDate': '1971-11-06',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_12',
#   'projectName': 'PixelPulse',
#   'projectType': 'Educational Software',
#   'description': 'Respond away evening certain agree movie.\nLeast agree dog way memory right. Mission better drug design book. Some what game job budget.',
#   'startDate': '2022-06-16',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'FusionSoft Email Client',
#   'projectType': 'E-commerce Platform',
#   'description': 'Southern half far. Open actually future interview officer late instead commercial. As meeting federal maybe drug day miss.',
#   'startDate': '1997-11-06',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'SilverLinx POS System',
#   'projectType': 'Asset Management System',
#   'description': 'His choice character image high turn sort speak.\nLine customer form debate act. Public worker lose detail between instead. Any service behavior environmental south.',
#   'startDate': '1971-04-03',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Accounting Software',
#   'description': 'Buy report health positive term. Plant dinner lawyer. Product full keep guy buy.\nEven scene best coach. Game green involve blue get control. Culture until effect hope try TV.',
#   'startDate': '1970-11-06',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Event Management Software',
#   'description': 'Themselves lawyer trouble pull authority television now. Writer purpose impact begin within box itself.\nAmerican do this conference your possible. Participant first start contain clearly.',
#   'startDate': '2017-03-08',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_14',
#   'projectName': 'InnovaTech',
#   'projectType': 'Educational Software',
#   'description': 'And common more including mind field during. Professor yourself read message protect finally lawyer.\nWatch clear audience include. Opportunity sense specific provide.',
#   'startDate': '1977-03-09',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_14',
#   'projectName': 'TechTrek Data Analyzer',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Seat protect surface yard particularly window attorney. Movie until wife yard.\nPresent manager thus couple any.',
#   'startDate': '1977-12-11',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_14',
#   'projectName': 'CyberCode Online Store',
#   'projectType': 'Inventory Management System',
#   'description': 'Still chance forward blood. Word dog pattern interesting.\nShe floor power sell. Drug argue wrong floor race. Already born fact real son course evidence.\nFive head each mention.',
#   'startDate': '2017-02-20',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_14',
#   'projectName': 'CyberLink',
#   'projectType': 'Asset Management System',
#   'description': 'Class of chance entire worker strategy.\nHealth memory their class today plant. Sell will contain boy century national meet.',
#   'startDate': '1996-08-06',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Release Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_15',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'POS System',
#   'description': 'Guy than conference would sound. Clearly when yet create within let cultural. Contain heart onto save large reason.\nSuccessful personal old issue. Mind interesting really part.',
#   'startDate': '1993-10-22',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Configuration Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_15',
#   'projectName': 'AgileFlow',
#   'projectType': 'Crypto Trader',
#   'description': 'Company whose chance commercial person name. Power home couple ability know.',
#   'startDate': '2014-09-12',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_15',
#   'projectName': 'AgileTech',
#   'projectType': 'Online Marketplace',
#   'description': 'Husband summer activity vote decade financial will. Movie how line local north similar. Start there Congress group follow. Stand ok thus peace another manage billion open.',
#   'startDate': '1975-04-23',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Data Scientist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_15',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Ticketing System',
#   'description': 'Improve adult throw lay might. Only star she improve owner three. Feeling front scene wrong actually total.',
#   'startDate': '1997-11-13',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_16',
#   'projectName': 'AgileFlow',
#   'projectType': 'Chatbot',
#   'description': 'Indicate red type ready task. Field author report opportunity international rich during. Rule interview tonight guess direction standard.\nOver fill add such. Nation include majority day feel behind.',
#   'startDate': '2001-10-07',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Product Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_16',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'Educational Software',
#   'description': 'Institution language weight show visit. Matter pass yourself smile recognize school.\nMessage security person no his clear campaign election.\nJob close apply.',
#   'startDate': '1988-08-19',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Technical Writer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_16',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Content Delivery Network',
#   'description': 'Imagine letter team language. Else say improve probably. Drop or beyond dog oil base.',
#   'startDate': '1993-04-19',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_16',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Time Tracking Tool',
#   'description': 'Under office not be. But positive interesting law western idea ahead.\nWhile data decade common machine. Part church material director long dinner. Easy film second choice join everyone.',
#   'startDate': '1990-07-05',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Artificial Intelligence Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_17',
#   'projectName': 'ByteForge',
#   'projectType': 'Data Analyzer',
#   'description': 'According behind anyone standard. Writer our level because fall feeling.\nFew measure media. Power avoid practice good population sea. Tv husband find company.',
#   'startDate': '2021-04-30',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_17',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'Online Marketplace',
#   'description': 'Take office service hour head especially. Agreement president work building rich say. Magazine Democrat image nothing. Price nature new create.',
#   'startDate': '2011-09-23',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_17',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Warehouse Management System',
#   'description': 'Million skill beyond behind condition perhaps. Operation enter artist. Heavy grow describe whom suggest power itself.',
#   'startDate': '2005-01-28',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_17',
#   'projectName': 'PixelWorks',
#   'projectType': 'Virtual Assistant',
#   'description': 'Explain reduce outside entire. Much audience system prove court dinner. Maintain soon arm behind.\nAuthor blood leader new skin ahead. Indeed might industry which paper alone.',
#   'startDate': '1970-01-07',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Artificial Intelligence Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_18',
#   'projectName': 'PixelPlex Crypto Trader',
#   'projectType': 'Educational Software',
#   'description': 'Enjoy bad spend. Positive street with officer administration part.\nImportant father follow machine then occur all. Site so commercial cost because. Scene perform tell compare to simple maybe study.',
#   'startDate': '1993-08-12',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Business Analyst',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_18',
#   'projectName': 'PixelWorks',
#   'projectType': 'Customer Service Software',
#   'description': 'Various much production all safe whatever per body. Customer everybody specific skill agency. Sense information produce do field cell.',
#   'startDate': '2007-05-29',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_18',
#   'projectName': 'DataWave',
#   'projectType': 'Content Delivery Network',
#   'description': 'Marriage still level tonight force size.\nFace wife majority machine eat my. Seek wait bad section service poor. Evening idea Mrs current nor election note. Like remain federal fire.',
#   'startDate': '2017-06-04',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_18',
#   'projectName': 'CatalystCommerce',
#   'projectType': 'Content Delivery Network',
#   'description': 'Suggest perhaps medical attorney capital. Central husband physical represent during factor. Father step fact animal civil remember force.\nBox water movement study arrive debate director.',
#   'startDate': '1997-09-18',
#   'endDate': datetime.date(2024, 5, 1),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_19',
#   'projectName': 'AgileFlow',
#   'projectType': 'Chatbot',
#   'description': 'Number similar skin yourself. Suggest big you usually side song kind marriage. Paper again off economic walk season.\nTrue look run toward allow all. Anyone operation decide less.',
#   'startDate': '2021-01-24',
#   'endDate': datetime.date(2024, 5, 1),
#   'role': 'DevOps Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_19',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Ticketing System',
#   'description': 'Stand miss special population recent treat account. Serve college lot situation blood chance already. Fight level believe though pressure.',
#   'startDate': '2016-01-28',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_19',
#   'projectName': 'VortexVision Virtual Assistant',
#   'projectType': 'Workflow Management Software',
#   'description': 'Property hold first important financial worry art year. Degree born whom against recently pull area serve.',
#   'startDate': '2009-11-07',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'DevOps Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_19',
#   'projectName': 'TechSprint',
#   'projectType': 'Task Management Tool',
#   'description': 'Capital now the successful middle follow note well.\nTraining enjoy tough close subject season hot. Person certain fly while enter by our. Speak dog save finish her method.\nOfficer standard dark ever.',
#   'startDate': '2009-02-23',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_20',
#   'projectName': 'DataPulse',
#   'projectType': 'Dashboard Creator',
#   'description': 'Stock matter total medical effect stop natural. Mission memory miss store everybody similar. Tv represent yard position.\nEvery money bad social cell. Need catch air send this than.',
#   'startDate': '1985-03-01',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_20',
#   'projectName': 'PixelPulse',
#   'projectType': 'Healthcare Management System',
#   'description': 'Billion traditional letter room company. Eat quite eye real. High let rule house. Two cost since woman far break.',
#   'startDate': '2020-04-02',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_20',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Remote Support Tool',
#   'description': 'Grow according happy consumer mind Mr director. Offer employee decision local race.',
#   'startDate': '2012-03-03',
#   'endDate': datetime.date(2024, 4, 10),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_20',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'E-commerce Platform',
#   'description': 'Respond daughter perhaps marriage range. Wife rock long human.\nThis make yet we. Card media find cost piece trouble. Head individual mind.',
#   'startDate': '1987-11-22',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_21',
#   'projectName': 'SwiftWave',
#   'projectType': 'Warehouse Management System',
#   'description': 'We message animal team town involve seven table. Place rather improve black scientist next enough role. Color where traditional owner fish film close. Receive easy owner performance coach.',
#   'startDate': '2007-08-13',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_21',
#   'projectName': 'CatalystCommerce',
#   'projectType': 'CRM System',
#   'description': 'Stand outside staff night actually almost lose. Involve city against process little meeting could. Church shake world time.\nMeeting medical culture. Campaign tax detail approach.',
#   'startDate': '2017-05-26',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_21',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Appointment Scheduling Software',
#   'description': 'Up job should green sign interview everyone. Star across show summer.\nHappy their get.\nThink get ground father suddenly. Second fire message.\nBag environmental moment look. High run right political.',
#   'startDate': '1976-01-14',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_21',
#   'projectName': 'TechSpark',
#   'projectType': 'Learning Management System',
#   'description': 'Practice hot easy collection buy. Network strong despite front. Professor travel decide include.\nDetermine wind strategy former how. Left bit scientist.',
#   'startDate': '2003-05-09',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_22',
#   'projectName': 'PixelWare',
#   'projectType': 'Asset Management System',
#   'description': 'Through per seek answer have street. Front building argue cut seven data. Leave history behind head.\nReady two yes write who.',
#   'startDate': '1991-01-04',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_22',
#   'projectName': 'PixelPulse',
#   'projectType': 'Workflow Management Software',
#   'description': 'Moment authority land place. Treat real movie send his in war budget.\nFederal another letter thus plant green available. Explain option among your. Sound close water station blood.',
#   'startDate': '2016-05-17',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Project Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_22',
#   'projectName': 'CyberCode Online Store',
#   'projectType': 'Customer Relationship Management',
#   'description': 'While whether gas minute should own. Sell unit road put agree grow. Give trouble rest.\nInside card box prevent gas standard apply would. Production range less bad go knowledge.',
#   'startDate': '1991-07-13',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_22',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Human Resource Management System',
#   'description': 'Its research language skin. Traditional left recently. Again phone want act.\nRoom return resource effect focus piece. Example admit fear career responsibility interesting.',
#   'startDate': '2023-10-30',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Technical Writer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_23',
#   'projectName': 'PixelWorks',
#   'projectType': 'CRM System',
#   'description': 'Decide little through. Trade candidate military movement. Summer particular party home.\nShould modern six fine. Second bit ball interest both cause.',
#   'startDate': '1982-07-05',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_23',
#   'projectName': 'CodeCraft',
#   'projectType': 'Retail Management System',
#   'description': 'Edge apply few road. Some realize service piece program.\nAdministration boy health green social conference. Forward public item suggest course stop send student.',
#   'startDate': '1977-07-30',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Performance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_23',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'CRM System',
#   'description': 'Clearly what open example which apply. Much only skin institution group country on.\nFact yeah both room yes animal. Mrs require represent early owner exactly include lawyer.',
#   'startDate': '2002-07-08',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_23',
#   'projectName': 'CatalystCommerce',
#   'projectType': 'Fleet Management System',
#   'description': 'Especially north season mission. Part set heart free rate. Past body store compare.\nAddress upon reflect government eat financial energy. Lot according improve safe receive quickly.',
#   'startDate': '2007-02-03',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_24',
#   'projectName': 'AgileFlow',
#   'projectType': 'Healthcare Management System',
#   'description': 'Matter stop woman thank yeah. Perhaps idea able lawyer quickly claim talk economic.\nSocial sometimes central attack. Protect interesting be traditional build. Certain stage population century give.',
#   'startDate': '1995-06-11',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_24',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Payment Gateway',
#   'description': 'Instead course example finish. No much notice president. Attack trial home woman news third.\nAccording training firm forward movie would. Capital maybe what TV cut. Think road beyond.',
#   'startDate': '2013-09-14',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_24',
#   'projectName': 'DataPulse',
#   'projectType': 'Inventory Management System',
#   'description': 'Baby course surface late bill. Social lead help common house management model. Democrat project despite card author role thousand.',
#   'startDate': '1994-05-05',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Business Analyst',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_24',
#   'projectName': 'SwiftCode',
#   'projectType': 'Supply Chain Management Software',
#   'description': 'About its approach realize respond sell leave. Service lay return learn billion recent relationship.\nExactly the professional after. Must bar major clear. Seat organization media never.',
#   'startDate': '1977-09-05',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Performance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_25',
#   'projectName': 'CyberLink',
#   'projectType': 'CRM System',
#   'description': 'Before new lay teach everything western. Study either hundred property to now. Tell knowledge part fish serve.\nSell produce garden leave. Individual where mission. According debate actually now six.',
#   'startDate': '2010-09-07',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_25',
#   'projectName': 'DataSync',
#   'projectType': 'Help Desk Software',
#   'description': 'According them federal there discuss people. Seem seek good computer.',
#   'startDate': '2002-09-06',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_25',
#   'projectName': 'FusionSoft Email Client',
#   'projectType': 'Crypto Trader',
#   'description': 'Citizen alone religious prevent. Early current check whom instead central.',
#   'startDate': '2024-02-11',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_25',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Virtual Assistant',
#   'description': 'Suggest international back green decide by. Mr Congress pull time message charge. Avoid more moment range can.\nSo Democrat structure middle reason top candidate. Air to these receive car.',
#   'startDate': '2004-12-26',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_26',
#   'projectName': 'ByteForge',
#   'projectType': 'Booking System',
#   'description': 'Event expect wish. Lot with stage early bed government human. Run too among employee discuss expect teach.\nWall road order travel bad. Red soon particular network bag by.',
#   'startDate': '2021-09-06',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_26',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'Booking System',
#   'description': 'Computer better turn start inside black. Down authority across think. Evidence low worry begin age manage move.\nHold protect again especially century out. Teach push decision reduce start red travel.',
#   'startDate': '2013-11-01',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_26',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'POS System',
#   'description': 'Image half building consumer car. Blood theory home purpose look professional. Spring tree crime officer they citizen could.',
#   'startDate': '1980-12-17',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_26',
#   'projectName': 'CyberLink',
#   'projectType': 'Accounting Software',
#   'description': 'Expect lay wind late. Inside figure government a blood.\nAt new score writer. Guess store husband along. Whether with doctor image find term one.',
#   'startDate': '1973-07-16',
#   'endDate': datetime.date(2024, 4, 29),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_27',
#   'projectName': 'CodeCraft',
#   'projectType': 'Crypto Trader',
#   'description': 'As Mrs simple man. Tv add include agency strategy they collection ground.\nSay north third life. Everything result crime pass. Have involve son world consumer Republican.',
#   'startDate': '1999-08-16',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_27',
#   'projectName': 'DataSync',
#   'projectType': 'Sales Forecasting Software',
#   'description': 'Ground article no. Avoid want floor true.\nExplain still beyond. Seven its cut agency standard pressure act. Still professional first cup.',
#   'startDate': '2012-01-07',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_27',
#   'projectName': 'BlueFinity Evoke',
#   'projectType': 'Fleet Management System',
#   'description': 'Back action four child. Reach shake mind seven rule show worker.\nCheck pass writer discuss. Bag beat yet hair left key seek. Number much free local.',
#   'startDate': '1997-03-22',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_27',
#   'projectName': 'PixelWare',
#   'projectType': 'Supply Chain Management Software',
#   'description': 'Program employee kitchen discover him. Gun at answer training line drive.\nDefense claim land of enjoy offer. Only source could religious resource service finish.',
#   'startDate': '2009-07-20',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_28',
#   'projectName': 'SwiftCode',
#   'projectType': 'Task Management Tool',
#   'description': 'Into believe north morning remain. That tree no general modern wear traditional.\nCut avoid hope anyone agency follow structure plant. Manage operation past bring executive job record.',
#   'startDate': '2004-09-19',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_28',
#   'projectName': 'DataBridge',
#   'projectType': 'POS System',
#   'description': 'Explain moment week TV stock show. Voice break treatment leg value fill.\nMuch turn represent seem increase purpose easy.\nSave stop her memory. Level probably force continue ok decision play.',
#   'startDate': '1977-02-24',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_28',
#   'projectName': 'TechTrek Data Analyzer',
#   'projectType': 'Social Networking Platform',
#   'description': 'Month eat ahead table own result quickly.\nBoy out four. Rate trial way. Operation see discuss condition field sense.\nManagement least west trial watch friend by. Challenge hope letter his.',
#   'startDate': '2016-08-30',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_28',
#   'projectName': 'DataCraft',
#   'projectType': 'Workflow Management Software',
#   'description': 'Short become part figure party mother question truth. Society certain as. Either go eight Republican west computer.',
#   'startDate': '1985-02-28',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Configuration Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_29',
#   'projectName': 'InnovaTech',
#   'projectType': 'Booking System',
#   'description': 'Each develop audience compare actually represent project. Read seem answer hair area return. Collection collection them current cause office interview. Out culture responsibility drop will on.',
#   'startDate': '1974-12-26',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_29',
#   'projectName': 'InnovatePro',
#   'projectType': 'Content Management System',
#   'description': 'Magazine service want common hair onto church analysis. Floor material run white reason.\nBoth section song yourself learn. According friend hard mean such student.',
#   'startDate': '2023-06-01',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Release Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_29',
#   'projectName': 'ByteForge',
#   'projectType': 'Customer Relationship Management',
#   'description': 'Part concern give none nation test same. Art run raise remain nice radio.\nKid trip himself. Expect expect leader some. Threat meet agent response. Author federal carry never.',
#   'startDate': '1990-02-25',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Performance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_29',
#   'projectName': 'AgileWare',
#   'projectType': 'Customer Service Software',
#   'description': 'Off other owner. Well difference chair food government.\nCall reflect list heart ever cup truth traditional. Project spend total shoulder film everybody near boy.',
#   'startDate': '1973-02-05',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_30',
#   'projectName': 'PixelWorks',
#   'projectType': 'Backup Solution',
# ...
#   'startDate': '2022-08-29',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_240',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Accounting Software',
#   'description': 'Especially situation bring we. Various article space detail best newspaper.\nHappen serve attention if drop five. Lead participant employee loss.',
#   'startDate': '2013-12-17',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Developer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_240',
#   'projectName': 'DataCraft',
#   'projectType': 'Warehouse Management System',
#   'description': 'Serious kind science environment table behind. This various tax thought arm pay.\nMember nature relate live improve. Class business important certain truth. Popular tonight view note.',
#   'startDate': '1996-03-29',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_240',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Document Management System',
#   'description': 'Which measure member technology pressure.\nEspecially agency offer dog. Also year cost land difference performance today.',
#   'startDate': '2018-05-26',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_241',
#   'projectName': 'DataBridge',
#   'projectType': 'Retail Management System',
#   'description': 'Name show strategy participant same main candidate. Art reality understand money give pretty save.\nNext you nation. Challenge house start TV.',
#   'startDate': '2021-10-21',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_241',
#   'projectName': 'DataPulse',
#   'projectType': 'Accounting Software',
#   'description': 'Dinner wait memory. War Mrs somebody could environmental daughter. Series camera management want moment such.',
#   'startDate': '1999-03-15',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_241',
#   'projectName': 'DataCraft',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Apply simply but use marriage road nature. Policy machine avoid recently rich away. Player perhaps out.\nParent wonder tax herself edge civil. Practice heart or. Art less give news.',
#   'startDate': '2001-08-12',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_241',
#   'projectName': 'ByteForge',
#   'projectType': 'Human Resource Management System',
#   'description': 'Behind blue method people. Painting as remain.\nPay television whole represent enter budget part. At when race relate none magazine design that.\nBag change huge. All career two too.',
#   'startDate': '2014-01-05',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Data Scientist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_242',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Ticketing System',
#   'description': 'Ability into join wife change human. Role strong week four. Bad great civil seem strategy between improve.\nMay box size white. Or four book.',
#   'startDate': '2017-06-08',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_242',
#   'projectName': 'AgileFlow',
#   'projectType': 'E-commerce Platform',
#   'description': 'Threat gas behind true away toward walk. Hard night personal where figure station after dog. Boy better nor represent.',
#   'startDate': '2019-12-24',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_242',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Warehouse Management System',
#   'description': 'Write claim physical treatment think. Herself example entire compare east eye friend. By then security month model center sound growth.',
#   'startDate': '2009-12-26',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Configuration Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_242',
#   'projectName': 'DataWave',
#   'projectType': 'Dashboard Creator',
#   'description': 'Adult mother security should speech detail eat. Member order couple opportunity see knowledge.',
#   'startDate': '2006-10-31',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_243',
#   'projectName': 'TechSprint',
#   'projectType': 'Content Delivery Network',
#   'description': 'Tonight police study. Detail southern together suggest.\nRecent commercial go finish between direction expert. Very boy wide break. Fly exist set style continue study.',
#   'startDate': '1988-07-05',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Technical Writer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_243',
#   'projectName': 'PixelWare',
#   'projectType': 'POS System',
#   'description': 'Build ability garden fall open. Project page popular Democrat clearly professor.\nStar add over coach section attack itself.\nDog process production eight discover. Environmental likely along like.',
#   'startDate': '2019-06-06',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_243',
#   'projectName': 'MetaMind Chatbot Builder',
#   'projectType': 'Time Tracking Tool',
#   'description': 'Watch how again along record increase. Later soon computer race ask about ago.',
#   'startDate': '2015-08-17',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Configuration Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_243',
#   'projectName': 'DataCraft',
#   'projectType': 'Project Management Software',
#   'description': 'Off watch report church word source. Wall movement question. Candidate agency security sister ground ground. Else everyone his grow determine quite.',
#   'startDate': '1997-11-03',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'PixelPlex Crypto Trader',
#   'projectType': 'Remote Support Tool',
#   'description': 'Week test defense agree white group have. Range rise source I reach hot month. Raise cold nothing listen significant.',
#   'startDate': '2018-04-09',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Workflow Management Software',
#   'description': 'Within current field husband camera down. Wonder pressure month.\nVarious return raise nation economy their day. At leg much onto speak.',
#   'startDate': '1993-12-06',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'SwiftCode',
#   'projectType': 'Fleet Management System',
#   'description': 'Thank international human boy set six young. Set image table officer myself interview old.\nDrive impact stand various fire east. Cover front reach job training allow month.',
#   'startDate': '1984-07-09',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'VortexVision Virtual Assistant',
#   'projectType': 'Healthcare Management System',
#   'description': 'Focus cup wrong evening finish by many without. Serve administration reality major special contain.',
#   'startDate': '1975-07-22',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'Online Marketplace',
#   'description': 'Attention fly I day current color research now. Share across language.\nCarry also your general specific always keep. Seat view although around industry just know statement. Your society wall way.',
#   'startDate': '2010-10-10',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Warehouse Management System',
#   'description': 'Item shoulder clearly ever. Their discussion everyone seek. Law fire choice memory.\nTeam Congress they worry. Cell try raise force. Like service teacher whose. Produce against debate score property.',
#   'startDate': '2010-01-05',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'DataCraft',
#   'projectType': 'Retail Management System',
#   'description': 'Small floor be theory quite tonight.',
#   'startDate': '1983-10-04',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Backup Solution',
#   'description': 'Court indeed understand hear discussion protect.\nFactor myself his through assume choose listen. Human able our run age.\nResponse cover some provide. Investment value clearly politics section say.',
#   'startDate': '1974-02-06',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_246',
#   'projectName': 'ByteForge',
#   'projectType': 'Online Marketplace',
#   'description': 'Alone bring PM agency me. Or member rest benefit.\nItem meet per score reality country. Staff condition process against. Away example pull dinner down investment cover.',
#   'startDate': '1977-05-22',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Business Analyst',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_246',
#   'projectName': 'SilverLinx POS System',
#   'projectType': 'Dashboard Creator',
#   'description': 'East home accept try per. Lay collection discuss.\nProfessor moment special whole. Entire instead where despite husband share local practice. Car analysis travel join choose report.',
#   'startDate': '1990-07-09',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Technical Writer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_246',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'POS System',
#   'description': 'School organization manager rate relationship. Pm along attack force.\nSome particularly growth concern. Heavy today including mind politics already parent.\nMedia each about decide.',
#   'startDate': '1985-08-29',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_246',
#   'projectName': 'DataPulse',
#   'projectType': 'Help Desk Software',
#   'description': 'Plant number expect she thing country simple. South create season reflect including population individual national.\nDraw system they ground. Top remember power rule. Quite piece a agent.',
#   'startDate': '1979-06-07',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_247',
#   'projectName': 'SwiftWave',
#   'projectType': 'Ticketing System',
#   'description': 'Official six ahead late resource few democratic. Current order behind source mention. Term main employee time man lose wide.\nLeast after could another. Contain guy growth current.',
#   'startDate': '1985-07-17',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_247',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Project Management Software',
#   'description': 'Money media their put would follow by. Rather although born call part movement.\nThose current feel force bit. Begin value couple lose southern lot. Watch later most stop.',
#   'startDate': '2021-03-04',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_247',
#   'projectName': 'InnovatePro',
#   'projectType': 'Healthcare Management System',
#   'description': 'Get movie personal nation.\nHeavy deal great drive. Card after either behind town fear market.\nLater bar arm. Player page learn degree must. Foot campaign experience occur their image your.',
#   'startDate': '1999-06-05',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_247',
#   'projectName': 'PixelPulse',
#   'projectType': 'Web Application',
#   'description': 'Food civil grow. Skin perhaps price some. Local heavy fund relate.\nReason people treat through answer performance executive project. Board star show task those house.',
#   'startDate': '2010-04-08',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_248',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Survey Software',
#   'description': 'Reason chance take whom. Third available player trip report little. Report for all authority.\nCongress drug ground practice chair. Air want despite. Rather new left.',
#   'startDate': '1998-12-11',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_248',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Retail Management System',
#   'description': 'Physical thought election day occur. Factor somebody foot evening policy form.\nLate even writer yet performance note. Raise deep defense common situation. Watch less weight world.',
#   'startDate': '2011-05-06',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Business Analyst',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_248',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Event Management Software',
#   'description': 'Around face fine reduce American you religious. Situation on shake physical own drop.\nBetween ok home water let loss. Quality song if view office Congress according morning.',
#   'startDate': '1997-12-13',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_248',
#   'projectName': 'AgileWare',
#   'projectType': 'Payment Gateway',
#   'description': 'These its it lay bed baby win. Bit size thought.\nGrowth wish number theory especially hit growth. Little large body suggest use official.',
#   'startDate': '1999-04-27',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_249',
#   'projectName': 'FusionSoft Email Client',
#   'projectType': 'Educational Software',
#   'description': 'Response various seat order show program last. Away yeah still our personal ask generation. Skin art her space newspaper its.\nModel travel national project. Hospital anything nor old.',
#   'startDate': '1999-09-24',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_249',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Backup Solution',
#   'description': 'Kind reality item impact raise possible use. Point member mother trial oil including. Down later the pass trial body.',
#   'startDate': '2001-07-16',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_249',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Virtual Assistant',
#   'description': 'Industry near action people. Phone else side star air certain. International spring player child same themselves wait. Until significant lose.',
#   'startDate': '1971-08-09',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_249',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Booking System',
#   'description': 'Lose tonight sign situation. They today environment produce.\nThough family court thousand. Again production result task billion rate themselves. Born Congress show rather dark matter.',
#   'startDate': '2018-01-24',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  ...]

# %%
df=pd.DataFrame(data)

# %%
skills = [
    "Python",
    "JavaScript",
    "HTML",
    "CSS",
    "React",
    "Angular",
    "Vue.js",
    "Node.js",
    "Django",
    "Flask",
    "Java",
    "Kotlin",
    "Swift",
    "Objective-C",
    "C#",
    ".NET",
    "PHP",
    "Ruby",
    "SQL",
    "NoSQL",
    "MongoDB",
    "MySQL",
    "PostgreSQL",
    "Git",
    "Docker",
    "Kubernetes",
    "AWS",
    "Azure",
    "Google Cloud Platform",
    "RESTful API",
    "GraphQL",
    "CI/CD",
    "Agile Methodologies",
    "Scrum",
    "Test-Driven Development",
    "Behavior-Driven Development",
    "DevOps",
    "Continuous Integration",
    "Continuous Deployment",
    "Microservices",
    "Containerization",
    "Machine Learning",
    "Artificial Intelligence",
    "Data Science",
    "Data Analysis",
    "Data Visualization",
    "Statistical Analysis",
    "Cybersecurity",
    "Network Security",
    "Penetration Testing",
    "Cryptography",
    "Information Security",
    "UI/UX Design",
    "Wireframing",
    "Prototyping",
    "User Research",
    "Interaction Design",
    "Responsive Design",
    "Accessibility",
    "Product Management",
    "Agile Product Management",
    "Requirements Analysis",
    "User Stories",
    "Business Analysis",
    "Technical Writing",
    "Documentation",
    "Support",
    "Troubleshooting",
    "Problem Solving",
    "Communication",
    "Collaboration",
    "Leadership"
]

# %%
data = []
for i in fake_data_list:
    empid = i
    Skill = random.sample(skills, 4)  # Pick 4 unique certificates randomly
    for s in Skill:
        record = {
            "Empid": empid,
            "skillName": s,
            "Proficiency": random.choice(["Intermidiate", "Expert","Beginner","Advance"])
        }
        data.append(record)

# %%
df=pd.DataFrame(data)
df
# Out:
#       Empid              skillName   Proficiency
# 0     Emp_0        Troubleshooting       Advance
# 1     Emp_0                GraphQL        Expert
# 2     Emp_0                 Vue.js       Advance
# 3     Emp_0        Problem Solving      Beginner
# 4     Emp_1                Support        Expert
# ...     ...                    ...           ...
# 4011    NaN  Continuous Deployment      Beginner
# 4012    NaN                   .NET  Intermidiate
# 4013    NaN     Product Management  Intermidiate
# 4014    NaN       Machine Learning  Intermidiate
# 4015    NaN          Microservices      Beginner
#
# [4016 rows x 3 columns]

# %%
df.to_csv('skills.csv')
