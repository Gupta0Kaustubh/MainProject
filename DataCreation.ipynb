# %%
pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-24.4.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\kaustubhgupta\anaconda3\lib\site-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kaustubhgupta\anaconda3\lib\site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Downloading Faker-24.4.0-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 69.0 kB/s eta 0:00:26
#     --------------------------------------- 0.0/1.8 MB 59.6 kB/s eta 0:00:29
#     --------------------------------------- 0.0/1.8 MB 59.6 kB/s eta 0:00:29
#    - -------------------------------------- 0.1/1.8 MB 80.0 kB/s eta 0:00:22
#    - -------------------------------------- 0.1/1.8 MB 80.0 kB/s eta 0:00:22
#    - -------------------------------------- 0.1/1.8 MB 83.7 kB/s eta 0:00:21
#    - -------------------------------------- 0.1/1.8 MB 89.9 kB/s eta 0:00:19
#    -- ------------------------------------- 0.1/1.8 MB 102.8 kB/s eta 0:00:17
#    -- ------------------------------------- 0.1/1.8 MB 119.2 kB/s eta 0:00:14
#    -- ------------------------------------- 0.1/1.8 MB 119.2 kB/s eta 0:00:14
#    --- ------------------------------------ 0.1/1.8 MB 135.3 kB/s eta 0:00:12
#    --- ------------------------------------ 0.1/1.8 MB 135.3 kB/s eta 0:00:12
#    --- ------------------------------------ 0.2/1.8 MB 152.0 kB/s eta 0:00:11
#    ---- ----------------------------------- 0.2/1.8 MB 166.2 kB/s eta 0:00:10
#    ---- ----------------------------------- 0.2/1.8 MB 168.3 kB/s eta 0:00:10
#    ----- ---------------------------------- 0.2/1.8 MB 178.8 kB/s eta 0:00:09
#    ----- ---------------------------------- 0.2/1.8 MB 182.6 kB/s eta 0:00:09
#    ------ --------------------------------- 0.3/1.8 MB 205.3 kB/s eta 0:00:08
#    ------ --------------------------------- 0.3/1.8 MB 208.2 kB/s eta 0:00:08
#    ------- -------------------------------- 0.3/1.8 MB 221.0 kB/s eta 0:00:07
#    ------- -------------------------------- 0.3/1.8 MB 230.4 kB/s eta 0:00:07
#    -------- ------------------------------- 0.4/1.8 MB 241.5 kB/s eta 0:00:06
#    --------- ------------------------------ 0.4/1.8 MB 254.2 kB/s eta 0:00:06
#    --------- ------------------------------ 0.4/1.8 MB 272.5 kB/s eta 0:00:05
#    ---------- ----------------------------- 0.5/1.8 MB 283.6 kB/s eta 0:00:05
#    ----------- ---------------------------- 0.5/1.8 MB 296.8 kB/s eta 0:00:05
#    ------------ --------------------------- 0.5/1.8 MB 306.7 kB/s eta 0:00:05
#    ------------ --------------------------- 0.6/1.8 MB 316.0 kB/s eta 0:00:04
#    ------------- -------------------------- 0.6/1.8 MB 333.4 kB/s eta 0:00:04
#    -------------- ------------------------- 0.6/1.8 MB 344.3 kB/s eta 0:00:04
#    --------------- ------------------------ 0.7/1.8 MB 360.0 kB/s eta 0:00:03
#    ---------------- ----------------------- 0.7/1.8 MB 370.1 kB/s eta 0:00:03
#    ----------------- ---------------------- 0.8/1.8 MB 387.1 kB/s eta 0:00:03
#    ------------------ --------------------- 0.8/1.8 MB 393.3 kB/s eta 0:00:03
#    ------------------- -------------------- 0.8/1.8 MB 404.1 kB/s eta 0:00:03
#    ------------------- -------------------- 0.9/1.8 MB 409.6 kB/s eta 0:00:03
#    ------------------- -------------------- 0.9/1.8 MB 409.6 kB/s eta 0:00:03
#    --------------------- ------------------ 0.9/1.8 MB 419.9 kB/s eta 0:00:02
#    --------------------- ------------------ 1.0/1.8 MB 423.3 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.0/1.8 MB 425.2 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 426.8 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 429.9 kB/s eta 0:00:02
#    ------------------------ --------------- 1.1/1.8 MB 434.1 kB/s eta 0:00:02
#    ------------------------ --------------- 1.1/1.8 MB 437.0 kB/s eta 0:00:02
#    ------------------------- -------------- 1.1/1.8 MB 427.7 kB/s eta 0:00:02
#    ------------------------- -------------- 1.1/1.8 MB 436.9 kB/s eta 0:00:02
#    -------------------------- ------------- 1.2/1.8 MB 442.2 kB/s eta 0:00:02
#    -------------------------- ------------- 1.2/1.8 MB 438.3 kB/s eta 0:00:02
#    --------------------------- ------------ 1.2/1.8 MB 440.6 kB/s eta 0:00:02
#    --------------------------- ------------ 1.2/1.8 MB 439.4 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.2/1.8 MB 439.3 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.3/1.8 MB 440.5 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.3/1.8 MB 438.1 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.3/1.8 MB 434.6 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.3/1.8 MB 434.7 kB/s eta 0:00:02
#    ------------------------------ --------- 1.3/1.8 MB 436.9 kB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 433.6 kB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 433.7 kB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 430.5 kB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 432.6 kB/s eta 0:00:01
#    -------------------------------- ------- 1.4/1.8 MB 431.7 kB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 433.8 kB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 435.0 kB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 433.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.8 MB 435.9 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.5/1.8 MB 435.0 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 437.9 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 439.8 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 442.5 kB/s eta 0:00:01
#    ------------------------------------- -- 1.7/1.8 MB 445.2 kB/s eta 0:00:01
#    -------------------------------------- - 1.7/1.8 MB 448.8 kB/s eta 0:00:01
#    ---------------------------------------  1.7/1.8 MB 451.3 kB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 453.8 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 448.5 kB/s eta 0:00:00
# Installing collected packages: Faker
# Successfully installed Faker-24.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
import random

# %%
fake=Faker()

# %%
fake.phone_number()
# Out:
# '001-263-621-1691x9085'

# %%
pip random
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "random"

# %%
from faker import Faker


fake = Faker()

fake_data_list = []
job_roles = [
    "Software Engineer",
    "Frontend Developer",
    "Backend Developer",
    "Full-stack Developer",
    "Mobile App Developer (iOS/Android)",
    "DevOps Engineer",
    "Database Administrator (DBA)",
    "Quality Assurance Engineer (QA Engineer)",
    "Software Tester",
    "Technical Architect",
    "UI/UX Designer",
    "Product Manager",
    "Scrum Master",
    "Agile Coach",
    "Business Analyst",
    "Systems Analyst",
    "Network Engineer",
    "Security Engineer",
    "Data Scientist",
    "Machine Learning Engineer",
    "Artificial Intelligence Specialist",
    "Cloud Solutions Architect",
    "Technical Writer (Documentation Specialist)",
    "IT Support Engineer",
    "IT Administrator",
    "Release Manager",
    "Configuration Manager",
    "Automation Engineer",
    "Performance Engineer",
    "Customer Support Engineer"
]

skills = [
    "Python", "JavaScript", "HTML", "CSS", "React", "Angular", "Vue.js", "Node.js", "Django", "Flask",
    "Java", "Kotlin", "Swift", "Objective-C", "C#", ".NET", "PHP", "Ruby", "SQL", "NoSQL",
    "MongoDB", "MySQL", "PostgreSQL", "Git", "Docker", "Kubernetes", "AWS", "Azure", "Google Cloud Platform",
    "RESTful API", "GraphQL", "CI/CD", "Agile Methodologies", "Scrum", "Test-Driven Development",
    "Behavior-Driven Development", "DevOps", "Continuous Integration", "Continuous Deployment", "Microservices",
    "Containerization", "Machine Learning", "Artificial Intelligence", "Data Science", "Data Analysis",
    "Data Visualization", "Statistical Analysis", "Cybersecurity", "Network Security", "Penetration Testing",
    "Cryptography", "Information Security", "UI/UX Design", "Wireframing", "Prototyping", "User Research",
    "Interaction Design", "Responsive Design", "Accessibility", "Product Management", "Agile Product Management",
    "Requirements Analysis", "User Stories", "Business Analysis", "Technical Writing", "Documentation",
    "Support", "Troubleshooting", "Problem Solving", "Communication", "Collaboration", "Leadership"
]



for i in range(1, 1000):
    certificates = random.sample(skills, 4)
    user_data = {
        "userId": "Emp_" + str(i),
        "firstName": fake.first_name(),
        "middleName": fake.first_name(),
        "lastName": fake.last_name(),
        "email": fake.email(),
        "phoneNumber": fake.phone_number(),
        "gender": fake.random_element(elements=("Male", "Female")),
        "doj": fake.date_this_decade(),
        "specializations": certificates,
        "dob": fake.date_of_birth(),
        "city": fake.city(),
        "state": fake.state(),
        "experience": fake.random_int(min=1, max=20),
        "userType": fake.random_element(elements=("Admin", "User")),
        "subscribeNewsletter": fake.boolean(),
        "passwords": fake.password(length=8),  # Ensures password is at least 8 characters long
    }
    fake_data_list.append(user_data)

# Print the generated fake data
for user_data in fake_data_list:
    print(user_data)
# Out:
# {'userId': 'Emp_1', 'firstName': 'Ashley', 'middleName': 'Maria', 'lastName': 'Gonzales', 'email': 'amykennedy@example.net', 'phoneNumber': '001-401-860-9318x36916', 'gender': 'Female', 'doj': datetime.date(2020, 6, 30), 'specializations': ['Vue.js', 'Technical Writing', 'Continuous Integration', 'Communication'], 'dob': datetime.date(2015, 9, 10), 'city': 'Brownview', 'state': 'New Jersey', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '6)s2P(0d'}
# {'userId': 'Emp_2', 'firstName': 'Darrell', 'middleName': 'Regina', 'lastName': 'Rocha', 'email': 'robinbell@example.org', 'phoneNumber': '786-329-5972', 'gender': 'Female', 'doj': datetime.date(2021, 3, 28), 'specializations': ['Azure', '.NET', 'React', 'Responsive Design'], 'dob': datetime.date(1995, 8, 29), 'city': 'Brandonmouth', 'state': 'Delaware', 'experience': 11, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'zs&VJ1Ye'}
# {'userId': 'Emp_3', 'firstName': 'Jody', 'middleName': 'Daniel', 'lastName': 'Vargas', 'email': 'jill81@example.org', 'phoneNumber': '969-710-6794', 'gender': 'Female', 'doj': datetime.date(2020, 3, 8), 'specializations': ['Continuous Integration', 'Swift', 'Technical Writing', 'Information Security'], 'dob': datetime.date(1915, 12, 22), 'city': 'East Tammyland', 'state': 'New Mexico', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'i2r*1Fuf'}
# {'userId': 'Emp_4', 'firstName': 'Jennifer', 'middleName': 'Tyler', 'lastName': 'Chandler', 'email': 'urasmussen@example.net', 'phoneNumber': '+1-605-548-4769x71383', 'gender': 'Female', 'doj': datetime.date(2024, 2, 15), 'specializations': ['MongoDB', 'Vue.js', 'Kotlin', 'CSS'], 'dob': datetime.date(1937, 11, 1), 'city': 'Lake Rhondaside', 'state': 'New Jersey', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'r$0OnvKf'}
# {'userId': 'Emp_5', 'firstName': 'Nicole', 'middleName': 'Nicole', 'lastName': 'Smith', 'email': 'debraallen@example.com', 'phoneNumber': '980.918.7773x2409', 'gender': 'Female', 'doj': datetime.date(2021, 2, 2), 'specializations': ['Support', 'Artificial Intelligence', 'HTML', 'Microservices'], 'dob': datetime.date(1912, 7, 19), 'city': 'Turnerstad', 'state': 'New York', 'experience': 19, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '!00(Js@z'}
# {'userId': 'Emp_6', 'firstName': 'Carla', 'middleName': 'Tina', 'lastName': 'Ramirez', 'email': 'caleb66@example.org', 'phoneNumber': '001-246-944-5042x659', 'gender': 'Male', 'doj': datetime.date(2020, 5, 4), 'specializations': ['RESTful API', 'Microservices', 'Flask', 'CSS'], 'dob': datetime.date(1920, 9, 26), 'city': 'Whitestad', 'state': 'South Dakota', 'experience': 18, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'uBb^W1Qm'}
# {'userId': 'Emp_7', 'firstName': 'Gordon', 'middleName': 'Kurt', 'lastName': 'Pierce', 'email': 'rwoodard@example.net', 'phoneNumber': '636-743-6538x33169', 'gender': 'Female', 'doj': datetime.date(2020, 8, 15), 'specializations': ['SQL', 'Objective-C', 'Agile Methodologies', 'Accessibility'], 'dob': datetime.date(1941, 1, 13), 'city': 'New Edward', 'state': 'Kentucky', 'experience': 18, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'D(1XtU*c'}
# {'userId': 'Emp_8', 'firstName': 'Debra', 'middleName': 'Aaron', 'lastName': 'Bradley', 'email': 'cfisher@example.org', 'phoneNumber': '001-829-834-2911x4795', 'gender': 'Male', 'doj': datetime.date(2020, 3, 5), 'specializations': ['Troubleshooting', 'React', 'CI/CD', 'Node.js'], 'dob': datetime.date(1929, 12, 2), 'city': 'Ericland', 'state': 'Michigan', 'experience': 2, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': ')vt0G+tA'}
# {'userId': 'Emp_9', 'firstName': 'Eric', 'middleName': 'Daniel', 'lastName': 'Freeman', 'email': 'joshuagarcia@example.org', 'phoneNumber': '(570)879-0393x476', 'gender': 'Female', 'doj': datetime.date(2022, 4, 25), 'specializations': ['Leadership', 'Angular', 'Machine Learning', 'Google Cloud Platform'], 'dob': datetime.date(1947, 1, 1), 'city': 'East Helen', 'state': 'Texas', 'experience': 7, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'BK$3CXJe'}
# {'userId': 'Emp_10', 'firstName': 'Linda', 'middleName': 'Jillian', 'lastName': 'Wilkinson', 'email': 'blairdrew@example.net', 'phoneNumber': '001-436-499-9620', 'gender': 'Male', 'doj': datetime.date(2024, 3, 25), 'specializations': ['Django', 'Git', 'Information Security', 'Wireframing'], 'dob': datetime.date(1980, 3, 14), 'city': 'Reginaldland', 'state': 'North Carolina', 'experience': 10, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^1b8+QEh'}
# {'userId': 'Emp_11', 'firstName': 'Nicholas', 'middleName': 'Kenneth', 'lastName': 'Moody', 'email': 'ericberger@example.net', 'phoneNumber': '851.599.6027', 'gender': 'Female', 'doj': datetime.date(2020, 7, 17), 'specializations': ['Statistical Analysis', 'CSS', 'Kubernetes', 'Artificial Intelligence'], 'dob': datetime.date(1917, 1, 12), 'city': 'Caseyhaven', 'state': 'Connecticut', 'experience': 18, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '6&JT6H2r'}
# {'userId': 'Emp_12', 'firstName': 'Kathryn', 'middleName': 'Patrick', 'lastName': 'Henry', 'email': 'denise38@example.org', 'phoneNumber': '537.818.6237', 'gender': 'Male', 'doj': datetime.date(2023, 8, 24), 'specializations': ['Support', 'Microservices', 'Java', 'Accessibility'], 'dob': datetime.date(1971, 7, 23), 'city': 'Jocelyntown', 'state': 'Pennsylvania', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'r@xE6MFw'}
# {'userId': 'Emp_13', 'firstName': 'Autumn', 'middleName': 'John', 'lastName': 'Fuentes', 'email': 'xpruitt@example.net', 'phoneNumber': '3087352685', 'gender': 'Male', 'doj': datetime.date(2022, 11, 7), 'specializations': ['Technical Writing', 'Information Security', 'Machine Learning', 'Product Management'], 'dob': datetime.date(1950, 9, 26), 'city': 'Charleston', 'state': 'Ohio', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'y#n229Sv'}
# {'userId': 'Emp_14', 'firstName': 'Jerry', 'middleName': 'Andrew', 'lastName': 'Hamilton', 'email': 'jerrynguyen@example.org', 'phoneNumber': '(613)790-3960', 'gender': 'Female', 'doj': datetime.date(2022, 4, 7), 'specializations': ['Angular', 'React', 'Kubernetes', 'CI/CD'], 'dob': datetime.date(2001, 7, 14), 'city': 'South Ericaport', 'state': 'Minnesota', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%s4)cCje'}
# {'userId': 'Emp_15', 'firstName': 'Beth', 'middleName': 'Todd', 'lastName': 'Logan', 'email': 'pcaldwell@example.org', 'phoneNumber': '001-929-296-1309x0339', 'gender': 'Male', 'doj': datetime.date(2022, 6, 20), 'specializations': ['Continuous Integration', 'SQL', 'NoSQL', 'Support'], 'dob': datetime.date(1994, 5, 5), 'city': 'Heatherfort', 'state': 'Michigan', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%7QX^4Zw'}
# {'userId': 'Emp_16', 'firstName': 'William', 'middleName': 'Austin', 'lastName': 'Roman', 'email': 'freemananna@example.com', 'phoneNumber': '445.335.3634x33108', 'gender': 'Female', 'doj': datetime.date(2022, 8, 12), 'specializations': ['Continuous Integration', 'Behavior-Driven Development', 'Support', 'Vue.js'], 'dob': datetime.date(1964, 8, 14), 'city': 'Karenview', 'state': 'New Hampshire', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'X$5hVIwB'}
# {'userId': 'Emp_17', 'firstName': 'Christopher', 'middleName': 'Jeremy', 'lastName': 'Benson', 'email': 'gcardenas@example.net', 'phoneNumber': '796.294.1866x5439', 'gender': 'Female', 'doj': datetime.date(2020, 5, 23), 'specializations': ['Microservices', 'Collaboration', 'Agile Methodologies', 'Kubernetes'], 'dob': datetime.date(1919, 1, 5), 'city': 'Port Andreaville', 'state': 'Florida', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'zC_f3Tgl'}
# {'userId': 'Emp_18', 'firstName': 'Randy', 'middleName': 'Paula', 'lastName': 'Anderson', 'email': 'hfigueroa@example.com', 'phoneNumber': '3254194098', 'gender': 'Male', 'doj': datetime.date(2024, 1, 5), 'specializations': ['Python', 'Machine Learning', 'Collaboration', 'DevOps'], 'dob': datetime.date(1953, 6, 24), 'city': 'North Donnamouth', 'state': 'Pennsylvania', 'experience': 5, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '(P(04Lbv'}
# {'userId': 'Emp_19', 'firstName': 'Jesse', 'middleName': 'Christopher', 'lastName': 'Robinson', 'email': 'jared85@example.net', 'phoneNumber': '334.522.8403x70263', 'gender': 'Male', 'doj': datetime.date(2021, 12, 26), 'specializations': ['Artificial Intelligence', 'PHP', 'Kotlin', 'Prototyping'], 'dob': datetime.date(1992, 1, 13), 'city': 'West Michelle', 'state': 'Illinois', 'experience': 18, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '@R4YtTc0'}
# {'userId': 'Emp_20', 'firstName': 'Christopher', 'middleName': 'Carlos', 'lastName': 'Murphy', 'email': 'epatterson@example.com', 'phoneNumber': '+1-557-328-9961x8957', 'gender': 'Male', 'doj': datetime.date(2022, 1, 31), 'specializations': ['Cryptography', 'Kubernetes', 'Interaction Design', 'Accessibility'], 'dob': datetime.date(2005, 10, 16), 'city': 'West Linda', 'state': 'Texas', 'experience': 9, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '%2#1CTgx'}
# {'userId': 'Emp_21', 'firstName': 'Kenneth', 'middleName': 'Ryan', 'lastName': 'Ruiz', 'email': 'ellisvickie@example.com', 'phoneNumber': '289-980-1128x40546', 'gender': 'Male', 'doj': datetime.date(2021, 7, 19), 'specializations': ['Cryptography', 'Documentation', 'Python', 'Data Analysis'], 'dob': datetime.date(2004, 12, 23), 'city': 'Meganbury', 'state': 'Hawaii', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'M!DF0KAb'}
# {'userId': 'Emp_22', 'firstName': 'Roger', 'middleName': 'Lisa', 'lastName': 'Bell', 'email': 'ystone@example.com', 'phoneNumber': '502-630-8576', 'gender': 'Female', 'doj': datetime.date(2020, 10, 3), 'specializations': ['C#', 'Agile Product Management', 'Problem Solving', 'Requirements Analysis'], 'dob': datetime.date(1985, 11, 24), 'city': 'Clarkside', 'state': 'Rhode Island', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '*1ID8udw'}
# {'userId': 'Emp_23', 'firstName': 'Paul', 'middleName': 'Brenda', 'lastName': 'Vega', 'email': 'michaelhaas@example.net', 'phoneNumber': '703.418.9128', 'gender': 'Female', 'doj': datetime.date(2023, 9, 12), 'specializations': ['Requirements Analysis', 'SQL', 'Vue.js', 'Django'], 'dob': datetime.date(1985, 1, 5), 'city': 'Duaneburgh', 'state': 'South Dakota', 'experience': 2, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '+I7BZD7b'}
# {'userId': 'Emp_24', 'firstName': 'Megan', 'middleName': 'Gail', 'lastName': 'Moreno', 'email': 'ramirezjohnathan@example.net', 'phoneNumber': '897.950.6339x6830', 'gender': 'Female', 'doj': datetime.date(2022, 11, 14), 'specializations': ['Communication', 'C#', 'Wireframing', 'Kotlin'], 'dob': datetime.date(1912, 2, 25), 'city': 'Erinfurt', 'state': 'Arizona', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '#7HZRa5O'}
# {'userId': 'Emp_25', 'firstName': 'Donald', 'middleName': 'Kara', 'lastName': 'Buck', 'email': 'ashley62@example.net', 'phoneNumber': '001-722-959-6191x8535', 'gender': 'Male', 'doj': datetime.date(2022, 6, 19), 'specializations': ['Penetration Testing', 'Angular', 'Agile Methodologies', 'Cryptography'], 'dob': datetime.date(2001, 3, 2), 'city': 'West Stephenmouth', 'state': 'Minnesota', 'experience': 1, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'T(7boCWh'}
# {'userId': 'Emp_26', 'firstName': 'Amanda', 'middleName': 'Gerald', 'lastName': 'Salinas', 'email': 'hnewton@example.net', 'phoneNumber': '6107150831', 'gender': 'Male', 'doj': datetime.date(2023, 5, 25), 'specializations': ['Google Cloud Platform', 'User Research', 'Python', 'Information Security'], 'dob': datetime.date(1954, 2, 20), 'city': 'South Maryton', 'state': 'Alabama', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'n%&3OFt8'}
# {'userId': 'Emp_27', 'firstName': 'Donna', 'middleName': 'Tanner', 'lastName': 'Wilson', 'email': 'sonyahood@example.com', 'phoneNumber': '+1-475-676-3621', 'gender': 'Female', 'doj': datetime.date(2020, 12, 3), 'specializations': ['Ruby', 'Prototyping', 'Support', 'Kubernetes'], 'dob': datetime.date(1926, 11, 8), 'city': 'Charleshaven', 'state': 'Kansas', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'pAp*34Zl'}
# {'userId': 'Emp_28', 'firstName': 'Jesus', 'middleName': 'Christine', 'lastName': 'Molina', 'email': 'scottsusan@example.net', 'phoneNumber': '913-671-4918', 'gender': 'Female', 'doj': datetime.date(2023, 6, 25), 'specializations': ['Scrum', 'MongoDB', 'User Stories', 'Git'], 'dob': datetime.date(1954, 1, 27), 'city': 'North Amanda', 'state': 'Colorado', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'v(322_Ly'}
# {'userId': 'Emp_29', 'firstName': 'Michelle', 'middleName': 'Tiffany', 'lastName': 'Smith', 'email': 'pricebrandon@example.net', 'phoneNumber': '001-822-247-9461x9268', 'gender': 'Female', 'doj': datetime.date(2020, 8, 5), 'specializations': ['RESTful API', 'Kotlin', 'Git', 'AWS'], 'dob': datetime.date(1941, 7, 9), 'city': 'East Daniel', 'state': 'New Mexico', 'experience': 15, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'TQ_^g0Ar'}
# {'userId': 'Emp_30', 'firstName': 'Stephanie', 'middleName': 'John', 'lastName': 'Hernandez', 'email': 'scottcharles@example.com', 'phoneNumber': '001-451-883-0057x259', 'gender': 'Male', 'doj': datetime.date(2020, 1, 2), 'specializations': ['HTML', 'Continuous Deployment', 'Data Visualization', 'Documentation'], 'dob': datetime.date(2014, 3, 30), 'city': 'New Donald', 'state': 'Maine', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'n_3bCwwK'}
# {'userId': 'Emp_31', 'firstName': 'Joseph', 'middleName': 'Charles', 'lastName': 'Jimenez', 'email': 'vporter@example.org', 'phoneNumber': '629-522-3696x08087', 'gender': 'Male', 'doj': datetime.date(2021, 2, 2), 'specializations': ['Java', 'Vue.js', 'Business Analysis', 'Kotlin'], 'dob': datetime.date(2018, 1, 3), 'city': 'South Jerry', 'state': 'New Hampshire', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 't^J0U@q8'}
# {'userId': 'Emp_32', 'firstName': 'Sherry', 'middleName': 'Joan', 'lastName': 'Wilson', 'email': 'chadbaker@example.net', 'phoneNumber': '883-932-2450x150', 'gender': 'Male', 'doj': datetime.date(2023, 2, 25), 'specializations': ['Angular', 'Interaction Design', 'Behavior-Driven Development', 'Statistical Analysis'], 'dob': datetime.date(1934, 6, 2), 'city': 'Aliciaport', 'state': 'Maryland', 'experience': 6, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '$ahy8AiA'}
# {'userId': 'Emp_33', 'firstName': 'Brittney', 'middleName': 'Christine', 'lastName': 'Stone', 'email': 'stricklandvictor@example.net', 'phoneNumber': '483.563.3961', 'gender': 'Female', 'doj': datetime.date(2023, 5, 1), 'specializations': ['Scrum', 'Angular', 'Business Analysis', 'Agile Methodologies'], 'dob': datetime.date(2005, 11, 4), 'city': 'Ronaldmouth', 'state': 'Minnesota', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^(8Wy4r3'}
# {'userId': 'Emp_34', 'firstName': 'Erin', 'middleName': 'John', 'lastName': 'Randall', 'email': 'kwade@example.net', 'phoneNumber': '+1-920-542-7003', 'gender': 'Male', 'doj': datetime.date(2021, 12, 22), 'specializations': ['Continuous Deployment', 'Data Visualization', 'C#', 'Business Analysis'], 'dob': datetime.date(2002, 4, 21), 'city': 'East Ashley', 'state': 'New York', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '_@4Kcvqp'}
# {'userId': 'Emp_35', 'firstName': 'Jeanette', 'middleName': 'Patrick', 'lastName': 'Roberson', 'email': 'larsonsherri@example.net', 'phoneNumber': '(676)770-1095', 'gender': 'Male', 'doj': datetime.date(2022, 10, 15), 'specializations': ['Wireframing', 'Penetration Testing', 'Product Management', 'Test-Driven Development'], 'dob': datetime.date(2015, 1, 16), 'city': 'West Faith', 'state': 'Wyoming', 'experience': 1, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%9C33Fos'}
# {'userId': 'Emp_36', 'firstName': 'Misty', 'middleName': 'Christopher', 'lastName': 'Powell', 'email': 'paulasteele@example.com', 'phoneNumber': '001-552-801-2788x063', 'gender': 'Female', 'doj': datetime.date(2020, 5, 3), 'specializations': ['Django', 'Continuous Deployment', 'SQL', 'Machine Learning'], 'dob': datetime.date(1948, 10, 9), 'city': 'New Davidmouth', 'state': 'West Virginia', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'u+x2o4Ea'}
# {'userId': 'Emp_37', 'firstName': 'Connie', 'middleName': 'Michael', 'lastName': 'Welch', 'email': 'sandrazavala@example.net', 'phoneNumber': '418.965.6068x604', 'gender': 'Female', 'doj': datetime.date(2023, 3, 29), 'specializations': ['Cybersecurity', 'Requirements Analysis', 'Flask', 'Google Cloud Platform'], 'dob': datetime.date(1986, 6, 9), 'city': 'Ivanburgh', 'state': 'West Virginia', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'i)Wb4LWm'}
# {'userId': 'Emp_38', 'firstName': 'Peter', 'middleName': 'Billy', 'lastName': 'Taylor', 'email': 'pmoreno@example.org', 'phoneNumber': '547.918.5627x11517', 'gender': 'Female', 'doj': datetime.date(2022, 7, 12), 'specializations': ['Network Security', 'Troubleshooting', 'C#', 'Statistical Analysis'], 'dob': datetime.date(1956, 2, 17), 'city': 'South Ashley', 'state': 'Louisiana', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^Pg%0ZsR'}
# {'userId': 'Emp_39', 'firstName': 'Patrick', 'middleName': 'Kevin', 'lastName': 'Burgess', 'email': 'jennifer19@example.com', 'phoneNumber': '(657)974-1520x1490', 'gender': 'Male', 'doj': datetime.date(2023, 7, 26), 'specializations': ['Troubleshooting', 'CI/CD', 'SQL', 'Information Security'], 'dob': datetime.date(1975, 11, 30), 'city': 'Garciaburgh', 'state': 'Tennessee', 'experience': 14, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'e+1he(Qq'}
# {'userId': 'Emp_40', 'firstName': 'Logan', 'middleName': 'Tyler', 'lastName': 'Mitchell', 'email': 'joel46@example.net', 'phoneNumber': '668-754-5905', 'gender': 'Male', 'doj': datetime.date(2022, 10, 20), 'specializations': ['Continuous Integration', 'Network Security', 'Information Security', 'C#'], 'dob': datetime.date(1963, 12, 27), 'city': 'West Samuel', 'state': 'Kansas', 'experience': 9, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'Lk6_7RIy'}
# {'userId': 'Emp_41', 'firstName': 'Ronnie', 'middleName': 'James', 'lastName': 'Austin', 'email': 'warrenchristine@example.net', 'phoneNumber': '001-523-277-5428x4071', 'gender': 'Female', 'doj': datetime.date(2021, 12, 5), 'specializations': ['PHP', 'DevOps', 'Java', 'Vue.js'], 'dob': datetime.date(1917, 11, 26), 'city': 'Daleburgh', 'state': 'Arkansas', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'x(1PVEow'}
# {'userId': 'Emp_42', 'firstName': 'Shannon', 'middleName': 'Cindy', 'lastName': 'Maxwell', 'email': 'michaelfox@example.net', 'phoneNumber': '(646)710-3356', 'gender': 'Male', 'doj': datetime.date(2022, 12, 25), 'specializations': ['Documentation', 'Cybersecurity', 'CI/CD', 'Requirements Analysis'], 'dob': datetime.date(1908, 4, 4), 'city': 'Ramosstad', 'state': 'New Jersey', 'experience': 5, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '%4MOLsdc'}
# {'userId': 'Emp_43', 'firstName': 'Kelly', 'middleName': 'Frank', 'lastName': 'Underwood', 'email': 'georgenash@example.net', 'phoneNumber': '001-985-847-7830x503', 'gender': 'Male', 'doj': datetime.date(2023, 4, 17), 'specializations': ['Agile Methodologies', 'Technical Writing', 'User Stories', 'Machine Learning'], 'dob': datetime.date(1943, 2, 14), 'city': 'Jaredview', 'state': 'Nevada', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'L%78OQux'}
# {'userId': 'Emp_44', 'firstName': 'Elizabeth', 'middleName': 'Katherine', 'lastName': 'Morgan', 'email': 'yrodriguez@example.net', 'phoneNumber': '(231)416-1150', 'gender': 'Male', 'doj': datetime.date(2024, 2, 26), 'specializations': ['Network Security', 'Kubernetes', 'Documentation', 'MongoDB'], 'dob': datetime.date(1934, 10, 31), 'city': 'South Melvinfurt', 'state': 'North Carolina', 'experience': 11, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'zR))55Kw'}
# {'userId': 'Emp_45', 'firstName': 'Heather', 'middleName': 'Jeff', 'lastName': 'Gordon', 'email': 'fwells@example.org', 'phoneNumber': '357-821-2217', 'gender': 'Female', 'doj': datetime.date(2023, 10, 10), 'specializations': ['Problem Solving', 'Prototyping', 'NoSQL', 'Node.js'], 'dob': datetime.date(2016, 9, 1), 'city': 'North Danielchester', 'state': 'Rhode Island', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '(Vm7RPxm'}
# {'userId': 'Emp_46', 'firstName': 'Jacob', 'middleName': 'Lisa', 'lastName': 'Wright', 'email': 'andrew09@example.net', 'phoneNumber': '270-969-2712x0395', 'gender': 'Female', 'doj': datetime.date(2023, 3, 31), 'specializations': ['PostgreSQL', 'User Stories', 'Communication', 'Leadership'], 'dob': datetime.date(1953, 5, 6), 'city': 'North Alyssaport', 'state': 'Arizona', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': ')(0IzQsL'}
# {'userId': 'Emp_47', 'firstName': 'Anthony', 'middleName': 'Charles', 'lastName': 'Jones', 'email': 'marknguyen@example.com', 'phoneNumber': '468-839-5936', 'gender': 'Male', 'doj': datetime.date(2023, 12, 15), 'specializations': ['Documentation', 'Cybersecurity', 'Angular', 'Python'], 'dob': datetime.date(2002, 6, 27), 'city': 'West Albert', 'state': 'Arizona', 'experience': 13, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '4^4M*t_%'}
# {'userId': 'Emp_48', 'firstName': 'Justin', 'middleName': 'Gwendolyn', 'lastName': 'Robinson', 'email': 'stephaniemoore@example.net', 'phoneNumber': '345-849-9014x7565', 'gender': 'Female', 'doj': datetime.date(2021, 5, 27), 'specializations': ['MongoDB', 'DevOps', 'UI/UX Design', 'Vue.js'], 'dob': datetime.date(1952, 7, 23), 'city': 'Nicholaschester', 'state': 'Ohio', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '_^3$JbZN'}
# {'userId': 'Emp_49', 'firstName': 'Jennifer', 'middleName': 'Timothy', 'lastName': 'Figueroa', 'email': 'mary46@example.net', 'phoneNumber': '956-873-4531x1366', 'gender': 'Female', 'doj': datetime.date(2023, 9, 3), 'specializations': ['RESTful API', 'Kotlin', 'HTML', 'Agile Methodologies'], 'dob': datetime.date(1925, 3, 6), 'city': 'Audreyville', 'state': 'Alaska', 'experience': 5, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'RJU^1xPn'}
# {'userId': 'Emp_50', 'firstName': 'Elizabeth', 'middleName': 'Gary', 'lastName': 'Navarro', 'email': 'ustevens@example.net', 'phoneNumber': '+1-385-408-1622x433', 'gender': 'Female', 'doj': datetime.date(2021, 10, 5), 'specializations': ['Artificial Intelligence', 'MongoDB', 'Penetration Testing', 'Problem Solving'], 'dob': datetime.date(2014, 2, 12), 'city': 'Lake Jeremyfort', 'state': 'New Jersey', 'experience': 9, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '#&6yJfKl'}
# {'userId': 'Emp_51', 'firstName': 'Anthony', 'middleName': 'Brandon', 'lastName': 'Nelson', 'email': 'waltersvanessa@example.net', 'phoneNumber': '(392)204-0712x324', 'gender': 'Male', 'doj': datetime.date(2022, 8, 23), 'specializations': ['MySQL', 'User Stories', 'Python', 'Problem Solving'], 'dob': datetime.date(1969, 3, 15), 'city': 'Mccartyland', 'state': 'Maryland', 'experience': 9, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'T#1E_8fJ'}
# {'userId': 'Emp_52', 'firstName': 'Allison', 'middleName': 'Tracy', 'lastName': 'Keller', 'email': 'michael90@example.net', 'phoneNumber': '(295)954-6001', 'gender': 'Female', 'doj': datetime.date(2023, 1, 19), 'specializations': ['HTML', 'Business Analysis', 'Kubernetes', 'Objective-C'], 'dob': datetime.date(1973, 5, 26), 'city': 'Jennifermouth', 'state': 'Arkansas', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '!1EWKP8x'}
# {'userId': 'Emp_53', 'firstName': 'Lindsay', 'middleName': 'James', 'lastName': 'Flores', 'email': 'deborah92@example.org', 'phoneNumber': '(834)666-3437x705', 'gender': 'Male', 'doj': datetime.date(2023, 7, 6), 'specializations': ['Data Science', 'Requirements Analysis', 'Leadership', 'Responsive Design'], 'dob': datetime.date(1910, 1, 16), 'city': 'New Elizabeth', 'state': 'Florida', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'd*8Llsvg'}
# {'userId': 'Emp_54', 'firstName': 'Donna', 'middleName': 'Tammy', 'lastName': 'Levine', 'email': 'robertshort@example.org', 'phoneNumber': '(909)604-1620x32651', 'gender': 'Female', 'doj': datetime.date(2021, 7, 10), 'specializations': ['Network Security', 'React', 'User Research', 'Azure'], 'dob': datetime.date(1935, 12, 21), 'city': 'Port Patricia', 'state': 'Louisiana', 'experience': 6, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'cP!5FsEe'}
# {'userId': 'Emp_55', 'firstName': 'Robin', 'middleName': 'Albert', 'lastName': 'Duarte', 'email': 'ocooke@example.net', 'phoneNumber': '001-362-468-3471x38423', 'gender': 'Male', 'doj': datetime.date(2022, 2, 2), 'specializations': ['NoSQL', 'Google Cloud Platform', 'Cryptography', 'Angular'], 'dob': datetime.date(1974, 2, 12), 'city': 'New Stephanie', 'state': 'Maryland', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'v_Br4MTa'}
# {'userId': 'Emp_56', 'firstName': 'Jesse', 'middleName': 'Suzanne', 'lastName': 'Brown', 'email': 'hernandezbailey@example.com', 'phoneNumber': '874.921.2459x470', 'gender': 'Male', 'doj': datetime.date(2020, 9, 30), 'specializations': ['Kotlin', 'JavaScript', 'Wireframing', 'Swift'], 'dob': datetime.date(1967, 5, 18), 'city': 'Rasmussenville', 'state': 'Mississippi', 'experience': 12, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '!3PHrsOb'}
# {'userId': 'Emp_57', 'firstName': 'Mark', 'middleName': 'Chad', 'lastName': 'Stephens', 'email': 'kelly70@example.com', 'phoneNumber': '385-904-6958', 'gender': 'Female', 'doj': datetime.date(2023, 11, 8), 'specializations': ['Behavior-Driven Development', 'Test-Driven Development', 'Cryptography', 'Kotlin'], 'dob': datetime.date(1990, 5, 14), 'city': 'New Anne', 'state': 'Indiana', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '+N!^4ROa'}
# {'userId': 'Emp_58', 'firstName': 'Susan', 'middleName': 'Samuel', 'lastName': 'Hernandez', 'email': 'natalie29@example.org', 'phoneNumber': '583.679.9302x64776', 'gender': 'Male', 'doj': datetime.date(2021, 7, 1), 'specializations': ['Troubleshooting', 'Cybersecurity', 'Collaboration', 'Objective-C'], 'dob': datetime.date(1978, 7, 27), 'city': 'Ninaview', 'state': 'Alabama', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '(9+ZrV0g'}
# {'userId': 'Emp_59', 'firstName': 'Elizabeth', 'middleName': 'Joshua', 'lastName': 'Rios', 'email': 'erin93@example.org', 'phoneNumber': '502-593-2917', 'gender': 'Male', 'doj': datetime.date(2020, 5, 14), 'specializations': ['Machine Learning', 'AWS', 'C#', 'Continuous Integration'], 'dob': datetime.date(1952, 6, 10), 'city': 'West Stephen', 'state': 'Michigan', 'experience': 8, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'o(0YDN5x'}
# {'userId': 'Emp_60', 'firstName': 'Patrick', 'middleName': 'Roy', 'lastName': 'Salazar', 'email': 'griffintyler@example.org', 'phoneNumber': '771-469-2880x12821', 'gender': 'Male', 'doj': datetime.date(2023, 4, 21), 'specializations': ['C#', 'Ruby', 'CI/CD', 'Agile Methodologies'], 'dob': datetime.date(1926, 8, 3), 'city': 'Maureenland', 'state': 'Utah', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'cE^9Gmaf'}
# {'userId': 'Emp_61', 'firstName': 'Sara', 'middleName': 'Amy', 'lastName': 'Fitzpatrick', 'email': 'heather41@example.net', 'phoneNumber': '706-859-9288x973', 'gender': 'Female', 'doj': datetime.date(2022, 12, 31), 'specializations': ['Continuous Deployment', 'Cryptography', 'Vue.js', 'Accessibility'], 'dob': datetime.date(2004, 5, 20), 'city': 'Port Jeffreyland', 'state': 'South Dakota', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'mU$Ou0Qw'}
# {'userId': 'Emp_62', 'firstName': 'Isaiah', 'middleName': 'Mary', 'lastName': 'Padilla', 'email': 'mitchellpamela@example.net', 'phoneNumber': '(746)359-7579x3996', 'gender': 'Female', 'doj': datetime.date(2021, 5, 4), 'specializations': ['Microservices', 'Wireframing', 'UI/UX Design', 'Data Analysis'], 'dob': datetime.date(1950, 7, 29), 'city': 'Owenside', 'state': 'Delaware', 'experience': 2, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '+B381E^k'}
# {'userId': 'Emp_63', 'firstName': 'Joseph', 'middleName': 'Eric', 'lastName': 'Martinez', 'email': 'cunninghamcameron@example.com', 'phoneNumber': '990.394.5908x05717', 'gender': 'Male', 'doj': datetime.date(2020, 8, 12), 'specializations': ['Ruby', 'Statistical Analysis', 'Troubleshooting', 'Containerization'], 'dob': datetime.date(1977, 7, 10), 'city': 'Lake Michael', 'state': 'Kentucky', 'experience': 8, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'gQ%49Ao6'}
# {'userId': 'Emp_64', 'firstName': 'Gabrielle', 'middleName': 'Jonathan', 'lastName': 'Murray', 'email': 'nicole22@example.com', 'phoneNumber': '625.441.6597x28452', 'gender': 'Male', 'doj': datetime.date(2023, 3, 1), 'specializations': ['User Stories', 'CI/CD', 'Product Management', 'Troubleshooting'], 'dob': datetime.date(1960, 12, 31), 'city': 'Gibsonland', 'state': 'Tennessee', 'experience': 1, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '#Fs29Hik'}
# {'userId': 'Emp_65', 'firstName': 'Rodney', 'middleName': 'Nicole', 'lastName': 'Deleon', 'email': 'padams@example.net', 'phoneNumber': '001-921-399-6854x7541', 'gender': 'Female', 'doj': datetime.date(2020, 11, 17), 'specializations': ['Network Security', 'User Research', 'Angular', 'Test-Driven Development'], 'dob': datetime.date(1918, 2, 19), 'city': 'Stevenhaven', 'state': 'New Jersey', 'experience': 19, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '2#Yht1Xt'}
# {'userId': 'Emp_66', 'firstName': 'Kristy', 'middleName': 'Miguel', 'lastName': 'Haney', 'email': 'tony78@example.net', 'phoneNumber': '892.226.7602x913', 'gender': 'Male', 'doj': datetime.date(2020, 4, 13), 'specializations': ['CSS', 'Agile Methodologies', 'Technical Writing', 'Azure'], 'dob': datetime.date(1934, 6, 21), 'city': 'Brettton', 'state': 'Michigan', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'Kyx!3Sy('}
# {'userId': 'Emp_67', 'firstName': 'Kevin', 'middleName': 'Vincent', 'lastName': 'Duran', 'email': 'qjones@example.com', 'phoneNumber': '777.293.6751', 'gender': 'Male', 'doj': datetime.date(2022, 9, 27), 'specializations': ['SQL', 'Leadership', 'GraphQL', 'Kubernetes'], 'dob': datetime.date(2014, 10, 15), 'city': 'Victorialand', 'state': 'Maryland', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 's&)7XJfm'}
# {'userId': 'Emp_68', 'firstName': 'Carol', 'middleName': 'Jacob', 'lastName': 'Singleton', 'email': 'huntlinda@example.net', 'phoneNumber': '878.908.8515x611', 'gender': 'Male', 'doj': datetime.date(2024, 1, 31), 'specializations': ['Problem Solving', 'Support', 'Scrum', 'Artificial Intelligence'], 'dob': datetime.date(1968, 3, 4), 'city': 'Kellieburgh', 'state': 'Hawaii', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '+581L7Cx'}
# {'userId': 'Emp_69', 'firstName': 'Brian', 'middleName': 'Monica', 'lastName': 'Campbell', 'email': 'annolson@example.org', 'phoneNumber': '539.973.0852x2780', 'gender': 'Male', 'doj': datetime.date(2020, 6, 16), 'specializations': ['Microservices', 'Test-Driven Development', 'HTML', 'Artificial Intelligence'], 'dob': datetime.date(1998, 12, 25), 'city': 'West Morganhaven', 'state': 'Alaska', 'experience': 14, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '!s@qa6Qq'}
# {'userId': 'Emp_70', 'firstName': 'Patricia', 'middleName': 'Erin', 'lastName': 'Allen', 'email': 'bryantkristin@example.com', 'phoneNumber': '+1-435-665-9879x6202', 'gender': 'Female', 'doj': datetime.date(2021, 5, 15), 'specializations': ['React', 'Java', 'Containerization', 'Azure'], 'dob': datetime.date(1969, 5, 10), 'city': 'Jonland', 'state': 'Oklahoma', 'experience': 8, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '_G04JF7p'}
# {'userId': 'Emp_71', 'firstName': 'Kathy', 'middleName': 'Andrew', 'lastName': 'Rodriguez', 'email': 'ikane@example.org', 'phoneNumber': '(551)448-3994x1628', 'gender': 'Female', 'doj': datetime.date(2022, 9, 25), 'specializations': ['Problem Solving', 'Behavior-Driven Development', 'Information Security', 'Cybersecurity'], 'dob': datetime.date(2004, 3, 16), 'city': 'North Samuelmouth', 'state': 'Missouri', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'sAs)7UyX'}
# {'userId': 'Emp_72', 'firstName': 'Andre', 'middleName': 'Mike', 'lastName': 'Ramirez', 'email': 'quinnchristina@example.org', 'phoneNumber': '(374)800-8355', 'gender': 'Male', 'doj': datetime.date(2023, 2, 3), 'specializations': ['React', 'Agile Product Management', 'Behavior-Driven Development', 'Data Science'], 'dob': datetime.date(1935, 8, 7), 'city': 'Lake Carlabury', 'state': 'South Carolina', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^tC15Pez'}
# {'userId': 'Emp_73', 'firstName': 'Patricia', 'middleName': 'Cheryl', 'lastName': 'Young', 'email': 'cheryl14@example.org', 'phoneNumber': '+1-737-499-1689x3855', 'gender': 'Female', 'doj': datetime.date(2022, 9, 5), 'specializations': ['NoSQL', 'React', 'RESTful API', 'Continuous Integration'], 'dob': datetime.date(1911, 6, 23), 'city': 'Dunnhaven', 'state': 'Hawaii', 'experience': 6, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': ')0E@V6uu'}
# {'userId': 'Emp_74', 'firstName': 'Carrie', 'middleName': 'John', 'lastName': 'Jackson', 'email': 'craig71@example.org', 'phoneNumber': '314-372-8893x3100', 'gender': 'Male', 'doj': datetime.date(2022, 3, 26), 'specializations': ['User Stories', 'User Research', 'JavaScript', 'Vue.js'], 'dob': datetime.date(1948, 6, 5), 'city': 'New Seanbury', 'state': 'Alabama', 'experience': 10, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '$E4KWsGm'}
# {'userId': 'Emp_75', 'firstName': 'Debra', 'middleName': 'April', 'lastName': 'Cole', 'email': 'stephanieallen@example.com', 'phoneNumber': '001-261-709-9630x780', 'gender': 'Female', 'doj': datetime.date(2021, 8, 30), 'specializations': ['Product Management', 'Containerization', 'User Research', 'C#'], 'dob': datetime.date(1987, 1, 20), 'city': 'Sarahview', 'state': 'Delaware', 'experience': 12, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'TyN(e1Xz'}
# {'userId': 'Emp_76', 'firstName': 'Michael', 'middleName': 'Marilyn', 'lastName': 'Ryan', 'email': 'dmartinez@example.org', 'phoneNumber': '234-923-7149', 'gender': 'Male', 'doj': datetime.date(2023, 5, 29), 'specializations': ['RESTful API', 'Continuous Deployment', 'PostgreSQL', 'JavaScript'], 'dob': datetime.date(1939, 9, 27), 'city': 'Martinezport', 'state': 'Kentucky', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'OpL!2GDt'}
# {'userId': 'Emp_77', 'firstName': 'Michael', 'middleName': 'Cassandra', 'lastName': 'Olson', 'email': 'sellersbrittney@example.com', 'phoneNumber': '399.533.5526', 'gender': 'Female', 'doj': datetime.date(2023, 5, 2), 'specializations': ['Swift', 'Wireframing', 'Continuous Deployment', 'User Stories'], 'dob': datetime.date(2019, 2, 13), 'city': 'Nathanhaven', 'state': 'Rhode Island', 'experience': 15, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '!p61Is*6'}
# {'userId': 'Emp_78', 'firstName': 'Karen', 'middleName': 'Rodney', 'lastName': 'Holden', 'email': 'kevin23@example.com', 'phoneNumber': '247-425-8251x7079', 'gender': 'Female', 'doj': datetime.date(2022, 8, 27), 'specializations': ['C#', 'MySQL', 'React', 'Information Security'], 'dob': datetime.date(1951, 4, 26), 'city': 'North Katherine', 'state': 'Pennsylvania', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '!h8Ip3xo'}
# {'userId': 'Emp_79', 'firstName': 'Mark', 'middleName': 'Timothy', 'lastName': 'Roberts', 'email': 'browngary@example.org', 'phoneNumber': '+1-907-200-4461', 'gender': 'Female', 'doj': datetime.date(2021, 9, 9), 'specializations': ['Scrum', '.NET', 'Agile Product Management', 'Product Management'], 'dob': datetime.date(1929, 1, 25), 'city': 'Lisaland', 'state': 'Kansas', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '(8JyX_AZ'}
# {'userId': 'Emp_80', 'firstName': 'Ashley', 'middleName': 'Nicole', 'lastName': 'Dickerson', 'email': 'lbuchanan@example.net', 'phoneNumber': '964-817-3386x8334', 'gender': 'Male', 'doj': datetime.date(2024, 2, 21), 'specializations': ['Cybersecurity', 'Prototyping', 'Agile Product Management', 'Continuous Deployment'], 'dob': datetime.date(1926, 8, 11), 'city': 'Michaelton', 'state': 'Florida', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '^5j58Kw7'}
# {'userId': 'Emp_81', 'firstName': 'Tara', 'middleName': 'Kristi', 'lastName': 'Lewis', 'email': 'ashleypatterson@example.net', 'phoneNumber': '(629)995-9203', 'gender': 'Male', 'doj': datetime.date(2021, 7, 21), 'specializations': ['Support', 'Data Visualization', 'Documentation', 'Prototyping'], 'dob': datetime.date(1967, 2, 4), 'city': 'South Jamesfort', 'state': 'South Dakota', 'experience': 3, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '!6%RicwL'}
# {'userId': 'Emp_82', 'firstName': 'Erin', 'middleName': 'Zachary', 'lastName': 'Silva', 'email': 'leonardsheena@example.com', 'phoneNumber': '+1-216-878-2662x82853', 'gender': 'Male', 'doj': datetime.date(2021, 4, 12), 'specializations': ['Node.js', 'Requirements Analysis', 'Git', 'Docker'], 'dob': datetime.date(1935, 9, 22), 'city': 'New Elizabethstad', 'state': 'Missouri', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'T%8YuD2p'}
# {'userId': 'Emp_83', 'firstName': 'Cathy', 'middleName': 'Jennifer', 'lastName': 'Glover', 'email': 'hernandezmegan@example.com', 'phoneNumber': '001-622-217-6640x63068', 'gender': 'Male', 'doj': datetime.date(2020, 1, 21), 'specializations': ['Ruby', 'Support', 'Data Analysis', 'Microservices'], 'dob': datetime.date(1965, 1, 5), 'city': 'New Justinport', 'state': 'Pennsylvania', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')1sTYYvl'}
# {'userId': 'Emp_84', 'firstName': 'Willie', 'middleName': 'Regina', 'lastName': 'Fuentes', 'email': 'dhunt@example.org', 'phoneNumber': '353-554-0937x5464', 'gender': 'Male', 'doj': datetime.date(2023, 3, 13), 'specializations': ['DevOps', 'Node.js', 'Vue.js', 'Angular'], 'dob': datetime.date(1997, 2, 22), 'city': 'South Heatherland', 'state': 'Pennsylvania', 'experience': 11, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '*6#j9sDd'}
# {'userId': 'Emp_85', 'firstName': 'Deborah', 'middleName': 'John', 'lastName': 'Kaiser', 'email': 'charlotte88@example.net', 'phoneNumber': '(294)656-7358', 'gender': 'Female', 'doj': datetime.date(2023, 5, 31), 'specializations': ['C#', 'MySQL', 'Network Security', 'AWS'], 'dob': datetime.date(1973, 1, 30), 'city': 'Lake Joshua', 'state': 'New Hampshire', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'bs9!7L8b'}
# {'userId': 'Emp_86', 'firstName': 'Wyatt', 'middleName': 'Candice', 'lastName': 'Smith', 'email': 'brad58@example.net', 'phoneNumber': '001-291-470-3184x140', 'gender': 'Female', 'doj': datetime.date(2023, 9, 16), 'specializations': ['CSS', 'Communication', 'MongoDB', 'Node.js'], 'dob': datetime.date(2011, 2, 7), 'city': 'South Heatherstad', 'state': 'Tennessee', 'experience': 19, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '#d)7CkFs'}
# {'userId': 'Emp_87', 'firstName': 'Alexa', 'middleName': 'Curtis', 'lastName': 'Hayes', 'email': 'wjohnson@example.com', 'phoneNumber': '001-394-446-3733x856', 'gender': 'Male', 'doj': datetime.date(2022, 10, 15), 'specializations': ['Data Visualization', 'MySQL', 'Kubernetes', 'Containerization'], 'dob': datetime.date(2022, 3, 10), 'city': 'South Alexiston', 'state': 'Kansas', 'experience': 7, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '+3Yzf&h&'}
# {'userId': 'Emp_88', 'firstName': 'Alison', 'middleName': 'Margaret', 'lastName': 'Odonnell', 'email': 'wlarson@example.com', 'phoneNumber': '+1-407-407-3822x996', 'gender': 'Male', 'doj': datetime.date(2021, 4, 18), 'specializations': ['Penetration Testing', 'Business Analysis', 'Documentation', 'Ruby'], 'dob': datetime.date(1981, 7, 31), 'city': 'New Matthewview', 'state': 'Oklahoma', 'experience': 6, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '3!T2uHdu'}
# {'userId': 'Emp_89', 'firstName': 'Jonathan', 'middleName': 'Misty', 'lastName': 'Sanchez', 'email': 'williamlewis@example.net', 'phoneNumber': '462.271.2344x1455', 'gender': 'Male', 'doj': datetime.date(2020, 12, 3), 'specializations': ['Machine Learning', 'Communication', 'GraphQL', 'Google Cloud Platform'], 'dob': datetime.date(1969, 6, 9), 'city': 'Courtneystad', 'state': 'Nebraska', 'experience': 1, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^Z3K$dT8'}
# {'userId': 'Emp_90', 'firstName': 'Jonathan', 'middleName': 'Rebecca', 'lastName': 'Barron', 'email': 'hobbstara@example.com', 'phoneNumber': '(424)265-4629x84446', 'gender': 'Female', 'doj': datetime.date(2021, 1, 17), 'specializations': ['Continuous Integration', 'RESTful API', 'SQL', 'Kotlin'], 'dob': datetime.date(1955, 9, 9), 'city': 'Lake Bryan', 'state': 'Washington', 'experience': 13, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'F$472Nr('}
# {'userId': 'Emp_91', 'firstName': 'Kim', 'middleName': 'Dustin', 'lastName': 'Cooley', 'email': 'annettegonzalez@example.org', 'phoneNumber': '001-552-996-8753', 'gender': 'Female', 'doj': datetime.date(2021, 3, 17), 'specializations': ['Collaboration', 'Objective-C', 'Agile Product Management', 'User Research'], 'dob': datetime.date(2007, 2, 15), 'city': 'South Ryanchester', 'state': 'Colorado', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'S#o54GYg'}
# {'userId': 'Emp_92', 'firstName': 'William', 'middleName': 'Kelly', 'lastName': 'Daniels', 'email': 'kenneth19@example.com', 'phoneNumber': '634-205-9915', 'gender': 'Male', 'doj': datetime.date(2023, 11, 8), 'specializations': ['.NET', 'Python', 'Agile Methodologies', 'JavaScript'], 'dob': datetime.date(1914, 1, 19), 'city': 'Lake Matthewburgh', 'state': 'South Dakota', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '^!+Y2YBu'}
# {'userId': 'Emp_93', 'firstName': 'Joseph', 'middleName': 'Lori', 'lastName': 'Ferrell', 'email': 'stacy26@example.com', 'phoneNumber': '335-677-6628', 'gender': 'Male', 'doj': datetime.date(2020, 7, 19), 'specializations': ['Interaction Design', 'Microservices', 'Kotlin', 'Objective-C'], 'dob': datetime.date(2009, 2, 13), 'city': 'Josephchester', 'state': 'Texas', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '+#@1&By('}
# {'userId': 'Emp_94', 'firstName': 'David', 'middleName': 'Eric', 'lastName': 'Brown', 'email': 'youngamy@example.net', 'phoneNumber': '942.591.5577x6412', 'gender': 'Male', 'doj': datetime.date(2021, 10, 29), 'specializations': ['Communication', 'Continuous Deployment', 'Google Cloud Platform', 'Wireframing'], 'dob': datetime.date(2018, 1, 14), 'city': 'Albertchester', 'state': 'Oregon', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'Jw)1Zfhr'}
# {'userId': 'Emp_95', 'firstName': 'Elizabeth', 'middleName': 'James', 'lastName': 'Sanders', 'email': 'kyleperry@example.org', 'phoneNumber': '679-216-0606x2417', 'gender': 'Female', 'doj': datetime.date(2023, 4, 21), 'specializations': ['Git', 'Responsive Design', 'Problem Solving', 'Business Analysis'], 'dob': datetime.date(1994, 2, 7), 'city': 'Jimenezhaven', 'state': 'Illinois', 'experience': 4, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': ')7ZJ%_Vp'}
# {'userId': 'Emp_96', 'firstName': 'Andres', 'middleName': 'Jennifer', 'lastName': 'Smith', 'email': 'jhobbs@example.com', 'phoneNumber': '511-952-6077x96453', 'gender': 'Female', 'doj': datetime.date(2020, 1, 12), 'specializations': ['Data Visualization', 'React', 'Statistical Analysis', 'PHP'], 'dob': datetime.date(1986, 12, 19), 'city': 'Lake Michaelside', 'state': 'Wisconsin', 'experience': 2, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '$@6KHrHy'}
# {'userId': 'Emp_97', 'firstName': 'Jean', 'middleName': 'Jacob', 'lastName': 'Bailey', 'email': 'latoya35@example.com', 'phoneNumber': '+1-601-836-5693x2772', 'gender': 'Female', 'doj': datetime.date(2024, 1, 11), 'specializations': ['Vue.js', 'Cybersecurity', 'Network Security', 'Ruby'], 'dob': datetime.date(1941, 11, 8), 'city': 'Christianview', 'state': 'Illinois', 'experience': 7, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '*kz&5L4s'}
# {'userId': 'Emp_98', 'firstName': 'Taylor', 'middleName': 'Angela', 'lastName': 'Sanchez', 'email': 'rruiz@example.com', 'phoneNumber': '001-270-696-9106', 'gender': 'Female', 'doj': datetime.date(2022, 5, 28), 'specializations': ['MongoDB', 'Cybersecurity', 'Python', 'DevOps'], 'dob': datetime.date(1941, 2, 15), 'city': 'Ronaldville', 'state': 'Texas', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'ja2@86Qt'}
# {'userId': 'Emp_99', 'firstName': 'Amber', 'middleName': 'Donald', 'lastName': 'Mcconnell', 'email': 'sarah13@example.net', 'phoneNumber': '001-429-997-1415x259', 'gender': 'Female', 'doj': datetime.date(2022, 2, 23), 'specializations': ['PHP', 'Problem Solving', 'RESTful API', 'Vue.js'], 'dob': datetime.date(1976, 5, 13), 'city': 'Carolynhaven', 'state': 'Minnesota', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '(od3Qdyi'}
# {'userId': 'Emp_100', 'firstName': 'Eileen', 'middleName': 'Martin', 'lastName': 'Knight', 'email': 'jimmykhan@example.com', 'phoneNumber': '702.473.9356x07046', 'gender': 'Female', 'doj': datetime.date(2021, 2, 10), 'specializations': ['Vue.js', '.NET', 'DevOps', 'SQL'], 'dob': datetime.date(2004, 8, 31), 'city': 'Port Glennmouth', 'state': 'California', 'experience': 16, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '^5n#T^Ie'}
# {'userId': 'Emp_101', 'firstName': 'Rachel', 'middleName': 'Megan', 'lastName': 'Conway', 'email': 'shudson@example.net', 'phoneNumber': '746-497-2910x3427', 'gender': 'Male', 'doj': datetime.date(2021, 3, 7), 'specializations': ['MySQL', 'Prototyping', 'DevOps', 'CSS'], 'dob': datetime.date(1979, 3, 7), 'city': 'Matthewmouth', 'state': 'Texas', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'y#x7Bidi'}
# {'userId': 'Emp_102', 'firstName': 'Kevin', 'middleName': 'Michelle', 'lastName': 'Jenkins', 'email': 'qwilliams@example.com', 'phoneNumber': '489.840.1461', 'gender': 'Female', 'doj': datetime.date(2021, 2, 17), 'specializations': ['Problem Solving', 'Wireframing', 'C#', 'GraphQL'], 'dob': datetime.date(1997, 11, 19), 'city': 'Micheleshire', 'state': 'Kansas', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '(7UJ3lQl'}
# ...
# {'userId': 'Emp_966', 'firstName': 'Anthony', 'middleName': 'Amy', 'lastName': 'Osborne', 'email': 'timothyking@example.net', 'phoneNumber': '(283)946-9469x867', 'gender': 'Female', 'doj': datetime.date(2024, 2, 13), 'specializations': ['Node.js', 'Behavior-Driven Development', 'Azure', 'Responsive Design'], 'dob': datetime.date(1960, 12, 31), 'city': 'West Christopherland', 'state': 'California', 'experience': 5, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'fx$6Fara'}
# {'userId': 'Emp_967', 'firstName': 'Chase', 'middleName': 'Kimberly', 'lastName': 'Cross', 'email': 'william77@example.com', 'phoneNumber': '001-509-255-4018x4978', 'gender': 'Female', 'doj': datetime.date(2020, 5, 8), 'specializations': ['PHP', 'Prototyping', 'Accessibility', 'Objective-C'], 'dob': datetime.date(2001, 11, 23), 'city': 'Victoriastad', 'state': 'California', 'experience': 2, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '_5^XYjp)'}
# {'userId': 'Emp_968', 'firstName': 'John', 'middleName': 'Geoffrey', 'lastName': 'Shepherd', 'email': 'morrisanne@example.org', 'phoneNumber': '001-293-284-2832x1568', 'gender': 'Male', 'doj': datetime.date(2022, 4, 23), 'specializations': ['Artificial Intelligence', 'Vue.js', 'AWS', 'Django'], 'dob': datetime.date(1937, 1, 27), 'city': 'Lake Susan', 'state': 'Massachusetts', 'experience': 17, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '!7YlKnCT'}
# {'userId': 'Emp_969', 'firstName': 'Richard', 'middleName': 'Robert', 'lastName': 'Howard', 'email': 'heathertaylor@example.org', 'phoneNumber': '001-514-667-4039x318', 'gender': 'Female', 'doj': datetime.date(2023, 11, 25), 'specializations': ['Node.js', 'Requirements Analysis', 'Leadership', 'Kotlin'], 'dob': datetime.date(1980, 1, 6), 'city': 'East Rebeccaborough', 'state': 'Wisconsin', 'experience': 17, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '!X3pC9o7'}
# {'userId': 'Emp_970', 'firstName': 'Karen', 'middleName': 'James', 'lastName': 'Reyes', 'email': 'silvamaria@example.com', 'phoneNumber': '+1-484-564-6075x88889', 'gender': 'Female', 'doj': datetime.date(2021, 5, 31), 'specializations': ['HTML', 'Django', 'Statistical Analysis', 'Kotlin'], 'dob': datetime.date(2014, 10, 16), 'city': 'Hullside', 'state': 'Kentucky', 'experience': 10, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': ')8!1i9Xd'}
# {'userId': 'Emp_971', 'firstName': 'Amy', 'middleName': 'Lori', 'lastName': 'Huerta', 'email': 'alexandria62@example.org', 'phoneNumber': '924-921-5847x4376', 'gender': 'Female', 'doj': datetime.date(2022, 9, 27), 'specializations': ['NoSQL', 'Objective-C', 'Vue.js', 'Swift'], 'dob': datetime.date(2006, 2, 27), 'city': 'South Sarah', 'state': 'Vermont', 'experience': 9, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '@4jFQh_W'}
# {'userId': 'Emp_972', 'firstName': 'Anthony', 'middleName': 'Kathleen', 'lastName': 'Hancock', 'email': 'anne27@example.org', 'phoneNumber': '+1-936-855-4460x92447', 'gender': 'Male', 'doj': datetime.date(2022, 6, 16), 'specializations': ['Vue.js', 'JavaScript', 'MySQL', 'UI/UX Design'], 'dob': datetime.date(1939, 5, 15), 'city': 'Lake Michaeltown', 'state': 'Michigan', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '_(4Dy!u!'}
# {'userId': 'Emp_973', 'firstName': 'Lisa', 'middleName': 'Jacob', 'lastName': 'Spencer', 'email': 'vegasusan@example.com', 'phoneNumber': '763.917.1399', 'gender': 'Female', 'doj': datetime.date(2020, 5, 19), 'specializations': ['Kotlin', 'Business Analysis', 'Data Science', 'Network Security'], 'dob': datetime.date(1954, 6, 9), 'city': 'Lake Michaelport', 'state': 'Alabama', 'experience': 5, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '%(Hl5MoU'}
# {'userId': 'Emp_974', 'firstName': 'Christopher', 'middleName': 'Christopher', 'lastName': 'Vaughn', 'email': 'jonathan12@example.org', 'phoneNumber': '245.450.4690x587', 'gender': 'Male', 'doj': datetime.date(2020, 5, 24), 'specializations': ['NoSQL', 'C#', 'Django', 'Network Security'], 'dob': datetime.date(1930, 6, 18), 'city': 'Nicoleberg', 'state': 'Virginia', 'experience': 2, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'u7Q@1QSa'}
# {'userId': 'Emp_975', 'firstName': 'Catherine', 'middleName': 'Rebecca', 'lastName': 'Schmidt', 'email': 'erin87@example.net', 'phoneNumber': '(702)681-4923x036', 'gender': 'Male', 'doj': datetime.date(2020, 4, 28), 'specializations': ['Documentation', 'Machine Learning', 'AWS', 'Technical Writing'], 'dob': datetime.date(1920, 7, 7), 'city': 'Jonesfurt', 'state': 'Idaho', 'experience': 14, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '#X8yOOzl'}
# {'userId': 'Emp_976', 'firstName': 'Morgan', 'middleName': 'Seth', 'lastName': 'Murray', 'email': 'michellemartinez@example.org', 'phoneNumber': '438-495-8696', 'gender': 'Female', 'doj': datetime.date(2022, 11, 4), 'specializations': ['Troubleshooting', 'Technical Writing', 'Data Science', 'Problem Solving'], 'dob': datetime.date(2020, 4, 16), 'city': 'Stevenmouth', 'state': 'Illinois', 'experience': 11, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '@g0BvOPz'}
# {'userId': 'Emp_977', 'firstName': 'Jeffrey', 'middleName': 'John', 'lastName': 'Daniels', 'email': 'oramirez@example.net', 'phoneNumber': '(740)643-8604x050', 'gender': 'Male', 'doj': datetime.date(2021, 9, 4), 'specializations': ['PHP', 'GraphQL', 'User Research', 'Collaboration'], 'dob': datetime.date(2020, 12, 5), 'city': 'Lake Melissachester', 'state': 'Louisiana', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'pW99)5Sx'}
# {'userId': 'Emp_978', 'firstName': 'Phillip', 'middleName': 'Glen', 'lastName': 'Mercer', 'email': 'vhicks@example.org', 'phoneNumber': '956-577-1038', 'gender': 'Male', 'doj': datetime.date(2021, 10, 21), 'specializations': ['GraphQL', 'Documentation', 'CSS', 'Machine Learning'], 'dob': datetime.date(1913, 11, 2), 'city': 'Peterstad', 'state': 'Wyoming', 'experience': 15, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'v1*@5Cuk'}
# {'userId': 'Emp_979', 'firstName': 'Maria', 'middleName': 'David', 'lastName': 'Gardner', 'email': 'stephanie46@example.net', 'phoneNumber': '688-278-9893x9173', 'gender': 'Female', 'doj': datetime.date(2020, 8, 14), 'specializations': ['NoSQL', 'Kotlin', 'Agile Methodologies', 'Artificial Intelligence'], 'dob': datetime.date(2019, 1, 30), 'city': 'Christopherhaven', 'state': 'New Jersey', 'experience': 10, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^v1*$#Ob'}
# {'userId': 'Emp_980', 'firstName': 'Kimberly', 'middleName': 'Ivan', 'lastName': 'Cordova', 'email': 'lpetersen@example.com', 'phoneNumber': '703.645.3836', 'gender': 'Female', 'doj': datetime.date(2020, 3, 24), 'specializations': ['CI/CD', 'UI/UX Design', 'Agile Methodologies', 'MySQL'], 'dob': datetime.date(1922, 11, 22), 'city': 'Bauertown', 'state': 'Arizona', 'experience': 1, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '@0EXzPis'}
# {'userId': 'Emp_981', 'firstName': 'Deborah', 'middleName': 'Charles', 'lastName': 'Miles', 'email': 'meredith64@example.net', 'phoneNumber': '301.551.6968x540', 'gender': 'Male', 'doj': datetime.date(2020, 11, 29), 'specializations': ['Prototyping', 'Docker', 'CSS', 'Business Analysis'], 'dob': datetime.date(1990, 2, 10), 'city': 'Jenniferton', 'state': 'Kansas', 'experience': 14, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '#@%w2xAs'}
# {'userId': 'Emp_982', 'firstName': 'Michelle', 'middleName': 'Jeremy', 'lastName': 'Lambert', 'email': 'ajones@example.com', 'phoneNumber': '+1-479-669-7794', 'gender': 'Male', 'doj': datetime.date(2023, 8, 27), 'specializations': ['AWS', 'React', 'RESTful API', 'User Stories'], 'dob': datetime.date(1996, 7, 7), 'city': 'North Josemouth', 'state': 'Wisconsin', 'experience': 9, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^7PsDAfD'}
# {'userId': 'Emp_983', 'firstName': 'Maureen', 'middleName': 'Sylvia', 'lastName': 'Pham', 'email': 'wilsontony@example.org', 'phoneNumber': '001-830-404-7464x3774', 'gender': 'Male', 'doj': datetime.date(2020, 5, 2), 'specializations': ['SQL', 'Artificial Intelligence', 'Ruby', '.NET'], 'dob': datetime.date(2005, 1, 18), 'city': 'Brooksport', 'state': 'Kentucky', 'experience': 15, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '%t8RxvZc'}
# {'userId': 'Emp_984', 'firstName': 'Jeremy', 'middleName': 'Lauren', 'lastName': 'Hernandez', 'email': 'xmathis@example.com', 'phoneNumber': '313-338-8826', 'gender': 'Male', 'doj': datetime.date(2021, 12, 15), 'specializations': ['DevOps', 'Google Cloud Platform', 'Ruby', 'Statistical Analysis'], 'dob': datetime.date(1926, 7, 31), 'city': 'Nicholasport', 'state': 'North Dakota', 'experience': 6, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'Sh%k7Fse'}
# {'userId': 'Emp_985', 'firstName': 'Daniel', 'middleName': 'Christina', 'lastName': 'Day', 'email': 'deanna24@example.net', 'phoneNumber': '891.969.4608x8262', 'gender': 'Female', 'doj': datetime.date(2020, 5, 20), 'specializations': ['AWS', 'Scrum', 'Cryptography', 'SQL'], 'dob': datetime.date(1991, 2, 27), 'city': 'Stevenchester', 'state': 'Michigan', 'experience': 14, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '@z0KBxn4'}
# {'userId': 'Emp_986', 'firstName': 'Dawn', 'middleName': 'Sarah', 'lastName': 'Lyons', 'email': 'moorerachel@example.net', 'phoneNumber': '5832933520', 'gender': 'Female', 'doj': datetime.date(2020, 11, 13), 'specializations': ['Ruby', 'Google Cloud Platform', 'Node.js', 'Leadership'], 'dob': datetime.date(1919, 7, 17), 'city': 'East Anthonymouth', 'state': 'Oklahoma', 'experience': 16, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '%R8NbqEX'}
# {'userId': 'Emp_987', 'firstName': 'Michael', 'middleName': 'Mathew', 'lastName': 'Wolfe', 'email': 'palmerchristine@example.net', 'phoneNumber': '001-805-362-2665x106', 'gender': 'Female', 'doj': datetime.date(2021, 1, 25), 'specializations': ['Continuous Deployment', 'Wireframing', 'Network Security', 'Docker'], 'dob': datetime.date(1963, 11, 17), 'city': 'New Tyler', 'state': 'Ohio', 'experience': 19, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'B+3iBUYi'}
# {'userId': 'Emp_988', 'firstName': 'Daniel', 'middleName': 'Geoffrey', 'lastName': 'Caldwell', 'email': 'leahhuber@example.com', 'phoneNumber': '721-791-5041x533', 'gender': 'Female', 'doj': datetime.date(2021, 6, 10), 'specializations': ['Test-Driven Development', 'NoSQL', 'Agile Product Management', 'Kotlin'], 'dob': datetime.date(2011, 9, 13), 'city': 'East Jose', 'state': 'Colorado', 'experience': 2, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': '*LR9Lwk9'}
# {'userId': 'Emp_989', 'firstName': 'Mary', 'middleName': 'Spencer', 'lastName': 'Jensen', 'email': 'desireewheeler@example.net', 'phoneNumber': '9812399367', 'gender': 'Male', 'doj': datetime.date(2023, 5, 23), 'specializations': ['Continuous Integration', 'JavaScript', 'Swift', 'Requirements Analysis'], 'dob': datetime.date(1929, 1, 25), 'city': 'North Jesse', 'state': 'Colorado', 'experience': 11, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': '$38TYpn1'}
# {'userId': 'Emp_990', 'firstName': 'Brittany', 'middleName': 'Elizabeth', 'lastName': 'Church', 'email': 'wrightnicole@example.com', 'phoneNumber': '(269)954-4874x23753', 'gender': 'Female', 'doj': datetime.date(2022, 11, 14), 'specializations': ['Cybersecurity', 'RESTful API', 'React', 'Microservices'], 'dob': datetime.date(1931, 4, 25), 'city': 'Brianside', 'state': 'Missouri', 'experience': 18, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '9C#2TDvG'}
# {'userId': 'Emp_991', 'firstName': 'Mark', 'middleName': 'Brandon', 'lastName': 'Murillo', 'email': 'lmanning@example.net', 'phoneNumber': '+1-679-525-2409', 'gender': 'Male', 'doj': datetime.date(2022, 4, 18), 'specializations': ['Responsive Design', '.NET', 'MongoDB', 'Agile Product Management'], 'dob': datetime.date(2007, 7, 7), 'city': 'Smithside', 'state': 'New Jersey', 'experience': 19, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'Se&Op8Zc'}
# {'userId': 'Emp_992', 'firstName': 'Madeline', 'middleName': 'Samuel', 'lastName': 'Jensen', 'email': 'danahuang@example.org', 'phoneNumber': '+1-771-511-3663x6667', 'gender': 'Female', 'doj': datetime.date(2020, 12, 29), 'specializations': ['Data Science', 'Swift', 'Angular', 'JavaScript'], 'dob': datetime.date(1986, 11, 27), 'city': 'Ericachester', 'state': 'Michigan', 'experience': 17, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'l#dU6sMt'}
# {'userId': 'Emp_993', 'firstName': 'Jacob', 'middleName': 'Steve', 'lastName': 'Stokes', 'email': 'wheelermeredith@example.net', 'phoneNumber': '001-725-452-6107x7143', 'gender': 'Female', 'doj': datetime.date(2021, 8, 30), 'specializations': ['DevOps', 'Leadership', 'Test-Driven Development', 'Agile Product Management'], 'dob': datetime.date(1972, 3, 20), 'city': 'Port Ryan', 'state': 'Maine', 'experience': 9, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': 'd@^1&LHo'}
# {'userId': 'Emp_994', 'firstName': 'Timothy', 'middleName': 'Heather', 'lastName': 'Rogers', 'email': 'jesserogers@example.com', 'phoneNumber': '3984434586', 'gender': 'Female', 'doj': datetime.date(2022, 10, 16), 'specializations': ['Angular', 'Machine Learning', 'Accessibility', 'Test-Driven Development'], 'dob': datetime.date(1965, 6, 15), 'city': 'Douglasbury', 'state': 'Oregon', 'experience': 18, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': '6I_5Vx@F'}
# {'userId': 'Emp_995', 'firstName': 'Brandon', 'middleName': 'Tara', 'lastName': 'Fisher', 'email': 'jrivera@example.net', 'phoneNumber': '+1-600-853-7526', 'gender': 'Male', 'doj': datetime.date(2021, 5, 8), 'specializations': ['Google Cloud Platform', 'Swift', 'Continuous Integration', 'PHP'], 'dob': datetime.date(1938, 2, 11), 'city': 'East Erin', 'state': 'Louisiana', 'experience': 20, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': 'y&02Xf0I'}
# {'userId': 'Emp_996', 'firstName': 'Robin', 'middleName': 'Jennifer', 'lastName': 'Robinson', 'email': 'wdaniel@example.org', 'phoneNumber': '256.891.4428x2586', 'gender': 'Female', 'doj': datetime.date(2020, 10, 19), 'specializations': ['AWS', 'Cybersecurity', 'NoSQL', 'Leadership'], 'dob': datetime.date(2023, 3, 15), 'city': 'New Cassandra', 'state': 'Connecticut', 'experience': 3, 'userType': 'Admin', 'subscribeNewsletter': False, 'passwords': 'dh(M3RDm'}
# {'userId': 'Emp_997', 'firstName': 'Amanda', 'middleName': 'Louis', 'lastName': 'Knight', 'email': 'kelli61@example.net', 'phoneNumber': '666-611-6213', 'gender': 'Female', 'doj': datetime.date(2021, 3, 7), 'specializations': ['Objective-C', 'Ruby', 'Agile Methodologies', 'Agile Product Management'], 'dob': datetime.date(2023, 5, 9), 'city': 'North Craig', 'state': 'Nevada', 'experience': 12, 'userType': 'User', 'subscribeNewsletter': False, 'passwords': ')7QAsseb'}
# {'userId': 'Emp_998', 'firstName': 'Paul', 'middleName': 'Barbara', 'lastName': 'Sullivan', 'email': 'margaretmartin@example.com', 'phoneNumber': '545-350-1595', 'gender': 'Female', 'doj': datetime.date(2023, 1, 1), 'specializations': ['JavaScript', 'Responsive Design', 'Product Management', 'User Research'], 'dob': datetime.date(1932, 9, 4), 'city': 'Smithmouth', 'state': 'Arizona', 'experience': 9, 'userType': 'User', 'subscribeNewsletter': True, 'passwords': 'B#$4mMgq'}
# {'userId': 'Emp_999', 'firstName': 'Kristin', 'middleName': 'Sara', 'lastName': 'Malone', 'email': 'jordan06@example.net', 'phoneNumber': '230-300-3066x3078', 'gender': 'Male', 'doj': datetime.date(2021, 7, 28), 'specializations': ['Product Management', 'Agile Methodologies', 'Vue.js', 'Data Analysis'], 'dob': datetime.date(1918, 8, 31), 'city': 'South Kimberlymouth', 'state': 'Delaware', 'experience': 19, 'userType': 'Admin', 'subscribeNewsletter': True, 'passwords': '^u5BQ4aQ'}

# %%
# Write data to CSV file
csv_file_path = "user_data.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for user_data in fake_data_list:
        writer.writerow(user_data)

print(f"User data has been saved to {csv_file_path}")
# Out:
# User data has been saved to user_data.csv

# %%
fake_data_list = []
for i in range(1, 100):
    certificates = random.sample(skills, 4)
    user_data = {
        "userId": "Emp_" + str(i),
        "trainerName": fake.first_name(),
        "trainerDesignation": fake.random_element(elements=job_roles),
        "trainerRating": fake.random_int(min=1, max=5),
        "trainerSpecialization": certificates,
    }
    fake_data_list.append(user_data)

# Print the generated fake data
for user_data in fake_data_list:
    print(user_data)
# Out:
# {'userId': 'Emp_1', 'trainerName': 'Kevin', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 5, 'trainerSpecialization': ['Cryptography', 'Kubernetes', 'Java', 'UI/UX Design']}
# {'userId': 'Emp_2', 'trainerName': 'Angela', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 2, 'trainerSpecialization': ['Scrum', 'Docker', 'Artificial Intelligence', 'Problem Solving']}
# {'userId': 'Emp_3', 'trainerName': 'Alyssa', 'trainerDesignation': 'IT Administrator', 'trainerRating': 2, 'trainerSpecialization': ['Statistical Analysis', 'Objective-C', 'Cryptography', 'Problem Solving']}
# {'userId': 'Emp_4', 'trainerName': 'Ashley', 'trainerDesignation': 'Full-stack Developer', 'trainerRating': 4, 'trainerSpecialization': ['MongoDB', 'MySQL', 'Scrum', 'CSS']}
# {'userId': 'Emp_5', 'trainerName': 'Alexandra', 'trainerDesignation': 'Agile Coach', 'trainerRating': 5, 'trainerSpecialization': ['UI/UX Design', 'Git', 'Technical Writing', 'Collaboration']}
# {'userId': 'Emp_6', 'trainerName': 'Nicholas', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 3, 'trainerSpecialization': ['Responsive Design', 'MongoDB', 'Ruby', 'Machine Learning']}
# {'userId': 'Emp_7', 'trainerName': 'Ashley', 'trainerDesignation': 'Agile Coach', 'trainerRating': 5, 'trainerSpecialization': ['Agile Methodologies', 'CI/CD', 'Business Analysis', 'Azure']}
# {'userId': 'Emp_8', 'trainerName': 'Jacob', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Responsive Design', 'Git', 'DevOps', 'Network Security']}
# {'userId': 'Emp_9', 'trainerName': 'Brandon', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 3, 'trainerSpecialization': ['CSS', 'Docker', 'Technical Writing', 'Product Management']}
# {'userId': 'Emp_10', 'trainerName': 'Amanda', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Ruby', 'Agile Methodologies', 'Wireframing', 'DevOps']}
# {'userId': 'Emp_11', 'trainerName': 'Kristen', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Microservices', 'Kotlin', 'Angular', 'MySQL']}
# {'userId': 'Emp_12', 'trainerName': 'Christina', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 1, 'trainerSpecialization': ['Prototyping', 'Node.js', 'PostgreSQL', 'Containerization']}
# {'userId': 'Emp_13', 'trainerName': 'Melissa', 'trainerDesignation': 'Full-stack Developer', 'trainerRating': 4, 'trainerSpecialization': ['DevOps', 'Troubleshooting', 'Data Visualization', 'User Stories']}
# {'userId': 'Emp_14', 'trainerName': 'Paula', 'trainerDesignation': 'Data Scientist', 'trainerRating': 3, 'trainerSpecialization': ['Ruby', 'Data Analysis', 'React', 'CSS']}
# {'userId': 'Emp_15', 'trainerName': 'Christopher', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 3, 'trainerSpecialization': ['Docker', 'Test-Driven Development', 'SQL', 'Django']}
# {'userId': 'Emp_16', 'trainerName': 'David', 'trainerDesignation': 'Scrum Master', 'trainerRating': 3, 'trainerSpecialization': ['Agile Methodologies', 'Interaction Design', 'Vue.js', 'Business Analysis']}
# {'userId': 'Emp_17', 'trainerName': 'Jennifer', 'trainerDesignation': 'Release Manager', 'trainerRating': 1, 'trainerSpecialization': ['Test-Driven Development', 'Microservices', 'MongoDB', 'Ruby']}
# {'userId': 'Emp_18', 'trainerName': 'Valerie', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Kotlin', 'NoSQL', 'Ruby', 'DevOps']}
# {'userId': 'Emp_19', 'trainerName': 'Adam', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 4, 'trainerSpecialization': ['JavaScript', 'Leadership', 'Wireframing', 'GraphQL']}
# {'userId': 'Emp_20', 'trainerName': 'Doris', 'trainerDesignation': 'Agile Coach', 'trainerRating': 4, 'trainerSpecialization': ['Kotlin', 'Angular', 'Support', 'Agile Product Management']}
# {'userId': 'Emp_21', 'trainerName': 'Stephen', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 4, 'trainerSpecialization': ['SQL', 'GraphQL', 'Cryptography', 'Network Security']}
# {'userId': 'Emp_22', 'trainerName': 'Steven', 'trainerDesignation': 'Product Manager', 'trainerRating': 5, 'trainerSpecialization': ['MongoDB', 'JavaScript', 'Swift', 'Machine Learning']}
# {'userId': 'Emp_23', 'trainerName': 'Nicole', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 3, 'trainerSpecialization': ['Azure', 'Node.js', 'Behavior-Driven Development', 'Troubleshooting']}
# {'userId': 'Emp_24', 'trainerName': 'Tracey', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Vue.js', 'PHP', 'Ruby', 'Product Management']}
# {'userId': 'Emp_25', 'trainerName': 'Mark', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 3, 'trainerSpecialization': ['User Stories', 'Angular', 'Docker', 'React']}
# {'userId': 'Emp_26', 'trainerName': 'Erica', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Cybersecurity', 'UI/UX Design', 'Test-Driven Development', 'Java']}
# {'userId': 'Emp_27', 'trainerName': 'Susan', 'trainerDesignation': 'IT Administrator', 'trainerRating': 3, 'trainerSpecialization': ['Angular', 'Network Security', 'PHP', 'NoSQL']}
# {'userId': 'Emp_28', 'trainerName': 'Mary', 'trainerDesignation': 'Data Scientist', 'trainerRating': 1, 'trainerSpecialization': ['Responsive Design', 'Problem Solving', 'Data Analysis', 'Objective-C']}
# {'userId': 'Emp_29', 'trainerName': 'Kimberly', 'trainerDesignation': 'Software Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Technical Writing', 'Microservices', 'Collaboration', 'PHP']}
# {'userId': 'Emp_30', 'trainerName': 'Jonathan', 'trainerDesignation': 'Release Manager', 'trainerRating': 1, 'trainerSpecialization': ['RESTful API', 'Penetration Testing', 'CSS', 'Information Security']}
# {'userId': 'Emp_31', 'trainerName': 'Cameron', 'trainerDesignation': 'Technical Writer (Documentation Specialist)', 'trainerRating': 1, 'trainerSpecialization': ['Azure', 'MySQL', 'User Research', 'Data Science']}
# {'userId': 'Emp_32', 'trainerName': 'Dustin', 'trainerDesignation': 'Network Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Angular', 'MongoDB', 'Continuous Deployment', 'Kotlin']}
# {'userId': 'Emp_33', 'trainerName': 'Erika', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 4, 'trainerSpecialization': ['Behavior-Driven Development', 'RESTful API', 'Penetration Testing', 'Containerization']}
# {'userId': 'Emp_34', 'trainerName': 'Tiffany', 'trainerDesignation': 'Agile Coach', 'trainerRating': 5, 'trainerSpecialization': ['Agile Methodologies', 'Docker', 'Data Analysis', 'Azure']}
# {'userId': 'Emp_35', 'trainerName': 'Dennis', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 3, 'trainerSpecialization': ['Troubleshooting', 'Wireframing', 'Documentation', 'User Stories']}
# {'userId': 'Emp_36', 'trainerName': 'Bradley', 'trainerDesignation': 'Scrum Master', 'trainerRating': 5, 'trainerSpecialization': ['Test-Driven Development', 'Behavior-Driven Development', 'Python', 'Azure']}
# {'userId': 'Emp_37', 'trainerName': 'Heather', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Java', 'Continuous Deployment', 'Django', 'Docker']}
# {'userId': 'Emp_38', 'trainerName': 'Kelly', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 4, 'trainerSpecialization': ['Support', 'CI/CD', 'Continuous Integration', 'Information Security']}
# {'userId': 'Emp_39', 'trainerName': 'Stacey', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 4, 'trainerSpecialization': ['CSS', 'JavaScript', 'SQL', 'Python']}
# {'userId': 'Emp_40', 'trainerName': 'Maria', 'trainerDesignation': 'Database Administrator (DBA)', 'trainerRating': 5, 'trainerSpecialization': ['Accessibility', 'Network Security', '.NET', 'Prototyping']}
# {'userId': 'Emp_41', 'trainerName': 'Carrie', 'trainerDesignation': 'Business Analyst', 'trainerRating': 5, 'trainerSpecialization': ['Support', 'Scrum', 'Information Security', 'Git']}
# {'userId': 'Emp_42', 'trainerName': 'Michael', 'trainerDesignation': 'Quality Assurance Engineer (QA Engineer)', 'trainerRating': 3, 'trainerSpecialization': ['Problem Solving', 'AWS', 'Responsive Design', 'Prototyping']}
# {'userId': 'Emp_43', 'trainerName': 'Javier', 'trainerDesignation': 'Business Analyst', 'trainerRating': 3, 'trainerSpecialization': ['MongoDB', 'Communication', 'AWS', 'Prototyping']}
# {'userId': 'Emp_44', 'trainerName': 'Mark', 'trainerDesignation': 'IT Administrator', 'trainerRating': 1, 'trainerSpecialization': ['Cybersecurity', 'NoSQL', 'Communication', 'Interaction Design']}
# {'userId': 'Emp_45', 'trainerName': 'Alex', 'trainerDesignation': 'Security Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Business Analysis', 'Agile Methodologies', 'Microservices', 'Vue.js']}
# {'userId': 'Emp_46', 'trainerName': 'Samuel', 'trainerDesignation': 'Release Manager', 'trainerRating': 3, 'trainerSpecialization': ['Interaction Design', 'Python', 'Azure', 'Network Security']}
# {'userId': 'Emp_47', 'trainerName': 'Hannah', 'trainerDesignation': 'Product Manager', 'trainerRating': 4, 'trainerSpecialization': ['Kotlin', 'Data Visualization', 'AWS', 'Accessibility']}
# {'userId': 'Emp_48', 'trainerName': 'Robert', 'trainerDesignation': 'Configuration Manager', 'trainerRating': 4, 'trainerSpecialization': ['Behavior-Driven Development', 'Continuous Deployment', 'CSS', 'Documentation']}
# {'userId': 'Emp_49', 'trainerName': 'Jason', 'trainerDesignation': 'Scrum Master', 'trainerRating': 1, 'trainerSpecialization': ['Information Security', 'AWS', 'Ruby', 'Angular']}
# {'userId': 'Emp_50', 'trainerName': 'Gregory', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 5, 'trainerSpecialization': ['Behavior-Driven Development', 'CI/CD', 'CSS', 'Kotlin']}
# {'userId': 'Emp_51', 'trainerName': 'Joseph', 'trainerDesignation': 'Technical Architect', 'trainerRating': 1, 'trainerSpecialization': ['NoSQL', 'UI/UX Design', 'Azure', 'Wireframing']}
# {'userId': 'Emp_52', 'trainerName': 'Linda', 'trainerDesignation': 'Backend Developer', 'trainerRating': 2, 'trainerSpecialization': ['Kotlin', 'C#', 'Cryptography', 'PostgreSQL']}
# {'userId': 'Emp_53', 'trainerName': 'Roger', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Business Analysis', 'Django', 'GraphQL', 'React']}
# {'userId': 'Emp_54', 'trainerName': 'Joseph', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Azure', 'Responsive Design', 'Leadership', 'Test-Driven Development']}
# {'userId': 'Emp_55', 'trainerName': 'Mark', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 2, 'trainerSpecialization': ['Accessibility', 'Network Security', 'Responsive Design', 'HTML']}
# {'userId': 'Emp_56', 'trainerName': 'Diane', 'trainerDesignation': 'Business Analyst', 'trainerRating': 2, 'trainerSpecialization': ['Docker', 'Swift', 'Penetration Testing', 'Continuous Integration']}
# {'userId': 'Emp_57', 'trainerName': 'Joel', 'trainerDesignation': 'Customer Support Engineer', 'trainerRating': 5, 'trainerSpecialization': ['HTML', 'NoSQL', 'Cybersecurity', 'Angular']}
# {'userId': 'Emp_58', 'trainerName': 'Michael', 'trainerDesignation': 'Release Manager', 'trainerRating': 2, 'trainerSpecialization': ['Data Science', 'Agile Product Management', 'Collaboration', 'Kotlin']}
# {'userId': 'Emp_59', 'trainerName': 'Brittany', 'trainerDesignation': 'Data Scientist', 'trainerRating': 2, 'trainerSpecialization': ['Communication', '.NET', 'Azure', 'C#']}
# {'userId': 'Emp_60', 'trainerName': 'Devin', 'trainerDesignation': 'Network Engineer', 'trainerRating': 4, 'trainerSpecialization': ['Vue.js', 'MySQL', 'Node.js', 'Python']}
# {'userId': 'Emp_61', 'trainerName': 'Emily', 'trainerDesignation': 'IT Support Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Java', 'Azure', 'SQL', 'Troubleshooting']}
# {'userId': 'Emp_62', 'trainerName': 'Kathryn', 'trainerDesignation': 'Configuration Manager', 'trainerRating': 3, 'trainerSpecialization': ['MongoDB', 'Microservices', 'Flask', 'Data Science']}
# {'userId': 'Emp_63', 'trainerName': 'Melissa', 'trainerDesignation': 'Network Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Cybersecurity', 'Continuous Integration', 'Kubernetes', 'Documentation']}
# {'userId': 'Emp_64', 'trainerName': 'Anna', 'trainerDesignation': 'Product Manager', 'trainerRating': 1, 'trainerSpecialization': ['User Stories', 'CI/CD', 'User Research', 'Information Security']}
# {'userId': 'Emp_65', 'trainerName': 'Ashley', 'trainerDesignation': 'DevOps Engineer', 'trainerRating': 3, 'trainerSpecialization': ['PHP', 'Business Analysis', 'Machine Learning', 'HTML']}
# {'userId': 'Emp_66', 'trainerName': 'Brooke', 'trainerDesignation': 'Automation Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Leadership', 'Continuous Integration', 'Azure', 'Data Science']}
# {'userId': 'Emp_67', 'trainerName': 'George', 'trainerDesignation': 'Release Manager', 'trainerRating': 2, 'trainerSpecialization': ['Azure', 'Documentation', 'MySQL', 'GraphQL']}
# {'userId': 'Emp_68', 'trainerName': 'Christopher', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Leadership', 'Kubernetes', 'Google Cloud Platform', 'RESTful API']}
# {'userId': 'Emp_69', 'trainerName': 'Brandon', 'trainerDesignation': 'Systems Analyst', 'trainerRating': 3, 'trainerSpecialization': ['Documentation', 'React', 'NoSQL', 'Troubleshooting']}
# {'userId': 'Emp_70', 'trainerName': 'Matthew', 'trainerDesignation': 'Backend Developer', 'trainerRating': 2, 'trainerSpecialization': ['Wireframing', 'Test-Driven Development', 'GraphQL', 'Documentation']}
# {'userId': 'Emp_71', 'trainerName': 'James', 'trainerDesignation': 'Technical Architect', 'trainerRating': 3, 'trainerSpecialization': ['Cybersecurity', 'CI/CD', 'Flask', 'DevOps']}
# {'userId': 'Emp_72', 'trainerName': 'Paula', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 3, 'trainerSpecialization': ['Git', 'Node.js', 'Kubernetes', 'C#']}
# {'userId': 'Emp_73', 'trainerName': 'Eric', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 3, 'trainerSpecialization': ['User Research', 'Cryptography', 'Wireframing', 'Docker']}
# {'userId': 'Emp_74', 'trainerName': 'James', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 1, 'trainerSpecialization': ['UI/UX Design', 'MongoDB', 'Objective-C', 'Python']}
# {'userId': 'Emp_75', 'trainerName': 'Dominique', 'trainerDesignation': 'Artificial Intelligence Specialist', 'trainerRating': 3, 'trainerSpecialization': ['User Stories', 'Git', 'Technical Writing', 'Behavior-Driven Development']}
# {'userId': 'Emp_76', 'trainerName': 'Yolanda', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 3, 'trainerSpecialization': ['Azure', 'PHP', 'JavaScript', 'Cybersecurity']}
# {'userId': 'Emp_77', 'trainerName': 'Melissa', 'trainerDesignation': 'Technical Architect', 'trainerRating': 2, 'trainerSpecialization': ['User Stories', 'Requirements Analysis', 'Microservices', 'SQL']}
# {'userId': 'Emp_78', 'trainerName': 'Emily', 'trainerDesignation': 'Product Manager', 'trainerRating': 3, 'trainerSpecialization': ['HTML', 'Problem Solving', 'Data Science', 'Flask']}
# {'userId': 'Emp_79', 'trainerName': 'Sarah', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 5, 'trainerSpecialization': ['Technical Writing', 'SQL', 'Product Management', 'Documentation']}
# {'userId': 'Emp_80', 'trainerName': 'Richard', 'trainerDesignation': 'Business Analyst', 'trainerRating': 3, 'trainerSpecialization': ['JavaScript', 'Machine Learning', 'DevOps', 'Business Analysis']}
# {'userId': 'Emp_81', 'trainerName': 'Jacob', 'trainerDesignation': 'Security Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Technical Writing', 'Wireframing', 'Network Security', 'RESTful API']}
# {'userId': 'Emp_82', 'trainerName': 'Marissa', 'trainerDesignation': 'Backend Developer', 'trainerRating': 4, 'trainerSpecialization': ['Kubernetes', 'Continuous Deployment', 'Problem Solving', 'Agile Methodologies']}
# {'userId': 'Emp_83', 'trainerName': 'Joshua', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 5, 'trainerSpecialization': ['Communication', 'Test-Driven Development', 'Python', 'Prototyping']}
# {'userId': 'Emp_84', 'trainerName': 'Tina', 'trainerDesignation': 'Backend Developer', 'trainerRating': 1, 'trainerSpecialization': ['Scrum', 'Interaction Design', 'JavaScript', 'Azure']}
# {'userId': 'Emp_85', 'trainerName': 'Alexander', 'trainerDesignation': 'Software Engineer', 'trainerRating': 5, 'trainerSpecialization': ['AWS', 'Machine Learning', 'Technical Writing', 'Microservices']}
# {'userId': 'Emp_86', 'trainerName': 'Carlos', 'trainerDesignation': 'Security Engineer', 'trainerRating': 1, 'trainerSpecialization': ['Angular', 'CSS', 'AWS', 'SQL']}
# {'userId': 'Emp_87', 'trainerName': 'Teresa', 'trainerDesignation': 'Cloud Solutions Architect', 'trainerRating': 4, 'trainerSpecialization': ['Agile Product Management', 'Data Visualization', 'Support', 'User Research']}
# {'userId': 'Emp_88', 'trainerName': 'Rebecca', 'trainerDesignation': 'Full-stack Developer', 'trainerRating': 2, 'trainerSpecialization': ['Angular', 'Communication', 'DevOps', 'Continuous Deployment']}
# {'userId': 'Emp_89', 'trainerName': 'Jennifer', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 3, 'trainerSpecialization': ['CSS', '.NET', 'Flask', 'Containerization']}
# {'userId': 'Emp_90', 'trainerName': 'Thomas', 'trainerDesignation': 'Agile Coach', 'trainerRating': 1, 'trainerSpecialization': ['PostgreSQL', 'Cryptography', 'Network Security', 'User Research']}
# {'userId': 'Emp_91', 'trainerName': 'Gerald', 'trainerDesignation': 'Technical Architect', 'trainerRating': 2, 'trainerSpecialization': ['Problem Solving', 'Git', 'Business Analysis', 'Support']}
# {'userId': 'Emp_92', 'trainerName': 'Stephanie', 'trainerDesignation': 'Mobile App Developer (iOS/Android)', 'trainerRating': 5, 'trainerSpecialization': ['Kotlin', 'CI/CD', 'React', 'Ruby']}
# {'userId': 'Emp_93', 'trainerName': 'Bryan', 'trainerDesignation': 'Performance Engineer', 'trainerRating': 2, 'trainerSpecialization': ['Technical Writing', 'Data Visualization', 'Docker', 'Cryptography']}
# {'userId': 'Emp_94', 'trainerName': 'Sarah', 'trainerDesignation': 'Scrum Master', 'trainerRating': 1, 'trainerSpecialization': ['SQL', 'Continuous Integration', 'AWS', 'NoSQL']}
# {'userId': 'Emp_95', 'trainerName': 'Shannon', 'trainerDesignation': 'Release Manager', 'trainerRating': 5, 'trainerSpecialization': ['Leadership', 'Agile Product Management', 'UI/UX Design', 'Communication']}
# {'userId': 'Emp_96', 'trainerName': 'Stephen', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 4, 'trainerSpecialization': ['Documentation', 'Vue.js', 'Docker', 'Machine Learning']}
# {'userId': 'Emp_97', 'trainerName': 'Brian', 'trainerDesignation': 'Product Manager', 'trainerRating': 3, 'trainerSpecialization': ['Vue.js', 'CI/CD', '.NET', 'Kubernetes']}
# {'userId': 'Emp_98', 'trainerName': 'Madeline', 'trainerDesignation': 'Machine Learning Engineer', 'trainerRating': 3, 'trainerSpecialization': ['MySQL', 'HTML', 'RESTful API', 'Data Analysis']}
# {'userId': 'Emp_99', 'trainerName': 'Michelle', 'trainerDesignation': 'UI/UX Designer', 'trainerRating': 2, 'trainerSpecialization': ['Requirements Analysis', 'UI/UX Design', 'Microservices', 'CSS']}

# %%
# Write data to CSV file
csv_file_path = "trainer_data.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for user_data in fake_data_list:
        writer.writerow(user_data)

print(f"User data has been saved to {csv_file_path}")
# Out:
# User data has been saved to trainer_data.csv

# %%
from datetime import timedelta
fake_data_list = []

# Define the list of possible training names
training_names = [
    "Introduction to Python Programming",
    "Web Development Fundamentals",
    "Data Science Essentials",
    "Machine Learning Basics",
    "Introduction to JavaScript",
    "Frontend Development with React",
    "Backend Development with Node.js",
    "Database Management with MongoDB",
    "Cloud Computing Fundamentals",
    "Cybersecurity Essentials",
]

# Generate fake data
for i in range(1, 100):
    certificates = random.sample(training_names, 4)
    start_date = fake.date_this_decade()
    end_date = start_date + timedelta(days=random.randint(5, 10))  # Random end date 5 to 10 days ahead
    training_data = {
        "trainingId": "Training_" + str(i),
        "trainingName": fake.random_element(elements=certificates),
        "trainingDescription": fake.sentence(),
        "trainerId": "Trainer_" + str(i),
        "trainerName": fake.name(),
        "startDate": start_date,
        "endDate": end_date,
        "optimizedDuration": fake.random_int(min=1, max=40),
        "createdAt": fake.date_time_this_year(),
    }
    fake_data_list.append(training_data)

# Write data to CSV file
csv_file_path = "training_data.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for training_data in fake_data_list:
        writer.writerow(training_data)

print(f"Training data has been saved to {csv_file_path}")
# Out:
# Training data has been saved to training_data.csv

# %%
import csv
import random
from faker import Faker

fake = Faker()

fake_data_list = []

# Define the list of possible quiz names
quiz_names = [
    "Introduction to Python Quiz",
    "Web Development Fundamentals Quiz",
    "Data Science Essentials Quiz",
    "Machine Learning Basics Quiz",
    "Introduction to JavaScript Quiz",
    "Frontend Development with React Quiz",
    "Backend Development with Node.js Quiz",
    "Database Management with MongoDB Quiz",
    "Cloud Computing Fundamentals Quiz",
    "Cybersecurity Essentials Quiz"
]

# Define the list of possible file names for questions
question_files = [
    "questions1.csv",
    "questions2.csv",
    "questions3.csv",
    "questions4.csv",
    "questions5.csv"
]

# Generate fake data
for i in range(1, 100):
    quiz_data = {
        "quizName": fake.random_element(elements=quiz_names),
        "trainingId": "Training_" + str(i),
        "trainingName": fake.sentence(),
        "maxScores": fake.random_int(min=100, max=100),
        "minScores": fake.random_int(min=50, max=50),
        "difficultyLevel": fake.random_element(elements=("easy", "moderate", "hard")),
        "questionFile": fake.random_element(elements=question_files),
    }
    fake_data_list.append(quiz_data)

# Write data to CSV file
csv_file_path = "quiz_data.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = fake_data_list[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for quiz_data in fake_data_list:
        writer.writerow(quiz_data)

print(f"Quiz data has been saved to {csv_file_path}")
# Out:
# Quiz data has been saved to quiz_data.csv

# %%
import csv
import random
from faker import Faker

fake = Faker()

fake_data_list = []

# Define the list of possible training statuses
training_statuses = ['pending', 'in_progress', 'completed']

# Generate fake data
for i in range(1, 1000):
    training_status = fake.random_element(elements=training_statuses)
    if training_status == 'pending':
        assessment_percentage_done = 0
        assessment_completion_time_in_hours= None
    elif training_status == 'completed':
        assessment_percentage_done = 100
        assessment_completion_time_in_hours = fake.random_int(min=0, max=24*30)
    else:
        assessment_percentage_done = fake.random_int(min=0, max=100)
        assessment_completion_time_in_hours = fake.random_int(min=0, max=24*30)
        
    if training_status in ['pending', 'in_progress']:
        score_achieved_in_quiz = None
        quiz_passed_or_failed = None
    else:
        score_achieved_in_quiz = fake.random_int(min=0, max=100)
        if score_achieved_in_quiz < 50:
            quiz_passed_or_failed = 'failed'
        else:
            quiz_passed_or_failed = 'passed'
        
    training_id = fake.random_int(min=1, max=100)
    trainer_id = fake.random_int(min=1, max=100)
    
    tracker_data = {
        "userId": "User_" + str(i),
        "trainingId": "Training_" + str(training_id),
        "trainerId": "Trainer_" + str(trainer_id),
        "trainingStatus": training_status,
        "assessment_percentage_done": assessment_percentage_done,
        "assessment_completion_time_in_hours": assessment_completion_time_in_hours,
        "scoreAchievedInQuiz": score_achieved_in_quiz,
        "quizPassedOrFailed": quiz_passed_or_failed,
        "ratingGivenByTrainer": fake.random_int(min=1, max=5),
    }
    fake_data_list.append(tracker_data)

# Write data to CSV file
csv_file_path = "tracker_data.csv"
with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
    fieldnames = ["userId", "trainingId", "trainerId", "trainingStatus", "assessment_percentage_done", 
                  "assessment_completion_time_in_hours", "scoreAchievedInQuiz", "quizPassedOrFailed", 
                  "ratingGivenByTrainer"]
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for tracker_data in fake_data_list:
        writer.writerow(tracker_data)

print(f"Tracker data has been saved to {csv_file_path}")
# Out:
# Tracker data has been saved to tracker_data.csv

# %%
import csv
import pandas as pd

# %%
df = pd.DataFrame(user_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.DataFrame(user_data[0])
#
# KeyError: 0

# %%
import pandas as pd

num_records=pd.read_csv('Project.userdetails.csv')

# %%
df=pd.DataFrame(num_records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 2
#       1 df=pd.DataFrame(num_records)
# ----> 2 iloc.df[1]
#
# NameError: name 'iloc' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7748\1395128912.py in ?()
#       1 fake_data_list=df['Empid']
# ----> 2 fake_data_list.removenull()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'removenull'

# %%
num_records
import rand

# %%
skills = [
    "Python", "JavaScript", "HTML", "CSS", "React", "Angular", "Vue.js", "Node.js", "Django", "Flask",
    "Java", "Kotlin", "Swift", "Objective-C", "C#", ".NET", "PHP", "Ruby", "SQL", "NoSQL",
    "MongoDB", "MySQL", "PostgreSQL", "Git", "Docker", "Kubernetes", "AWS", "Azure", "Google Cloud Platform",
    "RESTful API", "GraphQL", "CI/CD", "Agile Methodologies", "Scrum", "Test-Driven Development",
    "Behavior-Driven Development", "DevOps", "Continuous Integration", "Continuous Deployment", "Microservices",
    "Containerization", "Machine Learning", "Artificial Intelligence", "Data Science", "Data Analysis",
    "Data Visualization", "Statistical Analysis", "Cybersecurity", "Network Security", "Penetration Testing",
    "Cryptography", "Information Security", "UI/UX Design", "Wireframing", "Prototyping", "User Research",
    "Interaction Design", "Responsive Design", "Accessibility", "Product Management", "Agile Product Management",
    "Requirements Analysis", "User Stories", "Business Analysis", "Technical Writing", "Documentation",
    "Support", "Troubleshooting", "Problem Solving", "Communication", "Collaboration", "Leadership"
]

# %%
 data = []
for i in fake_data_list:
    empid = i
    certificates = random.sample(skills, 4)  # Pick 4 unique certificates randomly
    for certificate in certificates:
        record = {
            "Empid": empid,
            "certificateName": certificate,
            "issuingOrganization": fake.company(),
            "issueDate": fake.date(),
            "ExpireDate": fake.future_date(),
            "credentialID": fake.uuid4(),
            "Status": random.choice(["Approved", "Rejected"])
        }
        data.append(record)

# %%
df=pd.DataFrame(data)

# %%
df.to_csv('certificateData.csv')

# %%
projects = [
    "PixelPlex Crypto Trader",
    "BlueFinity Evoke",
    "CyberCode Online Store",
    "TechTrek Data Analyzer",
    "ByteBlitz Document Manager",
    "NexGen Mobile Scheduler",
    "Streamline Solutions CRM",
    "DataLink Inventory Tracker",
    "SilverLinx POS System",
    "EchoTech Task Manager",
    "CodeCraft Web Builder",
    "FusionSoft Email Client",
    "LogicLane Project Tracker",
    "VortexVision Virtual Assistant",
    "InnovateSoft Budget Planner",
    "DataForge Dashboard Creator",
    "SwiftShift Time Tracker",
    "MetaMind Chatbot Builder",
    "TechNova Backup Solution",
    "QuickTech Remote Support",
    "CatalystCommerce",
    "DataSync",
    "AgileFlow",
    "InnovatePro",
    "ByteBoost",
    "PixelWare",
    "DataPulse",
    "CyberLink",
    "SwiftWave",
    "TechSprint",
    "InnovaTech",
    "DataBridge",
    "PixelWorks",
    "CyberTech",
    "CodeCraft",
    "AgileWare",
    "ByteForge",
    "PixelPulse",
    "DataCraft",
    "TechSpark",
    "SwiftCode",
    "AgileTech",
    "DataWave"
]

# %%
project_types = [
    "Web Application",
    "Mobile App",
    "Desktop Software",
    "CRM System",
    "Inventory Management System",
    "E-commerce Platform",
    "Content Management System",
    "Task Management Tool",
    "Email Client",
    "Document Management System",
    "Chatbot",
    "Virtual Assistant",
    "Budget Planner",
    "Dashboard Creator",
    "Time Tracking Tool",
    "POS System",
    "Backup Solution",
    "Remote Support Tool",
    "Crypto Trader",
    "Data Analyzer",
    "Social Networking Platform",
    "Online Marketplace",
    "Customer Service Software",
    "Payment Gateway",
    "Booking System",
    "Learning Management System",
    "Customer Relationship Management",
    "Project Management Software",
    "Human Resource Management System",
    "Inventory Control System",
    "Event Management Software",
    "Appointment Scheduling Software",
    "Survey Software",
    "Healthcare Management System",
    "Sales Forecasting Software",
    "Accounting Software",
    "Asset Management System",
    "Content Delivery Network",
    "Data Visualization Tool",
    "Educational Software",
    "Fleet Management System",
    "Help Desk Software",
    "Retail Management System",
    "Supply Chain Management Software",
    "Ticketing System",
    "Warehouse Management System",
    "Workflow Management Software"
]

# %%
project_roles = [
    "Developer",
    "Designer",
    "Project Manager",
    "Quality Assurance Engineer",
    "Business Analyst",
    "DevOps Engineer",
    "Database Administrator",
    "Technical Architect",
    "UI/UX Designer",
    "Product Manager",
    "Network Engineer",
    "Cybersecurity Specialist",
    "Data Scientist",
    "Machine Learning Engineer",
    "Artificial Intelligence Engineer",
    "Cloud Solutions Architect",
    "Technical Writer",
    "IT Support Specialist",
    "Release Manager",
    "Configuration Manager",
    "Automation Tester",
    "Performance Engineer"
]

# %%
project1 = random.sample(projects, 4)
project1
# Out:
# ['DataCraft', 'CodeCraft', 'NexGen Mobile Scheduler', 'InnovaTech']

# %%
data = []
for i in fake_data_list:
    empid = i
    project = random.sample(projects, 4)  # Pick 4 unique certificates randomly
    for pro in project:
        record = {
            "Empid": empid,
            "projectName": pro,
            "projectType": random.choice(project_types),
            "description": fake.text(),
            "startDate": fake.date(),
            "endDate": fake.future_date(),
            "role": random.choice(project_roles),
            "Status": random.choice(["Approved", "Rejected"])
        }
        data.append(record)

# %%
  data
# Out:
# [{'Empid': 'Emp_0',
#   'projectName': 'PixelPulse',
#   'projectType': 'Document Management System',
#   'description': 'Window agent season consumer ahead. Benefit bring imagine.',
#   'startDate': '1992-01-12',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'IT Support Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_0',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Human Resource Management System',
#   'description': 'Edge how customer. This trade treatment science read than check gas. Ahead act might everything. Appear rise generation kitchen letter degree station.\nMost sit west population send book whole.',
#   'startDate': '1976-05-11',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_0',
#   'projectName': 'AgileTech',
#   'projectType': 'Web Application',
#   'description': 'Push government think. Nothing parent age.\nYet study rich thus door tell tree. Happen wife age hear movie election.\nMust somebody expert compare necessary vote campaign. Sometimes read environmental.',
#   'startDate': '1972-04-07',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_0',
#   'projectName': 'DataPulse',
#   'projectType': 'Accounting Software',
#   'description': 'Month close truth hard. Morning form control. Amount pay smile after seek nothing behavior result.\nThree act field true cover.',
#   'startDate': '2000-01-08',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'InnovaTech',
#   'projectType': 'Retail Management System',
#   'description': 'If doctor open several people per. Bar later air positive their. One thousand someone unit air.',
#   'startDate': '1972-01-15',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'DataBridge',
#   'projectType': 'Document Management System',
#   'description': 'Ever exactly rock street. Least life too notice network. Official its yet notice task as.',
#   'startDate': '2012-01-01',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'InnovatePro',
#   'projectType': 'Budget Planner',
#   'description': 'Capital human edge ever likely stock stock any. Ahead quality executive choice what. Discuss research product describe father factor.',
#   'startDate': '2016-11-08',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Release Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_1',
#   'projectName': 'AgileWare',
#   'projectType': 'Content Management System',
#   'description': 'Court present machine candidate get pick. Floor know might live.',
#   'startDate': '2016-08-27',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_2',
#   'projectName': 'ByteBoost',
#   'projectType': 'Event Management Software',
#   'description': 'Throw international hand. Education coach talk. Side second act including effect lose probably wind.\nReflect property beat similar. Hand number green American religious various necessary draw.',
#   'startDate': '1978-11-27',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_2',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Booking System',
#   'description': 'Spend buy accept yourself many president another. This executive there hear realize think. Most pattern stay term pressure sea.\nBy seek popular see wrong.',
#   'startDate': '1985-04-30',
#   'endDate': datetime.date(2024, 4, 10),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_2',
#   'projectName': 'InnovatePro',
#   'projectType': 'Virtual Assistant',
#   'description': 'Unit plan on course ahead brother. Far too west director very guy. Again least behavior organization form family boy. Scene color physical skin authority everybody attack.',
#   'startDate': '1981-08-11',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Developer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_2',
#   'projectName': 'CodeCraft',
#   'projectType': 'Inventory Control System',
#   'description': 'Cold price research end difficult.\nBeyond majority notice bill role. Discover while at three various think.',
#   'startDate': '1986-09-28',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_3',
#   'projectName': 'SwiftWave',
#   'projectType': 'Crypto Trader',
#   'description': 'Growth speech find specific happy conference. Top issue figure world situation drug worry. Leg force someone quite matter.',
#   'startDate': '1990-09-08',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_3',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Customer Service Software',
#   'description': 'Maybe international still notice develop operation.\nTelevision speech future dinner wind. Person decision again politics range Mr group. House for huge mother opportunity investment.',
#   'startDate': '1973-07-12',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'UI/UX Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_3',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Human Resource Management System',
#   'description': 'New class hit without when amount suggest. Happen official scene may power early woman. Space charge charge whose.',
#   'startDate': '1977-08-18',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_3',
#   'projectName': 'TechSpark',
#   'projectType': 'Chatbot',
#   'description': 'Something next PM send finally two.\nGeneration color human yeah truth conference the. Yet more lot expect determine traditional know. Boy play give put form letter response.',
#   'startDate': '2023-03-11',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_4',
#   'projectName': 'BlueFinity Evoke',
#   'projectType': 'Customer Service Software',
#   'description': 'Dark rule together garden travel them. Remember president citizen seem officer doctor amount for.',
#   'startDate': '2000-03-30',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_4',
#   'projectName': 'TechSprint',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Congress happen nice level short Democrat. Person suffer visit power just near group.',
#   'startDate': '2019-03-12',
#   'endDate': datetime.date(2024, 5, 1),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_4',
#   'projectName': 'QuickTech Remote Support',
#   'projectType': 'POS System',
#   'description': 'Or question middle ever behavior matter experience skill. Beat evidence house. Down shoulder dream fight.\nMan entire account yourself focus decision employee. She property picture cell woman stand.',
#   'startDate': '1984-01-10',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Artificial Intelligence Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_4',
#   'projectName': 'DataForge Dashboard Creator',
#   'projectType': 'Booking System',
#   'description': 'Policy collection above movement. Young also rate type big candidate political culture.\nA among value feel newspaper. System show although stock like. Stop amount kid board.',
#   'startDate': '1989-03-22',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_5',
#   'projectName': 'AgileFlow',
#   'projectType': 'Payment Gateway',
#   'description': 'Personal land page garden. Some player so push year. Step test industry.\nFloor million happen relate doctor like. Window plant send new ever situation. Understand stand place senior sport.',
#   'startDate': '1988-08-18',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Release Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_5',
#   'projectName': 'PixelPlex Crypto Trader',
#   'projectType': 'Payment Gateway',
#   'description': 'Finally we agent put church dream themselves whom. Side same teach pressure.\nEnjoy administration feel. These fill finish bed big good. Wish return democratic way also.',
#   'startDate': '1975-09-19',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_5',
#   'projectName': 'AgileWare',
#   'projectType': 'Learning Management System',
#   'description': 'Stop often race. Take attack result have. Become of officer whether simply. Idea sort enough.\nIncluding stand should cup budget. Perhaps total suffer smile dog. Each value effect method purpose join.',
#   'startDate': '2016-09-07',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_5',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Project Management Software',
#   'description': 'Send science safe lawyer store. Alone maintain season doctor.\nArea thousand feeling care their economy officer. Indicate authority happy morning article two senior.',
#   'startDate': '1977-01-12',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_6',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'Task Management Tool',
#   'description': 'Work service part firm. Economic toward join evening indeed environment western. Hair any off federal focus them everything.',
#   'startDate': '1985-06-05',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_6',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Dashboard Creator',
#   'description': 'Congress entire benefit. Television defense why surface catch. Firm quality center manager one.\nTotal summer wide. Space realize always meet approach country mouth.',
#   'startDate': '1995-10-03',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Data Scientist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_6',
#   'projectName': 'TechSpark',
#   'projectType': 'Event Management Software',
#   'description': 'Health condition front worry million order. Prove wall impact. Glass under address series sign American majority.\nInstead pressure mother great action real star. Stand everybody staff authority thus.',
#   'startDate': '1973-01-26',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'IT Support Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_6',
#   'projectName': 'PixelWorks',
#   'projectType': 'Budget Planner',
#   'description': 'Evening stand agree adult. Nor might business.\nProperty ask reason cover thank natural change. Necessary a son early join country store.',
#   'startDate': '1984-04-16',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_7',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Event Management Software',
#   'description': 'Although brother cost mind law. List matter whatever rock quality industry season. Drop section maintain begin.',
#   'startDate': '1992-01-25',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_7',
#   'projectName': 'MetaMind Chatbot Builder',
#   'projectType': 'Healthcare Management System',
#   'description': 'Wonder some apply ask loss increase imagine experience. Customer discover eye generation growth his.\nPicture ball light. Every fear reach investment staff really.',
#   'startDate': '1999-08-31',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_7',
#   'projectName': 'QuickTech Remote Support',
#   'projectType': 'E-commerce Platform',
#   'description': 'Attack be major sure financial long bar. Rock page once on rather you produce. See none indeed character room glass.\nFood manager feel store find science. War front person want man.',
#   'startDate': '1982-02-23',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'UI/UX Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_7',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Asset Management System',
#   'description': 'Imagine book lose. Fish network attention fact store along body. Often wide strategy not challenge.\nBlood up American seek. Assume back instead adult.',
#   'startDate': '2015-07-26',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'UI/UX Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_8',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Booking System',
#   'description': 'Particular road before two image she. Trial various decision drive. Range other should sea society remember. Institution professional parent easy exactly hundred own coach.',
#   'startDate': '1983-08-26',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_8',
#   'projectName': 'DataCraft',
#   'projectType': 'Data Analyzer',
#   'description': 'Air girl new talk treatment skill activity. Protect article attention would.',
#   'startDate': '2022-01-10',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_8',
#   'projectName': 'AgileTech',
#   'projectType': 'Customer Service Software',
#   'description': 'Sign town mean traditional significant.\nEven nearly cover result. Next nature before TV.\nBorn than pick realize yeah. Actually direction responsibility program left which.',
#   'startDate': '1972-10-12',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_8',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Human Resource Management System',
#   'description': 'Accept rate finish note travel wear throw. This hand sport interview everybody. Water enjoy music make.\nMean read require age.',
#   'startDate': '1977-12-26',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Project Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'CyberCode Online Store',
#   'projectType': 'Human Resource Management System',
#   'description': 'Blood last half firm. Expert miss wear card use find investment. American radio line green environment here bill.',
#   'startDate': '2018-03-18',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'DataWave',
#   'projectType': 'Accounting Software',
#   'description': 'Site play local somebody drive forget Mrs. Main phone hot beat forward difficult.\nOnce teacher film pay. Across child economy each.',
#   'startDate': '1990-07-08',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Release Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Fleet Management System',
#   'description': 'Together car pressure some where must action. Listen test friend last exactly. Face article short cover as write region.',
#   'startDate': '1992-07-10',
#   'endDate': datetime.date(2024, 4, 10),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_9',
#   'projectName': 'InnovaTech',
#   'projectType': 'Document Management System',
#   'description': 'Data suffer message laugh media well behind.\nAgo and serious marriage. Near almost bank arm station car. Apply peace option during without recognize enter.',
#   'startDate': '1998-07-25',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_10',
#   'projectName': 'PixelWorks',
#   'projectType': 'Sales Forecasting Software',
#   'description': 'Full entire view detail option member. Process power majority check amount officer pattern crime. Fill here especially enjoy party.',
#   'startDate': '1998-07-21',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'UI/UX Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_10',
#   'projectName': 'TechTrek Data Analyzer',
#   'projectType': 'Survey Software',
#   'description': 'Stuff small light teacher everybody up nearly.\nReach them admit number avoid enough. Performance of PM perform cup fight. Most represent approach.',
#   'startDate': '2004-08-23',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'Technical Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_10',
#   'projectName': 'AgileFlow',
#   'projectType': 'Web Application',
#   'description': 'People from determine time democratic dog. Alone wait although name leader.\nHis Mr cost wall. Rock physical impact film daughter best amount.',
#   'startDate': '2010-01-28',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_10',
#   'projectName': 'VortexVision Virtual Assistant',
#   'projectType': 'Content Delivery Network',
#   'description': 'Decade stop including wish put down poor. Minute institution reach nation build last. Fire anything financial sure method far size.',
#   'startDate': '2004-11-06',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_11',
#   'projectName': 'DataWave',
#   'projectType': 'Fleet Management System',
#   'description': 'Key beyond between.\nBase side father. General bank five five cover.\nHuge rate probably reach possible. Son drop account begin recent lay recognize. Election medical card play maintain rich more part.',
#   'startDate': '1976-10-02',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_11',
#   'projectName': 'PixelWare',
#   'projectType': 'Mobile App',
#   'description': 'Low million view whom increase much guess door. Bad particular sure television development firm.',
#   'startDate': '1991-11-08',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_11',
#   'projectName': 'AgileFlow',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Seek reach official hold. Leg animal different cold business look tonight with.\nAccept truth over number network each great. Letter nice help behavior man realize.',
#   'startDate': '2003-01-28',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_11',
#   'projectName': 'SilverLinx POS System',
#   'projectType': 'Inventory Control System',
#   'description': 'Performance above open.\nThese card positive cost medical agency like. Father official here.',
#   'startDate': '1986-05-20',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_12',
#   'projectName': 'ByteBoost',
#   'projectType': 'Healthcare Management System',
#   'description': 'Ahead health us prevent science strategy middle. Language surface budget political woman help fall eat.\nBut with clearly significant group summer same.',
#   'startDate': '1992-02-14',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_12',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Chatbot',
#   'description': 'Apply a every hit board pass. Per because budget. Mrs exactly character list again husband. Write outside present offer general natural.',
#   'startDate': '1977-10-04',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Technical Writer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_12',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Warehouse Management System',
#   'description': 'Participant song left order some worker.\nParent moment skill agent modern explain he. These its win.',
#   'startDate': '1971-11-06',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_12',
#   'projectName': 'PixelPulse',
#   'projectType': 'Educational Software',
#   'description': 'Respond away evening certain agree movie.\nLeast agree dog way memory right. Mission better drug design book. Some what game job budget.',
#   'startDate': '2022-06-16',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'FusionSoft Email Client',
#   'projectType': 'E-commerce Platform',
#   'description': 'Southern half far. Open actually future interview officer late instead commercial. As meeting federal maybe drug day miss.',
#   'startDate': '1997-11-06',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'SilverLinx POS System',
#   'projectType': 'Asset Management System',
#   'description': 'His choice character image high turn sort speak.\nLine customer form debate act. Public worker lose detail between instead. Any service behavior environmental south.',
#   'startDate': '1971-04-03',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Accounting Software',
#   'description': 'Buy report health positive term. Plant dinner lawyer. Product full keep guy buy.\nEven scene best coach. Game green involve blue get control. Culture until effect hope try TV.',
#   'startDate': '1970-11-06',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_13',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Event Management Software',
#   'description': 'Themselves lawyer trouble pull authority television now. Writer purpose impact begin within box itself.\nAmerican do this conference your possible. Participant first start contain clearly.',
#   'startDate': '2017-03-08',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_14',
#   'projectName': 'InnovaTech',
#   'projectType': 'Educational Software',
#   'description': 'And common more including mind field during. Professor yourself read message protect finally lawyer.\nWatch clear audience include. Opportunity sense specific provide.',
#   'startDate': '1977-03-09',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_14',
#   'projectName': 'TechTrek Data Analyzer',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Seat protect surface yard particularly window attorney. Movie until wife yard.\nPresent manager thus couple any.',
#   'startDate': '1977-12-11',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_14',
#   'projectName': 'CyberCode Online Store',
#   'projectType': 'Inventory Management System',
#   'description': 'Still chance forward blood. Word dog pattern interesting.\nShe floor power sell. Drug argue wrong floor race. Already born fact real son course evidence.\nFive head each mention.',
#   'startDate': '2017-02-20',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_14',
#   'projectName': 'CyberLink',
#   'projectType': 'Asset Management System',
#   'description': 'Class of chance entire worker strategy.\nHealth memory their class today plant. Sell will contain boy century national meet.',
#   'startDate': '1996-08-06',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Release Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_15',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'POS System',
#   'description': 'Guy than conference would sound. Clearly when yet create within let cultural. Contain heart onto save large reason.\nSuccessful personal old issue. Mind interesting really part.',
#   'startDate': '1993-10-22',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Configuration Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_15',
#   'projectName': 'AgileFlow',
#   'projectType': 'Crypto Trader',
#   'description': 'Company whose chance commercial person name. Power home couple ability know.',
#   'startDate': '2014-09-12',
#   'endDate': datetime.date(2024, 4, 9),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_15',
#   'projectName': 'AgileTech',
#   'projectType': 'Online Marketplace',
#   'description': 'Husband summer activity vote decade financial will. Movie how line local north similar. Start there Congress group follow. Stand ok thus peace another manage billion open.',
#   'startDate': '1975-04-23',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Data Scientist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_15',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Ticketing System',
#   'description': 'Improve adult throw lay might. Only star she improve owner three. Feeling front scene wrong actually total.',
#   'startDate': '1997-11-13',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_16',
#   'projectName': 'AgileFlow',
#   'projectType': 'Chatbot',
#   'description': 'Indicate red type ready task. Field author report opportunity international rich during. Rule interview tonight guess direction standard.\nOver fill add such. Nation include majority day feel behind.',
#   'startDate': '2001-10-07',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Product Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_16',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'Educational Software',
#   'description': 'Institution language weight show visit. Matter pass yourself smile recognize school.\nMessage security person no his clear campaign election.\nJob close apply.',
#   'startDate': '1988-08-19',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Technical Writer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_16',
#   'projectName': 'LogicLane Project Tracker',
#   'projectType': 'Content Delivery Network',
#   'description': 'Imagine letter team language. Else say improve probably. Drop or beyond dog oil base.',
#   'startDate': '1993-04-19',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_16',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Time Tracking Tool',
#   'description': 'Under office not be. But positive interesting law western idea ahead.\nWhile data decade common machine. Part church material director long dinner. Easy film second choice join everyone.',
#   'startDate': '1990-07-05',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Artificial Intelligence Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_17',
#   'projectName': 'ByteForge',
#   'projectType': 'Data Analyzer',
#   'description': 'According behind anyone standard. Writer our level because fall feeling.\nFew measure media. Power avoid practice good population sea. Tv husband find company.',
#   'startDate': '2021-04-30',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_17',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'Online Marketplace',
#   'description': 'Take office service hour head especially. Agreement president work building rich say. Magazine Democrat image nothing. Price nature new create.',
#   'startDate': '2011-09-23',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_17',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Warehouse Management System',
#   'description': 'Million skill beyond behind condition perhaps. Operation enter artist. Heavy grow describe whom suggest power itself.',
#   'startDate': '2005-01-28',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_17',
#   'projectName': 'PixelWorks',
#   'projectType': 'Virtual Assistant',
#   'description': 'Explain reduce outside entire. Much audience system prove court dinner. Maintain soon arm behind.\nAuthor blood leader new skin ahead. Indeed might industry which paper alone.',
#   'startDate': '1970-01-07',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Artificial Intelligence Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_18',
#   'projectName': 'PixelPlex Crypto Trader',
#   'projectType': 'Educational Software',
#   'description': 'Enjoy bad spend. Positive street with officer administration part.\nImportant father follow machine then occur all. Site so commercial cost because. Scene perform tell compare to simple maybe study.',
#   'startDate': '1993-08-12',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Business Analyst',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_18',
#   'projectName': 'PixelWorks',
#   'projectType': 'Customer Service Software',
#   'description': 'Various much production all safe whatever per body. Customer everybody specific skill agency. Sense information produce do field cell.',
#   'startDate': '2007-05-29',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_18',
#   'projectName': 'DataWave',
#   'projectType': 'Content Delivery Network',
#   'description': 'Marriage still level tonight force size.\nFace wife majority machine eat my. Seek wait bad section service poor. Evening idea Mrs current nor election note. Like remain federal fire.',
#   'startDate': '2017-06-04',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_18',
#   'projectName': 'CatalystCommerce',
#   'projectType': 'Content Delivery Network',
#   'description': 'Suggest perhaps medical attorney capital. Central husband physical represent during factor. Father step fact animal civil remember force.\nBox water movement study arrive debate director.',
#   'startDate': '1997-09-18',
#   'endDate': datetime.date(2024, 5, 1),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_19',
#   'projectName': 'AgileFlow',
#   'projectType': 'Chatbot',
#   'description': 'Number similar skin yourself. Suggest big you usually side song kind marriage. Paper again off economic walk season.\nTrue look run toward allow all. Anyone operation decide less.',
#   'startDate': '2021-01-24',
#   'endDate': datetime.date(2024, 5, 1),
#   'role': 'DevOps Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_19',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Ticketing System',
#   'description': 'Stand miss special population recent treat account. Serve college lot situation blood chance already. Fight level believe though pressure.',
#   'startDate': '2016-01-28',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_19',
#   'projectName': 'VortexVision Virtual Assistant',
#   'projectType': 'Workflow Management Software',
#   'description': 'Property hold first important financial worry art year. Degree born whom against recently pull area serve.',
#   'startDate': '2009-11-07',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'DevOps Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_19',
#   'projectName': 'TechSprint',
#   'projectType': 'Task Management Tool',
#   'description': 'Capital now the successful middle follow note well.\nTraining enjoy tough close subject season hot. Person certain fly while enter by our. Speak dog save finish her method.\nOfficer standard dark ever.',
#   'startDate': '2009-02-23',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_20',
#   'projectName': 'DataPulse',
#   'projectType': 'Dashboard Creator',
#   'description': 'Stock matter total medical effect stop natural. Mission memory miss store everybody similar. Tv represent yard position.\nEvery money bad social cell. Need catch air send this than.',
#   'startDate': '1985-03-01',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_20',
#   'projectName': 'PixelPulse',
#   'projectType': 'Healthcare Management System',
#   'description': 'Billion traditional letter room company. Eat quite eye real. High let rule house. Two cost since woman far break.',
#   'startDate': '2020-04-02',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_20',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Remote Support Tool',
#   'description': 'Grow according happy consumer mind Mr director. Offer employee decision local race.',
#   'startDate': '2012-03-03',
#   'endDate': datetime.date(2024, 4, 10),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_20',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'E-commerce Platform',
#   'description': 'Respond daughter perhaps marriage range. Wife rock long human.\nThis make yet we. Card media find cost piece trouble. Head individual mind.',
#   'startDate': '1987-11-22',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_21',
#   'projectName': 'SwiftWave',
#   'projectType': 'Warehouse Management System',
#   'description': 'We message animal team town involve seven table. Place rather improve black scientist next enough role. Color where traditional owner fish film close. Receive easy owner performance coach.',
#   'startDate': '2007-08-13',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_21',
#   'projectName': 'CatalystCommerce',
#   'projectType': 'CRM System',
#   'description': 'Stand outside staff night actually almost lose. Involve city against process little meeting could. Church shake world time.\nMeeting medical culture. Campaign tax detail approach.',
#   'startDate': '2017-05-26',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_21',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Appointment Scheduling Software',
#   'description': 'Up job should green sign interview everyone. Star across show summer.\nHappy their get.\nThink get ground father suddenly. Second fire message.\nBag environmental moment look. High run right political.',
#   'startDate': '1976-01-14',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_21',
#   'projectName': 'TechSpark',
#   'projectType': 'Learning Management System',
#   'description': 'Practice hot easy collection buy. Network strong despite front. Professor travel decide include.\nDetermine wind strategy former how. Left bit scientist.',
#   'startDate': '2003-05-09',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_22',
#   'projectName': 'PixelWare',
#   'projectType': 'Asset Management System',
#   'description': 'Through per seek answer have street. Front building argue cut seven data. Leave history behind head.\nReady two yes write who.',
#   'startDate': '1991-01-04',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_22',
#   'projectName': 'PixelPulse',
#   'projectType': 'Workflow Management Software',
#   'description': 'Moment authority land place. Treat real movie send his in war budget.\nFederal another letter thus plant green available. Explain option among your. Sound close water station blood.',
#   'startDate': '2016-05-17',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Project Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_22',
#   'projectName': 'CyberCode Online Store',
#   'projectType': 'Customer Relationship Management',
#   'description': 'While whether gas minute should own. Sell unit road put agree grow. Give trouble rest.\nInside card box prevent gas standard apply would. Production range less bad go knowledge.',
#   'startDate': '1991-07-13',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_22',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Human Resource Management System',
#   'description': 'Its research language skin. Traditional left recently. Again phone want act.\nRoom return resource effect focus piece. Example admit fear career responsibility interesting.',
#   'startDate': '2023-10-30',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Technical Writer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_23',
#   'projectName': 'PixelWorks',
#   'projectType': 'CRM System',
#   'description': 'Decide little through. Trade candidate military movement. Summer particular party home.\nShould modern six fine. Second bit ball interest both cause.',
#   'startDate': '1982-07-05',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_23',
#   'projectName': 'CodeCraft',
#   'projectType': 'Retail Management System',
#   'description': 'Edge apply few road. Some realize service piece program.\nAdministration boy health green social conference. Forward public item suggest course stop send student.',
#   'startDate': '1977-07-30',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Performance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_23',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'CRM System',
#   'description': 'Clearly what open example which apply. Much only skin institution group country on.\nFact yeah both room yes animal. Mrs require represent early owner exactly include lawyer.',
#   'startDate': '2002-07-08',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_23',
#   'projectName': 'CatalystCommerce',
#   'projectType': 'Fleet Management System',
#   'description': 'Especially north season mission. Part set heart free rate. Past body store compare.\nAddress upon reflect government eat financial energy. Lot according improve safe receive quickly.',
#   'startDate': '2007-02-03',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_24',
#   'projectName': 'AgileFlow',
#   'projectType': 'Healthcare Management System',
#   'description': 'Matter stop woman thank yeah. Perhaps idea able lawyer quickly claim talk economic.\nSocial sometimes central attack. Protect interesting be traditional build. Certain stage population century give.',
#   'startDate': '1995-06-11',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_24',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Payment Gateway',
#   'description': 'Instead course example finish. No much notice president. Attack trial home woman news third.\nAccording training firm forward movie would. Capital maybe what TV cut. Think road beyond.',
#   'startDate': '2013-09-14',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_24',
#   'projectName': 'DataPulse',
#   'projectType': 'Inventory Management System',
#   'description': 'Baby course surface late bill. Social lead help common house management model. Democrat project despite card author role thousand.',
#   'startDate': '1994-05-05',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Business Analyst',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_24',
#   'projectName': 'SwiftCode',
#   'projectType': 'Supply Chain Management Software',
#   'description': 'About its approach realize respond sell leave. Service lay return learn billion recent relationship.\nExactly the professional after. Must bar major clear. Seat organization media never.',
#   'startDate': '1977-09-05',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Performance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_25',
#   'projectName': 'CyberLink',
#   'projectType': 'CRM System',
#   'description': 'Before new lay teach everything western. Study either hundred property to now. Tell knowledge part fish serve.\nSell produce garden leave. Individual where mission. According debate actually now six.',
#   'startDate': '2010-09-07',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_25',
#   'projectName': 'DataSync',
#   'projectType': 'Help Desk Software',
#   'description': 'According them federal there discuss people. Seem seek good computer.',
#   'startDate': '2002-09-06',
#   'endDate': datetime.date(2024, 4, 12),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_25',
#   'projectName': 'FusionSoft Email Client',
#   'projectType': 'Crypto Trader',
#   'description': 'Citizen alone religious prevent. Early current check whom instead central.',
#   'startDate': '2024-02-11',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_25',
#   'projectName': 'EchoTech Task Manager',
#   'projectType': 'Virtual Assistant',
#   'description': 'Suggest international back green decide by. Mr Congress pull time message charge. Avoid more moment range can.\nSo Democrat structure middle reason top candidate. Air to these receive car.',
#   'startDate': '2004-12-26',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_26',
#   'projectName': 'ByteForge',
#   'projectType': 'Booking System',
#   'description': 'Event expect wish. Lot with stage early bed government human. Run too among employee discuss expect teach.\nWall road order travel bad. Red soon particular network bag by.',
#   'startDate': '2021-09-06',
#   'endDate': datetime.date(2024, 4, 23),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_26',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'Booking System',
#   'description': 'Computer better turn start inside black. Down authority across think. Evidence low worry begin age manage move.\nHold protect again especially century out. Teach push decision reduce start red travel.',
#   'startDate': '2013-11-01',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Automation Tester',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_26',
#   'projectName': 'InnovateSoft Budget Planner',
#   'projectType': 'POS System',
#   'description': 'Image half building consumer car. Blood theory home purpose look professional. Spring tree crime officer they citizen could.',
#   'startDate': '1980-12-17',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_26',
#   'projectName': 'CyberLink',
#   'projectType': 'Accounting Software',
#   'description': 'Expect lay wind late. Inside figure government a blood.\nAt new score writer. Guess store husband along. Whether with doctor image find term one.',
#   'startDate': '1973-07-16',
#   'endDate': datetime.date(2024, 4, 29),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_27',
#   'projectName': 'CodeCraft',
#   'projectType': 'Crypto Trader',
#   'description': 'As Mrs simple man. Tv add include agency strategy they collection ground.\nSay north third life. Everything result crime pass. Have involve son world consumer Republican.',
#   'startDate': '1999-08-16',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_27',
#   'projectName': 'DataSync',
#   'projectType': 'Sales Forecasting Software',
#   'description': 'Ground article no. Avoid want floor true.\nExplain still beyond. Seven its cut agency standard pressure act. Still professional first cup.',
#   'startDate': '2012-01-07',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_27',
#   'projectName': 'BlueFinity Evoke',
#   'projectType': 'Fleet Management System',
#   'description': 'Back action four child. Reach shake mind seven rule show worker.\nCheck pass writer discuss. Bag beat yet hair left key seek. Number much free local.',
#   'startDate': '1997-03-22',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_27',
#   'projectName': 'PixelWare',
#   'projectType': 'Supply Chain Management Software',
#   'description': 'Program employee kitchen discover him. Gun at answer training line drive.\nDefense claim land of enjoy offer. Only source could religious resource service finish.',
#   'startDate': '2009-07-20',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_28',
#   'projectName': 'SwiftCode',
#   'projectType': 'Task Management Tool',
#   'description': 'Into believe north morning remain. That tree no general modern wear traditional.\nCut avoid hope anyone agency follow structure plant. Manage operation past bring executive job record.',
#   'startDate': '2004-09-19',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_28',
#   'projectName': 'DataBridge',
#   'projectType': 'POS System',
#   'description': 'Explain moment week TV stock show. Voice break treatment leg value fill.\nMuch turn represent seem increase purpose easy.\nSave stop her memory. Level probably force continue ok decision play.',
#   'startDate': '1977-02-24',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_28',
#   'projectName': 'TechTrek Data Analyzer',
#   'projectType': 'Social Networking Platform',
#   'description': 'Month eat ahead table own result quickly.\nBoy out four. Rate trial way. Operation see discuss condition field sense.\nManagement least west trial watch friend by. Challenge hope letter his.',
#   'startDate': '2016-08-30',
#   'endDate': datetime.date(2024, 4, 21),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_28',
#   'projectName': 'DataCraft',
#   'projectType': 'Workflow Management Software',
#   'description': 'Short become part figure party mother question truth. Society certain as. Either go eight Republican west computer.',
#   'startDate': '1985-02-28',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Configuration Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_29',
#   'projectName': 'InnovaTech',
#   'projectType': 'Booking System',
#   'description': 'Each develop audience compare actually represent project. Read seem answer hair area return. Collection collection them current cause office interview. Out culture responsibility drop will on.',
#   'startDate': '1974-12-26',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_29',
#   'projectName': 'InnovatePro',
#   'projectType': 'Content Management System',
#   'description': 'Magazine service want common hair onto church analysis. Floor material run white reason.\nBoth section song yourself learn. According friend hard mean such student.',
#   'startDate': '2023-06-01',
#   'endDate': datetime.date(2024, 4, 25),
#   'role': 'Release Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_29',
#   'projectName': 'ByteForge',
#   'projectType': 'Customer Relationship Management',
#   'description': 'Part concern give none nation test same. Art run raise remain nice radio.\nKid trip himself. Expect expect leader some. Threat meet agent response. Author federal carry never.',
#   'startDate': '1990-02-25',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Performance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_29',
#   'projectName': 'AgileWare',
#   'projectType': 'Customer Service Software',
#   'description': 'Off other owner. Well difference chair food government.\nCall reflect list heart ever cup truth traditional. Project spend total shoulder film everybody near boy.',
#   'startDate': '1973-02-05',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_30',
#   'projectName': 'PixelWorks',
#   'projectType': 'Backup Solution',
# ...
#   'startDate': '2022-08-29',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_240',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Accounting Software',
#   'description': 'Especially situation bring we. Various article space detail best newspaper.\nHappen serve attention if drop five. Lead participant employee loss.',
#   'startDate': '2013-12-17',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Developer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_240',
#   'projectName': 'DataCraft',
#   'projectType': 'Warehouse Management System',
#   'description': 'Serious kind science environment table behind. This various tax thought arm pay.\nMember nature relate live improve. Class business important certain truth. Popular tonight view note.',
#   'startDate': '1996-03-29',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Product Manager',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_240',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Document Management System',
#   'description': 'Which measure member technology pressure.\nEspecially agency offer dog. Also year cost land difference performance today.',
#   'startDate': '2018-05-26',
#   'endDate': datetime.date(2024, 4, 19),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_241',
#   'projectName': 'DataBridge',
#   'projectType': 'Retail Management System',
#   'description': 'Name show strategy participant same main candidate. Art reality understand money give pretty save.\nNext you nation. Challenge house start TV.',
#   'startDate': '2021-10-21',
#   'endDate': datetime.date(2024, 4, 18),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_241',
#   'projectName': 'DataPulse',
#   'projectType': 'Accounting Software',
#   'description': 'Dinner wait memory. War Mrs somebody could environmental daughter. Series camera management want moment such.',
#   'startDate': '1999-03-15',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_241',
#   'projectName': 'DataCraft',
#   'projectType': 'Data Visualization Tool',
#   'description': 'Apply simply but use marriage road nature. Policy machine avoid recently rich away. Player perhaps out.\nParent wonder tax herself edge civil. Practice heart or. Art less give news.',
#   'startDate': '2001-08-12',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_241',
#   'projectName': 'ByteForge',
#   'projectType': 'Human Resource Management System',
#   'description': 'Behind blue method people. Painting as remain.\nPay television whole represent enter budget part. At when race relate none magazine design that.\nBag change huge. All career two too.',
#   'startDate': '2014-01-05',
#   'endDate': datetime.date(2024, 4, 4),
#   'role': 'Data Scientist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_242',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Ticketing System',
#   'description': 'Ability into join wife change human. Role strong week four. Bad great civil seem strategy between improve.\nMay box size white. Or four book.',
#   'startDate': '2017-06-08',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_242',
#   'projectName': 'AgileFlow',
#   'projectType': 'E-commerce Platform',
#   'description': 'Threat gas behind true away toward walk. Hard night personal where figure station after dog. Boy better nor represent.',
#   'startDate': '2019-12-24',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Cybersecurity Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_242',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Warehouse Management System',
#   'description': 'Write claim physical treatment think. Herself example entire compare east eye friend. By then security month model center sound growth.',
#   'startDate': '2009-12-26',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Configuration Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_242',
#   'projectName': 'DataWave',
#   'projectType': 'Dashboard Creator',
#   'description': 'Adult mother security should speech detail eat. Member order couple opportunity see knowledge.',
#   'startDate': '2006-10-31',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_243',
#   'projectName': 'TechSprint',
#   'projectType': 'Content Delivery Network',
#   'description': 'Tonight police study. Detail southern together suggest.\nRecent commercial go finish between direction expert. Very boy wide break. Fly exist set style continue study.',
#   'startDate': '1988-07-05',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Technical Writer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_243',
#   'projectName': 'PixelWare',
#   'projectType': 'POS System',
#   'description': 'Build ability garden fall open. Project page popular Democrat clearly professor.\nStar add over coach section attack itself.\nDog process production eight discover. Environmental likely along like.',
#   'startDate': '2019-06-06',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Designer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_243',
#   'projectName': 'MetaMind Chatbot Builder',
#   'projectType': 'Time Tracking Tool',
#   'description': 'Watch how again along record increase. Later soon computer race ask about ago.',
#   'startDate': '2015-08-17',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Configuration Manager',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_243',
#   'projectName': 'DataCraft',
#   'projectType': 'Project Management Software',
#   'description': 'Off watch report church word source. Wall movement question. Candidate agency security sister ground ground. Else everyone his grow determine quite.',
#   'startDate': '1997-11-03',
#   'endDate': datetime.date(2024, 4, 20),
#   'role': 'Designer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'PixelPlex Crypto Trader',
#   'projectType': 'Remote Support Tool',
#   'description': 'Week test defense agree white group have. Range rise source I reach hot month. Raise cold nothing listen significant.',
#   'startDate': '2018-04-09',
#   'endDate': datetime.date(2024, 4, 30),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Workflow Management Software',
#   'description': 'Within current field husband camera down. Wonder pressure month.\nVarious return raise nation economy their day. At leg much onto speak.',
#   'startDate': '1993-12-06',
#   'endDate': datetime.date(2024, 4, 24),
#   'role': 'Quality Assurance Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'SwiftCode',
#   'projectType': 'Fleet Management System',
#   'description': 'Thank international human boy set six young. Set image table officer myself interview old.\nDrive impact stand various fire east. Cover front reach job training allow month.',
#   'startDate': '1984-07-09',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_244',
#   'projectName': 'VortexVision Virtual Assistant',
#   'projectType': 'Healthcare Management System',
#   'description': 'Focus cup wrong evening finish by many without. Serve administration reality major special contain.',
#   'startDate': '1975-07-22',
#   'endDate': datetime.date(2024, 4, 7),
#   'role': 'Network Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'Streamline Solutions CRM',
#   'projectType': 'Online Marketplace',
#   'description': 'Attention fly I day current color research now. Share across language.\nCarry also your general specific always keep. Seat view although around industry just know statement. Your society wall way.',
#   'startDate': '2010-10-10',
#   'endDate': datetime.date(2024, 4, 26),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'TechNova Backup Solution',
#   'projectType': 'Warehouse Management System',
#   'description': 'Item shoulder clearly ever. Their discussion everyone seek. Law fire choice memory.\nTeam Congress they worry. Cell try raise force. Like service teacher whose. Produce against debate score property.',
#   'startDate': '2010-01-05',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Database Administrator',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'DataCraft',
#   'projectType': 'Retail Management System',
#   'description': 'Small floor be theory quite tonight.',
#   'startDate': '1983-10-04',
#   'endDate': datetime.date(2024, 4, 11),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_245',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Backup Solution',
#   'description': 'Court indeed understand hear discussion protect.\nFactor myself his through assume choose listen. Human able our run age.\nResponse cover some provide. Investment value clearly politics section say.',
#   'startDate': '1974-02-06',
#   'endDate': datetime.date(2024, 4, 14),
#   'role': 'Database Administrator',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_246',
#   'projectName': 'ByteForge',
#   'projectType': 'Online Marketplace',
#   'description': 'Alone bring PM agency me. Or member rest benefit.\nItem meet per score reality country. Staff condition process against. Away example pull dinner down investment cover.',
#   'startDate': '1977-05-22',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Business Analyst',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_246',
#   'projectName': 'SilverLinx POS System',
#   'projectType': 'Dashboard Creator',
#   'description': 'East home accept try per. Lay collection discuss.\nProfessor moment special whole. Entire instead where despite husband share local practice. Car analysis travel join choose report.',
#   'startDate': '1990-07-09',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'Technical Writer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_246',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'POS System',
#   'description': 'School organization manager rate relationship. Pm along attack force.\nSome particularly growth concern. Heavy today including mind politics already parent.\nMedia each about decide.',
#   'startDate': '1985-08-29',
#   'endDate': datetime.date(2024, 4, 28),
#   'role': 'Technical Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_246',
#   'projectName': 'DataPulse',
#   'projectType': 'Help Desk Software',
#   'description': 'Plant number expect she thing country simple. South create season reflect including population individual national.\nDraw system they ground. Top remember power rule. Quite piece a agent.',
#   'startDate': '1979-06-07',
#   'endDate': datetime.date(2024, 4, 8),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_247',
#   'projectName': 'SwiftWave',
#   'projectType': 'Ticketing System',
#   'description': 'Official six ahead late resource few democratic. Current order behind source mention. Term main employee time man lose wide.\nLeast after could another. Contain guy growth current.',
#   'startDate': '1985-07-17',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_247',
#   'projectName': 'NexGen Mobile Scheduler',
#   'projectType': 'Project Management Software',
#   'description': 'Money media their put would follow by. Rather although born call part movement.\nThose current feel force bit. Begin value couple lose southern lot. Watch later most stop.',
#   'startDate': '2021-03-04',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'DevOps Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_247',
#   'projectName': 'InnovatePro',
#   'projectType': 'Healthcare Management System',
#   'description': 'Get movie personal nation.\nHeavy deal great drive. Card after either behind town fear market.\nLater bar arm. Player page learn degree must. Foot campaign experience occur their image your.',
#   'startDate': '1999-06-05',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Performance Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_247',
#   'projectName': 'PixelPulse',
#   'projectType': 'Web Application',
#   'description': 'Food civil grow. Skin perhaps price some. Local heavy fund relate.\nReason people treat through answer performance executive project. Board star show task those house.',
#   'startDate': '2010-04-08',
#   'endDate': datetime.date(2024, 4, 3),
#   'role': 'Developer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_248',
#   'projectName': 'CodeCraft Web Builder',
#   'projectType': 'Survey Software',
#   'description': 'Reason chance take whom. Third available player trip report little. Report for all authority.\nCongress drug ground practice chair. Air want despite. Rather new left.',
#   'startDate': '1998-12-11',
#   'endDate': datetime.date(2024, 4, 6),
#   'role': 'Network Engineer',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_248',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Retail Management System',
#   'description': 'Physical thought election day occur. Factor somebody foot evening policy form.\nLate even writer yet performance note. Raise deep defense common situation. Watch less weight world.',
#   'startDate': '2011-05-06',
#   'endDate': datetime.date(2024, 4, 17),
#   'role': 'Business Analyst',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_248',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Event Management Software',
#   'description': 'Around face fine reduce American you religious. Situation on shake physical own drop.\nBetween ok home water let loss. Quality song if view office Congress according morning.',
#   'startDate': '1997-12-13',
#   'endDate': datetime.date(2024, 4, 27),
#   'role': 'Cloud Solutions Architect',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_248',
#   'projectName': 'AgileWare',
#   'projectType': 'Payment Gateway',
#   'description': 'These its it lay bed baby win. Bit size thought.\nGrowth wish number theory especially hit growth. Little large body suggest use official.',
#   'startDate': '1999-04-27',
#   'endDate': datetime.date(2024, 4, 22),
#   'role': 'IT Support Specialist',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_249',
#   'projectName': 'FusionSoft Email Client',
#   'projectType': 'Educational Software',
#   'description': 'Response various seat order show program last. Away yeah still our personal ask generation. Skin art her space newspaper its.\nModel travel national project. Hospital anything nor old.',
#   'startDate': '1999-09-24',
#   'endDate': datetime.date(2024, 4, 5),
#   'role': 'Machine Learning Engineer',
#   'Status': 'Approved'},
#  {'Empid': 'Emp_249',
#   'projectName': 'SwiftShift Time Tracker',
#   'projectType': 'Backup Solution',
#   'description': 'Kind reality item impact raise possible use. Point member mother trial oil including. Down later the pass trial body.',
#   'startDate': '2001-07-16',
#   'endDate': datetime.date(2024, 4, 13),
#   'role': 'Data Scientist',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_249',
#   'projectName': 'DataLink Inventory Tracker',
#   'projectType': 'Virtual Assistant',
#   'description': 'Industry near action people. Phone else side star air certain. International spring player child same themselves wait. Until significant lose.',
#   'startDate': '1971-08-09',
#   'endDate': datetime.date(2024, 4, 15),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  {'Empid': 'Emp_249',
#   'projectName': 'ByteBlitz Document Manager',
#   'projectType': 'Booking System',
#   'description': 'Lose tonight sign situation. They today environment produce.\nThough family court thousand. Again production result task billion rate themselves. Born Congress show rather dark matter.',
#   'startDate': '2018-01-24',
#   'endDate': datetime.date(2024, 4, 16),
#   'role': 'Automation Tester',
#   'Status': 'Rejected'},
#  ...]

# %%
df=pd.DataFrame(data)

# %%
skills = [
    "Python",
    "JavaScript",
    "HTML",
    "CSS",
    "React",
    "Angular",
    "Vue.js",
    "Node.js",
    "Django",
    "Flask",
    "Java",
    "Kotlin",
    "Swift",
    "Objective-C",
    "C#",
    ".NET",
    "PHP",
    "Ruby",
    "SQL",
    "NoSQL",
    "MongoDB",
    "MySQL",
    "PostgreSQL",
    "Git",
    "Docker",
    "Kubernetes",
    "AWS",
    "Azure",
    "Google Cloud Platform",
    "RESTful API",
    "GraphQL",
    "CI/CD",
    "Agile Methodologies",
    "Scrum",
    "Test-Driven Development",
    "Behavior-Driven Development",
    "DevOps",
    "Continuous Integration",
    "Continuous Deployment",
    "Microservices",
    "Containerization",
    "Machine Learning",
    "Artificial Intelligence",
    "Data Science",
    "Data Analysis",
    "Data Visualization",
    "Statistical Analysis",
    "Cybersecurity",
    "Network Security",
    "Penetration Testing",
    "Cryptography",
    "Information Security",
    "UI/UX Design",
    "Wireframing",
    "Prototyping",
    "User Research",
    "Interaction Design",
    "Responsive Design",
    "Accessibility",
    "Product Management",
    "Agile Product Management",
    "Requirements Analysis",
    "User Stories",
    "Business Analysis",
    "Technical Writing",
    "Documentation",
    "Support",
    "Troubleshooting",
    "Problem Solving",
    "Communication",
    "Collaboration",
    "Leadership"
]

# %%
data = []
for i in fake_data_list:
    empid = i
    Skill = random.sample(skills, 4)  # Pick 4 unique certificates randomly
    for s in Skill:
        record = {
            "Empid": empid,
            "skillName": s,
            "Proficiency": random.choice(["Intermidiate", "Expert","Beginner","Advance"])
        }
        data.append(record)

# %%
df=pd.DataFrame(data)
df
# Out:
#       Empid              skillName   Proficiency
# 0     Emp_0        Troubleshooting       Advance
# 1     Emp_0                GraphQL        Expert
# 2     Emp_0                 Vue.js       Advance
# 3     Emp_0        Problem Solving      Beginner
# 4     Emp_1                Support        Expert
# ...     ...                    ...           ...
# 4011    NaN  Continuous Deployment      Beginner
# 4012    NaN                   .NET  Intermidiate
# 4013    NaN     Product Management  Intermidiate
# 4014    NaN       Machine Learning  Intermidiate
# 4015    NaN          Microservices      Beginner
#
# [4016 rows x 3 columns]

# %%
df.to_csv('skills.csv')
