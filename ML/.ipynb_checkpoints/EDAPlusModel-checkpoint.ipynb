# %% [markdown]
# ## Importing all the necessary libraries

# %%
import snowflake.connector
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# Suppress warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing & Understanding the dataset

# %%
try:
    # Connect to Snowflake using environment variables
    conn = snowflake.connector.connect(
        user="kaustubh",
        password="@@Kaustubh123",
        account="rh57156.central-india.azure",
        warehouse="COMPUTE_WH",
        database="Main_Project",
        schema="Main_Project_Schema_Mart",
        role = "ACCOUNTADMIN"
    )

    # Print connection success message
    print("Connected to Snowflake successfully!")

    # Now, you can perform further operations with snowflake_conn
except snowflake.connector.errors.DatabaseError as e:
    # Print connection failure message
    print(f"Failed to connect to Snowflake: {e}")
# Out:
# Connected to Snowflake successfully!

# %%
cur = conn.cursor()

# Execute SQL query to fetch data
sql_query = f"SELECT * FROM TOTALINFO"
cur.execute(sql_query)

# Fetch data into a pandas DataFrame
data = cur.fetchall()
columns = [col[0] for col in cur.description]
df = pd.DataFrame(data, columns=columns)

# Close cursor and connection
cur.close()
conn.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4131 entries, 0 to 4130
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   USERID                               4131 non-null   object
#  1   FULLNAME                             4131 non-null   object
#  2   EMAIL                                4131 non-null   object
#  3   PHONENUMBER                          4131 non-null   object
#  4   GENDER                               4131 non-null   object
#  5   DOJ                                  4131 non-null   object
#  6   SPECIALIZATION                       4131 non-null   object
#  7   DOB                                  4131 non-null   object
#  8   CITY                                 4131 non-null   object
#  9   STATE                                4131 non-null   object
#  10  EXPERIENCE                           4130 non-null   float64
#  11  USERTYPE                             4131 non-null   object
#  12  SUBSCRIBENEWSLETTER                  4131 non-null   object
#  13  TRAININGID                           4100 non-null   object
#  14  TRAINERID                            4100 non-null   object
#  15  TRAINERNAME                          724 non-null    object
#  16  TRAINERDESIGNATION                   724 non-null    object
#  17  TRAINERRATING                        724 non-null    float64
#  18  TRAINERSPECIALIZATION                724 non-null    object
#  19  TRAININGNAME                         4084 non-null   object
#  20  OPTIMIZEDDURATION                    4084 non-null   float64
#  21  DIFFICULTYLEVEL                      4084 non-null   object
#  22  TRAININGSTATUS                       4100 non-null   object
#  23  ASSESSMENT_PERCENTAGE_DONE           4100 non-null   float64
#  24  ASSESSMENT_COMPLETION_TIME_IN_HOURS  1380 non-null   float64
#  25  SCOREACHIEVEDINQUIZ                  1380 non-null   float64
#  26  QUIZPASSEDORFAILED                   4100 non-null   object
#  27  RATINGGIVENBYTRAINER                 4100 non-null   float64
# dtypes: float64(7), object(21)
# memory usage: 903.8+ KB

# %%
df.head()
# Out:
#     USERID        FULLNAME                      EMAIL           PHONENUMBER  \
# 0  Emp_181     Andrew Cole   davisgregory@example.org                 -9025
# 1  Emp_181     Andrew Cole   davisgregory@example.org                 -9025
# 2  Emp_181     Andrew Cole   davisgregory@example.org                 -9025
# 3  Emp_181     Andrew Cole   davisgregory@example.org                 -9025
# 4  Emp_172  Jonathan Patel  gonzalesbrian@example.org  001-515-605-2768x915
#
#    GENDER         DOJ          SPECIALIZATION         DOB              CITY  \
# 0  Female  23-09-2020  [Continuous Deployment  09-09-1996  South Taylorberg
# 1  Female  23-09-2020                 GraphQL  09-09-1996  South Taylorberg
# 2  Female  23-09-2020              PostgreSQL  09-09-1996  South Taylorberg
# 3  Female  23-09-2020                Node.js]  09-09-1996  South Taylorberg
# 4    Male  13-01-2021                [MongoDB  14-07-1939     West Paulland
#
#             STATE  ...                              TRAINERSPECIALIZATION  \
# 0  North Carolina  ...  ['Ruby', 'Statistical Analysis', 'Kubernetes',...
# 1  North Carolina  ...  ['Ruby', 'Statistical Analysis', 'Kubernetes',...
# 2  North Carolina  ...  ['Ruby', 'Statistical Analysis', 'Kubernetes',...
# 3  North Carolina  ...  ['Ruby', 'Statistical Analysis', 'Kubernetes',...
# 4         Vermont  ...                                               None
#
#               TRAININGNAME OPTIMIZEDDURATION DIFFICULTYLEVEL TRAININGSTATUS  \
# 0  Machine Learning Basics              24.0        moderate    in_progress
# 1  Machine Learning Basics              24.0        moderate    in_progress
# 2  Machine Learning Basics              24.0        moderate    in_progress
# 3  Machine Learning Basics              24.0        moderate    in_progress
# 4  Data Science Essentials              23.0            easy        pending
#
#   ASSESSMENT_PERCENTAGE_DONE ASSESSMENT_COMPLETION_TIME_IN_HOURS  \
# 0                       87.0                                 NaN
# 1                       87.0                                 NaN
# 2                       87.0                                 NaN
# 3                       87.0                                 NaN
# 4                        0.0                                 NaN
#
#    SCOREACHIEVEDINQUIZ QUIZPASSEDORFAILED RATINGGIVENBYTRAINER
# 0                  NaN                                     4.0
# 1                  NaN                                     4.0
# 2                  NaN                                     4.0
# 3                  NaN                                     4.0
# 4                  NaN                                     4.0
#
# [5 rows x 28 columns]

# %%
df['SPECIALIZATION'] = df['SPECIALIZATION'].str.replace(r"[\[\],]", '', regex=True)

# %%
df.describe()
# Out:
#         EXPERIENCE  TRAINERRATING  OPTIMIZEDDURATION  \
# count  4130.000000     724.000000        4084.000000
# mean     11.824213       3.149171          19.258570
# std       6.004567       1.554848          11.062388
# min       1.000000       1.000000           1.000000
# 25%       6.000000       2.000000           9.000000
# 50%      13.000000       3.000000          20.000000
# 75%      17.000000       5.000000          29.000000
# max      20.000000       5.000000          39.000000
#
#        ASSESSMENT_PERCENTAGE_DONE  ASSESSMENT_COMPLETION_TIME_IN_HOURS  \
# count                 4100.000000                          1380.000000
# mean                    50.425366                            29.742029
# std                     44.489312                            17.442252
# min                      0.000000                             1.000000
# 25%                      0.000000                            14.000000
# 50%                     54.000000                            29.000000
# 75%                    100.000000                            44.000000
# max                    100.000000                            60.000000
#
#        SCOREACHIEVEDINQUIZ  RATINGGIVENBYTRAINER
# count          1380.000000           4100.000000
# mean             48.011594              2.907317
# std              28.640350              1.411691
# min               0.000000              1.000000
# 25%              23.000000              2.000000
# 50%              49.000000              3.000000
# 75%              71.000000              4.000000
# max             100.000000              5.000000

# %%
df.nunique()
# Out:
# USERID                                 203
# FULLNAME                               203
# EMAIL                                  203
# PHONENUMBER                            202
# GENDER                                   5
# DOJ                                    190
# SPECIALIZATION                         105
# DOB                                    200
# CITY                                   199
# STATE                                   51
# EXPERIENCE                              20
# USERTYPE                                 5
# SUBSCRIBENEWSLETTER                      3
# TRAININGID                             100
# TRAINERID                                1
# TRAINERNAME                             14
# TRAINERDESIGNATION                      12
# TRAINERRATING                            4
# TRAINERSPECIALIZATION                   16
# TRAININGNAME                            10
# OPTIMIZEDDURATION                       33
# DIFFICULTYLEVEL                          3
# TRAININGSTATUS                           3
# ASSESSMENT_PERCENTAGE_DONE              98
# ASSESSMENT_COMPLETION_TIME_IN_HOURS     60
# SCOREACHIEVEDINQUIZ                     96
# QUIZPASSEDORFAILED                       3
# RATINGGIVENBYTRAINER                     5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4131 entries, 0 to 4130
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   USERID                               4131 non-null   object
#  1   FULLNAME                             4131 non-null   object
#  2   EMAIL                                4131 non-null   object
#  3   PHONENUMBER                          4131 non-null   object
#  4   GENDER                               4131 non-null   object
#  5   DOJ                                  4131 non-null   object
#  6   SPECIALIZATION                       4131 non-null   object
#  7   DOB                                  4131 non-null   object
#  8   CITY                                 4131 non-null   object
#  9   STATE                                4131 non-null   object
#  10  EXPERIENCE                           4130 non-null   float64
#  11  USERTYPE                             4131 non-null   object
#  12  SUBSCRIBENEWSLETTER                  4131 non-null   object
#  13  TRAININGID                           4100 non-null   object
#  14  TRAINERID                            4100 non-null   object
#  15  TRAINERNAME                          724 non-null    object
#  16  TRAINERDESIGNATION                   724 non-null    object
#  17  TRAINERRATING                        724 non-null    float64
#  18  TRAINERSPECIALIZATION                724 non-null    object
#  19  TRAININGNAME                         4084 non-null   object
#  20  OPTIMIZEDDURATION                    4084 non-null   float64
#  21  DIFFICULTYLEVEL                      4084 non-null   object
#  22  TRAININGSTATUS                       4100 non-null   object
#  23  ASSESSMENT_PERCENTAGE_DONE           4100 non-null   float64
#  24  ASSESSMENT_COMPLETION_TIME_IN_HOURS  1380 non-null   float64
#  25  SCOREACHIEVEDINQUIZ                  1380 non-null   float64
#  26  QUIZPASSEDORFAILED                   4100 non-null   object
#  27  RATINGGIVENBYTRAINER                 4100 non-null   float64
# dtypes: float64(7), object(21)
# memory usage: 903.8+ KB

# %% [markdown]
# ## Handling Missing Values and outliers

# %%
df = df.dropna(subset=['DIFFICULTYLEVEL'])
df = df.dropna(subset=['TRAININGNAME'])
df = df.dropna(subset=['OPTIMIZEDDURATION'])
df = df.dropna(subset=['TRAINERRATING'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 0 to 4099
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   USERID                               724 non-null    object
#  1   FULLNAME                             724 non-null    object
#  2   EMAIL                                724 non-null    object
#  3   PHONENUMBER                          724 non-null    object
#  4   GENDER                               724 non-null    object
#  5   DOJ                                  724 non-null    object
#  6   SPECIALIZATION                       724 non-null    object
#  7   DOB                                  724 non-null    object
#  8   CITY                                 724 non-null    object
#  9   STATE                                724 non-null    object
#  10  EXPERIENCE                           724 non-null    float64
#  11  USERTYPE                             724 non-null    object
#  12  SUBSCRIBENEWSLETTER                  724 non-null    object
#  13  TRAININGID                           724 non-null    object
#  14  TRAINERID                            724 non-null    object
#  15  TRAINERNAME                          724 non-null    object
#  16  TRAINERDESIGNATION                   724 non-null    object
#  17  TRAINERRATING                        724 non-null    float64
#  18  TRAINERSPECIALIZATION                724 non-null    object
#  19  TRAININGNAME                         724 non-null    object
#  20  OPTIMIZEDDURATION                    724 non-null    float64
#  21  DIFFICULTYLEVEL                      724 non-null    object
#  22  TRAININGSTATUS                       724 non-null    object
#  23  ASSESSMENT_PERCENTAGE_DONE           724 non-null    float64
#  24  ASSESSMENT_COMPLETION_TIME_IN_HOURS  240 non-null    float64
#  25  SCOREACHIEVEDINQUIZ                  240 non-null    float64
#  26  QUIZPASSEDORFAILED                   724 non-null    object
#  27  RATINGGIVENBYTRAINER                 724 non-null    float64
# dtypes: float64(7), object(21)
# memory usage: 164.0+ KB

# %% [markdown]
# ## Removing The NaN Values

# %%
df['SCOREACHIEVEDINQUIZ'].fillna(df['SCOREACHIEVEDINQUIZ'].median(), inplace=True)
df['ASSESSMENT_COMPLETION_TIME_IN_HOURS'].fillna(df['ASSESSMENT_COMPLETION_TIME_IN_HOURS'].median(), inplace=True)
df['TRAINERRATING'].fillna(df['TRAINERRATING'].median(), inplace=True)

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 0 to 4099
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   USERID                               724 non-null    object
#  1   FULLNAME                             724 non-null    object
#  2   EMAIL                                724 non-null    object
#  3   PHONENUMBER                          724 non-null    object
#  4   GENDER                               724 non-null    object
#  5   DOJ                                  724 non-null    object
#  6   SPECIALIZATION                       724 non-null    object
#  7   DOB                                  724 non-null    object
#  8   CITY                                 724 non-null    object
#  9   STATE                                724 non-null    object
#  10  EXPERIENCE                           724 non-null    float64
#  11  USERTYPE                             724 non-null    object
#  12  SUBSCRIBENEWSLETTER                  724 non-null    object
#  13  TRAININGID                           724 non-null    object
#  14  TRAINERID                            724 non-null    object
#  15  TRAINERNAME                          724 non-null    object
#  16  TRAINERDESIGNATION                   724 non-null    object
#  17  TRAINERRATING                        724 non-null    float64
#  18  TRAINERSPECIALIZATION                724 non-null    object
#  19  TRAININGNAME                         724 non-null    object
#  20  OPTIMIZEDDURATION                    724 non-null    float64
#  21  DIFFICULTYLEVEL                      724 non-null    object
#  22  TRAININGSTATUS                       724 non-null    object
#  23  ASSESSMENT_PERCENTAGE_DONE           724 non-null    float64
#  24  ASSESSMENT_COMPLETION_TIME_IN_HOURS  724 non-null    float64
#  25  SCOREACHIEVEDINQUIZ                  724 non-null    float64
#  26  QUIZPASSEDORFAILED                   724 non-null    object
#  27  RATINGGIVENBYTRAINER                 724 non-null    float64
# dtypes: float64(7), object(21)
# memory usage: 164.0+ KB

# %%
df.head()
# Out:
#      USERID        FULLNAME                        EMAIL  \
# 0   Emp_181     Andrew Cole     davisgregory@example.org
# 1   Emp_181     Andrew Cole     davisgregory@example.org
# 2   Emp_181     Andrew Cole     davisgregory@example.org
# 3   Emp_181     Andrew Cole     davisgregory@example.org
# 28   Emp_21  Sarah Crawford  williamwilliams@example.org
#
#              PHONENUMBER  GENDER         DOJ         SPECIALIZATION  \
# 0                  -9025  Female  23-09-2020  Continuous Deployment
# 1                  -9025  Female  23-09-2020                GraphQL
# 2                  -9025  Female  23-09-2020             PostgreSQL
# 3                  -9025  Female  23-09-2020                Node.js
# 28  +1-611-901-9789x3062  Female  14-04-2022                    Git
#
#            DOB              CITY           STATE  ...  \
# 0   09-09-1996  South Taylorberg  North Carolina  ...
# 1   09-09-1996  South Taylorberg  North Carolina  ...
# 2   09-09-1996  South Taylorberg  North Carolina  ...
# 3   09-09-1996  South Taylorberg  North Carolina  ...
# 28  24-05-1967      Stephanieton      New Jersey  ...
#
#                                 TRAINERSPECIALIZATION  \
# 0   ['Ruby', 'Statistical Analysis', 'Kubernetes',...
# 1   ['Ruby', 'Statistical Analysis', 'Kubernetes',...
# 2   ['Ruby', 'Statistical Analysis', 'Kubernetes',...
# 3   ['Ruby', 'Statistical Analysis', 'Kubernetes',...
# 28  ['Ruby', 'Statistical Analysis', 'Kubernetes',...
#
#                TRAININGNAME OPTIMIZEDDURATION DIFFICULTYLEVEL TRAININGSTATUS  \
# 0   Machine Learning Basics              24.0        moderate    in_progress
# 1   Machine Learning Basics              24.0        moderate    in_progress
# 2   Machine Learning Basics              24.0        moderate    in_progress
# 3   Machine Learning Basics              24.0        moderate    in_progress
# 28  Machine Learning Basics              24.0        moderate    in_progress
#
#    ASSESSMENT_PERCENTAGE_DONE ASSESSMENT_COMPLETION_TIME_IN_HOURS  \
# 0                        87.0                                34.0
# 1                        87.0                                34.0
# 2                        87.0                                34.0
# 3                        87.0                                34.0
# 28                       67.0                                34.0
#
#     SCOREACHIEVEDINQUIZ QUIZPASSEDORFAILED RATINGGIVENBYTRAINER
# 0                  52.0                                     4.0
# 1                  52.0                                     4.0
# 2                  52.0                                     4.0
# 3                  52.0                                     4.0
# 28                 52.0                                     5.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Finding Correlation Between different Categorical Columns

# %%
from scipy.stats import chi2_contingency

# Assuming df is your DataFrame
# Selecting only the categorical columns
categorical_columns = ['GENDER', 'SPECIALIZATION', 'DIFFICULTYLEVEL', 'TRAININGSTATUS', 'QUIZPASSEDORFAILED']

# Create an empty DataFrame to store the chi-square p-values
chi_square_results = pd.DataFrame(index=categorical_columns, columns=categorical_columns)

# Compute chi-square statistic and p-values for each pair of categorical columns
for col1 in categorical_columns:
    for col2 in categorical_columns:
        if col1 != col2:
            # Create a contingency table
            contingency_table = pd.crosstab(df[col1], df[col2])
            # Compute chi-square statistic and p-value
            chi2, p, _, _ = chi2_contingency(contingency_table)
            # Store the p-value in the DataFrame
            chi_square_results.loc[col1, col2] = p

# Convert p-values to numeric format
chi_square_results = chi_square_results.astype(float)

# Create a heatmap plot of the p-values with annotations
plt.figure(figsize=(10, 8))
sns.heatmap(chi_square_results, annot=True, cmap="coolwarm", fmt=".3f", linewidths=0.5)
plt.title("Chi-square p-values between categorical variables")
plt.xlabel("Categorical Variables")
plt.ylabel("Categorical Variables")

# Annotate each cell with its value
for i in range(len(categorical_columns)):
    for j in range(len(categorical_columns)):
        plt.text(j+0.5, i+0.5, f"{chi_square_results.iloc[i, j]:.3f}", ha="center", va="center")

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 0 to 4099
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   USERID                               724 non-null    object
#  1   FULLNAME                             724 non-null    object
#  2   EMAIL                                724 non-null    object
#  3   PHONENUMBER                          724 non-null    object
#  4   GENDER                               724 non-null    object
#  5   DOJ                                  724 non-null    object
#  6   SPECIALIZATION                       724 non-null    object
#  7   DOB                                  724 non-null    object
#  8   CITY                                 724 non-null    object
#  9   STATE                                724 non-null    object
#  10  EXPERIENCE                           724 non-null    float64
#  11  USERTYPE                             724 non-null    object
#  12  SUBSCRIBENEWSLETTER                  724 non-null    object
#  13  TRAININGID                           724 non-null    object
#  14  TRAINERID                            724 non-null    object
#  15  TRAINERNAME                          724 non-null    object
#  16  TRAINERDESIGNATION                   724 non-null    object
#  17  TRAINERRATING                        724 non-null    float64
#  18  TRAINERSPECIALIZATION                724 non-null    object
#  19  TRAININGNAME                         724 non-null    object
#  20  OPTIMIZEDDURATION                    724 non-null    float64
#  21  DIFFICULTYLEVEL                      724 non-null    object
#  22  TRAININGSTATUS                       724 non-null    object
#  23  ASSESSMENT_PERCENTAGE_DONE           724 non-null    float64
#  24  ASSESSMENT_COMPLETION_TIME_IN_HOURS  724 non-null    float64
#  25  SCOREACHIEVEDINQUIZ                  724 non-null    float64
#  26  QUIZPASSEDORFAILED                   724 non-null    object
#  27  RATINGGIVENBYTRAINER                 724 non-null    float64
# dtypes: float64(7), object(21)
# memory usage: 164.0+ KB

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = df[numerical_columns].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap='summer', annot=True, fmt=".3f")

# Add annotations to each cell
for i in range(correlation_matrix.shape[0]):
    for j in range(correlation_matrix.shape[1]):
        plt.text(j+0.5, i+0.5, "%.3f" % correlation_matrix.iloc[i, j], ha='center', va='center', color='black')

plt.title('Correlation Heatmap with Annotations Inside Cells')
plt.show()

# %% [markdown]
# ## Keeping the only columns that are required

# %%
df = df[['GENDER', 'SPECIALIZATION', 'EXPERIENCE', 'DIFFICULTYLEVEL','TRAINERRATING', 'TRAININGNAME', 'OPTIMIZEDDURATION', 'SCOREACHIEVEDINQUIZ', 'ASSESSMENT_COMPLETION_TIME_IN_HOURS']]
df
# Out:
#       GENDER         SPECIALIZATION  EXPERIENCE DIFFICULTYLEVEL  \
# 0     Female  Continuous Deployment        17.0        moderate
# 1     Female                GraphQL        17.0        moderate
# 2     Female             PostgreSQL        17.0        moderate
# 3     Female                Node.js        17.0        moderate
# 28    Female                    Git        13.0        moderate
# ...      ...                    ...         ...             ...
# 4091  Female                    Git         5.0        moderate
# 4096    Male                Node.js         6.0            hard
# 4097    Male            Objective-C         6.0            hard
# 4098    Male                  Azure         6.0            hard
# 4099    Male     Data Visualization         6.0            hard
#
#       TRAINERRATING                        TRAININGNAME  OPTIMIZEDDURATION  \
# 0               1.0             Machine Learning Basics               24.0
# 1               1.0             Machine Learning Basics               24.0
# 2               1.0             Machine Learning Basics               24.0
# 3               1.0             Machine Learning Basics               24.0
# 28              1.0             Machine Learning Basics               24.0
# ...             ...                                 ...                ...
# 4091            2.0     Frontend Development with React               28.0
# 4096            2.0  Introduction to Python Programming               20.0
# 4097            2.0  Introduction to Python Programming               20.0
# 4098            2.0  Introduction to Python Programming               20.0
# 4099            2.0  Introduction to Python Programming               20.0
#
#       SCOREACHIEVEDINQUIZ  ASSESSMENT_COMPLETION_TIME_IN_HOURS
# 0                    52.0                                 34.0
# 1                    52.0                                 34.0
# 2                    52.0                                 34.0
# 3                    52.0                                 34.0
# 28                   52.0                                 34.0
# ...                   ...                                  ...
# 4091                 52.0                                 34.0
# 4096                 52.0                                 34.0
# 4097                 52.0                                 34.0
# 4098                 52.0                                 34.0
# 4099                 52.0                                 34.0
#
# [724 rows x 9 columns]

# %% [markdown]
# ## Ananlysis On Transformed Data

# %% [markdown]
# ### Univariate Analysis

# %%
# Distribution plot for numeric variables
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in numeric_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Count plot for categorical variables
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Count of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame

# Bar plot for categorical variables against numeric variables
for col1 in categorical_cols:
    for col2 in numeric_cols:
        plt.figure(figsize=(8, 6))
        sns.barplot(data=df, x=col1, y=col2)
        plt.title(f'Mean {col2} by {col1}')
        plt.xlabel(col1)
        plt.ylabel(f'Mean {col2}')
        plt.xticks(rotation=45)
        plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Pair plot for multiple numeric variables
sns.pairplot(df[numeric_cols])
plt.title('Pair Plot of Numeric Variables')
plt.show()

# Heatmap with correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Variables')
plt.show()

# 3D scatter plot for three numeric variables
if len(numeric_cols) >= 3:
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(df[numeric_cols[0]], df[numeric_cols[1]], df[numeric_cols[2]], c='blue', marker='o')
    ax.set_xlabel(numeric_cols[0])
    ax.set_ylabel(numeric_cols[1])
    ax.set_zlabel(numeric_cols[2])
    plt.title('3D Scatter Plot of Numeric Variables')
    plt.show()
else:
    print("Insufficient numeric variables for 3D scatter plot.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 12
#      10 # Heatmap with correlation matrix
#      11 plt.figure(figsize=(10, 8))
# ---> 12 sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
#      13 plt.title('Correlation Heatmap of Numeric Variables')
#      14 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Female'

# %% [markdown]
# ## ML Modeling

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

# Assume df1 is your preprocessed DataFrame with features and target column 'SCOREACHIEVEDINQUIZ'

# Separate features and target variable
X = df[['GENDER', 'SPECIALIZATION', 'EXPERIENCE', 'DIFFICULTYLEVEL', 'TRAININGNAME', 'OPTIMIZEDDURATION', 'TRAINERRATING']]
y = df['ASSESSMENT_COMPLETION_TIME_IN_HOURS']

# Encode categorical variables
X_encoded = pd.get_dummies(X)

# Handle NaN values
imputer = SimpleImputer(strategy='mean')
X_imputed = pd.DataFrame(imputer.fit_transform(X_encoded), columns=X_encoded.columns)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

# Initialize models
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest Regressor': RandomForestRegressor(random_state=42),
    'Gradient Boosting Regressor': GradientBoostingRegressor(random_state=42),
    'Support Vector Regressor': SVR(),
    'Neural Network (MLPRegressor)': MLPRegressor(random_state=42)
}

# Train and evaluate models
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"{name}: Mean Squared Error = {mse}")

# You can also perform cross-validation to get more reliable estimates of model performance
for name, model in models.items():
    scores = cross_val_score(model, X_imputed, y, cv=5, scoring='neg_mean_squared_error')
    mse_mean = -scores.mean()
    print(f"{name}: Cross-validated Mean Squared Error = {mse_mean}")
# Out:
# Linear Regression: Mean Squared Error = 3.3613144579306586e+20
# Random Forest Regressor: Mean Squared Error = 74.08678915478927
# Gradient Boosting Regressor: Mean Squared Error = 80.75211947121304
# Support Vector Regressor: Mean Squared Error = 71.31879182267676
# Neural Network (MLPRegressor): Mean Squared Error = 85.20392646653795
# Linear Regression: Cross-validated Mean Squared Error = 1.6298294355828343e+21
# Random Forest Regressor: Cross-validated Mean Squared Error = 119.84659276819926
# Gradient Boosting Regressor: Cross-validated Mean Squared Error = 109.7810804790616
# Support Vector Regressor: Cross-validated Mean Squared Error = 83.79432892520808
# Neural Network (MLPRegressor): Cross-validated Mean Squared Error = 110.82495941570104

# %% [markdown]
# ## Implementing Linear Regression Model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# Assume df1 is your preprocessed DataFrame with features and target column 'ASSESSMENT_COMPLETION_TIME_IN_HOURS'

# Separate features and target variable
X = df[['GENDER', 'SPECIALIZATION', 'EXPERIENCE', 'DIFFICULTYLEVEL', 'TRAININGNAME', 'OPTIMIZEDDURATION']]
y = df['ASSESSMENT_COMPLETION_TIME_IN_HOURS']

# Encode categorical variables
X_encoded = pd.get_dummies(X)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Handle NaN values
imputer = SimpleImputer(strategy='mean')
X_imputed = pd.DataFrame(imputer.fit_transform(X_encoded), columns=X_encoded.columns)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y_encoded, test_size=0.2, random_state=42)

# Train the Linear Regression model
linear_regressor = LinearRegression()
linear_regressor.fit(X_train, y_train)

# Make predictions on the test set
y_pred = linear_regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

threshold = 2

# Convert regression predictions to binary classification labels
y_pred_binary = (y_pred <= threshold).astype(int)
y_test_binary = (y_test <= threshold).astype(int)

# Calculate accuracy for binary classification
accuracy = (y_pred_binary == y_test_binary).mean()

print(f"Accuracy: {accuracy*100} %")
# Out:
# Mean Squared Error: 1.63607485997183e+19
# Accuracy: 95.17241379310344 %

# %% [markdown]
# ## Testing the model on dummy dataset

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Define dummy values for features
dummy_data = {
    'GENDER': ['Male'],
    'SPECIALIZATION': ['Docker'],
    'EXPERIENCE': [5],
    'DIFFICULTYLEVEL': ['moderate'],
    'TRAININGNAME': ['Machine Learning Basics'],
    'OPTIMIZEDDURATION': [8]
}

# Create DataFrame with dummy values
dummy_df = pd.DataFrame(dummy_data)

# Get the list of feature names used during training
training_feature_names = X_imputed.columns.tolist()

# Ensure that the dummy DataFrame has the same columns as training data
dummy_df = pd.get_dummies(dummy_df)
dummy_df = dummy_df.reindex(columns=training_feature_names, fill_value=0)

# Handle NaN values
imputer = SimpleImputer(strategy='mean')
dummy_imputed = pd.DataFrame(imputer.fit_transform(dummy_df), columns=dummy_df.columns)

# Make prediction
prediction = linear_regressor.predict(dummy_imputed)

# Print prediction
print("Predicted Completion Time:", int(prediction[0]) ,'hrs')
# Out:
# Predicted Completion Time: 15 hrs
